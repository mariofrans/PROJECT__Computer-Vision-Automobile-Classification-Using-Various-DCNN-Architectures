# %%
# !pip install pandas numpy seaborn matplotlib tensorflow keras sklearn &> /dev/null

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications import DenseNet201

import time
start_time = time.time()

# %%
PATH_DATA_TRAIN = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/train'
PATH_DATA_TEST = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/test'
PATH_DATA_VALIDATION = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/validation'
PATH_SAVED_MODEL = 'densenet201-imagenet.h5'

# %% [markdown]
# # Load Dataset As Generators

# %%
generator = ImageDataGenerator(rescale = 1./255.)

target_size = (100, 100)
batch_size = 32

train_batches = generator.flow_from_directory(
    PATH_DATA_TRAIN, class_mode='categorical', 
    batch_size=batch_size, target_size=target_size
)

validation_batches = generator.flow_from_directory(
    PATH_DATA_VALIDATION, class_mode='categorical',  
    batch_size=batch_size, target_size=target_size
)

test_batches = generator.flow_from_directory(
    PATH_DATA_TEST, class_mode='categorical', shuffle=False, 
    batch_size=batch_size, target_size=target_size
)
# Out:
# Found 12959 images belonging to 7 classes.
# Found 1616 images belonging to 7 classes.
# Found 1610 images belonging to 7 classes.

# %%
# preview data (batch size, width, height, colors)
print('x_train shape:', train_batches[0][0].shape)
print('x_validation shape:', validation_batches[0][0].shape)
print('x_test shape:', test_batches[0][0].shape)
print('y_train shape:', train_batches[0][1].shape)
print('y_validation shape:', validation_batches[0][1].shape)
print('y_test shape:', test_batches[0][1].shape)
# Out:
# x_train shape: (32, 100, 100, 3)
# x_validation shape: (32, 100, 100, 3)
# x_test shape: (32, 100, 100, 3)
# y_train shape: (32, 7)
# y_validation shape: (32, 7)
# y_test shape: (32, 7)

# %%
# input & output shape
input_shape = train_batches[0][0][0].shape
output_shape = len(train_batches[0][1][0])

# display input & output shape
print('Input Shape:', input_shape)
print('Output Shape:', output_shape)
# Out:
# Input Shape: (100, 100, 3)
# Output Shape: 7

# %% [markdown]
# # Build & Compile Model

# %%
model = DenseNet201(
    input_shape=input_shape, 
    weights="imagenet", 
    include_top=False, 
    pooling='max'
)

for layer in model.layers:
    layer.trainable = False

i = Input(shape=input_shape)
x = model(i)
x = Flatten()(x)
x = Dense(output_shape, activation='softmax')(x)

model = Model(inputs=i, outputs=x)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# 2022-11-10 14:40:06.872931: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 14:40:06.873933: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 14:40:07.185056: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 14:40:07.186222: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 14:40:07.187305: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 14:40:07.188448: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 14:40:07.190727: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-10 14:40:07.495910: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 14:40:07.497251: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 14:40:07.498406: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 14:40:07.499472: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 14:40:07.500548: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 14:40:07.501514: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 14:40:12.056528: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 14:40:12.057476: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 14:40:12.058256: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 14:40:12.059002: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 14:40:12.059753: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 14:40:12.060510: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-11-10 14:40:12.065660: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 14:40:12.066346: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 0s 0us/step
# 74850304/74836368 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# densenet201 (Functional)     (None, 1920)              18321984
# _________________________________________________________________
# flatten (Flatten)            (None, 1920)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 13447
# =================================================================
# Total params: 18,335,431
# Trainable params: 13,447
# Non-trainable params: 18,321,984
# _________________________________________________________________

# %% [markdown]
# # Train Model

# %%
# train model
r = model.fit(train_batches, validation_data=validation_batches, epochs=100)

# save model
model.save(PATH_SAVED_MODEL)

# load model
# model = load_model(PATH_SAVED_MODEL)
# Out:
# 2022-11-10 14:40:18.998501: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-11-10 14:40:30.370218: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 405/405 [==============================] - 211s 466ms/step - loss: 1.4167 - accuracy: 0.5133 - val_loss: 1.1370 - val_accuracy: 0.6009
# Epoch 2/100
# 405/405 [==============================] - 110s 271ms/step - loss: 1.0552 - accuracy: 0.6115 - val_loss: 1.1116 - val_accuracy: 0.6058
# Epoch 3/100
# 405/405 [==============================] - 110s 271ms/step - loss: 0.9488 - accuracy: 0.6501 - val_loss: 1.0079 - val_accuracy: 0.6399
# Epoch 4/100
# 405/405 [==============================] - 111s 273ms/step - loss: 0.8918 - accuracy: 0.6670 - val_loss: 0.9935 - val_accuracy: 0.6510
# Epoch 5/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.8609 - accuracy: 0.6748 - val_loss: 1.0285 - val_accuracy: 0.6436
# Epoch 6/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.8372 - accuracy: 0.6867 - val_loss: 1.0514 - val_accuracy: 0.6448
# Epoch 7/100
# 405/405 [==============================] - 110s 271ms/step - loss: 0.8220 - accuracy: 0.6938 - val_loss: 1.0358 - val_accuracy: 0.6436
# Epoch 8/100
# 405/405 [==============================] - 110s 271ms/step - loss: 0.8136 - accuracy: 0.6981 - val_loss: 1.0654 - val_accuracy: 0.6460
# Epoch 9/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.7820 - accuracy: 0.7034 - val_loss: 1.1515 - val_accuracy: 0.6176
# Epoch 10/100
# 405/405 [==============================] - 109s 270ms/step - loss: 0.7906 - accuracy: 0.7045 - val_loss: 1.2868 - val_accuracy: 0.6126
# Epoch 11/100
# 405/405 [==============================] - 109s 270ms/step - loss: 0.7750 - accuracy: 0.7064 - val_loss: 1.0686 - val_accuracy: 0.6355
# Epoch 12/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.7686 - accuracy: 0.7081 - val_loss: 1.0869 - val_accuracy: 0.6343
# Epoch 13/100
# 405/405 [==============================] - 111s 273ms/step - loss: 0.7652 - accuracy: 0.7126 - val_loss: 1.0783 - val_accuracy: 0.6411
# Epoch 14/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.7540 - accuracy: 0.7128 - val_loss: 1.1065 - val_accuracy: 0.6374
# Epoch 15/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.7529 - accuracy: 0.7144 - val_loss: 1.0554 - val_accuracy: 0.6584
# Epoch 16/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.7469 - accuracy: 0.7144 - val_loss: 1.1204 - val_accuracy: 0.6491
# Epoch 17/100
# 405/405 [==============================] - 109s 270ms/step - loss: 0.7556 - accuracy: 0.7135 - val_loss: 1.0760 - val_accuracy: 0.6442
# Epoch 18/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.7269 - accuracy: 0.7246 - val_loss: 1.1734 - val_accuracy: 0.6306
# Epoch 19/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.7516 - accuracy: 0.7183 - val_loss: 1.0919 - val_accuracy: 0.6516
# Epoch 20/100
# 405/405 [==============================] - 114s 282ms/step - loss: 0.7301 - accuracy: 0.7234 - val_loss: 1.0911 - val_accuracy: 0.6504
# Epoch 21/100
# 405/405 [==============================] - 113s 278ms/step - loss: 0.7396 - accuracy: 0.7253 - val_loss: 1.1153 - val_accuracy: 0.6423
# Epoch 22/100
# 405/405 [==============================] - 111s 273ms/step - loss: 0.7295 - accuracy: 0.7224 - val_loss: 1.1728 - val_accuracy: 0.6343
# Epoch 23/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.7221 - accuracy: 0.7241 - val_loss: 1.1248 - val_accuracy: 0.6535
# Epoch 24/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.7305 - accuracy: 0.7251 - val_loss: 1.2287 - val_accuracy: 0.6355
# Epoch 25/100
# 405/405 [==============================] - 110s 271ms/step - loss: 0.7220 - accuracy: 0.7278 - val_loss: 1.1592 - val_accuracy: 0.6361
# Epoch 26/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.7317 - accuracy: 0.7210 - val_loss: 1.2230 - val_accuracy: 0.6380
# Epoch 27/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.7399 - accuracy: 0.7191 - val_loss: 1.1903 - val_accuracy: 0.6355
# Epoch 28/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.7186 - accuracy: 0.7283 - val_loss: 1.1842 - val_accuracy: 0.6343
# Epoch 29/100
# 405/405 [==============================] - 108s 265ms/step - loss: 0.7068 - accuracy: 0.7304 - val_loss: 1.1888 - val_accuracy: 0.6374
# Epoch 30/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.7267 - accuracy: 0.7263 - val_loss: 1.2214 - val_accuracy: 0.6170
# Epoch 31/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.6990 - accuracy: 0.7344 - val_loss: 1.1426 - val_accuracy: 0.6485
# Epoch 32/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.7022 - accuracy: 0.7331 - val_loss: 1.1850 - val_accuracy: 0.6368
# Epoch 33/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.7066 - accuracy: 0.7322 - val_loss: 1.1410 - val_accuracy: 0.6510
# Epoch 34/100
# 405/405 [==============================] - 108s 268ms/step - loss: 0.7169 - accuracy: 0.7277 - val_loss: 1.1771 - val_accuracy: 0.6429
# Epoch 35/100
# 405/405 [==============================] - 109s 270ms/step - loss: 0.7144 - accuracy: 0.7302 - val_loss: 1.1614 - val_accuracy: 0.6498
# Epoch 36/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.7135 - accuracy: 0.7309 - val_loss: 1.2913 - val_accuracy: 0.6262
# Epoch 37/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.7133 - accuracy: 0.7297 - val_loss: 1.2499 - val_accuracy: 0.6374
# Epoch 38/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.7017 - accuracy: 0.7369 - val_loss: 1.1893 - val_accuracy: 0.6504
# Epoch 39/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.7232 - accuracy: 0.7274 - val_loss: 1.1983 - val_accuracy: 0.6442
# Epoch 40/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.7040 - accuracy: 0.7319 - val_loss: 1.2751 - val_accuracy: 0.6194
# Epoch 41/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.6960 - accuracy: 0.7335 - val_loss: 1.2415 - val_accuracy: 0.6330
# Epoch 42/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.6924 - accuracy: 0.7419 - val_loss: 1.2120 - val_accuracy: 0.6386
# Epoch 43/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.7066 - accuracy: 0.7332 - val_loss: 1.2630 - val_accuracy: 0.6405
# Epoch 44/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.7102 - accuracy: 0.7329 - val_loss: 1.3190 - val_accuracy: 0.6151
# Epoch 45/100
# 405/405 [==============================] - 107s 263ms/step - loss: 0.7017 - accuracy: 0.7381 - val_loss: 1.3234 - val_accuracy: 0.6293
# Epoch 46/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.6988 - accuracy: 0.7353 - val_loss: 1.2735 - val_accuracy: 0.6312
# Epoch 47/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.7006 - accuracy: 0.7325 - val_loss: 1.2717 - val_accuracy: 0.6182
# Epoch 48/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.6930 - accuracy: 0.7345 - val_loss: 1.2010 - val_accuracy: 0.6535
# Epoch 49/100
# 405/405 [==============================] - 106s 263ms/step - loss: 0.6852 - accuracy: 0.7387 - val_loss: 1.2308 - val_accuracy: 0.6566
# Epoch 50/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.6887 - accuracy: 0.7372 - val_loss: 1.3021 - val_accuracy: 0.6318
# Epoch 51/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.6958 - accuracy: 0.7383 - val_loss: 1.3045 - val_accuracy: 0.6231
# Epoch 52/100
# 405/405 [==============================] - 107s 263ms/step - loss: 0.6863 - accuracy: 0.7430 - val_loss: 1.2320 - val_accuracy: 0.6411
# Epoch 53/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.6896 - accuracy: 0.7342 - val_loss: 1.2568 - val_accuracy: 0.6417
# Epoch 54/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.6971 - accuracy: 0.7376 - val_loss: 1.2412 - val_accuracy: 0.6559
# Epoch 55/100
# 405/405 [==============================] - 107s 263ms/step - loss: 0.7033 - accuracy: 0.7361 - val_loss: 1.2385 - val_accuracy: 0.6559
# Epoch 56/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.7028 - accuracy: 0.7339 - val_loss: 1.2773 - val_accuracy: 0.6262
# Epoch 57/100
# 405/405 [==============================] - 107s 263ms/step - loss: 0.6843 - accuracy: 0.7389 - val_loss: 1.2567 - val_accuracy: 0.6374
# Epoch 58/100
# 405/405 [==============================] - 106s 263ms/step - loss: 0.6822 - accuracy: 0.7419 - val_loss: 1.2684 - val_accuracy: 0.6405
# Epoch 59/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.7050 - accuracy: 0.7369 - val_loss: 1.3220 - val_accuracy: 0.6405
# Epoch 60/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.6902 - accuracy: 0.7436 - val_loss: 1.3137 - val_accuracy: 0.6355
# Epoch 61/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.6855 - accuracy: 0.7426 - val_loss: 1.4025 - val_accuracy: 0.6269
# Epoch 62/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.6902 - accuracy: 0.7386 - val_loss: 1.3021 - val_accuracy: 0.6361
# Epoch 63/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.6955 - accuracy: 0.7383 - val_loss: 1.3009 - val_accuracy: 0.6337
# Epoch 64/100
# 405/405 [==============================] - 106s 263ms/step - loss: 0.6691 - accuracy: 0.7467 - val_loss: 1.2863 - val_accuracy: 0.6330
# Epoch 65/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.6984 - accuracy: 0.7356 - val_loss: 1.3264 - val_accuracy: 0.6194
# Epoch 66/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.6800 - accuracy: 0.7347 - val_loss: 1.2890 - val_accuracy: 0.6504
# Epoch 67/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.6794 - accuracy: 0.7438 - val_loss: 1.3130 - val_accuracy: 0.6467
# Epoch 68/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.6683 - accuracy: 0.7426 - val_loss: 1.3437 - val_accuracy: 0.6392
# Epoch 69/100
# 405/405 [==============================] - 108s 265ms/step - loss: 0.6797 - accuracy: 0.7459 - val_loss: 1.3564 - val_accuracy: 0.6200
# Epoch 70/100
# 405/405 [==============================] - 107s 263ms/step - loss: 0.6869 - accuracy: 0.7393 - val_loss: 1.3153 - val_accuracy: 0.6411
# Epoch 71/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.6844 - accuracy: 0.7403 - val_loss: 1.3109 - val_accuracy: 0.6392
# Epoch 72/100
# 405/405 [==============================] - 107s 263ms/step - loss: 0.6913 - accuracy: 0.7399 - val_loss: 1.3023 - val_accuracy: 0.6429
# Epoch 73/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.6773 - accuracy: 0.7407 - val_loss: 1.4118 - val_accuracy: 0.6300
# Epoch 74/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.6798 - accuracy: 0.7429 - val_loss: 1.3579 - val_accuracy: 0.6343
# Epoch 75/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.6765 - accuracy: 0.7440 - val_loss: 1.3093 - val_accuracy: 0.6510
# Epoch 76/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.6739 - accuracy: 0.7450 - val_loss: 1.3116 - val_accuracy: 0.6423
# Epoch 77/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.6678 - accuracy: 0.7438 - val_loss: 1.3434 - val_accuracy: 0.6330
# Epoch 78/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.6886 - accuracy: 0.7419 - val_loss: 1.3413 - val_accuracy: 0.6411
# Epoch 79/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.6760 - accuracy: 0.7459 - val_loss: 1.3980 - val_accuracy: 0.6380
# Epoch 80/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.6660 - accuracy: 0.7476 - val_loss: 1.3321 - val_accuracy: 0.6374
# Epoch 81/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.6543 - accuracy: 0.7494 - val_loss: 1.3546 - val_accuracy: 0.6337
# Epoch 82/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.6769 - accuracy: 0.7430 - val_loss: 1.3378 - val_accuracy: 0.6386
# Epoch 83/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.6791 - accuracy: 0.7432 - val_loss: 1.3736 - val_accuracy: 0.6306
# Epoch 84/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.6867 - accuracy: 0.7451 - val_loss: 1.4029 - val_accuracy: 0.6386
# Epoch 85/100
# 405/405 [==============================] - 107s 263ms/step - loss: 0.6607 - accuracy: 0.7485 - val_loss: 1.4609 - val_accuracy: 0.6330
# Epoch 86/100
# 405/405 [==============================] - 110s 271ms/step - loss: 0.6739 - accuracy: 0.7440 - val_loss: 1.3683 - val_accuracy: 0.6454
# Epoch 87/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.6833 - accuracy: 0.7406 - val_loss: 1.4247 - val_accuracy: 0.6312
# Epoch 88/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.6833 - accuracy: 0.7388 - val_loss: 1.3534 - val_accuracy: 0.6361
# Epoch 89/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.6768 - accuracy: 0.7417 - val_loss: 1.4553 - val_accuracy: 0.6238
# Epoch 90/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.6779 - accuracy: 0.7393 - val_loss: 1.3775 - val_accuracy: 0.6275
# Epoch 91/100
# 405/405 [==============================] - 105s 258ms/step - loss: 0.6664 - accuracy: 0.7483 - val_loss: 1.3756 - val_accuracy: 0.6238
# Epoch 92/100
# 405/405 [==============================] - 105s 258ms/step - loss: 0.6737 - accuracy: 0.7444 - val_loss: 1.4614 - val_accuracy: 0.6114
# Epoch 93/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.6757 - accuracy: 0.7460 - val_loss: 1.3802 - val_accuracy: 0.6349
# Epoch 94/100
# 405/405 [==============================] - 107s 263ms/step - loss: 0.6746 - accuracy: 0.7452 - val_loss: 1.3883 - val_accuracy: 0.6293
# Epoch 95/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.6684 - accuracy: 0.7447 - val_loss: 1.4095 - val_accuracy: 0.6343
# Epoch 96/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.6557 - accuracy: 0.7522 - val_loss: 1.4001 - val_accuracy: 0.6355
# Epoch 97/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.6703 - accuracy: 0.7449 - val_loss: 1.3517 - val_accuracy: 0.6399
# Epoch 98/100
# 405/405 [==============================] - 106s 263ms/step - loss: 0.6575 - accuracy: 0.7524 - val_loss: 1.3750 - val_accuracy: 0.6337
# Epoch 99/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.6736 - accuracy: 0.7447 - val_loss: 1.4438 - val_accuracy: 0.6176
# Epoch 100/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.6643 - accuracy: 0.7484 - val_loss: 1.3922 - val_accuracy: 0.6207

# %% [markdown]
# # Evaluate Model's Training & Validation Results

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()

# %% [markdown]
# # Generate Predictions With Model

# %%
y_pred = model.predict(test_batches).argmax(axis=1)

# %%
model.evaluate(test_batches)
# Out:
# 51/51 [==============================] - 13s 249ms/step - loss: 1.2569 - accuracy: 0.6460
# [1.2568857669830322, 0.6459627151489258]

# %% [markdown]
# # Evaluate Model's Prediction Results

# %%
# generate classification report
class_labels = list(test_batches.class_indices.keys())
report = classification_report(test_batches.classes, y_pred, target_names=class_labels, output_dict=True)
df_classification_report = pd.DataFrame(report).transpose()
df_classification_report
# Out:
#               precision    recall  f1-score      support
# hatchback      0.407407  0.423077  0.415094   156.000000
# mpv            0.666667  0.685185  0.675799   108.000000
# sedan          0.586517  0.630435  0.607683   414.000000
# sport          0.720280  0.683628  0.701476   452.000000
# suv            0.683502  0.714789  0.698795   284.000000
# truck          0.845070  0.750000  0.794702   160.000000
# wagon          0.291667  0.194444  0.233333    36.000000
# accuracy       0.645963  0.645963  0.645963     0.645963
# macro avg      0.600158  0.583080  0.589555  1610.000000
# weighted avg   0.648302  0.645963  0.646211  1610.000000

# %%
# compute confusion matrix
matrix = confusion_matrix(test_batches.classes, y_pred)

# normalize confusion matrix
matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
matrix = np.around(matrix, decimals=2)

# generate confusion matrix heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(matrix, annot=True, xticklabels=class_labels, yticklabels=class_labels)
plt.ylabel('Test Values')
plt.xlabel('Predicted Values')
# Out:
# Text(0.5, 69.0, 'Predicted Values')

# %% [markdown]
# # Compute Execution Time

# %%
execution_time_s = round(time.time() - start_time, 2)
execution_time_m = round(execution_time_s/60, 2)
execution_time_h = round(execution_time_m/60, 2)

print('Execution Time (Hours):', execution_time_h)
print('Execution Time (Minutes):', execution_time_m)
print('Execution Time (Seconds):', execution_time_s)
# Out:
# Execution Time (Hours): 3.21
# Execution Time (Minutes): 192.7
# Execution Time (Seconds): 11561.97
