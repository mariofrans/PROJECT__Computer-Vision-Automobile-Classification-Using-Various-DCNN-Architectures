# %%
# !pip install pandas numpy seaborn matplotlib tensorflow keras sklearn &> /dev/null

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications import Xception

import time
start_time = time.time()

# %%
PATH_DATA_TRAIN = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/train'
PATH_DATA_TEST = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/test'
PATH_DATA_VALIDATION = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/validation'
PATH_SAVED_MODEL = 'xception.h5'

# %% [markdown]
# # Load Dataset As Generators

# %%
generator = ImageDataGenerator(rescale = 1./255.)

target_size = (100, 100)
batch_size = 32

train_batches = generator.flow_from_directory(
    PATH_DATA_TRAIN, class_mode='categorical', 
    batch_size=batch_size, target_size=target_size
)

validation_batches = generator.flow_from_directory(
    PATH_DATA_VALIDATION, class_mode='categorical',  
    batch_size=batch_size, target_size=target_size
)

test_batches = generator.flow_from_directory(
    PATH_DATA_TEST, class_mode='categorical', shuffle=False, 
    batch_size=batch_size, target_size=target_size
)
# Out:
# Found 12959 images belonging to 7 classes.
# Found 1616 images belonging to 7 classes.
# Found 1610 images belonging to 7 classes.

# %%
# preview data (batch size, width, height, colors)
print('x_train shape:', train_batches[0][0].shape)
print('x_validation shape:', validation_batches[0][0].shape)
print('x_test shape:', test_batches[0][0].shape)
print('y_train shape:', train_batches[0][1].shape)
print('y_validation shape:', validation_batches[0][1].shape)
print('y_test shape:', test_batches[0][1].shape)
# Out:
# x_train shape: (32, 100, 100, 3)
# x_validation shape: (32, 100, 100, 3)
# x_test shape: (32, 100, 100, 3)
# y_train shape: (32, 7)
# y_validation shape: (32, 7)
# y_test shape: (32, 7)

# %%
# input & output shape
input_shape = train_batches[0][0][0].shape
output_shape = len(train_batches[0][1][0])

# display input & output shape
print('Input Shape:', input_shape)
print('Output Shape:', output_shape)
# Out:
# Input Shape: (100, 100, 3)
# Output Shape: 7

# %% [markdown]
# # Build & Compile Model

# %%
model = Xception(
    input_shape=input_shape,
    classes=output_shape,
    weights=None,
    classifier_activation='softmax'
)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# 2022-11-16 17:02:07.137224: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 17:02:07.138366: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 17:02:07.295843: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 17:02:07.296903: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 17:02:07.297799: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 17:02:07.298683: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 17:02:07.300420: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-16 17:02:07.554203: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 17:02:07.555102: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 17:02:07.555887: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 17:02:07.556737: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 17:02:07.557559: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 17:02:07.558381: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 17:02:10.702399: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 17:02:10.703481: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 17:02:10.704249: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 17:02:10.704995: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 17:02:10.705717: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 17:02:10.706417: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-11-16 17:02:10.710054: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 17:02:10.710839: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "xception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 49, 49, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 49, 49, 32)   128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 49, 49, 32)   0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 47, 47, 64)   18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 47, 47, 64)   256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 47, 47, 64)   0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 47, 47, 128)  8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 47, 47, 128)  512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 47, 47, 128)  0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 47, 47, 128)  17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 47, 47, 128)  512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 24, 24, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 24, 24, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 24, 24, 128)  512         conv2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 24, 24, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 24, 24, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 24, 24, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 24, 24, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 24, 24, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 24, 24, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 24, 24, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 12, 12, 256)  32768       add[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 12, 12, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 12, 12, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 12, 12, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 12, 12, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 12, 12, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 12, 12, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 12, 12, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 12, 12, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 12, 12, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 6, 6, 728)    186368      add_1[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 6, 6, 728)    0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 6, 6, 728)    2912        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 6, 6, 728)    0           block4_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 6, 6, 728)    0           add_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 6, 6, 728)    536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 6, 6, 728)    2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 6, 6, 728)    0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 6, 6, 728)    536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 6, 6, 728)    2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 6, 6, 728)    0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 6, 6, 728)    536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 6, 6, 728)    2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 6, 6, 728)    0           block5_sepconv3_bn[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 6, 6, 728)    0           add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 6, 6, 728)    536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 6, 6, 728)    2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 6, 6, 728)    0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 6, 6, 728)    536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 6, 6, 728)    2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 6, 6, 728)    0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 6, 6, 728)    536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 6, 6, 728)    2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 6, 6, 728)    0           block6_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 6, 6, 728)    0           add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 6, 6, 728)    536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 6, 6, 728)    2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 6, 6, 728)    0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 6, 6, 728)    536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 6, 6, 728)    2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 6, 6, 728)    0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 6, 6, 728)    536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 6, 6, 728)    2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 6, 6, 728)    0           block7_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 6, 6, 728)    0           add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 6, 6, 728)    536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 6, 6, 728)    2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 6, 6, 728)    0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 6, 6, 728)    536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 6, 6, 728)    2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 6, 6, 728)    0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 6, 6, 728)    536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 6, 6, 728)    2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 6, 6, 728)    0           block8_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 6, 6, 728)    0           add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 6, 6, 728)    536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 6, 6, 728)    2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 6, 6, 728)    0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 6, 6, 728)    536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 6, 6, 728)    2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 6, 6, 728)    0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 6, 6, 728)    536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 6, 6, 728)    2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 6, 6, 728)    0           block9_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 6, 6, 728)    0           add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 6, 6, 728)    536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 6, 6, 728)    2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 6, 6, 728)    0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 6, 6, 728)    536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 6, 6, 728)    2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 6, 6, 728)    0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 6, 6, 728)    536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 6, 6, 728)    2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 6, 6, 728)    0           block10_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 6, 6, 728)    0           add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 6, 6, 728)    536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 6, 6, 728)    2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 6, 6, 728)    0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 6, 6, 728)    536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 6, 6, 728)    2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 6, 6, 728)    0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 6, 6, 728)    536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 6, 6, 728)    2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 6, 6, 728)    0           block11_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 6, 6, 728)    0           add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 6, 6, 728)    536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 6, 6, 728)    2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 6, 6, 728)    0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 6, 6, 728)    536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 6, 6, 728)    2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 6, 6, 728)    0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 6, 6, 728)    536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 6, 6, 728)    2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 6, 6, 728)    0           block12_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 6, 6, 728)    0           add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 6, 6, 728)    536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 6, 6, 728)    2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 6, 6, 728)    0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 6, 6, 1024)   752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 6, 6, 1024)   4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 3, 3, 1024)   745472      add_10[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 3, 3, 1024)   0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 3, 3, 1024)   4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 3, 3, 1024)   0           block13_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 3, 3, 1536)   1582080     add_11[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 3, 3, 1536)   6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 3, 3, 1536)   0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 3, 3, 2048)   3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 3, 3, 2048)   8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 3, 3, 2048)   0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 7)            14343       avg_pool[0][0]
# ==================================================================================================
# Total params: 20,875,823
# Trainable params: 20,821,295
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %% [markdown]
# # Train Model

# %%
# train model
r = model.fit(train_batches, validation_data=validation_batches, epochs=100)

# save model
model.save(PATH_SAVED_MODEL)

# load model
# model = load_model(PATH_SAVED_MODEL)
# Out:
# 2022-11-16 17:02:12.178836: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-11-16 17:02:18.736262: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 405/405 [==============================] - 191s 435ms/step - loss: 1.5722 - accuracy: 0.3858 - val_loss: 1.8832 - val_accuracy: 0.2574
# Epoch 2/100
# 405/405 [==============================] - 128s 315ms/step - loss: 1.2253 - accuracy: 0.5387 - val_loss: 3.4427 - val_accuracy: 0.3391
# Epoch 3/100
# 405/405 [==============================] - 131s 323ms/step - loss: 0.9813 - accuracy: 0.6277 - val_loss: 1.2215 - val_accuracy: 0.5755
# Epoch 4/100
# 405/405 [==============================] - 135s 333ms/step - loss: 0.8291 - accuracy: 0.6899 - val_loss: 1.6189 - val_accuracy: 0.6015
# Epoch 5/100
# 405/405 [==============================] - 126s 312ms/step - loss: 0.7110 - accuracy: 0.7331 - val_loss: 1.7558 - val_accuracy: 0.4864
# Epoch 6/100
# 405/405 [==============================] - 128s 317ms/step - loss: 0.6015 - accuracy: 0.7782 - val_loss: 0.9871 - val_accuracy: 0.6894
# Epoch 7/100
# 405/405 [==============================] - 123s 302ms/step - loss: 0.5278 - accuracy: 0.8051 - val_loss: 0.8147 - val_accuracy: 0.7197
# Epoch 8/100
# 405/405 [==============================] - 121s 300ms/step - loss: 0.4234 - accuracy: 0.8453 - val_loss: 1.2734 - val_accuracy: 0.5743
# Epoch 9/100
# 405/405 [==============================] - 119s 293ms/step - loss: 0.3518 - accuracy: 0.8713 - val_loss: 1.1827 - val_accuracy: 0.6566
# Epoch 10/100
# 405/405 [==============================] - 117s 290ms/step - loss: 0.2741 - accuracy: 0.9006 - val_loss: 0.9818 - val_accuracy: 0.7129
# Epoch 11/100
# 405/405 [==============================] - 117s 288ms/step - loss: 0.2304 - accuracy: 0.9161 - val_loss: 1.2982 - val_accuracy: 0.6949
# Epoch 12/100
# 405/405 [==============================] - 118s 291ms/step - loss: 0.1872 - accuracy: 0.9317 - val_loss: 1.2754 - val_accuracy: 0.6788
# Epoch 13/100
# 405/405 [==============================] - 121s 298ms/step - loss: 0.1727 - accuracy: 0.9400 - val_loss: 1.0687 - val_accuracy: 0.7543
# Epoch 14/100
# 405/405 [==============================] - 120s 296ms/step - loss: 0.1387 - accuracy: 0.9509 - val_loss: 1.2490 - val_accuracy: 0.7017
# Epoch 15/100
# 405/405 [==============================] - 119s 293ms/step - loss: 0.1113 - accuracy: 0.9612 - val_loss: 2.0419 - val_accuracy: 0.5675
# Epoch 16/100
# 405/405 [==============================] - 117s 289ms/step - loss: 0.1143 - accuracy: 0.9604 - val_loss: 1.8361 - val_accuracy: 0.6652
# Epoch 17/100
# 405/405 [==============================] - 119s 292ms/step - loss: 0.1053 - accuracy: 0.9649 - val_loss: 1.3883 - val_accuracy: 0.7450
# Epoch 18/100
# 405/405 [==============================] - 118s 291ms/step - loss: 0.0768 - accuracy: 0.9724 - val_loss: 1.3772 - val_accuracy: 0.6980
# Epoch 19/100
# 405/405 [==============================] - 118s 290ms/step - loss: 0.0823 - accuracy: 0.9705 - val_loss: 1.6853 - val_accuracy: 0.6696
# Epoch 20/100
# 405/405 [==============================] - 120s 295ms/step - loss: 0.0775 - accuracy: 0.9738 - val_loss: 1.7296 - val_accuracy: 0.6652
# Epoch 21/100
# 405/405 [==============================] - 122s 300ms/step - loss: 0.0835 - accuracy: 0.9710 - val_loss: 2.0001 - val_accuracy: 0.6603
# Epoch 22/100
# 405/405 [==============================] - 118s 291ms/step - loss: 0.0676 - accuracy: 0.9774 - val_loss: 2.6595 - val_accuracy: 0.6423
# Epoch 23/100
# 405/405 [==============================] - 117s 290ms/step - loss: 0.0632 - accuracy: 0.9784 - val_loss: 1.5129 - val_accuracy: 0.7438
# Epoch 24/100
# 405/405 [==============================] - 117s 290ms/step - loss: 0.0804 - accuracy: 0.9714 - val_loss: 1.2663 - val_accuracy: 0.7450
# Epoch 25/100
# 405/405 [==============================] - 119s 293ms/step - loss: 0.0759 - accuracy: 0.9726 - val_loss: 1.1164 - val_accuracy: 0.7519
# Epoch 26/100
# 405/405 [==============================] - 117s 290ms/step - loss: 0.0586 - accuracy: 0.9795 - val_loss: 1.4981 - val_accuracy: 0.6974
# Epoch 27/100
# 405/405 [==============================] - 118s 290ms/step - loss: 0.0465 - accuracy: 0.9834 - val_loss: 1.9822 - val_accuracy: 0.5947
# Epoch 28/100
# 405/405 [==============================] - 115s 283ms/step - loss: 0.0525 - accuracy: 0.9812 - val_loss: 1.5380 - val_accuracy: 0.7246
# Epoch 29/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.0544 - accuracy: 0.9819 - val_loss: 1.9607 - val_accuracy: 0.6838
# Epoch 30/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.0567 - accuracy: 0.9805 - val_loss: 1.3475 - val_accuracy: 0.7407
# Epoch 31/100
# 405/405 [==============================] - 113s 279ms/step - loss: 0.0536 - accuracy: 0.9823 - val_loss: 3.3256 - val_accuracy: 0.6405
# Epoch 32/100
# 405/405 [==============================] - 116s 286ms/step - loss: 0.0574 - accuracy: 0.9796 - val_loss: 1.4849 - val_accuracy: 0.7376
# Epoch 33/100
# 405/405 [==============================] - 113s 279ms/step - loss: 0.0671 - accuracy: 0.9785 - val_loss: 1.4922 - val_accuracy: 0.7147
# Epoch 34/100
# 405/405 [==============================] - 118s 290ms/step - loss: 0.0416 - accuracy: 0.9871 - val_loss: 1.3479 - val_accuracy: 0.7444
# Epoch 35/100
# 405/405 [==============================] - 115s 284ms/step - loss: 0.0398 - accuracy: 0.9868 - val_loss: 1.4578 - val_accuracy: 0.7519
# Epoch 36/100
# 405/405 [==============================] - 118s 291ms/step - loss: 0.0358 - accuracy: 0.9883 - val_loss: 1.5334 - val_accuracy: 0.6943
# Epoch 37/100
# 405/405 [==============================] - 118s 290ms/step - loss: 0.0577 - accuracy: 0.9826 - val_loss: 2.6125 - val_accuracy: 0.6386
# Epoch 38/100
# 405/405 [==============================] - 115s 284ms/step - loss: 0.0531 - accuracy: 0.9820 - val_loss: 2.4998 - val_accuracy: 0.5402
# Epoch 39/100
# 405/405 [==============================] - 113s 278ms/step - loss: 0.0295 - accuracy: 0.9899 - val_loss: 1.5297 - val_accuracy: 0.6993
# Epoch 40/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.0292 - accuracy: 0.9897 - val_loss: 2.0462 - val_accuracy: 0.6250
# Epoch 41/100
# 405/405 [==============================] - 111s 275ms/step - loss: 0.0405 - accuracy: 0.9860 - val_loss: 1.2566 - val_accuracy: 0.7067
# Epoch 42/100
# 405/405 [==============================] - 110s 270ms/step - loss: 0.0313 - accuracy: 0.9900 - val_loss: 1.4703 - val_accuracy: 0.6962
# Epoch 43/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.0375 - accuracy: 0.9879 - val_loss: 1.3927 - val_accuracy: 0.7389
# Epoch 44/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.0406 - accuracy: 0.9856 - val_loss: 1.4355 - val_accuracy: 0.7562
# Epoch 45/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.0483 - accuracy: 0.9848 - val_loss: 1.2325 - val_accuracy: 0.7574
# Epoch 46/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.0268 - accuracy: 0.9914 - val_loss: 1.8363 - val_accuracy: 0.6021
# Epoch 47/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.0913 - accuracy: 0.9725 - val_loss: 1.1108 - val_accuracy: 0.7562
# Epoch 48/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.0242 - accuracy: 0.9914 - val_loss: 1.7147 - val_accuracy: 0.6856
# Epoch 49/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.0231 - accuracy: 0.9924 - val_loss: 2.5715 - val_accuracy: 0.5396
# Epoch 50/100
# 405/405 [==============================] - 110s 271ms/step - loss: 0.0600 - accuracy: 0.9814 - val_loss: 1.4225 - val_accuracy: 0.7587
# Epoch 51/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.0267 - accuracy: 0.9919 - val_loss: 1.4207 - val_accuracy: 0.7475
# Epoch 52/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.0208 - accuracy: 0.9928 - val_loss: 1.4947 - val_accuracy: 0.7494
# Epoch 53/100
# 405/405 [==============================] - 111s 275ms/step - loss: 0.0227 - accuracy: 0.9924 - val_loss: 1.6738 - val_accuracy: 0.7376
# Epoch 54/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.0255 - accuracy: 0.9918 - val_loss: 1.5553 - val_accuracy: 0.7420
# Epoch 55/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.0315 - accuracy: 0.9900 - val_loss: 1.4178 - val_accuracy: 0.7370
# Epoch 56/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.0491 - accuracy: 0.9844 - val_loss: 1.4541 - val_accuracy: 0.7438
# Epoch 57/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.0424 - accuracy: 0.9862 - val_loss: 1.3010 - val_accuracy: 0.7611
# Epoch 58/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.0313 - accuracy: 0.9897 - val_loss: 1.3091 - val_accuracy: 0.7506
# Epoch 59/100
# 405/405 [==============================] - 112s 277ms/step - loss: 0.0168 - accuracy: 0.9948 - val_loss: 1.3028 - val_accuracy: 0.7630
# Epoch 60/100
# 405/405 [==============================] - 111s 275ms/step - loss: 0.0177 - accuracy: 0.9947 - val_loss: 1.6258 - val_accuracy: 0.7351
# Epoch 61/100
# 405/405 [==============================] - 113s 278ms/step - loss: 0.0183 - accuracy: 0.9945 - val_loss: 1.6852 - val_accuracy: 0.7259
# Epoch 62/100
# 405/405 [==============================] - 112s 277ms/step - loss: 0.0291 - accuracy: 0.9900 - val_loss: 1.3535 - val_accuracy: 0.7376
# Epoch 63/100
# 405/405 [==============================] - 112s 277ms/step - loss: 0.0219 - accuracy: 0.9934 - val_loss: 1.7851 - val_accuracy: 0.6993
# Epoch 64/100
# 405/405 [==============================] - 111s 273ms/step - loss: 0.0288 - accuracy: 0.9911 - val_loss: 1.2251 - val_accuracy: 0.7494
# Epoch 65/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.0245 - accuracy: 0.9917 - val_loss: 1.4405 - val_accuracy: 0.7661
# Epoch 66/100
# 405/405 [==============================] - 109s 270ms/step - loss: 0.0217 - accuracy: 0.9927 - val_loss: 1.9313 - val_accuracy: 0.7358
# Epoch 67/100
# 405/405 [==============================] - 111s 273ms/step - loss: 0.0281 - accuracy: 0.9905 - val_loss: 1.6216 - val_accuracy: 0.6986
# Epoch 68/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.0207 - accuracy: 0.9927 - val_loss: 1.8299 - val_accuracy: 0.7178
# Epoch 69/100
# 405/405 [==============================] - 111s 273ms/step - loss: 0.0237 - accuracy: 0.9922 - val_loss: 1.7368 - val_accuracy: 0.7197
# Epoch 70/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.0271 - accuracy: 0.9914 - val_loss: 1.6084 - val_accuracy: 0.7110
# Epoch 71/100
# 405/405 [==============================] - 111s 273ms/step - loss: 0.0139 - accuracy: 0.9955 - val_loss: 1.6007 - val_accuracy: 0.7302
# Epoch 72/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.0345 - accuracy: 0.9894 - val_loss: 1.3634 - val_accuracy: 0.7017
# Epoch 73/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.0274 - accuracy: 0.9907 - val_loss: 1.3519 - val_accuracy: 0.7642
# Epoch 74/100
# 405/405 [==============================] - 109s 270ms/step - loss: 0.0320 - accuracy: 0.9904 - val_loss: 1.5458 - val_accuracy: 0.7191
# Epoch 75/100
# 405/405 [==============================] - 110s 271ms/step - loss: 0.0857 - accuracy: 0.9769 - val_loss: 1.1803 - val_accuracy: 0.7543
# Epoch 76/100
# 405/405 [==============================] - 109s 270ms/step - loss: 0.0107 - accuracy: 0.9968 - val_loss: 1.2296 - val_accuracy: 0.7655
# Epoch 77/100
# 405/405 [==============================] - 110s 271ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 1.5476 - val_accuracy: 0.7667
# Epoch 78/100
# 405/405 [==============================] - 110s 270ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 1.6707 - val_accuracy: 0.7500
# Epoch 79/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.0291 - accuracy: 0.9904 - val_loss: 5.5617 - val_accuracy: 0.4740
# Epoch 80/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.0435 - accuracy: 0.9864 - val_loss: 1.4041 - val_accuracy: 0.7339
# Epoch 81/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.0216 - accuracy: 0.9935 - val_loss: 1.3102 - val_accuracy: 0.7649
# Epoch 82/100
# 405/405 [==============================] - 110s 271ms/step - loss: 0.0359 - accuracy: 0.9899 - val_loss: 2.4085 - val_accuracy: 0.6776
# Epoch 83/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.0235 - accuracy: 0.9929 - val_loss: 1.2530 - val_accuracy: 0.7642
# Epoch 84/100
# 405/405 [==============================] - 111s 273ms/step - loss: 0.0125 - accuracy: 0.9958 - val_loss: 1.5551 - val_accuracy: 0.7432
# Epoch 85/100
# 405/405 [==============================] - 111s 273ms/step - loss: 0.0363 - accuracy: 0.9900 - val_loss: 1.2349 - val_accuracy: 0.7649
# Epoch 86/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.0105 - accuracy: 0.9969 - val_loss: 1.6062 - val_accuracy: 0.7469
# Epoch 87/100
# 405/405 [==============================] - 111s 273ms/step - loss: 0.0224 - accuracy: 0.9932 - val_loss: 1.5730 - val_accuracy: 0.7290
# Epoch 88/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.0183 - accuracy: 0.9947 - val_loss: 1.4807 - val_accuracy: 0.7358
# Epoch 89/100
# 405/405 [==============================] - 111s 272ms/step - loss: 0.0108 - accuracy: 0.9960 - val_loss: 1.6294 - val_accuracy: 0.7321
# Epoch 90/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.0132 - accuracy: 0.9949 - val_loss: 2.0117 - val_accuracy: 0.6925
# Epoch 91/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.0172 - accuracy: 0.9941 - val_loss: 1.5184 - val_accuracy: 0.7543
# Epoch 92/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.0142 - accuracy: 0.9950 - val_loss: 1.3914 - val_accuracy: 0.7574
# Epoch 93/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.0134 - accuracy: 0.9960 - val_loss: 1.4286 - val_accuracy: 0.7618
# Epoch 94/100
# 405/405 [==============================] - 112s 275ms/step - loss: 0.0203 - accuracy: 0.9934 - val_loss: 2.0202 - val_accuracy: 0.7104
# Epoch 95/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.0192 - accuracy: 0.9944 - val_loss: 1.7613 - val_accuracy: 0.7290
# Epoch 96/100
# 405/405 [==============================] - 111s 273ms/step - loss: 0.0151 - accuracy: 0.9947 - val_loss: 1.6084 - val_accuracy: 0.7395
# Epoch 97/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.0130 - accuracy: 0.9958 - val_loss: 1.9783 - val_accuracy: 0.6770
# Epoch 98/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.0185 - accuracy: 0.9937 - val_loss: 1.9467 - val_accuracy: 0.6764
# Epoch 99/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.0142 - accuracy: 0.9957 - val_loss: 1.8626 - val_accuracy: 0.7364
# Epoch 100/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.0208 - accuracy: 0.9931 - val_loss: 1.6887 - val_accuracy: 0.7469
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %% [markdown]
# # Evaluate Model's Training & Validation Results

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()

# %% [markdown]
# # Generate Predictions With Model

# %%
y_pred = model.predict(test_batches).argmax(axis=1)

# %%
model.evaluate(test_batches)
# Out:
# 51/51 [==============================] - 12s 235ms/step - loss: 1.6412 - accuracy: 0.7385
# [1.6412018537521362, 0.7385092973709106]

# %% [markdown]
# # Evaluate Model's Prediction Results

# %%
# generate classification report
class_labels = list(test_batches.class_indices.keys())
report = classification_report(test_batches.classes, y_pred, target_names=class_labels, output_dict=True)
df_classification_report = pd.DataFrame(report).transpose()
df_classification_report
# Out:
#               precision    recall  f1-score      support
# hatchback      0.640625  0.262821  0.372727   156.000000
# mpv            0.796117  0.759259  0.777251   108.000000
# sedan          0.787425  0.635266  0.703209   414.000000
# sport          0.674457  0.893805  0.768792   452.000000
# suv            0.793333  0.838028  0.815068   284.000000
# truck          0.878788  0.906250  0.892308   160.000000
# wagon          0.355556  0.444444  0.395062    36.000000
# accuracy       0.738509  0.738509  0.738509     0.738509
# macro avg      0.703757  0.677125  0.674917  1610.000000
# weighted avg   0.742534  0.738509  0.726200  1610.000000

# %%
# compute confusion matrix
matrix = confusion_matrix(test_batches.classes, y_pred)

# normalize confusion matrix
matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
matrix = np.around(matrix, decimals=2)

# generate confusion matrix heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(matrix, annot=True, xticklabels=class_labels, yticklabels=class_labels)
plt.ylabel('Test Values')
plt.xlabel('Predicted Values')
# Out:
# Text(0.5, 69.0, 'Predicted Values')

# %% [markdown]
# # Compute Execution Time

# %%
execution_time_s = round(time.time() - start_time, 2)
execution_time_m = round(execution_time_s/60, 2)
execution_time_h = round(execution_time_m/60, 2)

print('Execution Time (Hours):', execution_time_h)
print('Execution Time (Minutes):', execution_time_m)
print('Execution Time (Seconds):', execution_time_s)
# Out:
# Execution Time (Hours): 3.25
# Execution Time (Minutes): 195.22
# Execution Time (Seconds): 11712.98
