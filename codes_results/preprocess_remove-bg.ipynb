# %%
import os, io, math
import pandas as pd
from rembg.bg import remove
import numpy as np
from multiprocessing import Pool
from PIL import Image, ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
PATH_DATA_TRAIN = 'data/data-raw/train'
PATH_DATA_TEST = 'data/data-raw/test'
PATH_DATA_PREPROCESSED_TRAIN = 'data/data-preprocessed/train'
PATH_DATA_PREPROCESSED_TEST = 'data/data-preprocessed/test'

# %%
def generate_paths(path_data, path_data_remove_bg):

    df = pd.DataFrame()

    files = [i for i in os.listdir(path_data) if '.DS_Store' not in i]

    for file in files:
        df_file = pd.DataFrame()
        images = [i for i in os.listdir(f'{path_data}/{file}') if '.DS_Store' not in i]
        df_file['path_original'] = [f'{path_data}/{file}/{i}' for i in images]
        df_file['path_remove_bg'] = [f'{path_data_remove_bg}/{file}/{i}' for i in images]
        df = pd.concat([df, df_file])
    
    return df

# %%
df_path_train = generate_paths(PATH_DATA_TRAIN, PATH_DATA_PREPROCESSED_TRAIN)
df_path_train
# Out:
#                                path_original  \
# 0    data/data-raw/train/hatchback/02731.jpg
# 1    data/data-raw/train/hatchback/07113.jpg
# 2    data/data-raw/train/hatchback/07846.jpg
# 3    data/data-raw/train/hatchback/01748.jpg
# 4    data/data-raw/train/hatchback/00442.jpg
# ..                                       ...
# 202      data/data-raw/train/wagon/06610.jpg
# 203      data/data-raw/train/wagon/03032.jpg
# 204      data/data-raw/train/wagon/03387.jpg
# 205      data/data-raw/train/wagon/06599.jpg
# 206      data/data-raw/train/wagon/07122.jpg
#
#                                        path_remove_bg
# 0    data/data-preprocessed/train/hatchback/02731.jpg
# 1    data/data-preprocessed/train/hatchback/07113.jpg
# 2    data/data-preprocessed/train/hatchback/07846.jpg
# 3    data/data-preprocessed/train/hatchback/01748.jpg
# 4    data/data-preprocessed/train/hatchback/00442.jpg
# ..                                                ...
# 202      data/data-preprocessed/train/wagon/06610.jpg
# 203      data/data-preprocessed/train/wagon/03032.jpg
# 204      data/data-preprocessed/train/wagon/03387.jpg
# 205      data/data-preprocessed/train/wagon/06599.jpg
# 206      data/data-preprocessed/train/wagon/07122.jpg
#
# [8144 rows x 2 columns]

# %%
df_path_test = generate_paths(PATH_DATA_TEST, PATH_DATA_PREPROCESSED_TEST)
df_path_test
# Out:
#                               path_original  \
# 0    data/data-raw/test/hatchback/02725.jpg
# 1    data/data-raw/test/hatchback/01238.jpg
# 2    data/data-raw/test/hatchback/05089.jpg
# 3    data/data-raw/test/hatchback/00867.jpg
# 4    data/data-raw/test/hatchback/06027.jpg
# ..                                      ...
# 199      data/data-raw/test/wagon/03807.jpg
# 200      data/data-raw/test/wagon/06957.jpg
# 201      data/data-raw/test/wagon/06758.jpg
# 202      data/data-raw/test/wagon/03387.jpg
# 203      data/data-raw/test/wagon/07678.jpg
#
#                                       path_remove_bg
# 0    data/data-preprocessed/test/hatchback/02725.jpg
# 1    data/data-preprocessed/test/hatchback/01238.jpg
# 2    data/data-preprocessed/test/hatchback/05089.jpg
# 3    data/data-preprocessed/test/hatchback/00867.jpg
# 4    data/data-preprocessed/test/hatchback/06027.jpg
# ..                                               ...
# 199      data/data-preprocessed/test/wagon/03807.jpg
# 200      data/data-preprocessed/test/wagon/06957.jpg
# 201      data/data-preprocessed/test/wagon/06758.jpg
# 202      data/data-preprocessed/test/wagon/03387.jpg
# 203      data/data-preprocessed/test/wagon/07678.jpg
#
# [8041 rows x 2 columns]

# %%
def remove_bg(df):
    
    list_path_original = list(df['path_original'])
    list_path_remove_bg = list(df['path_remove_bg'])

    for i in range(len(df)):

        # display progress log
        if (i+1)%50==0:
            print('Completed:', i+1, '/', len(df))

        # load image
        image = Image.open(list_path_original[i])

        # remove background
        with io.BytesIO() as buf:
            image.save(buf, 'jpeg')
            image = buf.getvalue()
            image = remove(image)

        # convert into icon
        image = Image.open(io.BytesIO(image))
        image = image.convert("RGBA")

        # change background to white
        background = Image.new(image.mode[:-1], image.size, (255, 255, 255))
        background.paste(image, image.split()[-1]) 
        image = background

        # convert back to jpeg
        image = image.convert('RGB')
        image.save(list_path_remove_bg[i], 'JPEG')

# %%
remove_bg(df_path_train)
# Out:
# Completed: 50 / 8144
# Completed: 100 / 8144
# Completed: 150 / 8144
# Completed: 200 / 8144
# Completed: 250 / 8144
# Completed: 300 / 8144
# Completed: 350 / 8144
# Completed: 400 / 8144
# Completed: 450 / 8144
# Completed: 500 / 8144
# Completed: 550 / 8144
# Completed: 600 / 8144
# Completed: 650 / 8144
# Completed: 700 / 8144
# Completed: 750 / 8144
# Completed: 800 / 8144
# Completed: 850 / 8144
# Completed: 900 / 8144
# Completed: 950 / 8144
# Completed: 1000 / 8144
# Completed: 1050 / 8144
# Completed: 1100 / 8144
# Completed: 1150 / 8144
# Completed: 1200 / 8144
# Completed: 1250 / 8144
# Completed: 1300 / 8144
# Completed: 1350 / 8144
# Completed: 1400 / 8144
# Completed: 1450 / 8144
# Completed: 1500 / 8144
# Completed: 1550 / 8144
# Completed: 1600 / 8144
# Completed: 1650 / 8144
# Completed: 1700 / 8144
# Completed: 1750 / 8144
# Completed: 1800 / 8144
# Completed: 1850 / 8144
# Completed: 1900 / 8144
# Completed: 1950 / 8144
# Completed: 2000 / 8144
# Completed: 2050 / 8144
# Completed: 2100 / 8144
# Completed: 2150 / 8144
# Completed: 2200 / 8144
# Completed: 2250 / 8144
# Completed: 2300 / 8144
# Completed: 2350 / 8144
# Completed: 2400 / 8144
# Completed: 2450 / 8144
# Completed: 2500 / 8144
# Completed: 2550 / 8144
# Completed: 2600 / 8144
# Completed: 2650 / 8144
# Completed: 2700 / 8144
# Completed: 2750 / 8144
# Completed: 2800 / 8144
# Completed: 2850 / 8144
# Completed: 2900 / 8144
# Completed: 2950 / 8144
# Completed: 3000 / 8144
# Completed: 3050 / 8144
# Completed: 3100 / 8144
# Completed: 3150 / 8144
# Completed: 3200 / 8144
# Completed: 3250 / 8144
# Completed: 3300 / 8144
# Completed: 3350 / 8144
# Completed: 3400 / 8144
# Completed: 3450 / 8144
# Completed: 3500 / 8144
# Completed: 3550 / 8144
# Completed: 3600 / 8144
# Completed: 3650 / 8144
# Completed: 3700 / 8144
# Completed: 3750 / 8144
# Completed: 3800 / 8144
# Completed: 3850 / 8144
# Completed: 3900 / 8144
# Completed: 3950 / 8144
# Completed: 4000 / 8144
# Completed: 4050 / 8144
# Completed: 4100 / 8144
# Completed: 4150 / 8144
# Completed: 4200 / 8144
# Completed: 4250 / 8144
# Completed: 4300 / 8144
# Completed: 4350 / 8144
# Completed: 4400 / 8144
# Completed: 4450 / 8144
# Completed: 4500 / 8144
# Completed: 4550 / 8144
# Completed: 4600 / 8144
# Completed: 4650 / 8144
# Completed: 4700 / 8144
# Completed: 4750 / 8144
# Completed: 4800 / 8144
# Completed: 4850 / 8144
# Completed: 4900 / 8144
# Completed: 4950 / 8144
# Completed: 5000 / 8144
# Completed: 5050 / 8144
# Completed: 5100 / 8144
# Completed: 5150 / 8144
# Completed: 5200 / 8144
# Completed: 5250 / 8144
# Completed: 5300 / 8144
# Completed: 5350 / 8144
# Completed: 5400 / 8144
# Completed: 5450 / 8144
# Completed: 5500 / 8144
# Completed: 5550 / 8144
# Completed: 5600 / 8144
# Completed: 5650 / 8144
# Completed: 5700 / 8144
# Completed: 5750 / 8144
# Completed: 5800 / 8144
# Completed: 5850 / 8144
# Completed: 5900 / 8144
# Completed: 5950 / 8144
# Completed: 6000 / 8144
# Completed: 6050 / 8144
# Completed: 6100 / 8144
# Completed: 6150 / 8144
# Completed: 6200 / 8144
# Completed: 6250 / 8144
# Completed: 6300 / 8144
# Completed: 6350 / 8144
# Completed: 6400 / 8144
# Completed: 6450 / 8144
# Completed: 6500 / 8144
# Completed: 6550 / 8144
# Completed: 6600 / 8144
# Completed: 6650 / 8144
# Completed: 6700 / 8144
# Completed: 6750 / 8144
# Completed: 6800 / 8144
# Completed: 6850 / 8144
# Completed: 6900 / 8144
# Completed: 6950 / 8144
# Completed: 7000 / 8144
# Completed: 7050 / 8144
# Completed: 7100 / 8144
# Completed: 7150 / 8144
# Completed: 7200 / 8144
# Completed: 7250 / 8144
# Completed: 7300 / 8144
# Completed: 7350 / 8144
# Completed: 7400 / 8144
# Completed: 7450 / 8144
# Completed: 7500 / 8144
# Completed: 7550 / 8144
# Completed: 7600 / 8144
# Completed: 7650 / 8144
# Completed: 7700 / 8144
# Completed: 7750 / 8144
# Completed: 7800 / 8144
# Completed: 7850 / 8144
# Completed: 7900 / 8144
# Completed: 7950 / 8144
# Completed: 8000 / 8144
# Completed: 8050 / 8144
# Completed: 8100 / 8144

# %%
remove_bg(df_path_test)
# Out:
# Completed: 50 / 8041
# Completed: 100 / 8041
# Completed: 150 / 8041
# Completed: 200 / 8041
# Completed: 250 / 8041
# Completed: 300 / 8041
# Completed: 350 / 8041
# Completed: 400 / 8041
# Completed: 450 / 8041
# Completed: 500 / 8041
# Completed: 550 / 8041
# Completed: 600 / 8041
# Completed: 650 / 8041
# Completed: 700 / 8041
# Completed: 750 / 8041
# Completed: 800 / 8041
# Completed: 850 / 8041
# Completed: 900 / 8041
# Completed: 950 / 8041
# Completed: 1000 / 8041
# Completed: 1050 / 8041
# Completed: 1100 / 8041
# Completed: 1150 / 8041
# Completed: 1200 / 8041
# Completed: 1250 / 8041
# Completed: 1300 / 8041
# Completed: 1350 / 8041
# Completed: 1400 / 8041
# Completed: 1450 / 8041
# Completed: 1500 / 8041
# Completed: 1550 / 8041
# Completed: 1600 / 8041
# Completed: 1650 / 8041
# Completed: 1700 / 8041
# Completed: 1750 / 8041
# Completed: 1800 / 8041
# Completed: 1850 / 8041
# Completed: 1900 / 8041
# Completed: 1950 / 8041
# Completed: 2000 / 8041
# Completed: 2050 / 8041
# Completed: 2100 / 8041
# Completed: 2150 / 8041
# Completed: 2200 / 8041
# Completed: 2250 / 8041
# Completed: 2300 / 8041
# Completed: 2350 / 8041
# Completed: 2400 / 8041
# Completed: 2450 / 8041
# Completed: 2500 / 8041
# Completed: 2550 / 8041
# Completed: 2600 / 8041
# Completed: 2650 / 8041
# Completed: 2700 / 8041
# Completed: 2750 / 8041
# Completed: 2800 / 8041
# Completed: 2850 / 8041
# Completed: 2900 / 8041
# Completed: 2950 / 8041
# Completed: 3000 / 8041
# Completed: 3050 / 8041
# Completed: 3100 / 8041
# Completed: 3150 / 8041
# Completed: 3200 / 8041
# Completed: 3250 / 8041
# Completed: 3300 / 8041
# Completed: 3350 / 8041
# Completed: 3400 / 8041
# Completed: 3450 / 8041
# Completed: 3500 / 8041
# Completed: 3550 / 8041
# Completed: 3600 / 8041
# Completed: 3650 / 8041
# Completed: 3700 / 8041
# Completed: 3750 / 8041
# Completed: 3800 / 8041
# Completed: 3850 / 8041
# Completed: 3900 / 8041
# Completed: 3950 / 8041
# Completed: 4000 / 8041
# Completed: 4050 / 8041
# Completed: 4100 / 8041
# Completed: 4150 / 8041
# Completed: 4200 / 8041
# Completed: 4250 / 8041
# Completed: 4300 / 8041
# Completed: 4350 / 8041
# Completed: 4400 / 8041
# Completed: 4450 / 8041
# Completed: 4500 / 8041
# Completed: 4550 / 8041
# Completed: 4600 / 8041
# Completed: 4650 / 8041
# Completed: 4700 / 8041
# Completed: 4750 / 8041
# Completed: 4800 / 8041
# Completed: 4850 / 8041
# Completed: 4900 / 8041
# Completed: 4950 / 8041
# Completed: 5000 / 8041
# Completed: 5050 / 8041
# Completed: 5100 / 8041
# Completed: 5150 / 8041
# Completed: 5200 / 8041
# Completed: 5250 / 8041
# Completed: 5300 / 8041
# Completed: 5350 / 8041
# Completed: 5400 / 8041
# Completed: 5450 / 8041
# Completed: 5500 / 8041
# Completed: 5550 / 8041
# Completed: 5600 / 8041
# Completed: 5650 / 8041
# Completed: 5700 / 8041
# Completed: 5750 / 8041
# Completed: 5800 / 8041
# Completed: 5850 / 8041
# Completed: 5900 / 8041
# Completed: 5950 / 8041
# Completed: 6000 / 8041
# Completed: 6050 / 8041
# Completed: 6100 / 8041
# Completed: 6150 / 8041
# Completed: 6200 / 8041
# Completed: 6250 / 8041
# Completed: 6300 / 8041
# Completed: 6350 / 8041
# Completed: 6400 / 8041
# Completed: 6450 / 8041
# Completed: 6500 / 8041
# Completed: 6550 / 8041
# Completed: 6600 / 8041
# Completed: 6650 / 8041
# Completed: 6700 / 8041
# Completed: 6750 / 8041
# Completed: 6800 / 8041
# Completed: 6850 / 8041
# Completed: 6900 / 8041
# Completed: 6950 / 8041
# Completed: 7000 / 8041
# Completed: 7050 / 8041
# Completed: 7100 / 8041
# Completed: 7150 / 8041
# Completed: 7200 / 8041
# Completed: 7250 / 8041
# Completed: 7300 / 8041
# Completed: 7350 / 8041
# Completed: 7400 / 8041
# Completed: 7450 / 8041
# Completed: 7500 / 8041
# Completed: 7550 / 8041
# Completed: 7600 / 8041
# Completed: 7650 / 8041
# Completed: 7700 / 8041
# Completed: 7750 / 8041
# Completed: 7800 / 8041
# Completed: 7850 / 8041
# Completed: 7900 / 8041
# Completed: 7950 / 8041
# Completed: 8000 / 8041
