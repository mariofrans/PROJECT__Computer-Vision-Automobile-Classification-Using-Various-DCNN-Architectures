# %%
# !pip install pandas numpy seaborn matplotlib tensorflow keras sklearn &> /dev/null

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications import InceptionV3

import time
start_time = time.time()

# %%
PATH_DATA_TRAIN = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/train'
PATH_DATA_TEST = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/test'
PATH_DATA_VALIDATION = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/validation'
PATH_SAVED_MODEL = 'inception-v3-imagenet.h5'

# %% [markdown]
# # Load Dataset As Generators

# %%
generator = ImageDataGenerator(rescale = 1./255.)

target_size = (100, 100)
batch_size = 32

train_batches = generator.flow_from_directory(
    PATH_DATA_TRAIN, class_mode='categorical', 
    batch_size=batch_size, target_size=target_size
)

validation_batches = generator.flow_from_directory(
    PATH_DATA_VALIDATION, class_mode='categorical',  
    batch_size=batch_size, target_size=target_size
)

test_batches = generator.flow_from_directory(
    PATH_DATA_TEST, class_mode='categorical', shuffle=False, 
    batch_size=batch_size, target_size=target_size
)
# Out:
# Found 12959 images belonging to 7 classes.
# Found 1616 images belonging to 7 classes.
# Found 1610 images belonging to 7 classes.

# %%
# preview data (batch size, width, height, colors)
print('x_train shape:', train_batches[0][0].shape)
print('x_validation shape:', validation_batches[0][0].shape)
print('x_test shape:', test_batches[0][0].shape)
print('y_train shape:', train_batches[0][1].shape)
print('y_validation shape:', validation_batches[0][1].shape)
print('y_test shape:', test_batches[0][1].shape)
# Out:
# x_train shape: (32, 100, 100, 3)
# x_validation shape: (32, 100, 100, 3)
# x_test shape: (32, 100, 100, 3)
# y_train shape: (32, 7)
# y_validation shape: (32, 7)
# y_test shape: (32, 7)

# %%
# input & output shape
input_shape = train_batches[0][0][0].shape
output_shape = len(train_batches[0][1][0])

# display input & output shape
print('Input Shape:', input_shape)
print('Output Shape:', output_shape)
# Out:
# Input Shape: (100, 100, 3)
# Output Shape: 7

# %% [markdown]
# # Build & Compile Model

# %%
model = InceptionV3(
    input_shape=input_shape, 
    weights="imagenet", 
    include_top=False, 
    pooling='max'
)

for layer in model.layers:
    layer.trainable = False

i = Input(shape=input_shape)
x = model(i)
x = Flatten()(x)
x = Dense(output_shape, activation='softmax')(x)

model = Model(inputs=i, outputs=x)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# 2022-11-10 00:04:37.028950: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 00:04:37.029923: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 00:04:37.361962: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 00:04:37.363052: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 00:04:37.363828: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 00:04:37.364662: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 00:04:37.366458: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-10 00:04:37.614192: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 00:04:37.615154: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 00:04:37.616021: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 00:04:37.616831: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 00:04:37.617503: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 00:04:37.618179: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 00:04:42.365893: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 00:04:42.366781: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 00:04:42.367543: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 00:04:42.368290: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 00:04:42.369003: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 00:04:42.369654: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-11-10 00:04:42.377073: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 00:04:42.377793: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# 87924736/87910968 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# inception_v3 (Functional)    (None, 2048)              21802784
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 14343
# =================================================================
# Total params: 21,817,127
# Trainable params: 14,343
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %% [markdown]
# # Train Model

# %%
# train model
r = model.fit(train_batches, validation_data=validation_batches, epochs=100)

# save model
model.save(PATH_SAVED_MODEL)

# load model
# model = load_model(PATH_SAVED_MODEL)
# Out:
# 2022-11-10 00:04:46.288624: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-11-10 00:04:52.690725: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 405/405 [==============================] - 204s 460ms/step - loss: 1.5412 - accuracy: 0.4131 - val_loss: 1.4827 - val_accuracy: 0.4270
# Epoch 2/100
# 405/405 [==============================] - 104s 257ms/step - loss: 1.3280 - accuracy: 0.4839 - val_loss: 1.3328 - val_accuracy: 0.4950
# Epoch 3/100
# 405/405 [==============================] - 104s 256ms/step - loss: 1.2389 - accuracy: 0.5243 - val_loss: 1.3523 - val_accuracy: 0.4821
# Epoch 4/100
# 405/405 [==============================] - 103s 255ms/step - loss: 1.1978 - accuracy: 0.5389 - val_loss: 1.3703 - val_accuracy: 0.4994
# Epoch 5/100
# 405/405 [==============================] - 104s 257ms/step - loss: 1.1748 - accuracy: 0.5489 - val_loss: 1.3189 - val_accuracy: 0.4932
# Epoch 6/100
# 405/405 [==============================] - 103s 254ms/step - loss: 1.1403 - accuracy: 0.5598 - val_loss: 1.4215 - val_accuracy: 0.4653
# Epoch 7/100
# 405/405 [==============================] - 103s 254ms/step - loss: 1.1147 - accuracy: 0.5698 - val_loss: 1.3645 - val_accuracy: 0.4926
# Epoch 8/100
# 405/405 [==============================] - 102s 252ms/step - loss: 1.0967 - accuracy: 0.5774 - val_loss: 1.3524 - val_accuracy: 0.4981
# Epoch 9/100
# 405/405 [==============================] - 102s 252ms/step - loss: 1.0708 - accuracy: 0.5875 - val_loss: 1.3597 - val_accuracy: 0.4957
# Epoch 10/100
# 405/405 [==============================] - 104s 256ms/step - loss: 1.0554 - accuracy: 0.5956 - val_loss: 1.4376 - val_accuracy: 0.4684
# Epoch 11/100
# 405/405 [==============================] - 102s 250ms/step - loss: 1.0483 - accuracy: 0.5960 - val_loss: 1.3562 - val_accuracy: 0.4975
# Epoch 12/100
# 405/405 [==============================] - 100s 247ms/step - loss: 1.0359 - accuracy: 0.5990 - val_loss: 1.4103 - val_accuracy: 0.4821
# Epoch 13/100
# 405/405 [==============================] - 101s 250ms/step - loss: 1.0190 - accuracy: 0.6030 - val_loss: 1.3599 - val_accuracy: 0.4889
# Epoch 14/100
# 405/405 [==============================] - 101s 250ms/step - loss: 1.0157 - accuracy: 0.6050 - val_loss: 1.4301 - val_accuracy: 0.4876
# Epoch 15/100
# 405/405 [==============================] - 103s 254ms/step - loss: 1.0024 - accuracy: 0.6115 - val_loss: 1.3827 - val_accuracy: 0.4864
# Epoch 16/100
# 405/405 [==============================] - 100s 248ms/step - loss: 0.9964 - accuracy: 0.6129 - val_loss: 1.4815 - val_accuracy: 0.4728
# Epoch 17/100
# 405/405 [==============================] - 102s 251ms/step - loss: 0.9912 - accuracy: 0.6154 - val_loss: 1.4230 - val_accuracy: 0.4752
# Epoch 18/100
# 405/405 [==============================] - 101s 250ms/step - loss: 0.9704 - accuracy: 0.6219 - val_loss: 1.4932 - val_accuracy: 0.4833
# Epoch 19/100
# 405/405 [==============================] - 101s 251ms/step - loss: 0.9695 - accuracy: 0.6229 - val_loss: 1.4275 - val_accuracy: 0.4901
# Epoch 20/100
# 405/405 [==============================] - 101s 249ms/step - loss: 0.9594 - accuracy: 0.6238 - val_loss: 1.4553 - val_accuracy: 0.4814
# Epoch 21/100
# 405/405 [==============================] - 101s 249ms/step - loss: 0.9572 - accuracy: 0.6272 - val_loss: 1.5031 - val_accuracy: 0.4604
# Epoch 22/100
# 405/405 [==============================] - 101s 249ms/step - loss: 0.9480 - accuracy: 0.6301 - val_loss: 1.4804 - val_accuracy: 0.4895
# Epoch 23/100
# 405/405 [==============================] - 102s 251ms/step - loss: 0.9557 - accuracy: 0.6265 - val_loss: 1.4732 - val_accuracy: 0.4691
# Epoch 24/100
# 405/405 [==============================] - 102s 251ms/step - loss: 0.9400 - accuracy: 0.6331 - val_loss: 1.4573 - val_accuracy: 0.4913
# Epoch 25/100
# 405/405 [==============================] - 103s 253ms/step - loss: 0.9357 - accuracy: 0.6359 - val_loss: 1.4782 - val_accuracy: 0.4926
# Epoch 26/100
# 405/405 [==============================] - 101s 250ms/step - loss: 0.9218 - accuracy: 0.6395 - val_loss: 1.5667 - val_accuracy: 0.4821
# Epoch 27/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.9209 - accuracy: 0.6416 - val_loss: 1.4953 - val_accuracy: 0.4827
# Epoch 28/100
# 405/405 [==============================] - 102s 252ms/step - loss: 0.9211 - accuracy: 0.6414 - val_loss: 1.4998 - val_accuracy: 0.4882
# Epoch 29/100
# 405/405 [==============================] - 101s 249ms/step - loss: 0.9125 - accuracy: 0.6468 - val_loss: 1.5266 - val_accuracy: 0.4932
# Epoch 30/100
# 405/405 [==============================] - 101s 250ms/step - loss: 0.9111 - accuracy: 0.6430 - val_loss: 1.5337 - val_accuracy: 0.4777
# Epoch 31/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.9091 - accuracy: 0.6443 - val_loss: 1.5191 - val_accuracy: 0.4771
# Epoch 32/100
# 405/405 [==============================] - 103s 253ms/step - loss: 0.8987 - accuracy: 0.6470 - val_loss: 1.5005 - val_accuracy: 0.4833
# Epoch 33/100
# 405/405 [==============================] - 102s 252ms/step - loss: 0.9070 - accuracy: 0.6475 - val_loss: 1.5380 - val_accuracy: 0.4765
# Epoch 34/100
# 405/405 [==============================] - 102s 251ms/step - loss: 0.8931 - accuracy: 0.6489 - val_loss: 1.5484 - val_accuracy: 0.4722
# Epoch 35/100
# 405/405 [==============================] - 102s 251ms/step - loss: 0.8921 - accuracy: 0.6561 - val_loss: 1.5282 - val_accuracy: 0.4901
# Epoch 36/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.8926 - accuracy: 0.6480 - val_loss: 1.5544 - val_accuracy: 0.4814
# Epoch 37/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.8788 - accuracy: 0.6555 - val_loss: 1.5539 - val_accuracy: 0.4715
# Epoch 38/100
# 405/405 [==============================] - 102s 253ms/step - loss: 0.8798 - accuracy: 0.6588 - val_loss: 1.5339 - val_accuracy: 0.4870
# Epoch 39/100
# 405/405 [==============================] - 102s 251ms/step - loss: 0.8811 - accuracy: 0.6551 - val_loss: 1.5731 - val_accuracy: 0.4783
# Epoch 40/100
# 405/405 [==============================] - 102s 251ms/step - loss: 0.8790 - accuracy: 0.6570 - val_loss: 1.5800 - val_accuracy: 0.4759
# Epoch 41/100
# 405/405 [==============================] - 101s 249ms/step - loss: 0.8645 - accuracy: 0.6626 - val_loss: 1.5768 - val_accuracy: 0.4802
# Epoch 42/100
# 405/405 [==============================] - 102s 251ms/step - loss: 0.8668 - accuracy: 0.6614 - val_loss: 1.5677 - val_accuracy: 0.4734
# Epoch 43/100
# 405/405 [==============================] - 101s 250ms/step - loss: 0.8701 - accuracy: 0.6629 - val_loss: 1.5912 - val_accuracy: 0.4759
# Epoch 44/100
# 405/405 [==============================] - 101s 250ms/step - loss: 0.8725 - accuracy: 0.6524 - val_loss: 1.5773 - val_accuracy: 0.4765
# Epoch 45/100
# 405/405 [==============================] - 103s 253ms/step - loss: 0.8598 - accuracy: 0.6671 - val_loss: 1.6461 - val_accuracy: 0.4666
# Epoch 46/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.8618 - accuracy: 0.6629 - val_loss: 1.6852 - val_accuracy: 0.4598
# Epoch 47/100
# 405/405 [==============================] - 102s 252ms/step - loss: 0.8498 - accuracy: 0.6650 - val_loss: 1.6399 - val_accuracy: 0.4623
# Epoch 48/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.8544 - accuracy: 0.6659 - val_loss: 1.5999 - val_accuracy: 0.4851
# Epoch 49/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.8505 - accuracy: 0.6694 - val_loss: 1.6458 - val_accuracy: 0.4573
# Epoch 50/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.8462 - accuracy: 0.6659 - val_loss: 1.6186 - val_accuracy: 0.4623
# Epoch 51/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.8478 - accuracy: 0.6698 - val_loss: 1.6172 - val_accuracy: 0.4684
# Epoch 52/100
# 405/405 [==============================] - 104s 258ms/step - loss: 0.8441 - accuracy: 0.6735 - val_loss: 1.6480 - val_accuracy: 0.4573
# Epoch 53/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.8365 - accuracy: 0.6733 - val_loss: 1.6558 - val_accuracy: 0.4629
# Epoch 54/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.8520 - accuracy: 0.6636 - val_loss: 1.6998 - val_accuracy: 0.4641
# Epoch 55/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.8363 - accuracy: 0.6715 - val_loss: 1.6580 - val_accuracy: 0.4629
# Epoch 56/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.8346 - accuracy: 0.6720 - val_loss: 1.6700 - val_accuracy: 0.4666
# Epoch 57/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.8414 - accuracy: 0.6709 - val_loss: 1.6670 - val_accuracy: 0.4678
# Epoch 58/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.8358 - accuracy: 0.6727 - val_loss: 1.6727 - val_accuracy: 0.4814
# Epoch 59/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.8253 - accuracy: 0.6744 - val_loss: 1.7016 - val_accuracy: 0.4666
# Epoch 60/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.8301 - accuracy: 0.6746 - val_loss: 1.6899 - val_accuracy: 0.4629
# Epoch 61/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.8272 - accuracy: 0.6755 - val_loss: 1.6846 - val_accuracy: 0.4598
# Epoch 62/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.8236 - accuracy: 0.6780 - val_loss: 1.6702 - val_accuracy: 0.4641
# Epoch 63/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.8227 - accuracy: 0.6756 - val_loss: 1.7197 - val_accuracy: 0.4592
# Epoch 64/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.8213 - accuracy: 0.6818 - val_loss: 1.7348 - val_accuracy: 0.4660
# Epoch 65/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.8233 - accuracy: 0.6817 - val_loss: 1.7678 - val_accuracy: 0.4635
# Epoch 66/100
# 405/405 [==============================] - 111s 273ms/step - loss: 0.8196 - accuracy: 0.6756 - val_loss: 1.7083 - val_accuracy: 0.4511
# Epoch 67/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.8070 - accuracy: 0.6822 - val_loss: 1.7277 - val_accuracy: 0.4653
# Epoch 68/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.8232 - accuracy: 0.6778 - val_loss: 1.6978 - val_accuracy: 0.4728
# Epoch 69/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.8182 - accuracy: 0.6774 - val_loss: 1.7090 - val_accuracy: 0.4554
# Epoch 70/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.8194 - accuracy: 0.6783 - val_loss: 1.7467 - val_accuracy: 0.4703
# Epoch 71/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.8193 - accuracy: 0.6784 - val_loss: 1.7325 - val_accuracy: 0.4703
# Epoch 72/100
# 405/405 [==============================] - 102s 251ms/step - loss: 0.8114 - accuracy: 0.6837 - val_loss: 1.7677 - val_accuracy: 0.4592
# Epoch 73/100
# 405/405 [==============================] - 102s 251ms/step - loss: 0.8065 - accuracy: 0.6860 - val_loss: 1.7417 - val_accuracy: 0.4660
# Epoch 74/100
# 405/405 [==============================] - 102s 251ms/step - loss: 0.8064 - accuracy: 0.6845 - val_loss: 1.7479 - val_accuracy: 0.4759
# Epoch 75/100
# 405/405 [==============================] - 101s 248ms/step - loss: 0.7974 - accuracy: 0.6882 - val_loss: 1.7309 - val_accuracy: 0.4647
# Epoch 76/100
# 405/405 [==============================] - 124s 307ms/step - loss: 0.8039 - accuracy: 0.6848 - val_loss: 1.7676 - val_accuracy: 0.4499
# Epoch 77/100
# 405/405 [==============================] - 119s 295ms/step - loss: 0.8046 - accuracy: 0.6837 - val_loss: 1.7915 - val_accuracy: 0.4406
# Epoch 78/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.7971 - accuracy: 0.6843 - val_loss: 1.7530 - val_accuracy: 0.4536
# Epoch 79/100
# 405/405 [==============================] - 102s 252ms/step - loss: 0.7984 - accuracy: 0.6838 - val_loss: 1.8056 - val_accuracy: 0.4548
# Epoch 80/100
# 405/405 [==============================] - 103s 253ms/step - loss: 0.7978 - accuracy: 0.6836 - val_loss: 1.7592 - val_accuracy: 0.4592
# Epoch 81/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.7940 - accuracy: 0.6910 - val_loss: 1.7943 - val_accuracy: 0.4437
# Epoch 82/100
# 405/405 [==============================] - 114s 282ms/step - loss: 0.8052 - accuracy: 0.6850 - val_loss: 1.8421 - val_accuracy: 0.4505
# Epoch 83/100
# 405/405 [==============================] - 101s 250ms/step - loss: 0.7871 - accuracy: 0.6889 - val_loss: 1.8331 - val_accuracy: 0.4381
# Epoch 84/100
# 405/405 [==============================] - 102s 252ms/step - loss: 0.7906 - accuracy: 0.6926 - val_loss: 1.7949 - val_accuracy: 0.4511
# Epoch 85/100
# 405/405 [==============================] - 102s 253ms/step - loss: 0.7907 - accuracy: 0.6888 - val_loss: 1.8369 - val_accuracy: 0.4616
# Epoch 86/100
# 405/405 [==============================] - 102s 253ms/step - loss: 0.8049 - accuracy: 0.6809 - val_loss: 1.7718 - val_accuracy: 0.4623
# Epoch 87/100
# 405/405 [==============================] - 101s 250ms/step - loss: 0.7874 - accuracy: 0.6923 - val_loss: 1.8332 - val_accuracy: 0.4530
# Epoch 88/100
# 405/405 [==============================] - 101s 250ms/step - loss: 0.7949 - accuracy: 0.6856 - val_loss: 1.7885 - val_accuracy: 0.4641
# Epoch 89/100
# 405/405 [==============================] - 102s 251ms/step - loss: 0.7886 - accuracy: 0.6885 - val_loss: 1.8260 - val_accuracy: 0.4684
# Epoch 90/100
# 405/405 [==============================] - 102s 252ms/step - loss: 0.7843 - accuracy: 0.6930 - val_loss: 1.8459 - val_accuracy: 0.4486
# Epoch 91/100
# 405/405 [==============================] - 100s 248ms/step - loss: 0.7828 - accuracy: 0.6914 - val_loss: 1.8577 - val_accuracy: 0.4425
# Epoch 92/100
# 405/405 [==============================] - 100s 246ms/step - loss: 0.7817 - accuracy: 0.6925 - val_loss: 1.8448 - val_accuracy: 0.4666
# Epoch 93/100
# 405/405 [==============================] - 102s 252ms/step - loss: 0.7826 - accuracy: 0.6936 - val_loss: 1.8826 - val_accuracy: 0.4548
# Epoch 94/100
# 405/405 [==============================] - 101s 250ms/step - loss: 0.7793 - accuracy: 0.6904 - val_loss: 1.8446 - val_accuracy: 0.4592
# Epoch 95/100
# 405/405 [==============================] - 100s 248ms/step - loss: 0.7853 - accuracy: 0.6907 - val_loss: 1.8445 - val_accuracy: 0.4505
# Epoch 96/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.7774 - accuracy: 0.6920 - val_loss: 1.8155 - val_accuracy: 0.4567
# Epoch 97/100
# 405/405 [==============================] - 101s 249ms/step - loss: 0.7752 - accuracy: 0.6965 - val_loss: 1.8722 - val_accuracy: 0.4418
# Epoch 98/100
# 405/405 [==============================] - 101s 250ms/step - loss: 0.7730 - accuracy: 0.6978 - val_loss: 1.8459 - val_accuracy: 0.4610
# Epoch 99/100
# 405/405 [==============================] - 101s 249ms/step - loss: 0.7689 - accuracy: 0.6985 - val_loss: 1.8683 - val_accuracy: 0.4524
# Epoch 100/100
# 405/405 [==============================] - 101s 250ms/step - loss: 0.7686 - accuracy: 0.6976 - val_loss: 1.9475 - val_accuracy: 0.4480

# %% [markdown]
# # Evaluate Model's Training & Validation Results

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()

# %% [markdown]
# # Generate Predictions With Model

# %%
y_pred = model.predict(test_batches).argmax(axis=1)

# %%
model.evaluate(test_batches)
# Out:
# 51/51 [==============================] - 12s 232ms/step - loss: 1.9158 - accuracy: 0.4410
# [1.9158111810684204, 0.4409937858581543]

# %% [markdown]
# # Evaluate Model's Prediction Results

# %%
# generate classification report
class_labels = list(test_batches.class_indices.keys())
report = classification_report(test_batches.classes, y_pred, target_names=class_labels, output_dict=True)
df_classification_report = pd.DataFrame(report).transpose()
df_classification_report
# Out:
#               precision    recall  f1-score      support
# hatchback      0.241667  0.185897  0.210145   156.000000
# mpv            0.324138  0.435185  0.371542   108.000000
# sedan          0.441489  0.200483  0.275748   414.000000
# sport          0.532872  0.681416  0.598058   452.000000
# suv            0.390710  0.503521  0.440000   284.000000
# truck          0.518717  0.606250  0.559078   160.000000
# wagon          0.115385  0.083333  0.096774    36.000000
# accuracy       0.440994  0.440994  0.440994     0.440994
# macro avg      0.366425  0.385155  0.364478  1610.000000
# weighted avg   0.431337  0.440994  0.419433  1610.000000

# %%
# compute confusion matrix
matrix = confusion_matrix(test_batches.classes, y_pred)

# normalize confusion matrix
matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
matrix = np.around(matrix, decimals=2)

# generate confusion matrix heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(matrix, annot=True, xticklabels=class_labels, yticklabels=class_labels)
plt.ylabel('Test Values')
plt.xlabel('Predicted Values')
# Out:
# Text(0.5, 69.0, 'Predicted Values')

# %% [markdown]
# # Compute Execution Time

# %%
execution_time_s = round(time.time() - start_time, 2)
execution_time_m = round(execution_time_s/60, 2)
execution_time_h = round(execution_time_m/60, 2)

print('Execution Time (Hours):', execution_time_h)
print('Execution Time (Minutes):', execution_time_m)
print('Execution Time (Seconds):', execution_time_s)
# Out:
# Execution Time (Hours): 2.91
# Execution Time (Minutes): 174.88
# Execution Time (Seconds): 10492.51
