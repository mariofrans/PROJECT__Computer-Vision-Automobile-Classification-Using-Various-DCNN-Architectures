# %%
# !pip install pandas numpy seaborn matplotlib tensorflow keras sklearn &> /dev/null

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout, GlobalMaxPooling2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.models import Model

import time
start_time = time.time()

# %%
PATH_DATA_TRAIN = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/train'
PATH_DATA_TEST = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/test'
PATH_DATA_VALIDATION = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/validation'
PATH_SAVED_MODEL = 'mario.h5'

# %% [markdown]
# # Load Dataset As Generators

# %%
generator = ImageDataGenerator(rescale = 1./255.)

target_size = (100, 100)
batch_size = 32

train_batches = generator.flow_from_directory(
    PATH_DATA_TRAIN, class_mode='categorical', 
    batch_size=batch_size, target_size=target_size
)

validation_batches = generator.flow_from_directory(
    PATH_DATA_VALIDATION, class_mode='categorical',  
    batch_size=batch_size, target_size=target_size
)

test_batches = generator.flow_from_directory(
    PATH_DATA_TEST, class_mode='categorical', shuffle=False, 
    batch_size=batch_size, target_size=target_size
)
# Out:
# Found 12959 images belonging to 7 classes.
# Found 1616 images belonging to 7 classes.
# Found 1610 images belonging to 7 classes.

# %%
# preview data (batch size, width, height, colors)
print('x_train shape:', train_batches[0][0].shape)
print('x_validation shape:', validation_batches[0][0].shape)
print('x_test shape:', test_batches[0][0].shape)
print('y_train shape:', train_batches[0][1].shape)
print('y_validation shape:', validation_batches[0][1].shape)
print('y_test shape:', test_batches[0][1].shape)
# Out:
# x_train shape: (32, 100, 100, 3)
# x_validation shape: (32, 100, 100, 3)
# x_test shape: (32, 100, 100, 3)
# y_train shape: (32, 7)
# y_validation shape: (32, 7)
# y_test shape: (32, 7)

# %%
# input & output shape
input_shape = train_batches[0][0][0].shape
output_shape = len(train_batches[0][1][0])

# display input & output shape
print('Input Shape:', input_shape)
print('Output Shape:', output_shape)
# Out:
# Input Shape: (100, 100, 3)
# Output Shape: 7

# %% [markdown]
# # Build & Compile Model

# %%
i = Input(shape=input_shape)

x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = BatchNormalization()(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Flatten()(x)
x = Dropout(0.2)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(output_shape, activation='softmax')(x)

model = Model(i, x)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# 2022-11-09 16:57:53.935705: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 16:57:53.936669: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 16:57:54.320347: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 16:57:54.321701: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 16:57:54.322826: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 16:57:54.323919: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 16:57:54.326795: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-09 16:57:54.624297: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 16:57:54.625209: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 16:57:54.625999: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 16:57:54.626726: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 16:57:54.627467: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 16:57:54.628208: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 16:57:59.621470: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 16:57:59.622545: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 16:57:59.623456: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 16:57:59.
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 100, 100, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 100, 100, 32)      128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 100, 100, 32)      9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 100, 100, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 50, 50, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 50, 50, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 50, 50, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 50, 50, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 50, 50, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 25, 25, 128)       73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 25, 25, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 25, 25, 128)       147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 25, 25, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 18432)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              18875392
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 7175
# =================================================================
# Total params: 19,171,367
# Trainable params: 19,170,471
# Non-trainable params: 896
# _________________________________________________________________
# 624234: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 16:57:59.625064: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 16:57:59.625897: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-11-09 16:57:59.631175: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 16:57:59.631992: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %% [markdown]
# # Train Model

# %%
# train model
r = model.fit(train_batches, validation_data=validation_batches, epochs=100)

# save model
model.save(PATH_SAVED_MODEL)

# load model
# model = load_model(PATH_SAVED_MODEL)
# Out:
# 2022-11-09 16:58:00.490379: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-11-09 16:58:03.991868: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 405/405 [==============================] - 210s 483ms/step - loss: 2.3399 - accuracy: 0.2855 - val_loss: 1.8050 - val_accuracy: 0.2828
# Epoch 2/100
# 405/405 [==============================] - 107s 264ms/step - loss: 1.6283 - accuracy: 0.3502 - val_loss: 2.5433 - val_accuracy: 0.2853
# Epoch 3/100
# 405/405 [==============================] - 106s 263ms/step - loss: 1.5337 - accuracy: 0.3821 - val_loss: 2.2897 - val_accuracy: 0.1999
# Epoch 4/100
# 405/405 [==============================] - 105s 259ms/step - loss: 1.4751 - accuracy: 0.4056 - val_loss: 2.3181 - val_accuracy: 0.3286
# Epoch 5/100
# 405/405 [==============================] - 107s 264ms/step - loss: 1.3934 - accuracy: 0.4376 - val_loss: 1.7504 - val_accuracy: 0.3676
# Epoch 6/100
# 405/405 [==============================] - 106s 261ms/step - loss: 1.3465 - accuracy: 0.4566 - val_loss: 1.6664 - val_accuracy: 0.4022
# Epoch 7/100
# 405/405 [==============================] - 107s 265ms/step - loss: 1.2695 - accuracy: 0.5022 - val_loss: 2.3165 - val_accuracy: 0.4097
# Epoch 8/100
# 405/405 [==============================] - 107s 265ms/step - loss: 1.2019 - accuracy: 0.5382 - val_loss: 1.1911 - val_accuracy: 0.5668
# Epoch 9/100
# 405/405 [==============================] - 108s 266ms/step - loss: 1.1032 - accuracy: 0.5727 - val_loss: 1.2710 - val_accuracy: 0.5043
# Epoch 10/100
# 405/405 [==============================] - 106s 260ms/step - loss: 1.0381 - accuracy: 0.6034 - val_loss: 1.2936 - val_accuracy: 0.4920
# Epoch 11/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.9742 - accuracy: 0.6346 - val_loss: 1.0960 - val_accuracy: 0.5718
# Epoch 12/100
# 405/405 [==============================] - 104s 258ms/step - loss: 0.8823 - accuracy: 0.6769 - val_loss: 15.4566 - val_accuracy: 0.1733
# Epoch 13/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.8094 - accuracy: 0.7014 - val_loss: 1.0037 - val_accuracy: 0.6145
# Epoch 14/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.7339 - accuracy: 0.7352 - val_loss: 0.9939 - val_accuracy: 0.6683
# Epoch 15/100
# 405/405 [==============================] - 115s 284ms/step - loss: 0.6607 - accuracy: 0.7629 - val_loss: 0.9634 - val_accuracy: 0.6677
# Epoch 16/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.6235 - accuracy: 0.7811 - val_loss: 1.0758 - val_accuracy: 0.6516
# Epoch 17/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.5790 - accuracy: 0.7964 - val_loss: 2.0892 - val_accuracy: 0.5012
# Epoch 18/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.5225 - accuracy: 0.8146 - val_loss: 0.9413 - val_accuracy: 0.6838
# Epoch 19/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.4640 - accuracy: 0.8404 - val_loss: 1.6309 - val_accuracy: 0.5588
# Epoch 20/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.4466 - accuracy: 0.8430 - val_loss: 1.4464 - val_accuracy: 0.6188
# Epoch 21/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.4182 - accuracy: 0.8542 - val_loss: 1.0400 - val_accuracy: 0.6980
# Epoch 22/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.3572 - accuracy: 0.8761 - val_loss: 1.1419 - val_accuracy: 0.6869
# Epoch 23/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.3581 - accuracy: 0.8785 - val_loss: 1.1145 - val_accuracy: 0.7067
# Epoch 24/100
# 405/405 [==============================] - 106s 263ms/step - loss: 0.3208 - accuracy: 0.8901 - val_loss: 1.1821 - val_accuracy: 0.6652
# Epoch 25/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.2964 - accuracy: 0.9011 - val_loss: 1.0241 - val_accuracy: 0.7191
# Epoch 26/100
# 405/405 [==============================] - 107s 263ms/step - loss: 0.2883 - accuracy: 0.9020 - val_loss: 1.2665 - val_accuracy: 0.6671
# Epoch 27/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.2868 - accuracy: 0.9042 - val_loss: 1.4151 - val_accuracy: 0.6448
# Epoch 28/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.2473 - accuracy: 0.9160 - val_loss: 1.4886 - val_accuracy: 0.6584
# Epoch 29/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.2443 - accuracy: 0.9191 - val_loss: 1.2532 - val_accuracy: 0.7054
# Epoch 30/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.2461 - accuracy: 0.9184 - val_loss: 1.2987 - val_accuracy: 0.6850
# Epoch 31/100
# 405/405 [==============================] - 105s 258ms/step - loss: 0.2238 - accuracy: 0.9282 - val_loss: 1.3283 - val_accuracy: 0.7178
# Epoch 32/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.2209 - accuracy: 0.9282 - val_loss: 1.4861 - val_accuracy: 0.6968
# Epoch 33/100
# 405/405 [==============================] - 106s 260ms/step - loss: 0.2025 - accuracy: 0.9323 - val_loss: 1.4791 - val_accuracy: 0.7098
# Epoch 34/100
# 405/405 [==============================] - 105s 258ms/step - loss: 0.1980 - accuracy: 0.9357 - val_loss: 1.4571 - val_accuracy: 0.7079
# Epoch 35/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.2045 - accuracy: 0.9316 - val_loss: 1.4125 - val_accuracy: 0.7209
# Epoch 36/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.2034 - accuracy: 0.9344 - val_loss: 1.2659 - val_accuracy: 0.6925
# Epoch 37/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.1877 - accuracy: 0.9382 - val_loss: 1.6685 - val_accuracy: 0.6757
# Epoch 38/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.1734 - accuracy: 0.9417 - val_loss: 1.4577 - val_accuracy: 0.7141
# Epoch 39/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.1669 - accuracy: 0.9485 - val_loss: 1.4394 - val_accuracy: 0.7153
# Epoch 40/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.1716 - accuracy: 0.9456 - val_loss: 1.6049 - val_accuracy: 0.7042
# Epoch 41/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.1685 - accuracy: 0.9475 - val_loss: 1.7612 - val_accuracy: 0.7172
# Epoch 42/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.1591 - accuracy: 0.9488 - val_loss: 1.4373 - val_accuracy: 0.7011
# Epoch 43/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.1636 - accuracy: 0.9491 - val_loss: 1.5598 - val_accuracy: 0.7116
# Epoch 44/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.1403 - accuracy: 0.9556 - val_loss: 1.6735 - val_accuracy: 0.7092
# Epoch 45/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.1347 - accuracy: 0.9568 - val_loss: 2.0328 - val_accuracy: 0.7030
# Epoch 46/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.1409 - accuracy: 0.9560 - val_loss: 3.0048 - val_accuracy: 0.6355
# Epoch 47/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.1419 - accuracy: 0.9534 - val_loss: 2.2328 - val_accuracy: 0.7005
# Epoch 48/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.1406 - accuracy: 0.9572 - val_loss: 1.9112 - val_accuracy: 0.7054
# Epoch 49/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.1505 - accuracy: 0.9531 - val_loss: 1.7064 - val_accuracy: 0.7184
# Epoch 50/100
# 405/405 [==============================] - 106s 260ms/step - loss: 0.1239 - accuracy: 0.9623 - val_loss: 1.6849 - val_accuracy: 0.6869
# Epoch 51/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.1345 - accuracy: 0.9567 - val_loss: 1.6681 - val_accuracy: 0.7129
# Epoch 52/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.1264 - accuracy: 0.9593 - val_loss: 1.6981 - val_accuracy: 0.7085
# Epoch 53/100
# 405/405 [==============================] - 104s 258ms/step - loss: 0.1355 - accuracy: 0.9599 - val_loss: 1.5904 - val_accuracy: 0.7017
# Epoch 54/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.1103 - accuracy: 0.9660 - val_loss: 1.6102 - val_accuracy: 0.6807
# Epoch 55/100
# 405/405 [==============================] - 102s 251ms/step - loss: 0.1186 - accuracy: 0.9637 - val_loss: 1.9971 - val_accuracy: 0.6436
# Epoch 56/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.1279 - accuracy: 0.9611 - val_loss: 1.4311 - val_accuracy: 0.7036
# Epoch 57/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.1246 - accuracy: 0.9615 - val_loss: 1.9551 - val_accuracy: 0.6931
# Epoch 58/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.1066 - accuracy: 0.9662 - val_loss: 1.5597 - val_accuracy: 0.7166
# Epoch 59/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.1233 - accuracy: 0.9620 - val_loss: 1.8108 - val_accuracy: 0.7073
# Epoch 60/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.1064 - accuracy: 0.9679 - val_loss: 1.4272 - val_accuracy: 0.7092
# Epoch 61/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.1138 - accuracy: 0.9645 - val_loss: 1.6450 - val_accuracy: 0.7166
# Epoch 62/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.1178 - accuracy: 0.9640 - val_loss: 1.9037 - val_accuracy: 0.7351
# Epoch 63/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.1011 - accuracy: 0.9689 - val_loss: 1.7982 - val_accuracy: 0.7382
# Epoch 64/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.1037 - accuracy: 0.9687 - val_loss: 1.6078 - val_accuracy: 0.7092
# Epoch 65/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.0965 - accuracy: 0.9706 - val_loss: 1.7666 - val_accuracy: 0.7048
# Epoch 66/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.1060 - accuracy: 0.9689 - val_loss: 1.4171 - val_accuracy: 0.7314
# Epoch 67/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.0949 - accuracy: 0.9699 - val_loss: 1.8040 - val_accuracy: 0.7172
# Epoch 68/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.1046 - accuracy: 0.9689 - val_loss: 1.7187 - val_accuracy: 0.7172
# Epoch 69/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.1009 - accuracy: 0.9688 - val_loss: 1.6458 - val_accuracy: 0.6881
# Epoch 70/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.0845 - accuracy: 0.9746 - val_loss: 1.8852 - val_accuracy: 0.7178
# Epoch 71/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.0844 - accuracy: 0.9744 - val_loss: 1.5064 - val_accuracy: 0.7240
# Epoch 72/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.0757 - accuracy: 0.9772 - val_loss: 2.1381 - val_accuracy: 0.6900
# Epoch 73/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.0986 - accuracy: 0.9710 - val_loss: 1.5420 - val_accuracy: 0.6999
# Epoch 74/100
# 405/405 [==============================] - 105s 258ms/step - loss: 0.1085 - accuracy: 0.9679 - val_loss: 2.0135 - val_accuracy: 0.6912
# Epoch 75/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.0911 - accuracy: 0.9705 - val_loss: 1.9768 - val_accuracy: 0.7147
# Epoch 76/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.0924 - accuracy: 0.9722 - val_loss: 2.8545 - val_accuracy: 0.6473
# Epoch 77/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.0852 - accuracy: 0.9745 - val_loss: 2.3127 - val_accuracy: 0.6912
# Epoch 78/100
# 405/405 [==============================] - 106s 263ms/step - loss: 0.0761 - accuracy: 0.9768 - val_loss: 1.7536 - val_accuracy: 0.7351
# Epoch 79/100
# 405/405 [==============================] - 106s 263ms/step - loss: 0.0817 - accuracy: 0.9772 - val_loss: 2.1157 - val_accuracy: 0.6788
# Epoch 80/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.0856 - accuracy: 0.9737 - val_loss: 2.2636 - val_accuracy: 0.6850
# Epoch 81/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.0799 - accuracy: 0.9747 - val_loss: 1.8336 - val_accuracy: 0.7395
# Epoch 82/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.0796 - accuracy: 0.9761 - val_loss: 2.1173 - val_accuracy: 0.7314
# Epoch 83/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.0868 - accuracy: 0.9751 - val_loss: 1.9236 - val_accuracy: 0.7234
# Epoch 84/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.0766 - accuracy: 0.9786 - val_loss: 1.7094 - val_accuracy: 0.7296
# Epoch 85/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.0889 - accuracy: 0.9735 - val_loss: 1.9152 - val_accuracy: 0.7184
# Epoch 86/100
# 405/405 [==============================] - 104s 258ms/step - loss: 0.0722 - accuracy: 0.9772 - val_loss: 1.7722 - val_accuracy: 0.7184
# Epoch 87/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.0697 - accuracy: 0.9793 - val_loss: 1.9466 - val_accuracy: 0.7234
# Epoch 88/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.0725 - accuracy: 0.9782 - val_loss: 1.8920 - val_accuracy: 0.7222
# Epoch 89/100
# 405/405 [==============================] - 105s 258ms/step - loss: 0.0748 - accuracy: 0.9781 - val_loss: 1.9915 - val_accuracy: 0.6900
# Epoch 90/100
# 405/405 [==============================] - 104s 258ms/step - loss: 0.0848 - accuracy: 0.9749 - val_loss: 1.6360 - val_accuracy: 0.7339
# Epoch 91/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.0678 - accuracy: 0.9802 - val_loss: 1.7251 - val_accuracy: 0.7234
# Epoch 92/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.0796 - accuracy: 0.9784 - val_loss: 1.8072 - val_accuracy: 0.7160
# Epoch 93/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.0625 - accuracy: 0.9818 - val_loss: 1.8341 - val_accuracy: 0.7191
# Epoch 94/100
# 405/405 [==============================] - 106s 263ms/step - loss: 0.0637 - accuracy: 0.9815 - val_loss: 1.7151 - val_accuracy: 0.7321
# Epoch 95/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.0634 - accuracy: 0.9804 - val_loss: 1.9331 - val_accuracy: 0.7314
# Epoch 96/100
# 405/405 [==============================] - 105s 258ms/step - loss: 0.0850 - accuracy: 0.9764 - val_loss: 1.6497 - val_accuracy: 0.7178
# Epoch 97/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.0768 - accuracy: 0.9774 - val_loss: 3.0256 - val_accuracy: 0.7271
# Epoch 98/100
# 405/405 [==============================] - 104s 258ms/step - loss: 0.0628 - accuracy: 0.9816 - val_loss: 1.6799 - val_accuracy: 0.6850
# Epoch 99/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.0494 - accuracy: 0.9839 - val_loss: 2.0821 - val_accuracy: 0.7228
# Epoch 100/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.0664 - accuracy: 0.9812 - val_loss: 1.7716 - val_accuracy: 0.7153

# %% [markdown]
# # Evaluate Model's Training & Validation Results

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()

# %% [markdown]
# # Generate Predictions With Model

# %%
y_pred = model.predict(test_batches).argmax(axis=1)

# %%
model.evaluate(test_batches)
# Out:
# 51/51 [==============================] - 12s 240ms/step - loss: 1.6238 - accuracy: 0.7261
# [1.6238433122634888, 0.7260869741439819]

# %% [markdown]
# # Evaluate Model's Prediction Results

# %%
# generate classification report
class_labels = list(test_batches.class_indices.keys())
report = classification_report(test_batches.classes, y_pred, target_names=class_labels, output_dict=True)
df_classification_report = pd.DataFrame(report).transpose()
df_classification_report
# Out:
#               precision    recall  f1-score      support
# hatchback      0.666667  0.371795  0.477366   156.000000
# mpv            0.793814  0.712963  0.751220   108.000000
# sedan          0.622309  0.768116  0.687568   414.000000
# sport          0.787952  0.723451  0.754325   452.000000
# suv            0.778502  0.841549  0.808799   284.000000
# truck          0.814607  0.906250  0.857988   160.000000
# wagon          0.333333  0.138889  0.196078    36.000000
# accuracy       0.726087  0.726087  0.726087     0.726087
# macro avg      0.685312  0.637573  0.647621  1610.000000
# weighted avg   0.724816  0.726087  0.717543  1610.000000

# %%
# compute confusion matrix
matrix = confusion_matrix(test_batches.classes, y_pred)

# normalize confusion matrix
matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
matrix = np.around(matrix, decimals=2)

# generate confusion matrix heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(matrix, annot=True, xticklabels=class_labels, yticklabels=class_labels)
plt.ylabel('Test Values')
plt.xlabel('Predicted Values')
# Out:
# Text(0.5, 69.0, 'Predicted Values')

# %% [markdown]
# # Compute Execution Time

# %%
execution_time_s = round(time.time() - start_time, 2)
execution_time_m = round(execution_time_s/60, 2)
execution_time_h = round(execution_time_m/60, 2)

print('Execution Time (Hours):', execution_time_h)
print('Execution Time (Minutes):', execution_time_m)
print('Execution Time (Seconds):', execution_time_s)
# Out:
# Execution Time (Hours): 2.73
# Execution Time (Minutes): 163.77
# Execution Time (Seconds): 9826.47
