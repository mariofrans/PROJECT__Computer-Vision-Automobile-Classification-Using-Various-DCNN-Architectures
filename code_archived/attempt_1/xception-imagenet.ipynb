# %%
# !pip install pandas numpy seaborn matplotlib tensorflow keras sklearn &> /dev/null

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications import Xception

import time
start_time = time.time()

# %%
PATH_DATA_TRAIN = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/train'
PATH_DATA_TEST = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/test'
PATH_DATA_VALIDATION = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/validation'
PATH_SAVED_MODEL = 'xception-imagenet.h5'

# %% [markdown]
# # Load Dataset As Generators

# %%
generator = ImageDataGenerator(rescale = 1./255.)

target_size = (100, 100)
batch_size = 32

train_batches = generator.flow_from_directory(
    PATH_DATA_TRAIN, class_mode='categorical', 
    batch_size=batch_size, target_size=target_size
)

validation_batches = generator.flow_from_directory(
    PATH_DATA_VALIDATION, class_mode='categorical',  
    batch_size=batch_size, target_size=target_size
)

test_batches = generator.flow_from_directory(
    PATH_DATA_TEST, class_mode='categorical', shuffle=False, 
    batch_size=batch_size, target_size=target_size
)
# Out:
# Found 12959 images belonging to 7 classes.
# Found 1616 images belonging to 7 classes.
# Found 1610 images belonging to 7 classes.

# %%
# preview data (batch size, width, height, colors)
print('x_train shape:', train_batches[0][0].shape)
print('x_validation shape:', validation_batches[0][0].shape)
print('x_test shape:', test_batches[0][0].shape)
print('y_train shape:', train_batches[0][1].shape)
print('y_validation shape:', validation_batches[0][1].shape)
print('y_test shape:', test_batches[0][1].shape)
# Out:
# x_train shape: (32, 100, 100, 3)
# x_validation shape: (32, 100, 100, 3)
# x_test shape: (32, 100, 100, 3)
# y_train shape: (32, 7)
# y_validation shape: (32, 7)
# y_test shape: (32, 7)

# %%
# input & output shape
input_shape = train_batches[0][0][0].shape
output_shape = len(train_batches[0][1][0])

# display input & output shape
print('Input Shape:', input_shape)
print('Output Shape:', output_shape)
# Out:
# Input Shape: (100, 100, 3)
# Output Shape: 7

# %% [markdown]
# # Build & Compile Model

# %%
model = Xception(
    input_shape=input_shape, 
    weights="imagenet", 
    include_top=False, 
    pooling='max'
)

for layer in model.layers:
    layer.trainable = False

i = Input(shape=input_shape)
x = model(i)
x = Flatten()(x)
x = Dense(output_shape, activation='softmax')(x)

model = Model(inputs=i, outputs=x)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# 2022-11-10 21:04:22.767331: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 21:04:22.768407: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 21:04:22.948661: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 21:04:22.949687: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 21:04:22.950536: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 21:04:22.951390: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 21:04:22.953463: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-10 21:04:23.223787: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 21:04:23.224705: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 21:04:23.225526: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 21:04:23.226237: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 21:04:23.226958: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 21:04:23.227656: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 21:04:26.685130: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 21:04:26.686044: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 21:04:26.686797: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 21:04:26.687511: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 21:04:26.688258: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 21:04:26.689040: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-11-10 21:04:26.692864: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 21:04:26.693557: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 0s 0us/step
# 83697664/83683744 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# xception (Functional)        (None, 2048)              20861480
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 14343
# =================================================================
# Total params: 20,875,823
# Trainable params: 14,343
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %% [markdown]
# # Train Model

# %%
# train model
r = model.fit(train_batches, validation_data=validation_batches, epochs=100)

# save model
model.save(PATH_SAVED_MODEL)

# load model
# model = load_model(PATH_SAVED_MODEL)
# Out:
# 2022-11-10 21:04:29.335690: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-11-10 21:04:33.426901: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 405/405 [==============================] - 171s 395ms/step - loss: 1.4069 - accuracy: 0.4642 - val_loss: 1.3315 - val_accuracy: 0.4858
# Epoch 2/100
# 405/405 [==============================] - 99s 244ms/step - loss: 1.1832 - accuracy: 0.5496 - val_loss: 1.2188 - val_accuracy: 0.5408
# Epoch 3/100
# 405/405 [==============================] - 100s 248ms/step - loss: 1.1182 - accuracy: 0.5757 - val_loss: 1.1480 - val_accuracy: 0.5563
# Epoch 4/100
# 405/405 [==============================] - 97s 239ms/step - loss: 1.0643 - accuracy: 0.5942 - val_loss: 1.1407 - val_accuracy: 0.5774
# Epoch 5/100
# 405/405 [==============================] - 96s 238ms/step - loss: 1.0214 - accuracy: 0.6141 - val_loss: 1.1218 - val_accuracy: 0.5879
# Epoch 6/100
# 405/405 [==============================] - 95s 234ms/step - loss: 0.9779 - accuracy: 0.6288 - val_loss: 1.1578 - val_accuracy: 0.5866
# Epoch 7/100
# 405/405 [==============================] - 94s 233ms/step - loss: 0.9565 - accuracy: 0.6366 - val_loss: 1.1560 - val_accuracy: 0.5804
# Epoch 8/100
# 405/405 [==============================] - 96s 237ms/step - loss: 0.9373 - accuracy: 0.6481 - val_loss: 1.1672 - val_accuracy: 0.5761
# Epoch 9/100
# 405/405 [==============================] - 101s 249ms/step - loss: 0.9037 - accuracy: 0.6571 - val_loss: 1.1526 - val_accuracy: 0.5854
# Epoch 10/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.8845 - accuracy: 0.6610 - val_loss: 1.1548 - val_accuracy: 0.5774
# Epoch 11/100
# 405/405 [==============================] - 97s 239ms/step - loss: 0.8737 - accuracy: 0.6653 - val_loss: 1.1672 - val_accuracy: 0.5644
# Epoch 12/100
# 405/405 [==============================] - 95s 234ms/step - loss: 0.8569 - accuracy: 0.6795 - val_loss: 1.2077 - val_accuracy: 0.5538
# Epoch 13/100
# 405/405 [==============================] - 95s 236ms/step - loss: 0.8493 - accuracy: 0.6791 - val_loss: 1.1721 - val_accuracy: 0.5780
# Epoch 14/100
# 405/405 [==============================] - 94s 232ms/step - loss: 0.8272 - accuracy: 0.6877 - val_loss: 1.2222 - val_accuracy: 0.5495
# Epoch 15/100
# 405/405 [==============================] - 93s 228ms/step - loss: 0.8272 - accuracy: 0.6863 - val_loss: 1.1976 - val_accuracy: 0.5693
# Epoch 16/100
# 405/405 [==============================] - 93s 229ms/step - loss: 0.8149 - accuracy: 0.6919 - val_loss: 1.1842 - val_accuracy: 0.5774
# Epoch 17/100
# 405/405 [==============================] - 93s 230ms/step - loss: 0.7942 - accuracy: 0.7010 - val_loss: 1.2832 - val_accuracy: 0.5514
# Epoch 18/100
# 405/405 [==============================] - 93s 230ms/step - loss: 0.7863 - accuracy: 0.6997 - val_loss: 1.2273 - val_accuracy: 0.5619
# Epoch 19/100
# 405/405 [==============================] - 94s 231ms/step - loss: 0.7745 - accuracy: 0.7047 - val_loss: 1.2276 - val_accuracy: 0.5699
# Epoch 20/100
# 405/405 [==============================] - 93s 230ms/step - loss: 0.7645 - accuracy: 0.7124 - val_loss: 1.2163 - val_accuracy: 0.5749
# Epoch 21/100
# 405/405 [==============================] - 94s 231ms/step - loss: 0.7633 - accuracy: 0.7048 - val_loss: 1.2225 - val_accuracy: 0.5712
# Epoch 22/100
# 405/405 [==============================] - 93s 230ms/step - loss: 0.7548 - accuracy: 0.7109 - val_loss: 1.2010 - val_accuracy: 0.5835
# Epoch 23/100
# 405/405 [==============================] - 94s 233ms/step - loss: 0.7455 - accuracy: 0.7157 - val_loss: 1.2325 - val_accuracy: 0.5761
# Epoch 24/100
# 405/405 [==============================] - 93s 230ms/step - loss: 0.7402 - accuracy: 0.7138 - val_loss: 1.2877 - val_accuracy: 0.5705
# Epoch 25/100
# 405/405 [==============================] - 95s 234ms/step - loss: 0.7347 - accuracy: 0.7180 - val_loss: 1.2712 - val_accuracy: 0.5736
# Epoch 26/100
# 405/405 [==============================] - 95s 235ms/step - loss: 0.7215 - accuracy: 0.7230 - val_loss: 1.2887 - val_accuracy: 0.5644
# Epoch 27/100
# 405/405 [==============================] - 95s 235ms/step - loss: 0.7213 - accuracy: 0.7191 - val_loss: 1.2765 - val_accuracy: 0.5724
# Epoch 28/100
# 405/405 [==============================] - 95s 234ms/step - loss: 0.7160 - accuracy: 0.7220 - val_loss: 1.2579 - val_accuracy: 0.5761
# Epoch 29/100
# 405/405 [==============================] - 95s 235ms/step - loss: 0.7063 - accuracy: 0.7268 - val_loss: 1.3004 - val_accuracy: 0.5749
# Epoch 30/100
# 405/405 [==============================] - 95s 234ms/step - loss: 0.7075 - accuracy: 0.7312 - val_loss: 1.2879 - val_accuracy: 0.5619
# Epoch 31/100
# 405/405 [==============================] - 94s 231ms/step - loss: 0.7096 - accuracy: 0.7279 - val_loss: 1.3020 - val_accuracy: 0.5712
# Epoch 32/100
# 405/405 [==============================] - 92s 228ms/step - loss: 0.6930 - accuracy: 0.7339 - val_loss: 1.3199 - val_accuracy: 0.5619
# Epoch 33/100
# 405/405 [==============================] - 92s 227ms/step - loss: 0.6984 - accuracy: 0.7314 - val_loss: 1.3088 - val_accuracy: 0.5712
# Epoch 34/100
# 405/405 [==============================] - 94s 231ms/step - loss: 0.6742 - accuracy: 0.7433 - val_loss: 1.3105 - val_accuracy: 0.5588
# Epoch 35/100
# 405/405 [==============================] - 94s 231ms/step - loss: 0.6839 - accuracy: 0.7407 - val_loss: 1.3479 - val_accuracy: 0.5526
# Epoch 36/100
# 405/405 [==============================] - 95s 235ms/step - loss: 0.6755 - accuracy: 0.7410 - val_loss: 1.3185 - val_accuracy: 0.5668
# Epoch 37/100
# 405/405 [==============================] - 94s 232ms/step - loss: 0.6723 - accuracy: 0.7448 - val_loss: 1.3105 - val_accuracy: 0.5644
# Epoch 38/100
# 405/405 [==============================] - 92s 228ms/step - loss: 0.6761 - accuracy: 0.7374 - val_loss: 1.3978 - val_accuracy: 0.5489
# Epoch 39/100
# 405/405 [==============================] - 92s 226ms/step - loss: 0.6600 - accuracy: 0.7464 - val_loss: 1.3491 - val_accuracy: 0.5693
# Epoch 40/100
# 405/405 [==============================] - 91s 225ms/step - loss: 0.6624 - accuracy: 0.7446 - val_loss: 1.3624 - val_accuracy: 0.5761
# Epoch 41/100
# 405/405 [==============================] - 92s 228ms/step - loss: 0.6718 - accuracy: 0.7413 - val_loss: 1.4290 - val_accuracy: 0.5606
# Epoch 42/100
# 405/405 [==============================] - 92s 227ms/step - loss: 0.6503 - accuracy: 0.7486 - val_loss: 1.4196 - val_accuracy: 0.5371
# Epoch 43/100
# 405/405 [==============================] - 93s 228ms/step - loss: 0.6496 - accuracy: 0.7495 - val_loss: 1.4090 - val_accuracy: 0.5718
# Epoch 44/100
# 405/405 [==============================] - 94s 232ms/step - loss: 0.6519 - accuracy: 0.7494 - val_loss: 1.3801 - val_accuracy: 0.5625
# Epoch 45/100
# 405/405 [==============================] - 93s 231ms/step - loss: 0.6301 - accuracy: 0.7574 - val_loss: 1.4151 - val_accuracy: 0.5538
# Epoch 46/100
# 405/405 [==============================] - 94s 231ms/step - loss: 0.6349 - accuracy: 0.7555 - val_loss: 1.4301 - val_accuracy: 0.5637
# Epoch 47/100
# 405/405 [==============================] - 93s 229ms/step - loss: 0.6262 - accuracy: 0.7575 - val_loss: 1.4067 - val_accuracy: 0.5514
# Epoch 48/100
# 405/405 [==============================] - 94s 231ms/step - loss: 0.6308 - accuracy: 0.7592 - val_loss: 1.4285 - val_accuracy: 0.5575
# Epoch 49/100
# 405/405 [==============================] - 94s 232ms/step - loss: 0.6340 - accuracy: 0.7578 - val_loss: 1.3952 - val_accuracy: 0.5681
# Epoch 50/100
# 405/405 [==============================] - 93s 230ms/step - loss: 0.6249 - accuracy: 0.7605 - val_loss: 1.4126 - val_accuracy: 0.5551
# Epoch 51/100
# 405/405 [==============================] - 92s 227ms/step - loss: 0.6219 - accuracy: 0.7606 - val_loss: 1.4496 - val_accuracy: 0.5439
# Epoch 52/100
# 405/405 [==============================] - 91s 224ms/step - loss: 0.6217 - accuracy: 0.7599 - val_loss: 1.4598 - val_accuracy: 0.5551
# Epoch 53/100
# 405/405 [==============================] - 92s 228ms/step - loss: 0.6297 - accuracy: 0.7595 - val_loss: 1.4571 - val_accuracy: 0.5613
# Epoch 54/100
# 405/405 [==============================] - 93s 229ms/step - loss: 0.6141 - accuracy: 0.7628 - val_loss: 1.4383 - val_accuracy: 0.5514
# Epoch 55/100
# 405/405 [==============================] - 95s 235ms/step - loss: 0.6073 - accuracy: 0.7691 - val_loss: 1.4999 - val_accuracy: 0.5446
# Epoch 56/100
# 405/405 [==============================] - 97s 240ms/step - loss: 0.6074 - accuracy: 0.7663 - val_loss: 1.5251 - val_accuracy: 0.5402
# Epoch 57/100
# 405/405 [==============================] - 93s 230ms/step - loss: 0.6019 - accuracy: 0.7677 - val_loss: 1.4724 - val_accuracy: 0.5563
# Epoch 58/100
# 405/405 [==============================] - 93s 230ms/step - loss: 0.6076 - accuracy: 0.7646 - val_loss: 1.5018 - val_accuracy: 0.5514
# Epoch 59/100
# 405/405 [==============================] - 96s 238ms/step - loss: 0.6029 - accuracy: 0.7668 - val_loss: 1.4981 - val_accuracy: 0.5439
# Epoch 60/100
# 405/405 [==============================] - 96s 236ms/step - loss: 0.5954 - accuracy: 0.7712 - val_loss: 1.4944 - val_accuracy: 0.5575
# Epoch 61/100
# 405/405 [==============================] - 94s 232ms/step - loss: 0.6052 - accuracy: 0.7679 - val_loss: 1.4925 - val_accuracy: 0.5668
# Epoch 62/100
# 405/405 [==============================] - 93s 228ms/step - loss: 0.6002 - accuracy: 0.7681 - val_loss: 1.5159 - val_accuracy: 0.5625
# Epoch 63/100
# 405/405 [==============================] - 93s 231ms/step - loss: 0.5929 - accuracy: 0.7717 - val_loss: 1.5144 - val_accuracy: 0.5495
# Epoch 64/100
# 405/405 [==============================] - 93s 229ms/step - loss: 0.6018 - accuracy: 0.7661 - val_loss: 1.5174 - val_accuracy: 0.5514
# Epoch 65/100
# 405/405 [==============================] - 94s 231ms/step - loss: 0.5862 - accuracy: 0.7742 - val_loss: 1.5529 - val_accuracy: 0.5408
# Epoch 66/100
# 405/405 [==============================] - 96s 238ms/step - loss: 0.5876 - accuracy: 0.7724 - val_loss: 1.5506 - val_accuracy: 0.5464
# Epoch 67/100
# 405/405 [==============================] - 93s 229ms/step - loss: 0.5787 - accuracy: 0.7741 - val_loss: 1.5225 - val_accuracy: 0.5514
# Epoch 68/100
# 405/405 [==============================] - 92s 228ms/step - loss: 0.5776 - accuracy: 0.7795 - val_loss: 1.5676 - val_accuracy: 0.5402
# Epoch 69/100
# 405/405 [==============================] - 92s 227ms/step - loss: 0.5883 - accuracy: 0.7741 - val_loss: 1.5501 - val_accuracy: 0.5415
# Epoch 70/100
# 405/405 [==============================] - 93s 228ms/step - loss: 0.5813 - accuracy: 0.7737 - val_loss: 1.5683 - val_accuracy: 0.5557
# Epoch 71/100
# 405/405 [==============================] - 93s 229ms/step - loss: 0.5746 - accuracy: 0.7805 - val_loss: 1.5775 - val_accuracy: 0.5421
# Epoch 72/100
# 405/405 [==============================] - 93s 231ms/step - loss: 0.5783 - accuracy: 0.7797 - val_loss: 1.6075 - val_accuracy: 0.5538
# Epoch 73/100
# 405/405 [==============================] - 94s 232ms/step - loss: 0.5829 - accuracy: 0.7781 - val_loss: 1.5784 - val_accuracy: 0.5495
# Epoch 74/100
# 405/405 [==============================] - 94s 231ms/step - loss: 0.5677 - accuracy: 0.7814 - val_loss: 1.5849 - val_accuracy: 0.5476
# Epoch 75/100
# 405/405 [==============================] - 93s 229ms/step - loss: 0.5662 - accuracy: 0.7835 - val_loss: 1.5729 - val_accuracy: 0.5507
# Epoch 76/100
# 405/405 [==============================] - 93s 230ms/step - loss: 0.5746 - accuracy: 0.7816 - val_loss: 1.6384 - val_accuracy: 0.5359
# Epoch 77/100
# 405/405 [==============================] - 96s 237ms/step - loss: 0.5727 - accuracy: 0.7771 - val_loss: 1.6781 - val_accuracy: 0.5118
# Epoch 78/100
# 405/405 [==============================] - 96s 237ms/step - loss: 0.5656 - accuracy: 0.7812 - val_loss: 1.5958 - val_accuracy: 0.5551
# Epoch 79/100
# 405/405 [==============================] - 94s 232ms/step - loss: 0.5670 - accuracy: 0.7798 - val_loss: 1.6305 - val_accuracy: 0.5563
# Epoch 80/100
# 405/405 [==============================] - 92s 228ms/step - loss: 0.5554 - accuracy: 0.7875 - val_loss: 1.6594 - val_accuracy: 0.5254
# Epoch 81/100
# 405/405 [==============================] - 96s 238ms/step - loss: 0.5587 - accuracy: 0.7840 - val_loss: 1.6496 - val_accuracy: 0.5303
# Epoch 82/100
# 405/405 [==============================] - 96s 238ms/step - loss: 0.5590 - accuracy: 0.7808 - val_loss: 1.6356 - val_accuracy: 0.5476
# Epoch 83/100
# 405/405 [==============================] - 92s 228ms/step - loss: 0.5538 - accuracy: 0.7876 - val_loss: 1.6363 - val_accuracy: 0.5545
# Epoch 84/100
# 405/405 [==============================] - 93s 230ms/step - loss: 0.5597 - accuracy: 0.7874 - val_loss: 1.6309 - val_accuracy: 0.5377
# Epoch 85/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.5429 - accuracy: 0.7904 - val_loss: 1.6767 - val_accuracy: 0.5427
# Epoch 86/100
# 405/405 [==============================] - 97s 240ms/step - loss: 0.5676 - accuracy: 0.7841 - val_loss: 1.6973 - val_accuracy: 0.5322
# Epoch 87/100
# 405/405 [==============================] - 94s 232ms/step - loss: 0.5501 - accuracy: 0.7900 - val_loss: 1.6522 - val_accuracy: 0.5551
# Epoch 88/100
# 405/405 [==============================] - 93s 231ms/step - loss: 0.5517 - accuracy: 0.7880 - val_loss: 1.6924 - val_accuracy: 0.5334
# Epoch 89/100
# 405/405 [==============================] - 93s 228ms/step - loss: 0.5475 - accuracy: 0.7869 - val_loss: 1.6644 - val_accuracy: 0.5421
# Epoch 90/100
# 405/405 [==============================] - 93s 229ms/step - loss: 0.5462 - accuracy: 0.7889 - val_loss: 1.6601 - val_accuracy: 0.5489
# Epoch 91/100
# 405/405 [==============================] - 92s 228ms/step - loss: 0.5422 - accuracy: 0.7910 - val_loss: 1.6815 - val_accuracy: 0.5514
# Epoch 92/100
# 405/405 [==============================] - 93s 229ms/step - loss: 0.5536 - accuracy: 0.7895 - val_loss: 1.7213 - val_accuracy: 0.5340
# Epoch 93/100
# 405/405 [==============================] - 93s 229ms/step - loss: 0.5387 - accuracy: 0.7937 - val_loss: 1.7454 - val_accuracy: 0.5421
# Epoch 94/100
# 405/405 [==============================] - 93s 230ms/step - loss: 0.5517 - accuracy: 0.7865 - val_loss: 1.6931 - val_accuracy: 0.5446
# Epoch 95/100
# 405/405 [==============================] - 93s 230ms/step - loss: 0.5387 - accuracy: 0.7920 - val_loss: 1.6932 - val_accuracy: 0.5439
# Epoch 96/100
# 405/405 [==============================] - 92s 228ms/step - loss: 0.5377 - accuracy: 0.7973 - val_loss: 1.7195 - val_accuracy: 0.5254
# Epoch 97/100
# 405/405 [==============================] - 92s 226ms/step - loss: 0.5352 - accuracy: 0.7932 - val_loss: 1.7455 - val_accuracy: 0.5291
# Epoch 98/100
# 405/405 [==============================] - 92s 228ms/step - loss: 0.5320 - accuracy: 0.7983 - val_loss: 1.7721 - val_accuracy: 0.5384
# Epoch 99/100
# 405/405 [==============================] - 92s 227ms/step - loss: 0.5365 - accuracy: 0.7931 - val_loss: 1.7229 - val_accuracy: 0.5384
# Epoch 100/100
# 405/405 [==============================] - 93s 229ms/step - loss: 0.5341 - accuracy: 0.7944 - val_loss: 1.7366 - val_accuracy: 0.5390
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %% [markdown]
# # Evaluate Model's Training & Validation Results

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()

# %% [markdown]
# # Generate Predictions With Model

# %%
y_pred = model.predict(test_batches).argmax(axis=1)

# %%
model.evaluate(test_batches)
# Out:
# 51/51 [==============================] - 11s 213ms/step - loss: 1.7663 - accuracy: 0.5267
# [1.7662616968154907, 0.5267080664634705]

# %% [markdown]
# # Evaluate Model's Prediction Results

# %%
# generate classification report
class_labels = list(test_batches.class_indices.keys())
report = classification_report(test_batches.classes, y_pred, target_names=class_labels, output_dict=True)
df_classification_report = pd.DataFrame(report).transpose()
df_classification_report
# Out:
#               precision    recall  f1-score      support
# hatchback      0.352941  0.153846  0.214286   156.000000
# mpv            0.541284  0.546296  0.543779   108.000000
# sedan          0.438114  0.538647  0.483207   414.000000
# sport          0.637717  0.568584  0.601170   452.000000
# suv            0.536145  0.626761  0.577922   284.000000
# truck          0.705036  0.612500  0.655518   160.000000
# wagon          0.180000  0.250000  0.209302    36.000000
# accuracy       0.526708  0.526708  0.526708     0.526708
# macro avg      0.484462  0.470948  0.469312  1610.000000
# weighted avg   0.530867  0.526708  0.522038  1610.000000

# %%
# compute confusion matrix
matrix = confusion_matrix(test_batches.classes, y_pred)

# normalize confusion matrix
matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
matrix = np.around(matrix, decimals=2)

# generate confusion matrix heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(matrix, annot=True, xticklabels=class_labels, yticklabels=class_labels)
plt.ylabel('Test Values')
plt.xlabel('Predicted Values')
# Out:
# Text(0.5, 69.0, 'Predicted Values')

# %% [markdown]
# # Compute Execution Time

# %%
execution_time_s = round(time.time() - start_time, 2)
execution_time_m = round(execution_time_s/60, 2)
execution_time_h = round(execution_time_m/60, 2)

print('Execution Time (Hours):', execution_time_h)
print('Execution Time (Minutes):', execution_time_m)
print('Execution Time (Seconds):', execution_time_s)
# Out:
# Execution Time (Hours): 2.9
# Execution Time (Minutes): 174.15
# Execution Time (Seconds): 10448.93
