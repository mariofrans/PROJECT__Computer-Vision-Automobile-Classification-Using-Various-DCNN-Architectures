# %%
# !pip install pandas numpy seaborn matplotlib tensorflow keras sklearn &> /dev/null

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet50

import time
start_time = time.time()

# %%
PATH_DATA_TRAIN = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/train'
PATH_DATA_TEST = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/test'
PATH_DATA_VALIDATION = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/validation'
PATH_SAVED_MODEL = 'resnet50.h5'

# %% [markdown]
# # Load Dataset As Generators

# %%
generator = ImageDataGenerator(rescale = 1./255.)

target_size = (100, 100)
batch_size = 32

train_batches = generator.flow_from_directory(
    PATH_DATA_TRAIN, class_mode='categorical', 
    batch_size=batch_size, target_size=target_size
)

validation_batches = generator.flow_from_directory(
    PATH_DATA_VALIDATION, class_mode='categorical',  
    batch_size=batch_size, target_size=target_size
)

test_batches = generator.flow_from_directory(
    PATH_DATA_TEST, class_mode='categorical', shuffle=False, 
    batch_size=batch_size, target_size=target_size
)
# Out:
# Found 12959 images belonging to 7 classes.
# Found 1616 images belonging to 7 classes.
# Found 1610 images belonging to 7 classes.

# %%
# preview data (batch size, width, height, colors)
print('x_train shape:', train_batches[0][0].shape)
print('x_validation shape:', validation_batches[0][0].shape)
print('x_test shape:', test_batches[0][0].shape)
print('y_train shape:', train_batches[0][1].shape)
print('y_validation shape:', validation_batches[0][1].shape)
print('y_test shape:', test_batches[0][1].shape)
# Out:
# x_train shape: (32, 100, 100, 3)
# x_validation shape: (32, 100, 100, 3)
# x_test shape: (32, 100, 100, 3)
# y_train shape: (32, 7)
# y_validation shape: (32, 7)
# y_test shape: (32, 7)

# %%
# input & output shape
input_shape = train_batches[0][0][0].shape
output_shape = len(train_batches[0][1][0])

# display input & output shape
print('Input Shape:', input_shape)
print('Output Shape:', output_shape)
# Out:
# Input Shape: (100, 100, 3)
# Output Shape: 7

# %% [markdown]
# # Build & Compile Model

# %%
model = ResNet50(
    input_shape=input_shape,
    classes=output_shape,
    weights=None,
    classifier_activation='softmax'
)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# 2022-11-09 07:50:46.236947: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 07:50:46.237935: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 07:50:46.390175: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 07:50:46.391203: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 07:50:46.392027: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 07:50:46.392798: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 07:50:46.394286: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-09 07:50:46.632704: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 07:50:46.633615: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 07:50:46.634367: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 07:50:46.635148: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 07:50:46.635869: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 07:50:46.636592: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 07:50:50.114032: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 07:50:50.115125: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 07:50:50.115888: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 07:50:50.116662: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 07:50:50.117396: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 07:50:50.118114: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-11-09 07:50:50.122539: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 07:50:50.123221: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 106, 106, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 50, 50, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 50, 50, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 50, 50, 64)   0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 52, 52, 64)   0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 25, 25, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 25, 25, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 25, 25, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 25, 25, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 25, 25, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 25, 25, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 25, 25, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 25, 25, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 25, 25, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 25, 25, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 25, 25, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 25, 25, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 25, 25, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 25, 25, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 25, 25, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 25, 25, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 25, 25, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 25, 25, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 25, 25, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 25, 25, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 25, 25, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 25, 25, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 25, 25, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 25, 25, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 25, 25, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 25, 25, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 25, 25, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 25, 25, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 25, 25, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 25, 25, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 25, 25, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 25, 25, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 25, 25, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 13, 13, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 13, 13, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 13, 13, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 13, 13, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 13, 13, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 13, 13, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 13, 13, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 13, 13, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 13, 13, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 13, 13, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 13, 13, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 13, 13, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 13, 13, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 13, 13, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 13, 13, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 13, 13, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 13, 13, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 13, 13, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 13, 13, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 13, 13, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 13, 13, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 13, 13, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 13, 13, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 13, 13, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 13, 13, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 13, 13, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 13, 13, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 13, 13, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 13, 13, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 13, 13, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 13, 13, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 13, 13, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 13, 13, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 13, 13, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 7, 7, 256)    131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 7, 7, 256)    0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 7, 7, 256)    590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 7, 7, 256)    0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 7, 7, 1024)   525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 7, 7, 1024)   263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 7, 7, 1024)   4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 7, 7, 1024)   4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 7, 7, 1024)   0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 7, 7, 1024)   0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 7, 7, 256)    262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 7, 7, 256)    0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 7, 7, 256)    590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 7, 7, 256)    0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 7, 7, 1024)   263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 7, 7, 1024)   4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 7, 7, 1024)   0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 7, 7, 1024)   0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 7, 7, 256)    262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 7, 7, 256)    0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 7, 7, 256)    590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 7, 7, 256)    0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 7, 7, 1024)   263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 7, 7, 1024)   4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 7, 7, 1024)   0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 7, 7, 1024)   0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 7, 7, 256)    262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 7, 7, 256)    0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 7, 7, 256)    590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 7, 7, 256)    0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 7, 7, 1024)   263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 7, 7, 1024)   4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 7, 7, 1024)   0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 7, 7, 1024)   0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 7, 7, 256)    262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 7, 7, 256)    0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 7, 7, 256)    590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 7, 7, 256)    0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 7, 7, 1024)   263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 7, 7, 1024)   4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 7, 7, 1024)   0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 7, 7, 1024)   0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 7, 7, 256)    262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 7, 7, 256)    0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 7, 7, 256)    590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 7, 7, 256)    0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 7, 7, 1024)   263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 7, 7, 1024)   4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 7, 7, 1024)   0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 7, 7, 1024)   0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 4, 4, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 4, 4, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 4, 4, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 4, 4, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 4, 4, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 4, 4, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 4, 4, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 4, 4, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 4, 4, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 4, 4, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 4, 4, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 4, 4, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 4, 4, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 4, 4, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 4, 4, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 4, 4, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 4, 4, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 4, 4, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 4, 4, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 4, 4, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 4, 4, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 4, 4, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 4, 4, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 4, 4, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 4, 4, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 4, 4, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 4, 4, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 4, 4, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 4, 4, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 4, 4, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 4, 4, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 4, 4, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 7)            14343       avg_pool[0][0]
# ==================================================================================================
# Total params: 23,602,055
# Trainable params: 23,548,935
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [markdown]
# # Train Model

# %%
# train model
r = model.fit(train_batches, validation_data=validation_batches, epochs=100)

# save model
model.save(PATH_SAVED_MODEL)

# load model
# model = load_model(PATH_SAVED_MODEL)
# Out:
# 2022-11-09 07:50:51.822035: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-11-09 07:50:59.454500: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 405/405 [==============================] - 179s 402ms/step - loss: 1.8067 - accuracy: 0.3447 - val_loss: 2.1895 - val_accuracy: 0.2915
# Epoch 2/100
# 405/405 [==============================] - 112s 277ms/step - loss: 1.4423 - accuracy: 0.4673 - val_loss: 2.5064 - val_accuracy: 0.3243
# Epoch 3/100
# 405/405 [==============================] - 111s 275ms/step - loss: 1.2118 - accuracy: 0.5506 - val_loss: 2.7545 - val_accuracy: 0.3595
# Epoch 4/100
# 405/405 [==============================] - 112s 275ms/step - loss: 1.0244 - accuracy: 0.6223 - val_loss: 1.8887 - val_accuracy: 0.4394
# Epoch 5/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.9050 - accuracy: 0.6599 - val_loss: 2.5401 - val_accuracy: 0.4381
# Epoch 6/100
# 405/405 [==============================] - 112s 277ms/step - loss: 0.8284 - accuracy: 0.6910 - val_loss: 1.9422 - val_accuracy: 0.4462
# Epoch 7/100
# 405/405 [==============================] - 112s 275ms/step - loss: 0.7431 - accuracy: 0.7227 - val_loss: 1.7794 - val_accuracy: 0.5173
# Epoch 8/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.7055 - accuracy: 0.7366 - val_loss: 5.7463 - val_accuracy: 0.3038
# Epoch 9/100
# 405/405 [==============================] - 111s 275ms/step - loss: 0.6317 - accuracy: 0.7677 - val_loss: 1.6304 - val_accuracy: 0.5959
# Epoch 10/100
# 405/405 [==============================] - 112s 275ms/step - loss: 0.5778 - accuracy: 0.7795 - val_loss: 6.4602 - val_accuracy: 0.2444
# Epoch 11/100
# 405/405 [==============================] - 112s 275ms/step - loss: 0.5153 - accuracy: 0.8119 - val_loss: 1.9038 - val_accuracy: 0.5408
# Epoch 12/100
# 405/405 [==============================] - 112s 275ms/step - loss: 0.5313 - accuracy: 0.8063 - val_loss: 2.0082 - val_accuracy: 0.4270
# Epoch 13/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.4279 - accuracy: 0.8452 - val_loss: 2.2709 - val_accuracy: 0.4975
# Epoch 14/100
# 405/405 [==============================] - 111s 275ms/step - loss: 0.3860 - accuracy: 0.8531 - val_loss: 1.1039 - val_accuracy: 0.6578
# Epoch 15/100
# 405/405 [==============================] - 112s 275ms/step - loss: 0.3499 - accuracy: 0.8697 - val_loss: 2.9097 - val_accuracy: 0.4004
# Epoch 16/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.2865 - accuracy: 0.8934 - val_loss: 2.3365 - val_accuracy: 0.4722
# Epoch 17/100
# 405/405 [==============================] - 112s 277ms/step - loss: 0.3309 - accuracy: 0.8813 - val_loss: 2.9453 - val_accuracy: 0.5025
# Epoch 18/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.2531 - accuracy: 0.9068 - val_loss: 1.8383 - val_accuracy: 0.5854
# Epoch 19/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.2126 - accuracy: 0.9230 - val_loss: 1.7068 - val_accuracy: 0.5879
# Epoch 20/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.2049 - accuracy: 0.9277 - val_loss: 2.4024 - val_accuracy: 0.5365
# Epoch 21/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.1747 - accuracy: 0.9383 - val_loss: 4.0831 - val_accuracy: 0.3806
# Epoch 22/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.1517 - accuracy: 0.9457 - val_loss: 4.2185 - val_accuracy: 0.3800
# Epoch 23/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.3246 - accuracy: 0.8910 - val_loss: 1.5391 - val_accuracy: 0.5811
# Epoch 24/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.1701 - accuracy: 0.9404 - val_loss: 2.3774 - val_accuracy: 0.5545
# Epoch 25/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.0949 - accuracy: 0.9665 - val_loss: 1.6155 - val_accuracy: 0.6825
# Epoch 26/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.0928 - accuracy: 0.9668 - val_loss: 13.2037 - val_accuracy: 0.3540
# Epoch 27/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.1418 - accuracy: 0.9530 - val_loss: 3.8148 - val_accuracy: 0.4394
# Epoch 28/100
# 405/405 [==============================] - 110s 271ms/step - loss: 0.2863 - accuracy: 0.9055 - val_loss: 3.5814 - val_accuracy: 0.4356
# Epoch 29/100
# 405/405 [==============================] - 110s 271ms/step - loss: 0.1395 - accuracy: 0.9529 - val_loss: 1.7534 - val_accuracy: 0.6621
# Epoch 30/100
# 405/405 [==============================] - 110s 271ms/step - loss: 0.0427 - accuracy: 0.9863 - val_loss: 1.7964 - val_accuracy: 0.6894
# Epoch 31/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.0987 - accuracy: 0.9657 - val_loss: 3.0151 - val_accuracy: 0.5470
# Epoch 32/100
# 405/405 [==============================] - 110s 271ms/step - loss: 0.1347 - accuracy: 0.9548 - val_loss: 1.7486 - val_accuracy: 0.6324
# Epoch 33/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.0526 - accuracy: 0.9819 - val_loss: 2.2577 - val_accuracy: 0.6182
# Epoch 34/100
# 405/405 [==============================] - 109s 270ms/step - loss: 0.0563 - accuracy: 0.9820 - val_loss: 1.6786 - val_accuracy: 0.6627
# Epoch 35/100
# 405/405 [==============================] - 110s 270ms/step - loss: 0.0579 - accuracy: 0.9811 - val_loss: 1.7112 - val_accuracy: 0.6850
# Epoch 36/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.0733 - accuracy: 0.9754 - val_loss: 2.2242 - val_accuracy: 0.5922
# Epoch 37/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.0851 - accuracy: 0.9709 - val_loss: 4.4108 - val_accuracy: 0.4295
# Epoch 38/100
# 405/405 [==============================] - 111s 273ms/step - loss: 0.1107 - accuracy: 0.9625 - val_loss: 2.1224 - val_accuracy: 0.6033
# Epoch 39/100
# 405/405 [==============================] - 113s 279ms/step - loss: 0.0479 - accuracy: 0.9828 - val_loss: 3.9554 - val_accuracy: 0.5012
# Epoch 40/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.0370 - accuracy: 0.9881 - val_loss: 1.9954 - val_accuracy: 0.6510
# Epoch 41/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.0594 - accuracy: 0.9814 - val_loss: 1.6312 - val_accuracy: 0.6986
# Epoch 42/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.2638 - accuracy: 0.9229 - val_loss: 2.7860 - val_accuracy: 0.5316
# Epoch 43/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.0330 - accuracy: 0.9910 - val_loss: 1.7106 - val_accuracy: 0.6838
# Epoch 44/100
# 405/405 [==============================] - 113s 278ms/step - loss: 0.0271 - accuracy: 0.9907 - val_loss: 1.8956 - val_accuracy: 0.6696
# Epoch 45/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.0815 - accuracy: 0.9741 - val_loss: 2.3659 - val_accuracy: 0.6139
# Epoch 46/100
# 405/405 [==============================] - 111s 273ms/step - loss: 0.0666 - accuracy: 0.9771 - val_loss: 1.7333 - val_accuracy: 0.6819
# Epoch 47/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.0473 - accuracy: 0.9852 - val_loss: 2.3373 - val_accuracy: 0.6386
# Epoch 48/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.0626 - accuracy: 0.9807 - val_loss: 2.8970 - val_accuracy: 0.6021
# Epoch 49/100
# 405/405 [==============================] - 110s 271ms/step - loss: 0.0316 - accuracy: 0.9893 - val_loss: 1.9960 - val_accuracy: 0.6887
# Epoch 50/100
# 405/405 [==============================] - 110s 271ms/step - loss: 0.0400 - accuracy: 0.9870 - val_loss: 1.8622 - val_accuracy: 0.6856
# Epoch 51/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.0553 - accuracy: 0.9816 - val_loss: 2.0751 - val_accuracy: 0.6572
# Epoch 52/100
# 405/405 [==============================] - 111s 273ms/step - loss: 0.0405 - accuracy: 0.9861 - val_loss: 2.0374 - val_accuracy: 0.6269
# Epoch 53/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.0381 - accuracy: 0.9870 - val_loss: 1.4807 - val_accuracy: 0.7160
# Epoch 54/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.0371 - accuracy: 0.9880 - val_loss: 1.6419 - val_accuracy: 0.7110
# Epoch 55/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.0376 - accuracy: 0.9881 - val_loss: 1.5368 - val_accuracy: 0.7178
# Epoch 56/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.0440 - accuracy: 0.9853 - val_loss: 2.1757 - val_accuracy: 0.6300
# Epoch 57/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.0343 - accuracy: 0.9881 - val_loss: 1.9416 - val_accuracy: 0.6751
# Epoch 58/100
# 405/405 [==============================] - 110s 271ms/step - loss: 0.0298 - accuracy: 0.9899 - val_loss: 4.2789 - val_accuracy: 0.4660
# Epoch 59/100
# 405/405 [==============================] - 110s 271ms/step - loss: 0.0708 - accuracy: 0.9771 - val_loss: 3.8260 - val_accuracy: 0.4851
# Epoch 60/100
# 405/405 [==============================] - 110s 271ms/step - loss: 0.1337 - accuracy: 0.9571 - val_loss: 1.3638 - val_accuracy: 0.7166
# Epoch 61/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.0079 - accuracy: 0.9985 - val_loss: 1.4005 - val_accuracy: 0.7395
# Epoch 62/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 1.5980 - val_accuracy: 0.7358
# Epoch 63/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.0061 - accuracy: 0.9976 - val_loss: 2.1759 - val_accuracy: 0.6795
# Epoch 64/100
# 405/405 [==============================] - 111s 275ms/step - loss: 0.0513 - accuracy: 0.9829 - val_loss: 1.7182 - val_accuracy: 0.7067
# Epoch 65/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.0424 - accuracy: 0.9857 - val_loss: 1.8137 - val_accuracy: 0.6980
# Epoch 66/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.0225 - accuracy: 0.9931 - val_loss: 1.8092 - val_accuracy: 0.6974
# Epoch 67/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.0102 - accuracy: 0.9964 - val_loss: 2.1372 - val_accuracy: 0.6813
# Epoch 68/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.0604 - accuracy: 0.9812 - val_loss: 1.5305 - val_accuracy: 0.7234
# Epoch 69/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.0234 - accuracy: 0.9925 - val_loss: 1.7429 - val_accuracy: 0.7283
# Epoch 70/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.0602 - accuracy: 0.9802 - val_loss: 1.9813 - val_accuracy: 0.6368
# Epoch 71/100
# 405/405 [==============================] - 108s 265ms/step - loss: 0.0181 - accuracy: 0.9937 - val_loss: 2.3199 - val_accuracy: 0.6077
# Epoch 72/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.0307 - accuracy: 0.9894 - val_loss: 1.9763 - val_accuracy: 0.6683
# Epoch 73/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.0366 - accuracy: 0.9874 - val_loss: 1.9532 - val_accuracy: 0.6943
# Epoch 74/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.0268 - accuracy: 0.9913 - val_loss: 2.0518 - val_accuracy: 0.7104
# Epoch 75/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.0145 - accuracy: 0.9946 - val_loss: 1.7254 - val_accuracy: 0.7438
# Epoch 76/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.0340 - accuracy: 0.9895 - val_loss: 2.0699 - val_accuracy: 0.6887
# Epoch 77/100
# 405/405 [==============================] - 109s 270ms/step - loss: 0.0330 - accuracy: 0.9886 - val_loss: 2.1263 - val_accuracy: 0.6962
# Epoch 78/100
# 405/405 [==============================] - 109s 270ms/step - loss: 0.0157 - accuracy: 0.9944 - val_loss: 1.7864 - val_accuracy: 0.7123
# Epoch 79/100
# 405/405 [==============================] - 110s 270ms/step - loss: 0.0118 - accuracy: 0.9965 - val_loss: 2.7755 - val_accuracy: 0.6553
# Epoch 80/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.0601 - accuracy: 0.9816 - val_loss: 1.7079 - val_accuracy: 0.7290
# Epoch 81/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.0116 - accuracy: 0.9959 - val_loss: 1.6807 - val_accuracy: 0.7085
# Epoch 82/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.0080 - accuracy: 0.9977 - val_loss: 1.8735 - val_accuracy: 0.7160
# Epoch 83/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.0376 - accuracy: 0.9887 - val_loss: 2.0365 - val_accuracy: 0.7036
# Epoch 84/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.0205 - accuracy: 0.9929 - val_loss: 1.6952 - val_accuracy: 0.7481
# Epoch 85/100
# 405/405 [==============================] - 111s 275ms/step - loss: 0.0079 - accuracy: 0.9977 - val_loss: 2.3659 - val_accuracy: 0.6460
# Epoch 86/100
# 405/405 [==============================] - 111s 273ms/step - loss: 0.0604 - accuracy: 0.9826 - val_loss: 1.5690 - val_accuracy: 0.7079
# Epoch 87/100
# 405/405 [==============================] - 109s 270ms/step - loss: 0.0295 - accuracy: 0.9888 - val_loss: 1.8144 - val_accuracy: 0.7240
# Epoch 88/100
# 405/405 [==============================] - 110s 270ms/step - loss: 0.0355 - accuracy: 0.9900 - val_loss: 1.5014 - val_accuracy: 0.7420
# Epoch 89/100
# 405/405 [==============================] - 111s 273ms/step - loss: 0.0092 - accuracy: 0.9976 - val_loss: 1.6081 - val_accuracy: 0.7426
# Epoch 90/100
# 405/405 [==============================] - 110s 270ms/step - loss: 0.0147 - accuracy: 0.9952 - val_loss: 1.9001 - val_accuracy: 0.7085
# Epoch 91/100
# 405/405 [==============================] - 110s 270ms/step - loss: 0.0166 - accuracy: 0.9941 - val_loss: 1.8409 - val_accuracy: 0.7215
# Epoch 92/100
# 405/405 [==============================] - 111s 273ms/step - loss: 0.0194 - accuracy: 0.9930 - val_loss: 3.1634 - val_accuracy: 0.6126
# Epoch 93/100
# 405/405 [==============================] - 109s 270ms/step - loss: 0.0263 - accuracy: 0.9918 - val_loss: 2.5636 - val_accuracy: 0.6108
# Epoch 94/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.0240 - accuracy: 0.9920 - val_loss: 1.9578 - val_accuracy: 0.7228
# Epoch 95/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.0122 - accuracy: 0.9954 - val_loss: 4.0952 - val_accuracy: 0.4994
# Epoch 96/100
# 405/405 [==============================] - 108s 268ms/step - loss: 0.0171 - accuracy: 0.9945 - val_loss: 2.4161 - val_accuracy: 0.6875
# Epoch 97/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.0422 - accuracy: 0.9876 - val_loss: 4.6037 - val_accuracy: 0.4635
# Epoch 98/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.0231 - accuracy: 0.9917 - val_loss: 2.2461 - val_accuracy: 0.6894
# Epoch 99/100
# 405/405 [==============================] - 108s 265ms/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 1.8681 - val_accuracy: 0.7259
# Epoch 100/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 1.8759 - val_accuracy: 0.7413
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %% [markdown]
# # Evaluate Model's Training & Validation Results

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()

# %% [markdown]
# # Generate Predictions With Model

# %%
y_pred = model.predict(test_batches).argmax(axis=1)

# %%
model.evaluate(test_batches)
# Out:
# 51/51 [==============================] - 12s 238ms/step - loss: 1.8040 - accuracy: 0.7422
# [1.8040446043014526, 0.7422360181808472]

# %% [markdown]
# # Evaluate Model's Prediction Results

# %%
# generate classification report
class_labels = list(test_batches.class_indices.keys())
report = classification_report(test_batches.classes, y_pred, target_names=class_labels, output_dict=True)
df_classification_report = pd.DataFrame(report).transpose()
df_classification_report
# Out:
#               precision    recall  f1-score      support
# hatchback      0.575221  0.416667  0.483271   156.000000
# mpv            0.817204  0.703704  0.756219   108.000000
# sedan          0.697674  0.724638  0.710900   414.000000
# sport          0.778523  0.769912  0.774194   452.000000
# suv            0.756173  0.862676  0.805921   284.000000
# truck          0.803191  0.943750  0.867816   160.000000
# wagon          0.666667  0.277778  0.392157    36.000000
# accuracy       0.742236  0.742236  0.742236     0.742236
# macro avg      0.727808  0.671303  0.684354  1610.000000
# weighted avg   0.736637  0.742236  0.734882  1610.000000

# %%
# compute confusion matrix
matrix = confusion_matrix(test_batches.classes, y_pred)

# normalize confusion matrix
matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
matrix = np.around(matrix, decimals=2)

# generate confusion matrix heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(matrix, annot=True, xticklabels=class_labels, yticklabels=class_labels)
plt.ylabel('Test Values')
plt.xlabel('Predicted Values')
# Out:
# Text(0.5, 69.0, 'Predicted Values')

# %% [markdown]
# # Compute Execution Time

# %%
execution_time_s = round(time.time() - start_time, 2)
execution_time_m = round(execution_time_s/60, 2)
execution_time_h = round(execution_time_m/60, 2)

print('Execution Time (Hours):', execution_time_h)
print('Execution Time (Minutes):', execution_time_m)
print('Execution Time (Seconds):', execution_time_s)
# Out:
# Execution Time (Hours): 2.96
# Execution Time (Minutes): 177.57
# Execution Time (Seconds): 10654.07
