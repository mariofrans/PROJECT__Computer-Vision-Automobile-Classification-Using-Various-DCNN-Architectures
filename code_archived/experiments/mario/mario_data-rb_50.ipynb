# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout, GlobalMaxPooling2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
PATH_DATA = '../input/cars-data/data_remove_bg/data_remove_bg'

# %%
generator = ImageDataGenerator(rescale = 1./255., validation_split=0.2, width_shift_range=[1, 2, 3, 4, 5, 6, 7])

target_size = (50, 50)
batch_size = 32

train_batches = generator.flow_from_directory(
    PATH_DATA, class_mode='categorical', subset='training',
    batch_size=batch_size, target_size=target_size
)

test_batches = generator.flow_from_directory(
    PATH_DATA, class_mode='categorical', subset='validation', 
    batch_size=batch_size, target_size=target_size
)

validation_batches = generator.flow_from_directory(
    PATH_DATA, class_mode='categorical', subset='validation', 
    batch_size=batch_size, target_size=target_size
)
# Out:
# Found 12951 images belonging to 7 classes.
# Found 3234 images belonging to 7 classes.
# Found 3234 images belonging to 7 classes.

# %%
# preview data (batch size, width, height, colors)
print('x_train shape: ', train_batches[0][0].shape)
print('x_test shape: ', test_batches[0][0].shape)
print('y_train shape: ', train_batches[0][1].shape)
print('y_test shape: ', test_batches[0][1].shape)
# Out:
# x_train shape:  (32, 50, 50, 3)
# x_test shape:  (32, 50, 50, 3)
# y_train shape:  (32, 7)
# y_test shape:  (32, 7)

# %%
# input shape
input_shape = train_batches[0][0][0].shape
input_shape
# Out:
# (50, 50, 3)

# %%
# output shape
output_shape = len(train_batches[0][1][0])
output_shape
# Out:
# 7

# %%
# build model
i = Input(shape=input_shape)

x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = BatchNormalization()(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Flatten()(x)
x = Dropout(0.2)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(output_shape, activation='softmax')(x)

model = Model(i, x)

# compile & fit model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# 2022-09-18 00:40:23.126152: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-18 00:40:23.216719: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-18 00:40:23.217556: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-18 00:40:23.219222: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-18 00:40:23.219491: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-18 00:40:23.220196: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-18 00:40:23.220811: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-18 00:40:25.311565: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-18 00:40:25.312368: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-18 00:40:25.313019: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-18 00:40:25.313594: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 50, 50, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 50, 50, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 50, 50, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 50, 50, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 50, 50, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 25, 25, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 25, 25, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 25, 25, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 25, 25, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 12, 12, 128)       73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 128)       147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              4719616
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 7175
# =================================================================
# Total params: 5,015,591
# Trainable params: 5,014,695
# Non-trainable params: 896
# _________________________________________________________________

# %%
r = model.fit(train_batches, validation_data=validation_batches, epochs=100)
# Out:
# 2022-09-18 00:40:26.222847: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-09-18 00:40:28.449052: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 405/405 [==============================] - 221s 528ms/step - loss: 2.0075 - accuracy: 0.3145 - val_loss: 1.7923 - val_accuracy: 0.2934
# Epoch 2/100
# 405/405 [==============================] - 107s 265ms/step - loss: 1.5686 - accuracy: 0.3790 - val_loss: 2.0608 - val_accuracy: 0.2223
# Epoch 3/100
# 405/405 [==============================] - 108s 267ms/step - loss: 1.4252 - accuracy: 0.4300 - val_loss: 1.4272 - val_accuracy: 0.4335
# Epoch 4/100
# 405/405 [==============================] - 107s 265ms/step - loss: 1.3395 - accuracy: 0.4753 - val_loss: 1.7117 - val_accuracy: 0.3686
# Epoch 5/100
# 405/405 [==============================] - 107s 265ms/step - loss: 1.2386 - accuracy: 0.5224 - val_loss: 1.9163 - val_accuracy: 0.3655
# Epoch 6/100
# 405/405 [==============================] - 107s 265ms/step - loss: 1.1447 - accuracy: 0.5648 - val_loss: 1.3917 - val_accuracy: 0.4719
# Epoch 7/100
# 405/405 [==============================] - 107s 264ms/step - loss: 1.0624 - accuracy: 0.5925 - val_loss: 1.1891 - val_accuracy: 0.5557
# Epoch 8/100
# 405/405 [==============================] - 108s 267ms/step - loss: 1.0059 - accuracy: 0.6142 - val_loss: 2.3882 - val_accuracy: 0.3698
# Epoch 9/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.9433 - accuracy: 0.6433 - val_loss: 1.3277 - val_accuracy: 0.5544
# Epoch 10/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.8928 - accuracy: 0.6603 - val_loss: 1.0440 - val_accuracy: 0.6135
# Epoch 11/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.8529 - accuracy: 0.6800 - val_loss: 1.1789 - val_accuracy: 0.6011
# Epoch 12/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.7874 - accuracy: 0.7073 - val_loss: 1.0823 - val_accuracy: 0.6209
# Epoch 13/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.7524 - accuracy: 0.7171 - val_loss: 1.4822 - val_accuracy: 0.5445
# Epoch 14/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.7037 - accuracy: 0.7357 - val_loss: 1.0561 - val_accuracy: 0.6262
# Epoch 15/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.6696 - accuracy: 0.7533 - val_loss: 1.0727 - val_accuracy: 0.6070
# Epoch 16/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.6171 - accuracy: 0.7708 - val_loss: 0.9789 - val_accuracy: 0.6472
# Epoch 17/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.5857 - accuracy: 0.7872 - val_loss: 1.0239 - val_accuracy: 0.6444
# Epoch 18/100
# 405/405 [==============================] - 108s 268ms/step - loss: 0.5414 - accuracy: 0.8051 - val_loss: 1.0029 - val_accuracy: 0.6874
# Epoch 19/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.5044 - accuracy: 0.8133 - val_loss: 1.1734 - val_accuracy: 0.6249
# Epoch 20/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.4718 - accuracy: 0.8294 - val_loss: 1.0925 - val_accuracy: 0.6608
# Epoch 21/100
# 405/405 [==============================] - 106s 263ms/step - loss: 0.4600 - accuracy: 0.8314 - val_loss: 1.0194 - val_accuracy: 0.6920
# Epoch 22/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.4222 - accuracy: 0.8480 - val_loss: 2.2580 - val_accuracy: 0.5368
# Epoch 23/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.4083 - accuracy: 0.8522 - val_loss: 1.2366 - val_accuracy: 0.6750
# Epoch 24/100
# 405/405 [==============================] - 107s 266ms/step - loss: 0.3847 - accuracy: 0.8635 - val_loss: 1.0407 - val_accuracy: 0.6988
# Epoch 25/100
# 405/405 [==============================] - 106s 263ms/step - loss: 0.3679 - accuracy: 0.8695 - val_loss: 1.3279 - val_accuracy: 0.6497
# Epoch 26/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.3435 - accuracy: 0.8747 - val_loss: 1.1289 - val_accuracy: 0.6948
# Epoch 27/100
# 405/405 [==============================] - 108s 268ms/step - loss: 0.3070 - accuracy: 0.8900 - val_loss: 1.2322 - val_accuracy: 0.6670
# Epoch 28/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.2940 - accuracy: 0.8963 - val_loss: 1.2701 - val_accuracy: 0.6713
# Epoch 29/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.2921 - accuracy: 0.8980 - val_loss: 1.2932 - val_accuracy: 0.6688
# Epoch 30/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.2667 - accuracy: 0.9047 - val_loss: 1.0570 - val_accuracy: 0.7093
# Epoch 31/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.2581 - accuracy: 0.9087 - val_loss: 1.2115 - val_accuracy: 0.6929
# Epoch 32/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.2413 - accuracy: 0.9146 - val_loss: 1.2093 - val_accuracy: 0.7053
# Epoch 33/100
# 405/405 [==============================] - 108s 268ms/step - loss: 0.2384 - accuracy: 0.9160 - val_loss: 1.2249 - val_accuracy: 0.7059
# Epoch 34/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.2322 - accuracy: 0.9200 - val_loss: 1.3263 - val_accuracy: 0.7056
# Epoch 35/100
# 405/405 [==============================] - 108s 265ms/step - loss: 0.2259 - accuracy: 0.9205 - val_loss: 2.4438 - val_accuracy: 0.6274
# Epoch 36/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.2129 - accuracy: 0.9233 - val_loss: 3.0840 - val_accuracy: 0.4997
# Epoch 37/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.2009 - accuracy: 0.9310 - val_loss: 1.3293 - val_accuracy: 0.6982
# Epoch 38/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.1989 - accuracy: 0.9327 - val_loss: 1.4085 - val_accuracy: 0.6837
# Epoch 39/100
# 405/405 [==============================] - 107s 266ms/step - loss: 0.1817 - accuracy: 0.9377 - val_loss: 1.4607 - val_accuracy: 0.6923
# Epoch 40/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.1857 - accuracy: 0.9382 - val_loss: 3.3059 - val_accuracy: 0.6135
# Epoch 41/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.1748 - accuracy: 0.9415 - val_loss: 1.9380 - val_accuracy: 0.6382
# Epoch 42/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.1840 - accuracy: 0.9376 - val_loss: 1.3426 - val_accuracy: 0.6827
# Epoch 43/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.1651 - accuracy: 0.9453 - val_loss: 3.5766 - val_accuracy: 0.5368
# Epoch 44/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.1569 - accuracy: 0.9450 - val_loss: 1.3775 - val_accuracy: 0.7004
# Epoch 45/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.1680 - accuracy: 0.9452 - val_loss: 1.4119 - val_accuracy: 0.6960
# Epoch 46/100
# 405/405 [==============================] - 108s 265ms/step - loss: 0.1643 - accuracy: 0.9447 - val_loss: 1.3323 - val_accuracy: 0.6979
# Epoch 47/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.1529 - accuracy: 0.9495 - val_loss: 1.3672 - val_accuracy: 0.6849
# Epoch 48/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.1385 - accuracy: 0.9535 - val_loss: 1.2511 - val_accuracy: 0.7205
# Epoch 49/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.1483 - accuracy: 0.9517 - val_loss: 1.5981 - val_accuracy: 0.6790
# Epoch 50/100
# 405/405 [==============================] - 108s 268ms/step - loss: 0.1444 - accuracy: 0.9525 - val_loss: 1.7422 - val_accuracy: 0.6500
# Epoch 51/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.1389 - accuracy: 0.9538 - val_loss: 1.9956 - val_accuracy: 0.6620
# Epoch 52/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.1281 - accuracy: 0.9577 - val_loss: 1.8633 - val_accuracy: 0.6271
# Epoch 53/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.1119 - accuracy: 0.9619 - val_loss: 2.1973 - val_accuracy: 0.6562
# Epoch 54/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.1266 - accuracy: 0.9581 - val_loss: 2.5994 - val_accuracy: 0.6231
# Epoch 55/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.1300 - accuracy: 0.9585 - val_loss: 1.5431 - val_accuracy: 0.7010
# Epoch 56/100
# 405/405 [==============================] - 107s 263ms/step - loss: 0.1169 - accuracy: 0.9573 - val_loss: 3.2188 - val_accuracy: 0.5940
# Epoch 57/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.1261 - accuracy: 0.9571 - val_loss: 7.1369 - val_accuracy: 0.5622
# Epoch 58/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.1115 - accuracy: 0.9632 - val_loss: 1.4783 - val_accuracy: 0.7177
# Epoch 59/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.1274 - accuracy: 0.9578 - val_loss: 1.5178 - val_accuracy: 0.7044
# Epoch 60/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.1175 - accuracy: 0.9620 - val_loss: 2.2540 - val_accuracy: 0.6500
# Epoch 61/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.1269 - accuracy: 0.9591 - val_loss: 1.8761 - val_accuracy: 0.6599
# Epoch 62/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.1140 - accuracy: 0.9636 - val_loss: 8.4157 - val_accuracy: 0.5306
# Epoch 63/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.1023 - accuracy: 0.9674 - val_loss: 1.6944 - val_accuracy: 0.6994
# Epoch 64/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.1102 - accuracy: 0.9654 - val_loss: 1.3382 - val_accuracy: 0.7242
# Epoch 65/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.0983 - accuracy: 0.9681 - val_loss: 1.6837 - val_accuracy: 0.6929
# Epoch 66/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.1082 - accuracy: 0.9640 - val_loss: 1.5950 - val_accuracy: 0.7149
# Epoch 67/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.0964 - accuracy: 0.9682 - val_loss: 1.4931 - val_accuracy: 0.7001
# Epoch 68/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.0832 - accuracy: 0.9720 - val_loss: 1.3764 - val_accuracy: 0.7010
# Epoch 69/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.0977 - accuracy: 0.9669 - val_loss: 1.5488 - val_accuracy: 0.6976
# Epoch 70/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.1035 - accuracy: 0.9649 - val_loss: 1.6401 - val_accuracy: 0.6874
# Epoch 71/100
# 405/405 [==============================] - 108s 268ms/step - loss: 0.0916 - accuracy: 0.9690 - val_loss: 3.1573 - val_accuracy: 0.6147
# Epoch 72/100
# 405/405 [==============================] - 108s 268ms/step - loss: 0.0923 - accuracy: 0.9696 - val_loss: 1.8571 - val_accuracy: 0.6929
# Epoch 73/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.0888 - accuracy: 0.9707 - val_loss: 2.6864 - val_accuracy: 0.6639
# Epoch 74/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.0922 - accuracy: 0.9712 - val_loss: 8.7497 - val_accuracy: 0.5597
# Epoch 75/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.0971 - accuracy: 0.9685 - val_loss: 1.7178 - val_accuracy: 0.7146
# Epoch 76/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.0847 - accuracy: 0.9717 - val_loss: 1.5912 - val_accuracy: 0.7226
# Epoch 77/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.0804 - accuracy: 0.9758 - val_loss: 1.6026 - val_accuracy: 0.7134
# Epoch 78/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.0846 - accuracy: 0.9724 - val_loss: 1.7851 - val_accuracy: 0.7137
# Epoch 79/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.0894 - accuracy: 0.9717 - val_loss: 1.5293 - val_accuracy: 0.7270
# Epoch 80/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.0868 - accuracy: 0.9725 - val_loss: 1.5328 - val_accuracy: 0.7022
# Epoch 81/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.0786 - accuracy: 0.9742 - val_loss: 1.4833 - val_accuracy: 0.7115
# Epoch 82/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.0756 - accuracy: 0.9751 - val_loss: 1.5951 - val_accuracy: 0.7124
# Epoch 83/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.0812 - accuracy: 0.9732 - val_loss: 1.6941 - val_accuracy: 0.7220
# Epoch 84/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.0696 - accuracy: 0.9763 - val_loss: 6.2435 - val_accuracy: 0.6156
# Epoch 85/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.0861 - accuracy: 0.9719 - val_loss: 1.5428 - val_accuracy: 0.6954
# Epoch 86/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.0748 - accuracy: 0.9752 - val_loss: 1.6687 - val_accuracy: 0.6954
# Epoch 87/100
# 405/405 [==============================] - 106s 263ms/step - loss: 0.0762 - accuracy: 0.9751 - val_loss: 1.7889 - val_accuracy: 0.6945
# Epoch 88/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.0652 - accuracy: 0.9798 - val_loss: 1.9887 - val_accuracy: 0.6948
# Epoch 89/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.0760 - accuracy: 0.9758 - val_loss: 1.7679 - val_accuracy: 0.7038
# Epoch 90/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.0809 - accuracy: 0.9754 - val_loss: 1.5120 - val_accuracy: 0.7217
# Epoch 91/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.0722 - accuracy: 0.9776 - val_loss: 1.6969 - val_accuracy: 0.7195
# Epoch 92/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.0724 - accuracy: 0.9761 - val_loss: 1.7395 - val_accuracy: 0.7161
# Epoch 93/100
# 405/405 [==============================] - 107s 263ms/step - loss: 0.0574 - accuracy: 0.9819 - val_loss: 1.7347 - val_accuracy: 0.6957
# Epoch 94/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.0754 - accuracy: 0.9754 - val_loss: 1.7070 - val_accuracy: 0.7202
# Epoch 95/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.0626 - accuracy: 0.9799 - val_loss: 1.6598 - val_accuracy: 0.7273
# Epoch 96/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.0752 - accuracy: 0.9775 - val_loss: 1.7670 - val_accuracy: 0.7291
# Epoch 97/100
# 405/405 [==============================] - 108s 268ms/step - loss: 0.0667 - accuracy: 0.9805 - val_loss: 1.5482 - val_accuracy: 0.7130
# Epoch 98/100
# 405/405 [==============================] - 107s 266ms/step - loss: 0.0686 - accuracy: 0.9773 - val_loss: 1.5799 - val_accuracy: 0.7155
# Epoch 99/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.0690 - accuracy: 0.9778 - val_loss: 1.7871 - val_accuracy: 0.7093
# Epoch 100/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.0568 - accuracy: 0.9826 - val_loss: 1.9235 - val_accuracy: 0.7019

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()
