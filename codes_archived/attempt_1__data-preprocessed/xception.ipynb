# %%
# !pip install pandas numpy seaborn matplotlib tensorflow keras sklearn &> /dev/null

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications import Xception

import time
start_time = time.time()

# %%
PATH_DATA_TRAIN = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/train'
PATH_DATA_TEST = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/test'
PATH_DATA_VALIDATION = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/validation'
PATH_SAVED_MODEL = 'xception.h5'

# %% [markdown]
# # Load Dataset As Generators

# %%
generator = ImageDataGenerator(rescale = 1./255.)

target_size = (100, 100)
batch_size = 32

train_batches = generator.flow_from_directory(
    PATH_DATA_TRAIN, class_mode='categorical', 
    batch_size=batch_size, target_size=target_size
)

validation_batches = generator.flow_from_directory(
    PATH_DATA_VALIDATION, class_mode='categorical',  
    batch_size=batch_size, target_size=target_size
)

test_batches = generator.flow_from_directory(
    PATH_DATA_TEST, class_mode='categorical', shuffle=False, 
    batch_size=batch_size, target_size=target_size
)
# Out:
# Found 12959 images belonging to 7 classes.
# Found 1616 images belonging to 7 classes.
# Found 1610 images belonging to 7 classes.

# %%
# preview data (batch size, width, height, colors)
print('x_train shape:', train_batches[0][0].shape)
print('x_validation shape:', validation_batches[0][0].shape)
print('x_test shape:', test_batches[0][0].shape)
print('y_train shape:', train_batches[0][1].shape)
print('y_validation shape:', validation_batches[0][1].shape)
print('y_test shape:', test_batches[0][1].shape)
# Out:
# x_train shape: (32, 100, 100, 3)
# x_validation shape: (32, 100, 100, 3)
# x_test shape: (32, 100, 100, 3)
# y_train shape: (32, 7)
# y_validation shape: (32, 7)
# y_test shape: (32, 7)

# %%
# input & output shape
input_shape = train_batches[0][0][0].shape
output_shape = len(train_batches[0][1][0])

# display input & output shape
print('Input Shape:', input_shape)
print('Output Shape:', output_shape)
# Out:
# Input Shape: (100, 100, 3)
# Output Shape: 7

# %% [markdown]
# # Build & Compile Model

# %%
model = Xception(
    input_shape=input_shape,
    classes=output_shape,
    weights=None,
    classifier_activation='softmax'
)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# 2022-11-10 17:53:44.419640: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 17:53:44.420867: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 17:53:44.582419: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 17:53:44.583467: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 17:53:44.584275: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 17:53:44.585041: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 17:53:44.586592: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-10 17:53:44.830279: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 17:53:44.831169: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 17:53:44.831909: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 17:53:44.832589: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 17:53:44.833277: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 17:53:44.833965: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 17:53:48.192080: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 17:53:48.192944: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 17:53:48.193677: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 17:53:48.194406: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 17:53:48.195145: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 17:53:48.195843: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-11-10 17:53:48.200475: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 17:53:48.201220: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "xception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 49, 49, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 49, 49, 32)   128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 49, 49, 32)   0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 47, 47, 64)   18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 47, 47, 64)   256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 47, 47, 64)   0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 47, 47, 128)  8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 47, 47, 128)  512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 47, 47, 128)  0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 47, 47, 128)  17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 47, 47, 128)  512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 24, 24, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 24, 24, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 24, 24, 128)  512         conv2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 24, 24, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 24, 24, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 24, 24, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 24, 24, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 24, 24, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 24, 24, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 24, 24, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 12, 12, 256)  32768       add[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 12, 12, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 12, 12, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 12, 12, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 12, 12, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 12, 12, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 12, 12, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 12, 12, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 12, 12, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 12, 12, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 6, 6, 728)    186368      add_1[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 6, 6, 728)    0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 6, 6, 728)    2912        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 6, 6, 728)    0           block4_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 6, 6, 728)    0           add_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 6, 6, 728)    536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 6, 6, 728)    2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 6, 6, 728)    0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 6, 6, 728)    536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 6, 6, 728)    2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 6, 6, 728)    0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 6, 6, 728)    536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 6, 6, 728)    2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 6, 6, 728)    0           block5_sepconv3_bn[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 6, 6, 728)    0           add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 6, 6, 728)    536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 6, 6, 728)    2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 6, 6, 728)    0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 6, 6, 728)    536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 6, 6, 728)    2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 6, 6, 728)    0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 6, 6, 728)    536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 6, 6, 728)    2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 6, 6, 728)    0           block6_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 6, 6, 728)    0           add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 6, 6, 728)    536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 6, 6, 728)    2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 6, 6, 728)    0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 6, 6, 728)    536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 6, 6, 728)    2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 6, 6, 728)    0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 6, 6, 728)    536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 6, 6, 728)    2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 6, 6, 728)    0           block7_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 6, 6, 728)    0           add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 6, 6, 728)    536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 6, 6, 728)    2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 6, 6, 728)    0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 6, 6, 728)    536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 6, 6, 728)    2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 6, 6, 728)    0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 6, 6, 728)    536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 6, 6, 728)    2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 6, 6, 728)    0           block8_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 6, 6, 728)    0           add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 6, 6, 728)    536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 6, 6, 728)    2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 6, 6, 728)    0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 6, 6, 728)    536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 6, 6, 728)    2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 6, 6, 728)    0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 6, 6, 728)    536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 6, 6, 728)    2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 6, 6, 728)    0           block9_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 6, 6, 728)    0           add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 6, 6, 728)    536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 6, 6, 728)    2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 6, 6, 728)    0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 6, 6, 728)    536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 6, 6, 728)    2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 6, 6, 728)    0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 6, 6, 728)    536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 6, 6, 728)    2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 6, 6, 728)    0           block10_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 6, 6, 728)    0           add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 6, 6, 728)    536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 6, 6, 728)    2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 6, 6, 728)    0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 6, 6, 728)    536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 6, 6, 728)    2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 6, 6, 728)    0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 6, 6, 728)    536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 6, 6, 728)    2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 6, 6, 728)    0           block11_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 6, 6, 728)    0           add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 6, 6, 728)    536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 6, 6, 728)    2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 6, 6, 728)    0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 6, 6, 728)    536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 6, 6, 728)    2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 6, 6, 728)    0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 6, 6, 728)    536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 6, 6, 728)    2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 6, 6, 728)    0           block12_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 6, 6, 728)    0           add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 6, 6, 728)    536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 6, 6, 728)    2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 6, 6, 728)    0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 6, 6, 1024)   752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 6, 6, 1024)   4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 3, 3, 1024)   745472      add_10[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 3, 3, 1024)   0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 3, 3, 1024)   4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 3, 3, 1024)   0           block13_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 3, 3, 1536)   1582080     add_11[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 3, 3, 1536)   6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 3, 3, 1536)   0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 3, 3, 2048)   3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 3, 3, 2048)   8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 3, 3, 2048)   0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 7)            14343       avg_pool[0][0]
# ==================================================================================================
# Total params: 20,875,823
# Trainable params: 20,821,295
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %% [markdown]
# # Train Model

# %%
# train model
r = model.fit(train_batches, validation_data=validation_batches, epochs=100)

# save model
model.save(PATH_SAVED_MODEL)

# load model
# model = load_model(PATH_SAVED_MODEL)
# Out:
# 2022-11-10 17:53:49.733169: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-11-10 17:53:56.186058: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 405/405 [==============================] - 183s 415ms/step - loss: 1.5958 - accuracy: 0.3825 - val_loss: 1.9006 - val_accuracy: 0.2543
# Epoch 2/100
# 405/405 [==============================] - 108s 268ms/step - loss: 1.2378 - accuracy: 0.5327 - val_loss: 2.4422 - val_accuracy: 0.3899
# Epoch 3/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.9891 - accuracy: 0.6267 - val_loss: 15.1707 - val_accuracy: 0.2339
# Epoch 4/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.8386 - accuracy: 0.6862 - val_loss: 2.0077 - val_accuracy: 0.4814
# Epoch 5/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.7237 - accuracy: 0.7254 - val_loss: 1.4875 - val_accuracy: 0.5303
# Epoch 6/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.6122 - accuracy: 0.7740 - val_loss: 1.3656 - val_accuracy: 0.6250
# Epoch 7/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.5081 - accuracy: 0.8117 - val_loss: 0.9168 - val_accuracy: 0.6652
# Epoch 8/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.4415 - accuracy: 0.8399 - val_loss: 1.1423 - val_accuracy: 0.6677
# Epoch 9/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.3486 - accuracy: 0.8727 - val_loss: 1.6137 - val_accuracy: 0.5767
# Epoch 10/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.2809 - accuracy: 0.9008 - val_loss: 1.8207 - val_accuracy: 0.6163
# Epoch 11/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.2135 - accuracy: 0.9236 - val_loss: 1.1095 - val_accuracy: 0.6993
# Epoch 12/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.1927 - accuracy: 0.9293 - val_loss: 1.2150 - val_accuracy: 0.6764
# Epoch 13/100
# 405/405 [==============================] - 112s 277ms/step - loss: 0.1481 - accuracy: 0.9475 - val_loss: 1.8896 - val_accuracy: 0.6411
# Epoch 14/100
# 405/405 [==============================] - 114s 282ms/step - loss: 0.1380 - accuracy: 0.9536 - val_loss: 1.4024 - val_accuracy: 0.6955
# Epoch 15/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.1108 - accuracy: 0.9624 - val_loss: 1.4931 - val_accuracy: 0.6095
# Epoch 16/100
# 405/405 [==============================] - 114s 281ms/step - loss: 0.0965 - accuracy: 0.9661 - val_loss: 1.4498 - val_accuracy: 0.7054
# Epoch 17/100
# 405/405 [==============================] - 116s 285ms/step - loss: 0.0968 - accuracy: 0.9667 - val_loss: 1.1716 - val_accuracy: 0.7358
# Epoch 18/100
# 405/405 [==============================] - 113s 279ms/step - loss: 0.0834 - accuracy: 0.9715 - val_loss: 2.2181 - val_accuracy: 0.6262
# Epoch 19/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.0998 - accuracy: 0.9657 - val_loss: 1.2403 - val_accuracy: 0.6918
# Epoch 20/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.0906 - accuracy: 0.9691 - val_loss: 1.5770 - val_accuracy: 0.6720
# Epoch 21/100
# 405/405 [==============================] - 108s 265ms/step - loss: 0.0659 - accuracy: 0.9787 - val_loss: 1.2109 - val_accuracy: 0.7345
# Epoch 22/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.0708 - accuracy: 0.9742 - val_loss: 1.3248 - val_accuracy: 0.7580
# Epoch 23/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.0766 - accuracy: 0.9730 - val_loss: 2.2394 - val_accuracy: 0.6300
# Epoch 24/100
# 405/405 [==============================] - 110s 271ms/step - loss: 0.0652 - accuracy: 0.9778 - val_loss: 1.3733 - val_accuracy: 0.7246
# Epoch 25/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.0679 - accuracy: 0.9764 - val_loss: 1.3788 - val_accuracy: 0.7376
# Epoch 26/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.0589 - accuracy: 0.9796 - val_loss: 1.2902 - val_accuracy: 0.7333
# Epoch 27/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.0618 - accuracy: 0.9785 - val_loss: 3.3334 - val_accuracy: 0.6139
# Epoch 28/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.0833 - accuracy: 0.9723 - val_loss: 2.1907 - val_accuracy: 0.6751
# Epoch 29/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.0489 - accuracy: 0.9830 - val_loss: 1.5261 - val_accuracy: 0.7085
# Epoch 30/100
# 405/405 [==============================] - 107s 263ms/step - loss: 0.0415 - accuracy: 0.9864 - val_loss: 2.0028 - val_accuracy: 0.6213
# Epoch 31/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.0479 - accuracy: 0.9824 - val_loss: 1.5211 - val_accuracy: 0.7228
# Epoch 32/100
# 405/405 [==============================] - 107s 263ms/step - loss: 0.0582 - accuracy: 0.9802 - val_loss: 1.8690 - val_accuracy: 0.6881
# Epoch 33/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.0460 - accuracy: 0.9848 - val_loss: 1.4321 - val_accuracy: 0.6968
# Epoch 34/100
# 405/405 [==============================] - 111s 275ms/step - loss: 0.0498 - accuracy: 0.9825 - val_loss: 1.3119 - val_accuracy: 0.7426
# Epoch 35/100
# 405/405 [==============================] - 109s 270ms/step - loss: 0.0377 - accuracy: 0.9870 - val_loss: 1.3323 - val_accuracy: 0.7364
# Epoch 36/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.0300 - accuracy: 0.9902 - val_loss: 1.7299 - val_accuracy: 0.6498
# Epoch 37/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.1320 - accuracy: 0.9569 - val_loss: 1.1564 - val_accuracy: 0.7395
# Epoch 38/100
# 405/405 [==============================] - 109s 269ms/step - loss: 0.0511 - accuracy: 0.9820 - val_loss: 1.3569 - val_accuracy: 0.7426
# Epoch 39/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.0241 - accuracy: 0.9921 - val_loss: 2.1604 - val_accuracy: 0.6640
# Epoch 40/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.0182 - accuracy: 0.9943 - val_loss: 2.0899 - val_accuracy: 0.6318
# Epoch 41/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.0378 - accuracy: 0.9866 - val_loss: 1.7885 - val_accuracy: 0.6850
# Epoch 42/100
# 405/405 [==============================] - 108s 265ms/step - loss: 0.0283 - accuracy: 0.9908 - val_loss: 2.5313 - val_accuracy: 0.5675
# Epoch 43/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.0323 - accuracy: 0.9887 - val_loss: 1.5181 - val_accuracy: 0.7092
# Epoch 44/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.0462 - accuracy: 0.9839 - val_loss: 1.5722 - val_accuracy: 0.7197
# Epoch 45/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.0429 - accuracy: 0.9867 - val_loss: 1.5685 - val_accuracy: 0.6949
# Epoch 46/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.0217 - accuracy: 0.9928 - val_loss: 1.4847 - val_accuracy: 0.7277
# Epoch 47/100
# 405/405 [==============================] - 106s 263ms/step - loss: 0.0267 - accuracy: 0.9912 - val_loss: 1.4902 - val_accuracy: 0.7042
# Epoch 48/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.0518 - accuracy: 0.9837 - val_loss: 1.3497 - val_accuracy: 0.7283
# Epoch 49/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.0428 - accuracy: 0.9853 - val_loss: 1.3461 - val_accuracy: 0.7036
# Epoch 50/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.0440 - accuracy: 0.9854 - val_loss: 1.3129 - val_accuracy: 0.7265
# Epoch 51/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.0289 - accuracy: 0.9905 - val_loss: 1.7593 - val_accuracy: 0.7135
# Epoch 52/100
# 405/405 [==============================] - 107s 263ms/step - loss: 0.0224 - accuracy: 0.9920 - val_loss: 1.4307 - val_accuracy: 0.7222
# Epoch 53/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.0268 - accuracy: 0.9910 - val_loss: 2.0502 - val_accuracy: 0.7123
# Epoch 54/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.0320 - accuracy: 0.9897 - val_loss: 1.6673 - val_accuracy: 0.7345
# Epoch 55/100
# 405/405 [==============================] - 110s 271ms/step - loss: 0.0214 - accuracy: 0.9923 - val_loss: 1.3660 - val_accuracy: 0.7475
# Epoch 56/100
# 405/405 [==============================] - 119s 293ms/step - loss: 0.0314 - accuracy: 0.9904 - val_loss: 1.6230 - val_accuracy: 0.7240
# Epoch 57/100
# 405/405 [==============================] - 108s 267ms/step - loss: 0.0349 - accuracy: 0.9885 - val_loss: 1.5362 - val_accuracy: 0.7358
# Epoch 58/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.0313 - accuracy: 0.9894 - val_loss: 1.3973 - val_accuracy: 0.7426
# Epoch 59/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.0271 - accuracy: 0.9917 - val_loss: 1.9790 - val_accuracy: 0.7116
# Epoch 60/100
# 405/405 [==============================] - 106s 260ms/step - loss: 0.0267 - accuracy: 0.9909 - val_loss: 2.8364 - val_accuracy: 0.6114
# Epoch 61/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.0189 - accuracy: 0.9937 - val_loss: 1.2341 - val_accuracy: 0.7673
# Epoch 62/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.0134 - accuracy: 0.9951 - val_loss: 2.0786 - val_accuracy: 0.7061
# Epoch 63/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.0400 - accuracy: 0.9860 - val_loss: 1.4490 - val_accuracy: 0.7420
# Epoch 64/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.0229 - accuracy: 0.9927 - val_loss: 1.8803 - val_accuracy: 0.6906
# Epoch 65/100
# 405/405 [==============================] - 106s 260ms/step - loss: 0.0248 - accuracy: 0.9923 - val_loss: 1.6464 - val_accuracy: 0.6986
# Epoch 66/100
# 405/405 [==============================] - 106s 263ms/step - loss: 0.0188 - accuracy: 0.9936 - val_loss: 1.4165 - val_accuracy: 0.7141
# Epoch 67/100
# 405/405 [==============================] - 107s 263ms/step - loss: 0.0413 - accuracy: 0.9861 - val_loss: 1.4618 - val_accuracy: 0.7073
# Epoch 68/100
# 405/405 [==============================] - 106s 260ms/step - loss: 0.0215 - accuracy: 0.9926 - val_loss: 1.3635 - val_accuracy: 0.7432
# Epoch 69/100
# 405/405 [==============================] - 107s 263ms/step - loss: 0.0263 - accuracy: 0.9918 - val_loss: 2.2626 - val_accuracy: 0.7061
# Epoch 70/100
# 405/405 [==============================] - 108s 266ms/step - loss: 0.0258 - accuracy: 0.9905 - val_loss: 1.3528 - val_accuracy: 0.7562
# Epoch 71/100
# 405/405 [==============================] - 107s 263ms/step - loss: 0.0272 - accuracy: 0.9919 - val_loss: 1.3257 - val_accuracy: 0.7673
# Epoch 72/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.0162 - accuracy: 0.9945 - val_loss: 1.1754 - val_accuracy: 0.7710
# Epoch 73/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.0369 - accuracy: 0.9887 - val_loss: 4.5822 - val_accuracy: 0.6498
# Epoch 74/100
# 405/405 [==============================] - 107s 263ms/step - loss: 0.1034 - accuracy: 0.9718 - val_loss: 1.0728 - val_accuracy: 0.7463
# Epoch 75/100
# 405/405 [==============================] - 107s 263ms/step - loss: 0.0138 - accuracy: 0.9957 - val_loss: 1.4171 - val_accuracy: 0.7463
# Epoch 76/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.0099 - accuracy: 0.9973 - val_loss: 1.4135 - val_accuracy: 0.7618
# Epoch 77/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.0147 - accuracy: 0.9960 - val_loss: 5.0550 - val_accuracy: 0.4901
# Epoch 78/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.0278 - accuracy: 0.9917 - val_loss: 1.6509 - val_accuracy: 0.7215
# Epoch 79/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.0128 - accuracy: 0.9952 - val_loss: 1.4162 - val_accuracy: 0.7290
# Epoch 80/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.0172 - accuracy: 0.9942 - val_loss: 1.5030 - val_accuracy: 0.7457
# Epoch 81/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.0115 - accuracy: 0.9965 - val_loss: 1.4780 - val_accuracy: 0.7692
# Epoch 82/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.0262 - accuracy: 0.9915 - val_loss: 1.2784 - val_accuracy: 0.7475
# Epoch 83/100
# 405/405 [==============================] - 107s 263ms/step - loss: 0.0277 - accuracy: 0.9914 - val_loss: 1.4987 - val_accuracy: 0.7395
# Epoch 84/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.0226 - accuracy: 0.9927 - val_loss: 1.3551 - val_accuracy: 0.7574
# Epoch 85/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.0138 - accuracy: 0.9961 - val_loss: 1.3516 - val_accuracy: 0.7667
# Epoch 86/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.0094 - accuracy: 0.9971 - val_loss: 1.4340 - val_accuracy: 0.7618
# Epoch 87/100
# 405/405 [==============================] - 106s 260ms/step - loss: 0.0091 - accuracy: 0.9970 - val_loss: 1.5199 - val_accuracy: 0.7599
# Epoch 88/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.0231 - accuracy: 0.9928 - val_loss: 1.5002 - val_accuracy: 0.7463
# Epoch 89/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.0176 - accuracy: 0.9942 - val_loss: 1.4561 - val_accuracy: 0.7512
# Epoch 90/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.0206 - accuracy: 0.9927 - val_loss: 1.5406 - val_accuracy: 0.7333
# Epoch 91/100
# 405/405 [==============================] - 117s 288ms/step - loss: 0.0198 - accuracy: 0.9932 - val_loss: 1.5619 - val_accuracy: 0.7345
# Epoch 92/100
# 405/405 [==============================] - 118s 290ms/step - loss: 0.0239 - accuracy: 0.9924 - val_loss: 3.4352 - val_accuracy: 0.4325
# Epoch 93/100
# 405/405 [==============================] - 114s 282ms/step - loss: 0.0106 - accuracy: 0.9963 - val_loss: 1.4708 - val_accuracy: 0.7345
# Epoch 94/100
# 405/405 [==============================] - 114s 281ms/step - loss: 0.0506 - accuracy: 0.9844 - val_loss: 1.5584 - val_accuracy: 0.7240
# Epoch 95/100
# 405/405 [==============================] - 112s 277ms/step - loss: 0.0250 - accuracy: 0.9921 - val_loss: 1.4282 - val_accuracy: 0.7358
# Epoch 96/100
# 405/405 [==============================] - 109s 270ms/step - loss: 0.0103 - accuracy: 0.9966 - val_loss: 1.5935 - val_accuracy: 0.7401
# Epoch 97/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.0157 - accuracy: 0.9941 - val_loss: 1.7220 - val_accuracy: 0.7191
# Epoch 98/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.0206 - accuracy: 0.9927 - val_loss: 1.5811 - val_accuracy: 0.7686
# Epoch 99/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.0199 - accuracy: 0.9945 - val_loss: 1.4372 - val_accuracy: 0.7574
# Epoch 100/100
# 405/405 [==============================] - 105s 258ms/step - loss: 0.0095 - accuracy: 0.9973 - val_loss: 1.7534 - val_accuracy: 0.7123
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %% [markdown]
# # Evaluate Model's Training & Validation Results

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()

# %% [markdown]
# # Generate Predictions With Model

# %%
y_pred = model.predict(test_batches).argmax(axis=1)

# %%
model.evaluate(test_batches)
# Out:
# 51/51 [==============================] - 12s 227ms/step - loss: 1.6970 - accuracy: 0.7348
# [1.6969996690750122, 0.7347826361656189]

# %% [markdown]
# # Evaluate Model's Prediction Results

# %%
# generate classification report
class_labels = list(test_batches.class_indices.keys())
report = classification_report(test_batches.classes, y_pred, target_names=class_labels, output_dict=True)
df_classification_report = pd.DataFrame(report).transpose()
df_classification_report
# Out:
#               precision    recall  f1-score      support
# hatchback      0.671642  0.288462  0.403587   156.000000
# mpv            0.750000  0.777778  0.763636   108.000000
# sedan          0.773292  0.601449  0.676630   414.000000
# sport          0.695341  0.858407  0.768317   452.000000
# suv            0.764012  0.911972  0.831461   284.000000
# truck          0.805556  0.906250  0.852941   160.000000
# wagon          0.406250  0.361111  0.382353    36.000000
# accuracy       0.734783  0.734783  0.734783     0.734783
# macro avg      0.695156  0.672204  0.668418  1610.000000
# weighted avg   0.733358  0.734783  0.720004  1610.000000

# %%
# compute confusion matrix
matrix = confusion_matrix(test_batches.classes, y_pred)

# normalize confusion matrix
matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
matrix = np.around(matrix, decimals=2)

# generate confusion matrix heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(matrix, annot=True, xticklabels=class_labels, yticklabels=class_labels)
plt.ylabel('Test Values')
plt.xlabel('Predicted Values')
# Out:
# Text(0.5, 69.0, 'Predicted Values')

# %% [markdown]
# # Compute Execution Time

# %%
execution_time_s = round(time.time() - start_time, 2)
execution_time_m = round(execution_time_s/60, 2)
execution_time_h = round(execution_time_m/60, 2)

print('Execution Time (Hours):', execution_time_h)
print('Execution Time (Minutes):', execution_time_m)
print('Execution Time (Seconds):', execution_time_s)
# Out:
# Execution Time (Hours): 3.25
# Execution Time (Minutes): 195.22
# Execution Time (Seconds): 11712.98
