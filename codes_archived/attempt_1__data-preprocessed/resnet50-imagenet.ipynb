# %%
# !pip install pandas numpy seaborn matplotlib tensorflow keras sklearn &> /dev/null

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet50

import time
start_time = time.time()

# %%
PATH_DATA_TRAIN = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/train'
PATH_DATA_TEST = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/test'
PATH_DATA_VALIDATION = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/validation'
PATH_SAVED_MODEL = 'resnet50-imagenet.h5'

# %% [markdown]
# # Load Dataset As Generators

# %%
generator = ImageDataGenerator(rescale = 1./255.)

target_size = (100, 100)
batch_size = 32

train_batches = generator.flow_from_directory(
    PATH_DATA_TRAIN, class_mode='categorical', 
    batch_size=batch_size, target_size=target_size
)

validation_batches = generator.flow_from_directory(
    PATH_DATA_VALIDATION, class_mode='categorical',  
    batch_size=batch_size, target_size=target_size
)

test_batches = generator.flow_from_directory(
    PATH_DATA_TEST, class_mode='categorical', shuffle=False, 
    batch_size=batch_size, target_size=target_size
)
# Out:
# Found 12959 images belonging to 7 classes.
# Found 1616 images belonging to 7 classes.
# Found 1610 images belonging to 7 classes.

# %%
# preview data (batch size, width, height, colors)
print('x_train shape:', train_batches[0][0].shape)
print('x_validation shape:', validation_batches[0][0].shape)
print('x_test shape:', test_batches[0][0].shape)
print('y_train shape:', train_batches[0][1].shape)
print('y_validation shape:', validation_batches[0][1].shape)
print('y_test shape:', test_batches[0][1].shape)
# Out:
# x_train shape: (32, 100, 100, 3)
# x_validation shape: (32, 100, 100, 3)
# x_test shape: (32, 100, 100, 3)
# y_train shape: (32, 7)
# y_validation shape: (32, 7)
# y_test shape: (32, 7)

# %%
# input & output shape
input_shape = train_batches[0][0][0].shape
output_shape = len(train_batches[0][1][0])

# display input & output shape
print('Input Shape:', input_shape)
print('Output Shape:', output_shape)
# Out:
# Input Shape: (100, 100, 3)
# Output Shape: 7

# %% [markdown]
# # Build & Compile Model

# %%
model = ResNet50(
    input_shape=input_shape, 
    weights="imagenet", 
    include_top=False, 
    pooling='max'
)

for layer in model.layers:
    layer.trainable = False

i = Input(shape=input_shape)
x = model(i)
x = Flatten()(x)
x = Dense(output_shape, activation='softmax')(x)

model = Model(inputs=i, outputs=x)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# 2022-11-09 11:03:16.054531: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 11:03:16.055541: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 11:03:16.578438: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 11:03:16.579363: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 11:03:16.580259: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 11:03:16.581018: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 11:03:16.582507: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-09 11:03:16.840662: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 11:03:16.841464: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 11:03:16.842278: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 11:03:16.843084: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 11:03:16.843811: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 11:03:16.844491: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 11:03:21.730646: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 11:03:21.731517: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 11:03:21.732359: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 11:03:21.733170: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 11:03:21.734055: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 11:03:21.734789: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-11-09 11:03:21.741171: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 11:03:21.741892: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 14343
# =================================================================
# Total params: 23,602,055
# Trainable params: 14,343
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %% [markdown]
# # Train Model

# %%
# train model
r = model.fit(train_batches, validation_data=validation_batches, epochs=100)

# save model
model.save(PATH_SAVED_MODEL)

# load model
# model = load_model(PATH_SAVED_MODEL)
# Out:
# 2022-11-09 11:03:25.383009: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-11-09 11:03:30.700457: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 405/405 [==============================] - 191s 433ms/step - loss: 1.8478 - accuracy: 0.2986 - val_loss: 1.6552 - val_accuracy: 0.3366
# Epoch 2/100
# 405/405 [==============================] - 104s 257ms/step - loss: 1.6679 - accuracy: 0.3503 - val_loss: 1.5554 - val_accuracy: 0.3849
# Epoch 3/100
# 405/405 [==============================] - 103s 254ms/step - loss: 1.6211 - accuracy: 0.3698 - val_loss: 1.6887 - val_accuracy: 0.3521
# Epoch 4/100
# 405/405 [==============================] - 103s 254ms/step - loss: 1.5703 - accuracy: 0.3909 - val_loss: 1.5304 - val_accuracy: 0.4072
# Epoch 5/100
# 405/405 [==============================] - 103s 253ms/step - loss: 1.5226 - accuracy: 0.4116 - val_loss: 1.6247 - val_accuracy: 0.4196
# Epoch 6/100
# 405/405 [==============================] - 104s 256ms/step - loss: 1.5353 - accuracy: 0.4058 - val_loss: 1.5713 - val_accuracy: 0.3818
# Epoch 7/100
# 405/405 [==============================] - 103s 255ms/step - loss: 1.5301 - accuracy: 0.4157 - val_loss: 1.4921 - val_accuracy: 0.4196
# Epoch 8/100
# 405/405 [==============================] - 103s 254ms/step - loss: 1.4958 - accuracy: 0.4267 - val_loss: 1.4572 - val_accuracy: 0.4301
# Epoch 9/100
# 405/405 [==============================] - 104s 256ms/step - loss: 1.4730 - accuracy: 0.4337 - val_loss: 1.5836 - val_accuracy: 0.3849
# Epoch 10/100
# 405/405 [==============================] - 103s 254ms/step - loss: 1.4641 - accuracy: 0.4377 - val_loss: 1.4965 - val_accuracy: 0.4220
# Epoch 11/100
# 405/405 [==============================] - 103s 253ms/step - loss: 1.4398 - accuracy: 0.4432 - val_loss: 1.5726 - val_accuracy: 0.4400
# Epoch 12/100
# 405/405 [==============================] - 103s 254ms/step - loss: 1.4457 - accuracy: 0.4478 - val_loss: 1.4603 - val_accuracy: 0.4381
# Epoch 13/100
# 405/405 [==============================] - 104s 257ms/step - loss: 1.4080 - accuracy: 0.4638 - val_loss: 1.6313 - val_accuracy: 0.3800
# Epoch 14/100
# 405/405 [==============================] - 103s 255ms/step - loss: 1.4276 - accuracy: 0.4588 - val_loss: 1.5588 - val_accuracy: 0.4239
# Epoch 15/100
# 405/405 [==============================] - 103s 255ms/step - loss: 1.3989 - accuracy: 0.4632 - val_loss: 1.5664 - val_accuracy: 0.4363
# Epoch 16/100
# 405/405 [==============================] - 103s 255ms/step - loss: 1.4166 - accuracy: 0.4601 - val_loss: 1.6747 - val_accuracy: 0.3991
# Epoch 17/100
# 405/405 [==============================] - 103s 255ms/step - loss: 1.4111 - accuracy: 0.4678 - val_loss: 1.4834 - val_accuracy: 0.4356
# Epoch 18/100
# 405/405 [==============================] - 102s 253ms/step - loss: 1.3732 - accuracy: 0.4693 - val_loss: 1.4652 - val_accuracy: 0.4474
# Epoch 19/100
# 405/405 [==============================] - 103s 254ms/step - loss: 1.4088 - accuracy: 0.4677 - val_loss: 1.5331 - val_accuracy: 0.3973
# Epoch 20/100
# 405/405 [==============================] - 104s 257ms/step - loss: 1.3831 - accuracy: 0.4679 - val_loss: 1.4571 - val_accuracy: 0.4443
# Epoch 21/100
# 405/405 [==============================] - 102s 252ms/step - loss: 1.3667 - accuracy: 0.4811 - val_loss: 1.5647 - val_accuracy: 0.3651
# Epoch 22/100
# 405/405 [==============================] - 103s 253ms/step - loss: 1.3503 - accuracy: 0.4841 - val_loss: 1.4808 - val_accuracy: 0.4276
# Epoch 23/100
# 405/405 [==============================] - 103s 255ms/step - loss: 1.3613 - accuracy: 0.4821 - val_loss: 1.5741 - val_accuracy: 0.4016
# Epoch 24/100
# 405/405 [==============================] - 102s 253ms/step - loss: 1.3752 - accuracy: 0.4813 - val_loss: 1.4865 - val_accuracy: 0.4412
# Epoch 25/100
# 405/405 [==============================] - 102s 253ms/step - loss: 1.3583 - accuracy: 0.4792 - val_loss: 1.7494 - val_accuracy: 0.4035
# Epoch 26/100
# 405/405 [==============================] - 103s 253ms/step - loss: 1.3404 - accuracy: 0.4909 - val_loss: 1.4504 - val_accuracy: 0.4561
# Epoch 27/100
# 405/405 [==============================] - 103s 256ms/step - loss: 1.3486 - accuracy: 0.4916 - val_loss: 1.5217 - val_accuracy: 0.3923
# Epoch 28/100
# 405/405 [==============================] - 103s 253ms/step - loss: 1.3199 - accuracy: 0.4925 - val_loss: 1.5207 - val_accuracy: 0.4375
# Epoch 29/100
# 405/405 [==============================] - 103s 254ms/step - loss: 1.3358 - accuracy: 0.4910 - val_loss: 1.5156 - val_accuracy: 0.4579
# Epoch 30/100
# 405/405 [==============================] - 103s 253ms/step - loss: 1.3116 - accuracy: 0.5047 - val_loss: 1.5056 - val_accuracy: 0.4542
# Epoch 31/100
# 405/405 [==============================] - 104s 257ms/step - loss: 1.3184 - accuracy: 0.5035 - val_loss: 1.4673 - val_accuracy: 0.4356
# Epoch 32/100
# 405/405 [==============================] - 103s 255ms/step - loss: 1.3128 - accuracy: 0.5037 - val_loss: 1.5203 - val_accuracy: 0.4226
# Epoch 33/100
# 405/405 [==============================] - 107s 264ms/step - loss: 1.3006 - accuracy: 0.5122 - val_loss: 1.5631 - val_accuracy: 0.4431
# Epoch 34/100
# 405/405 [==============================] - 108s 265ms/step - loss: 1.3166 - accuracy: 0.4926 - val_loss: 1.5423 - val_accuracy: 0.4171
# Epoch 35/100
# 405/405 [==============================] - 106s 262ms/step - loss: 1.3231 - accuracy: 0.5001 - val_loss: 1.5133 - val_accuracy: 0.4338
# Epoch 36/100
# 405/405 [==============================] - 105s 260ms/step - loss: 1.3031 - accuracy: 0.4999 - val_loss: 1.4349 - val_accuracy: 0.4554
# Epoch 37/100
# 405/405 [==============================] - 107s 265ms/step - loss: 1.3040 - accuracy: 0.5084 - val_loss: 1.4626 - val_accuracy: 0.4480
# Epoch 38/100
# 405/405 [==============================] - 106s 263ms/step - loss: 1.3023 - accuracy: 0.5041 - val_loss: 1.4495 - val_accuracy: 0.4400
# Epoch 39/100
# 405/405 [==============================] - 106s 263ms/step - loss: 1.2764 - accuracy: 0.5128 - val_loss: 1.5404 - val_accuracy: 0.4208
# Epoch 40/100
# 405/405 [==============================] - 106s 261ms/step - loss: 1.2842 - accuracy: 0.5087 - val_loss: 1.8437 - val_accuracy: 0.4158
# Epoch 41/100
# 405/405 [==============================] - 106s 262ms/step - loss: 1.2677 - accuracy: 0.5130 - val_loss: 1.4954 - val_accuracy: 0.4455
# Epoch 42/100
# 405/405 [==============================] - 106s 261ms/step - loss: 1.2794 - accuracy: 0.5170 - val_loss: 1.5045 - val_accuracy: 0.4431
# Epoch 43/100
# 405/405 [==============================] - 106s 263ms/step - loss: 1.2627 - accuracy: 0.5199 - val_loss: 1.7420 - val_accuracy: 0.3849
# Epoch 44/100
# 405/405 [==============================] - 106s 261ms/step - loss: 1.2930 - accuracy: 0.5111 - val_loss: 1.5010 - val_accuracy: 0.4381
# Epoch 45/100
# 405/405 [==============================] - 105s 260ms/step - loss: 1.2735 - accuracy: 0.5174 - val_loss: 1.5185 - val_accuracy: 0.4363
# Epoch 46/100
# 405/405 [==============================] - 106s 263ms/step - loss: 1.2863 - accuracy: 0.5060 - val_loss: 1.5043 - val_accuracy: 0.4400
# Epoch 47/100
# 405/405 [==============================] - 107s 263ms/step - loss: 1.2630 - accuracy: 0.5179 - val_loss: 1.5686 - val_accuracy: 0.4078
# Epoch 48/100
# 405/405 [==============================] - 106s 262ms/step - loss: 1.2659 - accuracy: 0.5172 - val_loss: 1.4991 - val_accuracy: 0.4288
# Epoch 49/100
# 405/405 [==============================] - 106s 262ms/step - loss: 1.2565 - accuracy: 0.5223 - val_loss: 1.5251 - val_accuracy: 0.4517
# Epoch 50/100
# 405/405 [==============================] - 107s 263ms/step - loss: 1.2927 - accuracy: 0.5088 - val_loss: 1.5444 - val_accuracy: 0.4146
# Epoch 51/100
# 405/405 [==============================] - 106s 261ms/step - loss: 1.2602 - accuracy: 0.5246 - val_loss: 1.6490 - val_accuracy: 0.4375
# Epoch 52/100
# 405/405 [==============================] - 106s 262ms/step - loss: 1.2502 - accuracy: 0.5247 - val_loss: 1.6622 - val_accuracy: 0.4041
# Epoch 53/100
# 405/405 [==============================] - 107s 264ms/step - loss: 1.2442 - accuracy: 0.5301 - val_loss: 1.4561 - val_accuracy: 0.4499
# Epoch 54/100
# 405/405 [==============================] - 106s 262ms/step - loss: 1.2871 - accuracy: 0.5111 - val_loss: 1.6032 - val_accuracy: 0.4270
# Epoch 55/100
# 405/405 [==============================] - 106s 263ms/step - loss: 1.2622 - accuracy: 0.5279 - val_loss: 1.4542 - val_accuracy: 0.4604
# Epoch 56/100
# 405/405 [==============================] - 107s 263ms/step - loss: 1.2280 - accuracy: 0.5380 - val_loss: 1.5258 - val_accuracy: 0.4301
# Epoch 57/100
# 405/405 [==============================] - 108s 267ms/step - loss: 1.2553 - accuracy: 0.5274 - val_loss: 1.4832 - val_accuracy: 0.4394
# Epoch 58/100
# 405/405 [==============================] - 106s 263ms/step - loss: 1.2757 - accuracy: 0.5177 - val_loss: 1.5913 - val_accuracy: 0.4226
# Epoch 59/100
# 405/405 [==============================] - 106s 262ms/step - loss: 1.2434 - accuracy: 0.5245 - val_loss: 1.4549 - val_accuracy: 0.4629
# Epoch 60/100
# 405/405 [==============================] - 107s 264ms/step - loss: 1.2347 - accuracy: 0.5372 - val_loss: 1.6766 - val_accuracy: 0.4387
# Epoch 61/100
# 405/405 [==============================] - 107s 264ms/step - loss: 1.2593 - accuracy: 0.5229 - val_loss: 1.7018 - val_accuracy: 0.4356
# Epoch 62/100
# 405/405 [==============================] - 107s 265ms/step - loss: 1.2472 - accuracy: 0.5305 - val_loss: 1.6730 - val_accuracy: 0.3818
# Epoch 63/100
# 405/405 [==============================] - 107s 264ms/step - loss: 1.2416 - accuracy: 0.5292 - val_loss: 1.7184 - val_accuracy: 0.4196
# Epoch 64/100
# 405/405 [==============================] - 108s 266ms/step - loss: 1.2315 - accuracy: 0.5309 - val_loss: 1.5041 - val_accuracy: 0.4394
# Epoch 65/100
# 405/405 [==============================] - 108s 266ms/step - loss: 1.2512 - accuracy: 0.5333 - val_loss: 1.5028 - val_accuracy: 0.4462
# Epoch 66/100
# 405/405 [==============================] - 110s 273ms/step - loss: 1.2352 - accuracy: 0.5279 - val_loss: 1.5196 - val_accuracy: 0.4158
# Epoch 67/100
# 405/405 [==============================] - 110s 272ms/step - loss: 1.2609 - accuracy: 0.5205 - val_loss: 1.6659 - val_accuracy: 0.4325
# Epoch 68/100
# 405/405 [==============================] - 112s 276ms/step - loss: 1.2453 - accuracy: 0.5294 - val_loss: 1.6635 - val_accuracy: 0.4381
# Epoch 69/100
# 405/405 [==============================] - 110s 271ms/step - loss: 1.2153 - accuracy: 0.5402 - val_loss: 1.8063 - val_accuracy: 0.4233
# Epoch 70/100
# 405/405 [==============================] - 109s 270ms/step - loss: 1.2313 - accuracy: 0.5369 - val_loss: 1.6033 - val_accuracy: 0.4307
# Epoch 71/100
# 405/405 [==============================] - 110s 272ms/step - loss: 1.2139 - accuracy: 0.5367 - val_loss: 1.5468 - val_accuracy: 0.4425
# Epoch 72/100
# 405/405 [==============================] - 112s 277ms/step - loss: 1.2115 - accuracy: 0.5402 - val_loss: 1.5706 - val_accuracy: 0.4264
# Epoch 73/100
# 405/405 [==============================] - 112s 276ms/step - loss: 1.2113 - accuracy: 0.5412 - val_loss: 1.6782 - val_accuracy: 0.4325
# Epoch 74/100
# 405/405 [==============================] - 111s 274ms/step - loss: 1.2203 - accuracy: 0.5397 - val_loss: 1.5269 - val_accuracy: 0.4418
# Epoch 75/100
# 405/405 [==============================] - 110s 273ms/step - loss: 1.2042 - accuracy: 0.5475 - val_loss: 1.5384 - val_accuracy: 0.4288
# Epoch 76/100
# 405/405 [==============================] - 110s 272ms/step - loss: 1.2218 - accuracy: 0.5339 - val_loss: 1.4671 - val_accuracy: 0.4524
# Epoch 77/100
# 405/405 [==============================] - 109s 269ms/step - loss: 1.2106 - accuracy: 0.5396 - val_loss: 1.4929 - val_accuracy: 0.4573
# Epoch 78/100
# 405/405 [==============================] - 109s 269ms/step - loss: 1.2241 - accuracy: 0.5412 - val_loss: 1.5413 - val_accuracy: 0.4499
# Epoch 79/100
# 405/405 [==============================] - 110s 271ms/step - loss: 1.2078 - accuracy: 0.5419 - val_loss: 1.6613 - val_accuracy: 0.4028
# Epoch 80/100
# 405/405 [==============================] - 110s 273ms/step - loss: 1.2188 - accuracy: 0.5335 - val_loss: 1.5341 - val_accuracy: 0.4524
# Epoch 81/100
# 405/405 [==============================] - 109s 269ms/step - loss: 1.2033 - accuracy: 0.5470 - val_loss: 1.6705 - val_accuracy: 0.4165
# Epoch 82/100
# 405/405 [==============================] - 108s 267ms/step - loss: 1.1976 - accuracy: 0.5421 - val_loss: 1.5535 - val_accuracy: 0.4381
# Epoch 83/100
# 405/405 [==============================] - 107s 264ms/step - loss: 1.2065 - accuracy: 0.5389 - val_loss: 1.4537 - val_accuracy: 0.4592
# Epoch 84/100
# 405/405 [==============================] - 108s 267ms/step - loss: 1.2133 - accuracy: 0.5442 - val_loss: 1.4726 - val_accuracy: 0.4703
# Epoch 85/100
# 405/405 [==============================] - 107s 264ms/step - loss: 1.1954 - accuracy: 0.5452 - val_loss: 1.5730 - val_accuracy: 0.4282
# Epoch 86/100
# 405/405 [==============================] - 107s 264ms/step - loss: 1.1865 - accuracy: 0.5530 - val_loss: 1.6013 - val_accuracy: 0.4425
# Epoch 87/100
# 405/405 [==============================] - 108s 266ms/step - loss: 1.1955 - accuracy: 0.5482 - val_loss: 1.4901 - val_accuracy: 0.4629
# Epoch 88/100
# 405/405 [==============================] - 107s 263ms/step - loss: 1.2316 - accuracy: 0.5300 - val_loss: 1.8817 - val_accuracy: 0.3713
# Epoch 89/100
# 405/405 [==============================] - 107s 264ms/step - loss: 1.2057 - accuracy: 0.5419 - val_loss: 1.4805 - val_accuracy: 0.4548
# Epoch 90/100
# 405/405 [==============================] - 108s 266ms/step - loss: 1.2046 - accuracy: 0.5430 - val_loss: 1.6003 - val_accuracy: 0.4121
# Epoch 91/100
# 405/405 [==============================] - 108s 266ms/step - loss: 1.1778 - accuracy: 0.5570 - val_loss: 1.5912 - val_accuracy: 0.4208
# Epoch 92/100
# 405/405 [==============================] - 106s 261ms/step - loss: 1.2315 - accuracy: 0.5335 - val_loss: 1.6120 - val_accuracy: 0.4573
# Epoch 93/100
# 405/405 [==============================] - 107s 264ms/step - loss: 1.2020 - accuracy: 0.5444 - val_loss: 1.5366 - val_accuracy: 0.4325
# Epoch 94/100
# 405/405 [==============================] - 106s 262ms/step - loss: 1.1906 - accuracy: 0.5477 - val_loss: 1.5007 - val_accuracy: 0.4474
# Epoch 95/100
# 405/405 [==============================] - 105s 259ms/step - loss: 1.2128 - accuracy: 0.5414 - val_loss: 1.4876 - val_accuracy: 0.4431
# Epoch 96/100
# 405/405 [==============================] - 105s 261ms/step - loss: 1.1753 - accuracy: 0.5500 - val_loss: 1.5604 - val_accuracy: 0.4530
# Epoch 97/100
# 405/405 [==============================] - 109s 270ms/step - loss: 1.1808 - accuracy: 0.5522 - val_loss: 1.5947 - val_accuracy: 0.4165
# Epoch 98/100
# 405/405 [==============================] - 106s 261ms/step - loss: 1.2024 - accuracy: 0.5433 - val_loss: 1.6731 - val_accuracy: 0.4183
# Epoch 99/100
# 405/405 [==============================] - 106s 263ms/step - loss: 1.1824 - accuracy: 0.5561 - val_loss: 1.7890 - val_accuracy: 0.3843
# Epoch 100/100
# 405/405 [==============================] - 109s 268ms/step - loss: 1.1820 - accuracy: 0.5512 - val_loss: 1.5380 - val_accuracy: 0.4598
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %% [markdown]
# # Evaluate Model's Training & Validation Results

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()

# %% [markdown]
# # Generate Predictions With Model

# %%
y_pred = model.predict(test_batches).argmax(axis=1)

# %%
model.evaluate(test_batches)
# Out:
# 51/51 [==============================] - 13s 249ms/step - loss: 1.4365 - accuracy: 0.4696
# [1.4364570379257202, 0.469565212726593]

# %% [markdown]
# # Evaluate Model's Prediction Results

# %%
# generate classification report
class_labels = list(test_batches.class_indices.keys())
report = classification_report(test_batches.classes, y_pred, target_names=class_labels, output_dict=True)
df_classification_report = pd.DataFrame(report).transpose()
df_classification_report
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score      support
# hatchback      0.352941  0.076923  0.126316   156.000000
# mpv            0.322034  0.527778  0.400000   108.000000
# sedan          0.392989  0.514493  0.445607   414.000000
# sport          0.496337  0.599558  0.543086   452.000000
# suv            0.594470  0.454225  0.514970   284.000000
# truck          0.787234  0.462500  0.582677   160.000000
# wagon          0.000000  0.000000  0.000000    36.000000
# accuracy       0.469565  0.469565  0.469565     0.469565
# macro avg      0.420858  0.376497  0.373237  1610.000000
# weighted avg   0.479296  0.469565  0.454870  1610.000000

# %%
# compute confusion matrix
matrix = confusion_matrix(test_batches.classes, y_pred)

# normalize confusion matrix
matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
matrix = np.around(matrix, decimals=2)

# generate confusion matrix heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(matrix, annot=True, xticklabels=class_labels, yticklabels=class_labels)
plt.ylabel('Test Values')
plt.xlabel('Predicted Values')
# Out:
# Text(0.5, 69.0, 'Predicted Values')

# %% [markdown]
# # Compute Execution Time

# %%
execution_time_s = round(time.time() - start_time, 2)
execution_time_m = round(execution_time_s/60, 2)
execution_time_h = round(execution_time_m/60, 2)

print('Execution Time (Hours):', execution_time_h)
print('Execution Time (Minutes):', execution_time_m)
print('Execution Time (Seconds):', execution_time_s)
# Out:
# Execution Time (Hours): 2.96
# Execution Time (Minutes): 177.87
# Execution Time (Seconds): 10672.24
