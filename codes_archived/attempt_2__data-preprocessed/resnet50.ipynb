# %%
# !pip install pandas numpy seaborn matplotlib tensorflow keras sklearn &> /dev/null

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet50

import time
start_time = time.time()

# %%
PATH_DATA_TRAIN = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/train'
PATH_DATA_TEST = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/test'
PATH_DATA_VALIDATION = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/validation'
PATH_SAVED_MODEL = 'resnet50.h5'

# %% [markdown]
# # Load Dataset As Generators

# %%
generator = ImageDataGenerator(rescale = 1./255.)

target_size = (100, 100)
batch_size = 32

train_batches = generator.flow_from_directory(
    PATH_DATA_TRAIN, class_mode='categorical', 
    batch_size=batch_size, target_size=target_size
)

validation_batches = generator.flow_from_directory(
    PATH_DATA_VALIDATION, class_mode='categorical',  
    batch_size=batch_size, target_size=target_size
)

test_batches = generator.flow_from_directory(
    PATH_DATA_TEST, class_mode='categorical', shuffle=False, 
    batch_size=batch_size, target_size=target_size
)
# Out:
# Found 12959 images belonging to 7 classes.
# Found 1616 images belonging to 7 classes.
# Found 1610 images belonging to 7 classes.

# %%
# preview data (batch size, width, height, colors)
print('x_train shape:', train_batches[0][0].shape)
print('x_validation shape:', validation_batches[0][0].shape)
print('x_test shape:', test_batches[0][0].shape)
print('y_train shape:', train_batches[0][1].shape)
print('y_validation shape:', validation_batches[0][1].shape)
print('y_test shape:', test_batches[0][1].shape)
# Out:
# x_train shape: (32, 100, 100, 3)
# x_validation shape: (32, 100, 100, 3)
# x_test shape: (32, 100, 100, 3)
# y_train shape: (32, 7)
# y_validation shape: (32, 7)
# y_test shape: (32, 7)

# %%
# input & output shape
input_shape = train_batches[0][0][0].shape
output_shape = len(train_batches[0][1][0])

# display input & output shape
print('Input Shape:', input_shape)
print('Output Shape:', output_shape)
# Out:
# Input Shape: (100, 100, 3)
# Output Shape: 7

# %% [markdown]
# # Build & Compile Model

# %%
model = ResNet50(
    input_shape=input_shape,
    classes=output_shape,
    weights=None,
    classifier_activation='softmax'
)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# 2022-11-16 07:23:29.917363: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 07:23:29.918301: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 07:23:30.077099: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 07:23:30.078001: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 07:23:30.078786: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 07:23:30.079598: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 07:23:30.081523: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-16 07:23:30.326541: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 07:23:30.327663: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 07:23:30.328429: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 07:23:30.329144: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 07:23:30.329902: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 07:23:30.330626: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 07:23:33.661586: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 07:23:33.662592: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 07:23:33.663412: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 07:23:33.664161: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 07:23:33.664903: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 07:23:33.665607: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-11-16 07:23:33.669511: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 07:23:33.670292: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 106, 106, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 50, 50, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 50, 50, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 50, 50, 64)   0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 52, 52, 64)   0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 25, 25, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 25, 25, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 25, 25, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 25, 25, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 25, 25, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 25, 25, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 25, 25, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 25, 25, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 25, 25, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 25, 25, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 25, 25, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 25, 25, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 25, 25, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 25, 25, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 25, 25, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 25, 25, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 25, 25, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 25, 25, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 25, 25, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 25, 25, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 25, 25, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 25, 25, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 25, 25, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 25, 25, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 25, 25, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 25, 25, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 25, 25, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 25, 25, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 25, 25, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 25, 25, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 25, 25, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 25, 25, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 25, 25, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 13, 13, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 13, 13, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 13, 13, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 13, 13, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 13, 13, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 13, 13, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 13, 13, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 13, 13, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 13, 13, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 13, 13, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 13, 13, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 13, 13, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 13, 13, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 13, 13, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 13, 13, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 13, 13, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 13, 13, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 13, 13, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 13, 13, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 13, 13, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 13, 13, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 13, 13, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 13, 13, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 13, 13, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 13, 13, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 13, 13, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 13, 13, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 13, 13, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 13, 13, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 13, 13, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 13, 13, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 13, 13, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 13, 13, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 13, 13, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 7, 7, 256)    131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 7, 7, 256)    0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 7, 7, 256)    590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 7, 7, 256)    0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 7, 7, 1024)   525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 7, 7, 1024)   263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 7, 7, 1024)   4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 7, 7, 1024)   4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 7, 7, 1024)   0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 7, 7, 1024)   0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 7, 7, 256)    262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 7, 7, 256)    0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 7, 7, 256)    590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 7, 7, 256)    0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 7, 7, 1024)   263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 7, 7, 1024)   4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 7, 7, 1024)   0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 7, 7, 1024)   0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 7, 7, 256)    262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 7, 7, 256)    0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 7, 7, 256)    590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 7, 7, 256)    0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 7, 7, 1024)   263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 7, 7, 1024)   4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 7, 7, 1024)   0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 7, 7, 1024)   0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 7, 7, 256)    262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 7, 7, 256)    0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 7, 7, 256)    590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 7, 7, 256)    0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 7, 7, 1024)   263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 7, 7, 1024)   4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 7, 7, 1024)   0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 7, 7, 1024)   0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 7, 7, 256)    262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 7, 7, 256)    0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 7, 7, 256)    590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 7, 7, 256)    0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 7, 7, 1024)   263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 7, 7, 1024)   4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 7, 7, 1024)   0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 7, 7, 1024)   0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 7, 7, 256)    262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 7, 7, 256)    0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 7, 7, 256)    590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 7, 7, 256)    0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 7, 7, 1024)   263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 7, 7, 1024)   4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 7, 7, 1024)   0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 7, 7, 1024)   0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 4, 4, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 4, 4, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 4, 4, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 4, 4, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 4, 4, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 4, 4, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 4, 4, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 4, 4, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 4, 4, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 4, 4, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 4, 4, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 4, 4, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 4, 4, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 4, 4, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 4, 4, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 4, 4, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 4, 4, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 4, 4, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 4, 4, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 4, 4, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 4, 4, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 4, 4, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 4, 4, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 4, 4, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 4, 4, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 4, 4, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 4, 4, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 4, 4, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 4, 4, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 4, 4, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 4, 4, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 4, 4, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 7)            14343       avg_pool[0][0]
# ==================================================================================================
# Total params: 23,602,055
# Trainable params: 23,548,935
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [markdown]
# # Train Model

# %%
# train model
r = model.fit(train_batches, validation_data=validation_batches, epochs=100)

# save model
model.save(PATH_SAVED_MODEL)

# load model
# model = load_model(PATH_SAVED_MODEL)
# Out:
# 2022-11-16 07:23:35.243506: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-11-16 07:23:41.981524: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 405/405 [==============================] - 165s 369ms/step - loss: 1.8049 - accuracy: 0.3464 - val_loss: 3.0022 - val_accuracy: 0.1776
# Epoch 2/100
# 405/405 [==============================] - 106s 261ms/step - loss: 1.3731 - accuracy: 0.4834 - val_loss: 1.8025 - val_accuracy: 0.4344
# Epoch 3/100
# 405/405 [==============================] - 106s 262ms/step - loss: 1.1322 - accuracy: 0.5710 - val_loss: 1.7841 - val_accuracy: 0.4313
# Epoch 4/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.9768 - accuracy: 0.6352 - val_loss: 2.0336 - val_accuracy: 0.3738
# Epoch 5/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.8731 - accuracy: 0.6708 - val_loss: 5.3377 - val_accuracy: 0.2729
# Epoch 6/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.8089 - accuracy: 0.7015 - val_loss: 1.5472 - val_accuracy: 0.5173
# Epoch 7/100
# 405/405 [==============================] - 107s 264ms/step - loss: 0.7771 - accuracy: 0.7089 - val_loss: 2.0468 - val_accuracy: 0.4251
# Epoch 8/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.6861 - accuracy: 0.7420 - val_loss: 2.1973 - val_accuracy: 0.2853
# Epoch 9/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.6422 - accuracy: 0.7588 - val_loss: 8.3799 - val_accuracy: 0.2432
# Epoch 10/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.6173 - accuracy: 0.7707 - val_loss: 1.5158 - val_accuracy: 0.5105
# Epoch 11/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.5867 - accuracy: 0.7840 - val_loss: 3.8464 - val_accuracy: 0.3249
# Epoch 12/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.5625 - accuracy: 0.7919 - val_loss: 1.3530 - val_accuracy: 0.5897
# Epoch 13/100
# 405/405 [==============================] - 105s 258ms/step - loss: 0.4596 - accuracy: 0.8264 - val_loss: 1.2965 - val_accuracy: 0.5947
# Epoch 14/100
# 405/405 [==============================] - 105s 258ms/step - loss: 0.3954 - accuracy: 0.8501 - val_loss: 1.9076 - val_accuracy: 0.5043
# Epoch 15/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.4207 - accuracy: 0.8473 - val_loss: 1.7359 - val_accuracy: 0.5724
# Epoch 16/100
# 405/405 [==============================] - 104s 258ms/step - loss: 0.2921 - accuracy: 0.8930 - val_loss: 1.3315 - val_accuracy: 0.6454
# Epoch 17/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.2769 - accuracy: 0.8985 - val_loss: 1.2667 - val_accuracy: 0.6757
# Epoch 18/100
# 405/405 [==============================] - 109s 268ms/step - loss: 0.2868 - accuracy: 0.8962 - val_loss: 1.1807 - val_accuracy: 0.7005
# Epoch 19/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.1696 - accuracy: 0.9406 - val_loss: 1.3579 - val_accuracy: 0.6609
# Epoch 20/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.1760 - accuracy: 0.9356 - val_loss: 1.4750 - val_accuracy: 0.6213
# Epoch 21/100
# 405/405 [==============================] - 105s 258ms/step - loss: 0.1695 - accuracy: 0.9404 - val_loss: 2.1457 - val_accuracy: 0.5811
# Epoch 22/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.1435 - accuracy: 0.9470 - val_loss: 1.7236 - val_accuracy: 0.6436
# Epoch 23/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.1888 - accuracy: 0.9349 - val_loss: 810.0880 - val_accuracy: 0.2754
# Epoch 24/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.2804 - accuracy: 0.9004 - val_loss: 1.3157 - val_accuracy: 0.6807
# Epoch 25/100
# 405/405 [==============================] - 105s 258ms/step - loss: 0.0942 - accuracy: 0.9662 - val_loss: 1.5549 - val_accuracy: 0.6776
# Epoch 26/100
# 405/405 [==============================] - 105s 258ms/step - loss: 0.1058 - accuracy: 0.9627 - val_loss: 1.4553 - val_accuracy: 0.6764
# Epoch 27/100
# 405/405 [==============================] - 104s 258ms/step - loss: 0.0696 - accuracy: 0.9748 - val_loss: 6.9692 - val_accuracy: 0.4010
# Epoch 28/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.2215 - accuracy: 0.9267 - val_loss: 2.4071 - val_accuracy: 0.5278
# Epoch 29/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.0560 - accuracy: 0.9812 - val_loss: 5.1387 - val_accuracy: 0.5223
# Epoch 30/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.0897 - accuracy: 0.9688 - val_loss: 1.4834 - val_accuracy: 0.6962
# Epoch 31/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.0682 - accuracy: 0.9782 - val_loss: 1.7238 - val_accuracy: 0.6813
# Epoch 32/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.3042 - accuracy: 0.9026 - val_loss: 1.1670 - val_accuracy: 0.7240
# Epoch 33/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.0549 - accuracy: 0.9811 - val_loss: 1.8597 - val_accuracy: 0.6689
# Epoch 34/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.0384 - accuracy: 0.9884 - val_loss: 1.6689 - val_accuracy: 0.6646
# Epoch 35/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.0778 - accuracy: 0.9742 - val_loss: 1.9378 - val_accuracy: 0.6634
# Epoch 36/100
# 405/405 [==============================] - 104s 258ms/step - loss: 0.0633 - accuracy: 0.9778 - val_loss: 1.7390 - val_accuracy: 0.6609
# Epoch 37/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.0680 - accuracy: 0.9761 - val_loss: 2.6251 - val_accuracy: 0.5291
# Epoch 38/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.0458 - accuracy: 0.9850 - val_loss: 2.3913 - val_accuracy: 0.6361
# Epoch 39/100
# 405/405 [==============================] - 105s 258ms/step - loss: 0.0669 - accuracy: 0.9772 - val_loss: 1.7997 - val_accuracy: 0.7042
# Epoch 40/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.0906 - accuracy: 0.9692 - val_loss: 1.5241 - val_accuracy: 0.7036
# Epoch 41/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.0685 - accuracy: 0.9796 - val_loss: 3.7629 - val_accuracy: 0.4851
# Epoch 42/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.0574 - accuracy: 0.9801 - val_loss: 1.8273 - val_accuracy: 0.6770
# Epoch 43/100
# 405/405 [==============================] - 105s 258ms/step - loss: 0.0515 - accuracy: 0.9822 - val_loss: 2.2955 - val_accuracy: 0.5644
# Epoch 44/100
# 405/405 [==============================] - 105s 258ms/step - loss: 0.0392 - accuracy: 0.9873 - val_loss: 2.5338 - val_accuracy: 0.5285
# Epoch 45/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.0476 - accuracy: 0.9833 - val_loss: 1.8786 - val_accuracy: 0.7036
# Epoch 46/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.0452 - accuracy: 0.9839 - val_loss: 3.4621 - val_accuracy: 0.4932
# Epoch 47/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.0527 - accuracy: 0.9823 - val_loss: 1.5068 - val_accuracy: 0.7153
# Epoch 48/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.0621 - accuracy: 0.9780 - val_loss: 5.3411 - val_accuracy: 0.3892
# Epoch 49/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.1025 - accuracy: 0.9680 - val_loss: 1.6449 - val_accuracy: 0.6720
# Epoch 50/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.0247 - accuracy: 0.9922 - val_loss: 3.0850 - val_accuracy: 0.5693
# Epoch 51/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.0415 - accuracy: 0.9856 - val_loss: 3.2497 - val_accuracy: 0.5179
# Epoch 52/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.0274 - accuracy: 0.9899 - val_loss: 2.8013 - val_accuracy: 0.6312
# Epoch 53/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.0294 - accuracy: 0.9904 - val_loss: 1.6531 - val_accuracy: 0.7339
# Epoch 54/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.0417 - accuracy: 0.9864 - val_loss: 2.5062 - val_accuracy: 0.6392
# Epoch 55/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.0496 - accuracy: 0.9839 - val_loss: 1.9518 - val_accuracy: 0.6658
# Epoch 56/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.0281 - accuracy: 0.9901 - val_loss: 1.8666 - val_accuracy: 0.7092
# Epoch 57/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.0371 - accuracy: 0.9866 - val_loss: 2.0185 - val_accuracy: 0.6980
# Epoch 58/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.0409 - accuracy: 0.9866 - val_loss: 1.8326 - val_accuracy: 0.7147
# Epoch 59/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.0632 - accuracy: 0.9802 - val_loss: 1.6776 - val_accuracy: 0.6968
# Epoch 60/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.0190 - accuracy: 0.9931 - val_loss: 1.9420 - val_accuracy: 0.7030
# Epoch 61/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.0420 - accuracy: 0.9869 - val_loss: 1.6553 - val_accuracy: 0.7036
# Epoch 62/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.0411 - accuracy: 0.9846 - val_loss: 1.5089 - val_accuracy: 0.7407
# Epoch 63/100
# 405/405 [==============================] - 102s 252ms/step - loss: 0.0213 - accuracy: 0.9929 - val_loss: 3.4623 - val_accuracy: 0.4715
# Epoch 64/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.0246 - accuracy: 0.9914 - val_loss: 1.9956 - val_accuracy: 0.6423
# Epoch 65/100
# 405/405 [==============================] - 105s 258ms/step - loss: 0.0605 - accuracy: 0.9820 - val_loss: 1.7993 - val_accuracy: 0.7085
# Epoch 66/100
# 405/405 [==============================] - 104s 258ms/step - loss: 0.0357 - accuracy: 0.9887 - val_loss: 2.0606 - val_accuracy: 0.6634
# Epoch 67/100
# 405/405 [==============================] - 103s 253ms/step - loss: 0.0205 - accuracy: 0.9937 - val_loss: 2.0986 - val_accuracy: 0.6844
# Epoch 68/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.0307 - accuracy: 0.9894 - val_loss: 1.7660 - val_accuracy: 0.7203
# Epoch 69/100
# 405/405 [==============================] - 105s 258ms/step - loss: 0.0227 - accuracy: 0.9923 - val_loss: 2.3055 - val_accuracy: 0.6980
# Epoch 70/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.0578 - accuracy: 0.9815 - val_loss: 1.9444 - val_accuracy: 0.7104
# Epoch 71/100
# 405/405 [==============================] - 105s 258ms/step - loss: 0.0132 - accuracy: 0.9961 - val_loss: 1.9007 - val_accuracy: 0.6993
# Epoch 72/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.0127 - accuracy: 0.9951 - val_loss: 1.9038 - val_accuracy: 0.7036
# Epoch 73/100
# 405/405 [==============================] - 104s 258ms/step - loss: 0.0303 - accuracy: 0.9912 - val_loss: 1.6779 - val_accuracy: 0.6584
# Epoch 74/100
# 405/405 [==============================] - 108s 265ms/step - loss: 0.0249 - accuracy: 0.9923 - val_loss: 1.9326 - val_accuracy: 0.6993
# Epoch 75/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.0293 - accuracy: 0.9903 - val_loss: 1.7454 - val_accuracy: 0.6999
# Epoch 76/100
# 405/405 [==============================] - 105s 260ms/step - loss: 0.0230 - accuracy: 0.9923 - val_loss: 2.1667 - val_accuracy: 0.6986
# Epoch 77/100
# 405/405 [==============================] - 105s 258ms/step - loss: 0.0207 - accuracy: 0.9924 - val_loss: 1.8648 - val_accuracy: 0.7123
# Epoch 78/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.0331 - accuracy: 0.9888 - val_loss: 2.1181 - val_accuracy: 0.6281
# Epoch 79/100
# 405/405 [==============================] - 104s 258ms/step - loss: 0.0193 - accuracy: 0.9943 - val_loss: 1.9554 - val_accuracy: 0.6863
# Epoch 80/100
# 405/405 [==============================] - 103s 253ms/step - loss: 0.0763 - accuracy: 0.9791 - val_loss: 2.4688 - val_accuracy: 0.6033
# Epoch 81/100
# 405/405 [==============================] - 102s 251ms/step - loss: 0.0388 - accuracy: 0.9867 - val_loss: 1.8245 - val_accuracy: 0.7153
# Epoch 82/100
# 405/405 [==============================] - 103s 253ms/step - loss: 0.0081 - accuracy: 0.9982 - val_loss: 2.2616 - val_accuracy: 0.7030
# Epoch 83/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.0160 - accuracy: 0.9954 - val_loss: 1.6228 - val_accuracy: 0.7351
# Epoch 84/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.0044 - accuracy: 0.9989 - val_loss: 1.8003 - val_accuracy: 0.7197
# Epoch 85/100
# 405/405 [==============================] - 103s 253ms/step - loss: 0.0349 - accuracy: 0.9884 - val_loss: 1.6111 - val_accuracy: 0.7333
# Epoch 86/100
# 405/405 [==============================] - 103s 253ms/step - loss: 0.0420 - accuracy: 0.9863 - val_loss: 3.3821 - val_accuracy: 0.5371
# Epoch 87/100
# 405/405 [==============================] - 105s 258ms/step - loss: 0.0584 - accuracy: 0.9815 - val_loss: 1.6366 - val_accuracy: 0.7209
# Epoch 88/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.0068 - accuracy: 0.9983 - val_loss: 1.6827 - val_accuracy: 0.7271
# Epoch 89/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 1.7063 - val_accuracy: 0.7407
# Epoch 90/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 1.9554 - val_accuracy: 0.7259
# Epoch 91/100
# 405/405 [==============================] - 103s 253ms/step - loss: 0.0228 - accuracy: 0.9921 - val_loss: 1.7891 - val_accuracy: 0.7098
# Epoch 92/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.0362 - accuracy: 0.9877 - val_loss: 2.1628 - val_accuracy: 0.6621
# Epoch 93/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.0547 - accuracy: 0.9840 - val_loss: 1.5544 - val_accuracy: 0.7321
# Epoch 94/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.0175 - accuracy: 0.9945 - val_loss: 1.9309 - val_accuracy: 0.6838
# Epoch 95/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.0192 - accuracy: 0.9932 - val_loss: 1.7954 - val_accuracy: 0.7364
# Epoch 96/100
# 405/405 [==============================] - 103s 253ms/step - loss: 0.0051 - accuracy: 0.9981 - val_loss: 2.0556 - val_accuracy: 0.7215
# Epoch 97/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.0083 - accuracy: 0.9974 - val_loss: 2.0729 - val_accuracy: 0.7327
# Epoch 98/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.0248 - accuracy: 0.9911 - val_loss: 2.0629 - val_accuracy: 0.7098
# Epoch 99/100
# 405/405 [==============================] - 103s 253ms/step - loss: 0.1062 - accuracy: 0.9689 - val_loss: 2.3490 - val_accuracy: 0.6021
# Epoch 100/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.0419 - accuracy: 0.9876 - val_loss: 1.6887 - val_accuracy: 0.6757
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %% [markdown]
# # Evaluate Model's Training & Validation Results

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()

# %% [markdown]
# # Generate Predictions With Model

# %%
y_pred = model.predict(test_batches).argmax(axis=1)

# %%
model.evaluate(test_batches)
# Out:
# 51/51 [==============================] - 11s 216ms/step - loss: 1.6603 - accuracy: 0.6789
# [1.6602922677993774, 0.6788820028305054]

# %% [markdown]
# # Evaluate Model's Prediction Results

# %%
# generate classification report
class_labels = list(test_batches.class_indices.keys())
report = classification_report(test_batches.classes, y_pred, target_names=class_labels, output_dict=True)
df_classification_report = pd.DataFrame(report).transpose()
df_classification_report
# Out:
#               precision    recall  f1-score      support
# hatchback      0.633333  0.243590  0.351852   156.000000
# mpv            0.564885  0.685185  0.619247   108.000000
# sedan          0.649462  0.729469  0.687144   414.000000
# sport          0.741294  0.659292  0.697892   452.000000
# suv            0.639474  0.855634  0.731928   284.000000
# truck          0.851351  0.787500  0.818182   160.000000
# wagon          0.500000  0.333333  0.400000    36.000000
# accuracy       0.678882  0.678882  0.678882     0.678882
# macro avg      0.654257  0.613429  0.615178  1610.000000
# weighted avg   0.682967  0.678882  0.667621  1610.000000

# %%
# compute confusion matrix
matrix = confusion_matrix(test_batches.classes, y_pred)

# normalize confusion matrix
matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
matrix = np.around(matrix, decimals=2)

# generate confusion matrix heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(matrix, annot=True, xticklabels=class_labels, yticklabels=class_labels)
plt.ylabel('Test Values')
plt.xlabel('Predicted Values')
# Out:
# Text(0.5, 69.0, 'Predicted Values')

# %% [markdown]
# # Compute Execution Time

# %%
execution_time_s = round(time.time() - start_time, 2)
execution_time_m = round(execution_time_s/60, 2)
execution_time_h = round(execution_time_m/60, 2)

print('Execution Time (Hours):', execution_time_h)
print('Execution Time (Minutes):', execution_time_m)
print('Execution Time (Seconds):', execution_time_s)
# Out:
# Execution Time (Hours): 2.96
# Execution Time (Minutes): 177.57
# Execution Time (Seconds): 10654.07
