# %%
# !pip install pandas numpy seaborn matplotlib tensorflow keras sklearn &> /dev/null

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout, GlobalMaxPooling2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.models import Model

import time
start_time = time.time()

# %%
PATH_DATA_TRAIN = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/train'
PATH_DATA_TEST = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/test'
PATH_DATA_VALIDATION = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/validation'
PATH_SAVED_MODEL = 'mario.h5'

# %% [markdown]
# # Load Dataset As Generators

# %%
generator = ImageDataGenerator(rescale = 1./255.)

target_size = (100, 100)
batch_size = 32

train_batches = generator.flow_from_directory(
    PATH_DATA_TRAIN, class_mode='categorical', 
    batch_size=batch_size, target_size=target_size
)

validation_batches = generator.flow_from_directory(
    PATH_DATA_VALIDATION, class_mode='categorical',  
    batch_size=batch_size, target_size=target_size
)

test_batches = generator.flow_from_directory(
    PATH_DATA_TEST, class_mode='categorical', shuffle=False, 
    batch_size=batch_size, target_size=target_size
)
# Out:
# Found 12959 images belonging to 7 classes.
# Found 1616 images belonging to 7 classes.
# Found 1610 images belonging to 7 classes.

# %%
# preview data (batch size, width, height, colors)
print('x_train shape:', train_batches[0][0].shape)
print('x_validation shape:', validation_batches[0][0].shape)
print('x_test shape:', test_batches[0][0].shape)
print('y_train shape:', train_batches[0][1].shape)
print('y_validation shape:', validation_batches[0][1].shape)
print('y_test shape:', test_batches[0][1].shape)
# Out:
# x_train shape: (32, 100, 100, 3)
# x_validation shape: (32, 100, 100, 3)
# x_test shape: (32, 100, 100, 3)
# y_train shape: (32, 7)
# y_validation shape: (32, 7)
# y_test shape: (32, 7)

# %%
# input & output shape
input_shape = train_batches[0][0][0].shape
output_shape = len(train_batches[0][1][0])

# display input & output shape
print('Input Shape:', input_shape)
print('Output Shape:', output_shape)
# Out:
# Input Shape: (100, 100, 3)
# Output Shape: 7

# %% [markdown]
# # Build & Compile Model

# %%
i = Input(shape=input_shape)

x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = BatchNormalization()(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Flatten()(x)
x = Dropout(0.2)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(output_shape, activation='softmax')(x)

model = Model(i, x)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# 2022-11-16 04:30:23.609306: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:30:23.610313: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:30:23.784654: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:30:23.785649: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:30:23.786505: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:30:23.787396: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:30:23.789392: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-16 04:30:24.041369: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:30:24.042280: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:30:24.043202: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:30:24.044143: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:30:24.044961: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:30:24.045686: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:30:27.358254: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:30:27.359097: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:30:27.359885: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:30:27.360667: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:30:27.361414: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:30:27.362085: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-11-16 04:30:27.366218: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:30:27.366894: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 100, 100, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 100, 100, 32)      128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 100, 100, 32)      9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 100, 100, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 50, 50, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 50, 50, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 50, 50, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 50, 50, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 50, 50, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 25, 25, 128)       73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 25, 25, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 25, 25, 128)       147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 25, 25, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 18432)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              18875392
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 7175
# =================================================================
# Total params: 19,171,367
# Trainable params: 19,170,471
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# # Train Model

# %%
# train model
r = model.fit(train_batches, validation_data=validation_batches, epochs=100)

# save model
model.save(PATH_SAVED_MODEL)

# load model
# model = load_model(PATH_SAVED_MODEL)
# Out:
# 2022-11-16 04:30:28.122452: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-11-16 04:30:30.710028: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 405/405 [==============================] - 137s 311ms/step - loss: 2.3894 - accuracy: 0.2896 - val_loss: 16.6805 - val_accuracy: 0.2556
# Epoch 2/100
# 405/405 [==============================] - 97s 240ms/step - loss: 1.6249 - accuracy: 0.3490 - val_loss: 1.7476 - val_accuracy: 0.3032
# Epoch 3/100
# 405/405 [==============================] - 97s 241ms/step - loss: 1.5073 - accuracy: 0.3958 - val_loss: 2.7756 - val_accuracy: 0.2339
# Epoch 4/100
# 405/405 [==============================] - 97s 239ms/step - loss: 1.3948 - accuracy: 0.4371 - val_loss: 1.5083 - val_accuracy: 0.3899
# Epoch 5/100
# 405/405 [==============================] - 99s 243ms/step - loss: 1.3161 - accuracy: 0.4757 - val_loss: 1.8375 - val_accuracy: 0.3465
# Epoch 6/100
# 405/405 [==============================] - 98s 242ms/step - loss: 1.2489 - accuracy: 0.5084 - val_loss: 1.3529 - val_accuracy: 0.5050
# Epoch 7/100
# 405/405 [==============================] - 98s 241ms/step - loss: 1.1700 - accuracy: 0.5455 - val_loss: 4.8650 - val_accuracy: 0.2605
# Epoch 8/100
# 405/405 [==============================] - 97s 239ms/step - loss: 1.0844 - accuracy: 0.5740 - val_loss: 1.7185 - val_accuracy: 0.4691
# Epoch 9/100
# 405/405 [==============================] - 97s 239ms/step - loss: 0.9996 - accuracy: 0.6159 - val_loss: 2.1646 - val_accuracy: 0.3750
# Epoch 10/100
# 405/405 [==============================] - 96s 238ms/step - loss: 0.9534 - accuracy: 0.6370 - val_loss: 1.8736 - val_accuracy: 0.3527
# Epoch 11/100
# 405/405 [==============================] - 97s 239ms/step - loss: 0.8495 - accuracy: 0.6771 - val_loss: 0.9868 - val_accuracy: 0.6491
# Epoch 12/100
# 405/405 [==============================] - 97s 239ms/step - loss: 0.7764 - accuracy: 0.7075 - val_loss: 3.5726 - val_accuracy: 0.2778
# Epoch 13/100
# 405/405 [==============================] - 97s 240ms/step - loss: 0.7046 - accuracy: 0.7385 - val_loss: 1.7791 - val_accuracy: 0.4623
# Epoch 14/100
# 405/405 [==============================] - 97s 239ms/step - loss: 0.6392 - accuracy: 0.7620 - val_loss: 0.8995 - val_accuracy: 0.6832
# Epoch 15/100
# 405/405 [==============================] - 95s 236ms/step - loss: 0.5907 - accuracy: 0.7834 - val_loss: 0.9285 - val_accuracy: 0.6875
# Epoch 16/100
# 405/405 [==============================] - 96s 237ms/step - loss: 0.5115 - accuracy: 0.8136 - val_loss: 1.0542 - val_accuracy: 0.6733
# Epoch 17/100
# 405/405 [==============================] - 95s 235ms/step - loss: 0.4728 - accuracy: 0.8305 - val_loss: 1.7054 - val_accuracy: 0.5675
# Epoch 18/100
# 405/405 [==============================] - 96s 236ms/step - loss: 0.4145 - accuracy: 0.8503 - val_loss: 1.0542 - val_accuracy: 0.6844
# Epoch 19/100
# 405/405 [==============================] - 96s 237ms/step - loss: 0.3752 - accuracy: 0.8660 - val_loss: 1.3652 - val_accuracy: 0.6986
# Epoch 20/100
# 405/405 [==============================] - 96s 237ms/step - loss: 0.3667 - accuracy: 0.8706 - val_loss: 1.7438 - val_accuracy: 0.6157
# Epoch 21/100
# 405/405 [==============================] - 97s 239ms/step - loss: 0.3161 - accuracy: 0.8852 - val_loss: 1.4039 - val_accuracy: 0.6287
# Epoch 22/100
# 405/405 [==============================] - 96s 238ms/step - loss: 0.2917 - accuracy: 0.8971 - val_loss: 1.0517 - val_accuracy: 0.7104
# Epoch 23/100
# 405/405 [==============================] - 96s 237ms/step - loss: 0.2813 - accuracy: 0.9017 - val_loss: 1.5569 - val_accuracy: 0.6770
# Epoch 24/100
# 405/405 [==============================] - 96s 237ms/step - loss: 0.2457 - accuracy: 0.9130 - val_loss: 1.6064 - val_accuracy: 0.6231
# Epoch 25/100
# 405/405 [==============================] - 97s 239ms/step - loss: 0.2493 - accuracy: 0.9132 - val_loss: 1.0300 - val_accuracy: 0.6918
# Epoch 26/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.2249 - accuracy: 0.9219 - val_loss: 1.3962 - val_accuracy: 0.6751
# Epoch 27/100
# 405/405 [==============================] - 96s 237ms/step - loss: 0.2044 - accuracy: 0.9298 - val_loss: 1.9474 - val_accuracy: 0.6188
# Epoch 28/100
# 405/405 [==============================] - 96s 237ms/step - loss: 0.1932 - accuracy: 0.9333 - val_loss: 2.0080 - val_accuracy: 0.5804
# Epoch 29/100
# 405/405 [==============================] - 95s 235ms/step - loss: 0.1911 - accuracy: 0.9350 - val_loss: 4.6274 - val_accuracy: 0.5557
# Epoch 30/100
# 405/405 [==============================] - 97s 238ms/step - loss: 0.1973 - accuracy: 0.9333 - val_loss: 2.5537 - val_accuracy: 0.6386
# Epoch 31/100
# 405/405 [==============================] - 97s 239ms/step - loss: 0.1783 - accuracy: 0.9431 - val_loss: 1.8490 - val_accuracy: 0.6844
# Epoch 32/100
# 405/405 [==============================] - 97s 239ms/step - loss: 0.1726 - accuracy: 0.9420 - val_loss: 1.4369 - val_accuracy: 0.6702
# Epoch 33/100
# 405/405 [==============================] - 96s 237ms/step - loss: 0.1682 - accuracy: 0.9438 - val_loss: 1.8259 - val_accuracy: 0.6943
# Epoch 34/100
# 405/405 [==============================] - 96s 237ms/step - loss: 0.1643 - accuracy: 0.9461 - val_loss: 1.6589 - val_accuracy: 0.6776
# Epoch 35/100
# 405/405 [==============================] - 97s 239ms/step - loss: 0.1448 - accuracy: 0.9512 - val_loss: 1.4887 - val_accuracy: 0.7252
# Epoch 36/100
# 405/405 [==============================] - 96s 238ms/step - loss: 0.1594 - accuracy: 0.9485 - val_loss: 1.5580 - val_accuracy: 0.7011
# Epoch 37/100
# 405/405 [==============================] - 95s 235ms/step - loss: 0.1418 - accuracy: 0.9526 - val_loss: 1.7640 - val_accuracy: 0.7073
# Epoch 38/100
# 405/405 [==============================] - 96s 236ms/step - loss: 0.1578 - accuracy: 0.9498 - val_loss: 1.3335 - val_accuracy: 0.7135
# Epoch 39/100
# 405/405 [==============================] - 95s 235ms/step - loss: 0.1363 - accuracy: 0.9539 - val_loss: 28.7408 - val_accuracy: 0.4016
# Epoch 40/100
# 405/405 [==============================] - 95s 234ms/step - loss: 0.1279 - accuracy: 0.9586 - val_loss: 1.9588 - val_accuracy: 0.6900
# Epoch 41/100
# 405/405 [==============================] - 95s 234ms/step - loss: 0.1347 - accuracy: 0.9547 - val_loss: 3.0715 - val_accuracy: 0.6652
# Epoch 42/100
# 405/405 [==============================] - 95s 234ms/step - loss: 0.1391 - accuracy: 0.9565 - val_loss: 3.1573 - val_accuracy: 0.6615
# Epoch 43/100
# 405/405 [==============================] - 95s 234ms/step - loss: 0.1356 - accuracy: 0.9586 - val_loss: 6.2515 - val_accuracy: 0.5347
# Epoch 44/100
# 405/405 [==============================] - 95s 235ms/step - loss: 0.1177 - accuracy: 0.9614 - val_loss: 1.5134 - val_accuracy: 0.7011
# Epoch 45/100
# 405/405 [==============================] - 94s 233ms/step - loss: 0.1187 - accuracy: 0.9616 - val_loss: 1.5428 - val_accuracy: 0.6980
# Epoch 46/100
# 405/405 [==============================] - 94s 232ms/step - loss: 0.1141 - accuracy: 0.9629 - val_loss: 4.7507 - val_accuracy: 0.5693
# Epoch 47/100
# 405/405 [==============================] - 95s 234ms/step - loss: 0.0949 - accuracy: 0.9680 - val_loss: 1.6657 - val_accuracy: 0.7246
# Epoch 48/100
# 405/405 [==============================] - 95s 235ms/step - loss: 0.1078 - accuracy: 0.9635 - val_loss: 1.4432 - val_accuracy: 0.7215
# Epoch 49/100
# 405/405 [==============================] - 95s 235ms/step - loss: 0.1237 - accuracy: 0.9623 - val_loss: 2.2164 - val_accuracy: 0.6943
# Epoch 50/100
# 405/405 [==============================] - 95s 234ms/step - loss: 0.0950 - accuracy: 0.9695 - val_loss: 4.4894 - val_accuracy: 0.6231
# Epoch 51/100
# 405/405 [==============================] - 94s 233ms/step - loss: 0.1098 - accuracy: 0.9647 - val_loss: 1.5236 - val_accuracy: 0.7240
# Epoch 52/100
# 405/405 [==============================] - 95s 233ms/step - loss: 0.0974 - accuracy: 0.9691 - val_loss: 2.2665 - val_accuracy: 0.6578
# Epoch 53/100
# 405/405 [==============================] - 94s 233ms/step - loss: 0.0900 - accuracy: 0.9711 - val_loss: 1.6335 - val_accuracy: 0.7215
# Epoch 54/100
# 405/405 [==============================] - 95s 233ms/step - loss: 0.0886 - accuracy: 0.9708 - val_loss: 1.5733 - val_accuracy: 0.7160
# Epoch 55/100
# 405/405 [==============================] - 95s 236ms/step - loss: 0.0956 - accuracy: 0.9702 - val_loss: 1.4181 - val_accuracy: 0.7308
# Epoch 56/100
# 405/405 [==============================] - 95s 234ms/step - loss: 0.0840 - accuracy: 0.9740 - val_loss: 2.2796 - val_accuracy: 0.6405
# Epoch 57/100
# 405/405 [==============================] - 95s 235ms/step - loss: 0.1114 - accuracy: 0.9661 - val_loss: 1.6812 - val_accuracy: 0.7036
# Epoch 58/100
# 405/405 [==============================] - 95s 234ms/step - loss: 0.0890 - accuracy: 0.9709 - val_loss: 1.7687 - val_accuracy: 0.7265
# Epoch 59/100
# 405/405 [==============================] - 95s 236ms/step - loss: 0.0965 - accuracy: 0.9688 - val_loss: 2.0575 - val_accuracy: 0.6683
# Epoch 60/100
# 405/405 [==============================] - 95s 235ms/step - loss: 0.0886 - accuracy: 0.9719 - val_loss: 1.6129 - val_accuracy: 0.7246
# Epoch 61/100
# 405/405 [==============================] - 95s 235ms/step - loss: 0.0795 - accuracy: 0.9758 - val_loss: 1.6582 - val_accuracy: 0.7098
# Epoch 62/100
# 405/405 [==============================] - 95s 235ms/step - loss: 0.0890 - accuracy: 0.9735 - val_loss: 2.0628 - val_accuracy: 0.7129
# Epoch 63/100
# 405/405 [==============================] - 96s 238ms/step - loss: 0.0828 - accuracy: 0.9735 - val_loss: 2.9938 - val_accuracy: 0.6262
# Epoch 64/100
# 405/405 [==============================] - 95s 234ms/step - loss: 0.0885 - accuracy: 0.9714 - val_loss: 2.2187 - val_accuracy: 0.7308
# Epoch 65/100
# 405/405 [==============================] - 96s 236ms/step - loss: 0.0776 - accuracy: 0.9760 - val_loss: 33.7727 - val_accuracy: 0.4548
# Epoch 66/100
# 405/405 [==============================] - 96s 236ms/step - loss: 0.0794 - accuracy: 0.9758 - val_loss: 1.7220 - val_accuracy: 0.7382
# Epoch 67/100
# 405/405 [==============================] - 95s 236ms/step - loss: 0.0697 - accuracy: 0.9786 - val_loss: 1.9204 - val_accuracy: 0.7129
# Epoch 68/100
# 405/405 [==============================] - 96s 238ms/step - loss: 0.0759 - accuracy: 0.9765 - val_loss: 1.5918 - val_accuracy: 0.7166
# Epoch 69/100
# 405/405 [==============================] - 95s 236ms/step - loss: 0.0712 - accuracy: 0.9777 - val_loss: 1.4254 - val_accuracy: 0.7197
# Epoch 70/100
# 405/405 [==============================] - 96s 236ms/step - loss: 0.0706 - accuracy: 0.9793 - val_loss: 1.8091 - val_accuracy: 0.7246
# Epoch 71/100
# 405/405 [==============================] - 95s 234ms/step - loss: 0.0698 - accuracy: 0.9785 - val_loss: 2.2868 - val_accuracy: 0.6819
# Epoch 72/100
# 405/405 [==============================] - 95s 234ms/step - loss: 0.0602 - accuracy: 0.9808 - val_loss: 1.6947 - val_accuracy: 0.7166
# Epoch 73/100
# 405/405 [==============================] - 97s 239ms/step - loss: 0.0632 - accuracy: 0.9820 - val_loss: 2.6513 - val_accuracy: 0.6887
# Epoch 74/100
# 405/405 [==============================] - 96s 237ms/step - loss: 0.0655 - accuracy: 0.9801 - val_loss: 1.6195 - val_accuracy: 0.7283
# Epoch 75/100
# 405/405 [==============================] - 96s 238ms/step - loss: 0.0620 - accuracy: 0.9821 - val_loss: 2.1480 - val_accuracy: 0.6968
# Epoch 76/100
# 405/405 [==============================] - 95s 235ms/step - loss: 0.0795 - accuracy: 0.9769 - val_loss: 1.3125 - val_accuracy: 0.7116
# Epoch 77/100
# 405/405 [==============================] - 95s 235ms/step - loss: 0.0595 - accuracy: 0.9814 - val_loss: 1.7993 - val_accuracy: 0.7364
# Epoch 78/100
# 405/405 [==============================] - 96s 236ms/step - loss: 0.0656 - accuracy: 0.9801 - val_loss: 2.2902 - val_accuracy: 0.6980
# Epoch 79/100
# 405/405 [==============================] - 95s 234ms/step - loss: 0.0748 - accuracy: 0.9782 - val_loss: 1.7217 - val_accuracy: 0.7030
# Epoch 80/100
# 405/405 [==============================] - 96s 236ms/step - loss: 0.0667 - accuracy: 0.9807 - val_loss: 1.7527 - val_accuracy: 0.7327
# Epoch 81/100
# 405/405 [==============================] - 95s 234ms/step - loss: 0.0723 - accuracy: 0.9789 - val_loss: 1.6327 - val_accuracy: 0.6925
# Epoch 82/100
# 405/405 [==============================] - 95s 234ms/step - loss: 0.0482 - accuracy: 0.9850 - val_loss: 1.7007 - val_accuracy: 0.7321
# Epoch 83/100
# 405/405 [==============================] - 94s 233ms/step - loss: 0.0538 - accuracy: 0.9851 - val_loss: 1.6444 - val_accuracy: 0.7141
# Epoch 84/100
# 405/405 [==============================] - 94s 232ms/step - loss: 0.0552 - accuracy: 0.9819 - val_loss: 2.0151 - val_accuracy: 0.7351
# Epoch 85/100
# 405/405 [==============================] - 95s 234ms/step - loss: 0.0525 - accuracy: 0.9847 - val_loss: 2.0505 - val_accuracy: 0.7234
# Epoch 86/100
# 405/405 [==============================] - 95s 236ms/step - loss: 0.0632 - accuracy: 0.9813 - val_loss: 1.7729 - val_accuracy: 0.7092
# Epoch 87/100
# 405/405 [==============================] - 94s 232ms/step - loss: 0.0606 - accuracy: 0.9823 - val_loss: 1.6737 - val_accuracy: 0.7314
# Epoch 88/100
# 405/405 [==============================] - 94s 231ms/step - loss: 0.0608 - accuracy: 0.9829 - val_loss: 1.5286 - val_accuracy: 0.7358
# Epoch 89/100
# 405/405 [==============================] - 93s 231ms/step - loss: 0.0473 - accuracy: 0.9856 - val_loss: 2.2980 - val_accuracy: 0.6757
# Epoch 90/100
# 405/405 [==============================] - 94s 232ms/step - loss: 0.0549 - accuracy: 0.9843 - val_loss: 2.1451 - val_accuracy: 0.7067
# Epoch 91/100
# 405/405 [==============================] - 96s 237ms/step - loss: 0.0648 - accuracy: 0.9830 - val_loss: 2.6855 - val_accuracy: 0.7265
# Epoch 92/100
# 405/405 [==============================] - 94s 232ms/step - loss: 0.0502 - accuracy: 0.9854 - val_loss: 1.9205 - val_accuracy: 0.7166
# Epoch 93/100
# 405/405 [==============================] - 94s 232ms/step - loss: 0.0466 - accuracy: 0.9861 - val_loss: 1.7649 - val_accuracy: 0.7259
# Epoch 94/100
# 405/405 [==============================] - 94s 233ms/step - loss: 0.0416 - accuracy: 0.9876 - val_loss: 3.0421 - val_accuracy: 0.6856
# Epoch 95/100
# 405/405 [==============================] - 94s 233ms/step - loss: 0.0555 - accuracy: 0.9844 - val_loss: 2.5160 - val_accuracy: 0.7110
# Epoch 96/100
# 405/405 [==============================] - 94s 233ms/step - loss: 0.0604 - accuracy: 0.9816 - val_loss: 2.0517 - val_accuracy: 0.7376
# Epoch 97/100
# 405/405 [==============================] - 95s 233ms/step - loss: 0.0499 - accuracy: 0.9849 - val_loss: 1.7124 - val_accuracy: 0.7271
# Epoch 98/100
# 405/405 [==============================] - 94s 232ms/step - loss: 0.0450 - accuracy: 0.9861 - val_loss: 1.9282 - val_accuracy: 0.7240
# Epoch 99/100
# 405/405 [==============================] - 94s 233ms/step - loss: 0.0524 - accuracy: 0.9843 - val_loss: 2.2382 - val_accuracy: 0.6986
# Epoch 100/100
# 405/405 [==============================] - 94s 232ms/step - loss: 0.0417 - accuracy: 0.9881 - val_loss: 1.6352 - val_accuracy: 0.7277

# %% [markdown]
# # Evaluate Model's Training & Validation Results

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()

# %% [markdown]
# # Generate Predictions With Model

# %%
y_pred = model.predict(test_batches).argmax(axis=1)

# %%
model.evaluate(test_batches)
# Out:
# 51/51 [==============================] - 11s 219ms/step - loss: 1.5830 - accuracy: 0.7255
# [1.5830384492874146, 0.7254658341407776]

# %% [markdown]
# # Evaluate Model's Prediction Results

# %%
# generate classification report
class_labels = list(test_batches.class_indices.keys())
report = classification_report(test_batches.classes, y_pred, target_names=class_labels, output_dict=True)
df_classification_report = pd.DataFrame(report).transpose()
df_classification_report
# Out:
#               precision    recall  f1-score      support
# hatchback      0.626263  0.397436  0.486275   156.000000
# mpv            0.831461  0.685185  0.751269   108.000000
# sedan          0.629630  0.739130  0.680000   414.000000
# sport          0.744330  0.798673  0.770544   452.000000
# suv            0.770227  0.838028  0.802698   284.000000
# truck          0.968992  0.781250  0.865052   160.000000
# wagon          0.153846  0.055556  0.081633    36.000000
# accuracy       0.725466  0.725466  0.725466     0.725466
# macro avg      0.674964  0.613608  0.633924  1610.000000
# weighted avg   0.722932  0.725466  0.718084  1610.000000

# %%
# compute confusion matrix
matrix = confusion_matrix(test_batches.classes, y_pred)

# normalize confusion matrix
matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
matrix = np.around(matrix, decimals=2)

# generate confusion matrix heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(matrix, annot=True, xticklabels=class_labels, yticklabels=class_labels)
plt.ylabel('Test Values')
plt.xlabel('Predicted Values')
# Out:
# Text(0.5, 69.0, 'Predicted Values')

# %% [markdown]
# # Compute Execution Time

# %%
execution_time_s = round(time.time() - start_time, 2)
execution_time_m = round(execution_time_s/60, 2)
execution_time_h = round(execution_time_m/60, 2)

print('Execution Time (Hours):', execution_time_h)
print('Execution Time (Minutes):', execution_time_m)
print('Execution Time (Seconds):', execution_time_s)
# Out:
# Execution Time (Hours): 2.73
# Execution Time (Minutes): 163.77
# Execution Time (Seconds): 9826.47
