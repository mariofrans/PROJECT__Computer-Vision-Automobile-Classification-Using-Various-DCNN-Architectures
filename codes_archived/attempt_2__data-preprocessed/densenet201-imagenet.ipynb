# %%
# !pip install pandas numpy seaborn matplotlib tensorflow keras sklearn &> /dev/null

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications import DenseNet201

import time
start_time = time.time()

# %%
PATH_DATA_TRAIN = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/train'
PATH_DATA_TEST = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/test'
PATH_DATA_VALIDATION = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/validation'
PATH_SAVED_MODEL = 'densenet201-imagenet.h5'

# %% [markdown]
# # Load Dataset As Generators

# %%
generator = ImageDataGenerator(rescale = 1./255.)

target_size = (100, 100)
batch_size = 32

train_batches = generator.flow_from_directory(
    PATH_DATA_TRAIN, class_mode='categorical', 
    batch_size=batch_size, target_size=target_size
)

validation_batches = generator.flow_from_directory(
    PATH_DATA_VALIDATION, class_mode='categorical',  
    batch_size=batch_size, target_size=target_size
)

test_batches = generator.flow_from_directory(
    PATH_DATA_TEST, class_mode='categorical', shuffle=False, 
    batch_size=batch_size, target_size=target_size
)
# Out:
# Found 12959 images belonging to 7 classes.
# Found 1616 images belonging to 7 classes.
# Found 1610 images belonging to 7 classes.

# %%
# preview data (batch size, width, height, colors)
print('x_train shape:', train_batches[0][0].shape)
print('x_validation shape:', validation_batches[0][0].shape)
print('x_test shape:', test_batches[0][0].shape)
print('y_train shape:', train_batches[0][1].shape)
print('y_validation shape:', validation_batches[0][1].shape)
print('y_test shape:', test_batches[0][1].shape)
# Out:
# x_train shape: (32, 100, 100, 3)
# x_validation shape: (32, 100, 100, 3)
# x_test shape: (32, 100, 100, 3)
# y_train shape: (32, 7)
# y_validation shape: (32, 7)
# y_test shape: (32, 7)

# %%
# input & output shape
input_shape = train_batches[0][0][0].shape
output_shape = len(train_batches[0][1][0])

# display input & output shape
print('Input Shape:', input_shape)
print('Output Shape:', output_shape)
# Out:
# Input Shape: (100, 100, 3)
# Output Shape: 7

# %% [markdown]
# # Build & Compile Model

# %%
model = DenseNet201(
    input_shape=input_shape, 
    weights="imagenet", 
    include_top=False, 
    pooling='max'
)

for layer in model.layers:
    layer.trainable = False

i = Input(shape=input_shape)
x = model(i)
x = Flatten()(x)
x = Dense(output_shape, activation='softmax')(x)

model = Model(inputs=i, outputs=x)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# 2022-11-17 02:34:51.269052: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 02:34:51.270121: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 02:34:51.601876: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 02:34:51.602848: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 02:34:51.603647: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 02:34:51.604432: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 02:34:51.606653: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-17 02:34:51.849812: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 02:34:51.850600: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 02:34:51.851416: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 02:34:51.852157: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 02:34:51.852886: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 02:34:51.853574: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 02:34:56.666147: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 02:34:56.667096: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 02:34:56.667926: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 02:34:56.668732: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 02:34:56.669557: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 02:34:56.670238: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-11-17 02:34:56.675765: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 02:34:56.676477: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 1s 0us/step
# 74850304/74836368 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# densenet201 (Functional)     (None, 1920)              18321984
# _________________________________________________________________
# flatten (Flatten)            (None, 1920)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 13447
# =================================================================
# Total params: 18,335,431
# Trainable params: 13,447
# Non-trainable params: 18,321,984
# _________________________________________________________________

# %% [markdown]
# # Train Model

# %%
# train model
r = model.fit(train_batches, validation_data=validation_batches, epochs=100)

# save model
model.save(PATH_SAVED_MODEL)

# load model
# model = load_model(PATH_SAVED_MODEL)
# Out:
# 2022-11-17 02:35:03.958532: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-11-17 02:35:16.634714: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 405/405 [==============================] - 211s 460ms/step - loss: 1.4853 - accuracy: 0.4963 - val_loss: 1.3633 - val_accuracy: 0.5470
# Epoch 2/100
# 405/405 [==============================] - 114s 282ms/step - loss: 1.0624 - accuracy: 0.6121 - val_loss: 1.1434 - val_accuracy: 0.5972
# Epoch 3/100
# 405/405 [==============================] - 113s 278ms/step - loss: 0.9666 - accuracy: 0.6399 - val_loss: 1.0215 - val_accuracy: 0.6312
# Epoch 4/100
# 405/405 [==============================] - 113s 279ms/step - loss: 0.9045 - accuracy: 0.6630 - val_loss: 0.9983 - val_accuracy: 0.6399
# Epoch 5/100
# 405/405 [==============================] - 112s 277ms/step - loss: 0.8697 - accuracy: 0.6776 - val_loss: 1.0664 - val_accuracy: 0.6101
# Epoch 6/100
# 405/405 [==============================] - 113s 278ms/step - loss: 0.8407 - accuracy: 0.6857 - val_loss: 0.9981 - val_accuracy: 0.6429
# Epoch 7/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.8168 - accuracy: 0.6943 - val_loss: 1.0871 - val_accuracy: 0.6361
# Epoch 8/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.8265 - accuracy: 0.6898 - val_loss: 1.0185 - val_accuracy: 0.6559
# Epoch 9/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.7952 - accuracy: 0.7031 - val_loss: 1.1091 - val_accuracy: 0.6238
# Epoch 10/100
# 405/405 [==============================] - 112s 277ms/step - loss: 0.7945 - accuracy: 0.7040 - val_loss: 1.0830 - val_accuracy: 0.6491
# Epoch 11/100
# 405/405 [==============================] - 112s 277ms/step - loss: 0.7724 - accuracy: 0.7056 - val_loss: 0.9898 - val_accuracy: 0.6615
# Epoch 12/100
# 405/405 [==============================] - 111s 275ms/step - loss: 0.7653 - accuracy: 0.7118 - val_loss: 1.0371 - val_accuracy: 0.6572
# Epoch 13/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.7545 - accuracy: 0.7108 - val_loss: 1.0612 - val_accuracy: 0.6411
# Epoch 14/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.7555 - accuracy: 0.7170 - val_loss: 1.1434 - val_accuracy: 0.6429
# Epoch 15/100
# 405/405 [==============================] - 110s 273ms/step - loss: 0.7607 - accuracy: 0.7122 - val_loss: 1.1098 - val_accuracy: 0.6250
# Epoch 16/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.7538 - accuracy: 0.7154 - val_loss: 1.0626 - val_accuracy: 0.6429
# Epoch 17/100
# 405/405 [==============================] - 111s 275ms/step - loss: 0.7424 - accuracy: 0.7209 - val_loss: 1.1014 - val_accuracy: 0.6368
# Epoch 18/100
# 405/405 [==============================] - 111s 275ms/step - loss: 0.7450 - accuracy: 0.7199 - val_loss: 1.0572 - val_accuracy: 0.6578
# Epoch 19/100
# 405/405 [==============================] - 110s 273ms/step - loss: 0.7347 - accuracy: 0.7203 - val_loss: 1.0727 - val_accuracy: 0.6448
# Epoch 20/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.7479 - accuracy: 0.7173 - val_loss: 1.2115 - val_accuracy: 0.6157
# Epoch 21/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.7244 - accuracy: 0.7272 - val_loss: 1.1183 - val_accuracy: 0.6361
# Epoch 22/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.7194 - accuracy: 0.7244 - val_loss: 1.1029 - val_accuracy: 0.6417
# Epoch 23/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.7346 - accuracy: 0.7200 - val_loss: 1.2462 - val_accuracy: 0.6250
# Epoch 24/100
# 405/405 [==============================] - 111s 275ms/step - loss: 0.7197 - accuracy: 0.7274 - val_loss: 1.1488 - val_accuracy: 0.6399
# Epoch 25/100
# 405/405 [==============================] - 110s 273ms/step - loss: 0.7351 - accuracy: 0.7185 - val_loss: 1.2456 - val_accuracy: 0.6306
# Epoch 26/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.7193 - accuracy: 0.7296 - val_loss: 1.1439 - val_accuracy: 0.6293
# Epoch 27/100
# 405/405 [==============================] - 111s 273ms/step - loss: 0.7258 - accuracy: 0.7241 - val_loss: 1.1369 - val_accuracy: 0.6504
# Epoch 28/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.7233 - accuracy: 0.7244 - val_loss: 1.1759 - val_accuracy: 0.6287
# Epoch 29/100
# 405/405 [==============================] - 110s 273ms/step - loss: 0.7187 - accuracy: 0.7264 - val_loss: 1.1977 - val_accuracy: 0.6306
# Epoch 30/100
# 405/405 [==============================] - 110s 270ms/step - loss: 0.7082 - accuracy: 0.7331 - val_loss: 1.1438 - val_accuracy: 0.6547
# Epoch 31/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.7033 - accuracy: 0.7292 - val_loss: 1.2583 - val_accuracy: 0.6188
# Epoch 32/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.7101 - accuracy: 0.7271 - val_loss: 1.1855 - val_accuracy: 0.6361
# Epoch 33/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.7048 - accuracy: 0.7308 - val_loss: 1.1549 - val_accuracy: 0.6318
# Epoch 34/100
# 405/405 [==============================] - 111s 273ms/step - loss: 0.7015 - accuracy: 0.7359 - val_loss: 1.2018 - val_accuracy: 0.6361
# Epoch 35/100
# 405/405 [==============================] - 111s 275ms/step - loss: 0.7026 - accuracy: 0.7326 - val_loss: 1.1786 - val_accuracy: 0.6454
# Epoch 36/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.7037 - accuracy: 0.7285 - val_loss: 1.1837 - val_accuracy: 0.6448
# Epoch 37/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.7108 - accuracy: 0.7329 - val_loss: 1.2325 - val_accuracy: 0.6337
# Epoch 38/100
# 405/405 [==============================] - 111s 273ms/step - loss: 0.7069 - accuracy: 0.7332 - val_loss: 1.2264 - val_accuracy: 0.6411
# Epoch 39/100
# 405/405 [==============================] - 112s 277ms/step - loss: 0.7005 - accuracy: 0.7359 - val_loss: 1.2096 - val_accuracy: 0.6454
# Epoch 40/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.7111 - accuracy: 0.7291 - val_loss: 1.3288 - val_accuracy: 0.6089
# Epoch 41/100
# 405/405 [==============================] - 113s 278ms/step - loss: 0.7035 - accuracy: 0.7349 - val_loss: 1.3549 - val_accuracy: 0.6058
# Epoch 42/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.7041 - accuracy: 0.7335 - val_loss: 1.2349 - val_accuracy: 0.6417
# Epoch 43/100
# 405/405 [==============================] - 117s 288ms/step - loss: 0.7005 - accuracy: 0.7349 - val_loss: 1.2397 - val_accuracy: 0.6386
# Epoch 44/100
# 405/405 [==============================] - 118s 290ms/step - loss: 0.6973 - accuracy: 0.7363 - val_loss: 1.2556 - val_accuracy: 0.6324
# Epoch 45/100
# 405/405 [==============================] - 113s 278ms/step - loss: 0.7251 - accuracy: 0.7279 - val_loss: 1.2463 - val_accuracy: 0.6355
# Epoch 46/100
# 405/405 [==============================] - 113s 279ms/step - loss: 0.6901 - accuracy: 0.7383 - val_loss: 1.2584 - val_accuracy: 0.6337
# Epoch 47/100
# 405/405 [==============================] - 115s 283ms/step - loss: 0.6921 - accuracy: 0.7410 - val_loss: 1.3437 - val_accuracy: 0.6188
# Epoch 48/100
# 405/405 [==============================] - 116s 286ms/step - loss: 0.6975 - accuracy: 0.7382 - val_loss: 1.2513 - val_accuracy: 0.6448
# Epoch 49/100
# 405/405 [==============================] - 113s 280ms/step - loss: 0.6975 - accuracy: 0.7373 - val_loss: 1.2495 - val_accuracy: 0.6306
# Epoch 50/100
# 405/405 [==============================] - 113s 279ms/step - loss: 0.7012 - accuracy: 0.7366 - val_loss: 1.2793 - val_accuracy: 0.6380
# Epoch 51/100
# 405/405 [==============================] - 113s 279ms/step - loss: 0.6989 - accuracy: 0.7383 - val_loss: 1.2618 - val_accuracy: 0.6380
# Epoch 52/100
# 405/405 [==============================] - 113s 280ms/step - loss: 0.6885 - accuracy: 0.7406 - val_loss: 1.2930 - val_accuracy: 0.6349
# Epoch 53/100
# 405/405 [==============================] - 115s 284ms/step - loss: 0.6859 - accuracy: 0.7381 - val_loss: 1.2678 - val_accuracy: 0.6374
# Epoch 54/100
# 405/405 [==============================] - 115s 283ms/step - loss: 0.6924 - accuracy: 0.7351 - val_loss: 1.3685 - val_accuracy: 0.6077
# Epoch 55/100
# 405/405 [==============================] - 113s 278ms/step - loss: 0.6888 - accuracy: 0.7404 - val_loss: 1.3814 - val_accuracy: 0.6089
# Epoch 56/100
# 405/405 [==============================] - 113s 278ms/step - loss: 0.6887 - accuracy: 0.7389 - val_loss: 1.2905 - val_accuracy: 0.6256
# Epoch 57/100
# 405/405 [==============================] - 112s 277ms/step - loss: 0.6800 - accuracy: 0.7430 - val_loss: 1.3192 - val_accuracy: 0.6330
# Epoch 58/100
# 405/405 [==============================] - 119s 293ms/step - loss: 0.6809 - accuracy: 0.7405 - val_loss: 1.2907 - val_accuracy: 0.6386
# Epoch 59/100
# 405/405 [==============================] - 126s 311ms/step - loss: 0.6846 - accuracy: 0.7414 - val_loss: 1.3445 - val_accuracy: 0.6188
# Epoch 60/100
# 405/405 [==============================] - 120s 297ms/step - loss: 0.6745 - accuracy: 0.7446 - val_loss: 1.3024 - val_accuracy: 0.6386
# Epoch 61/100
# 405/405 [==============================] - 114s 283ms/step - loss: 0.6925 - accuracy: 0.7389 - val_loss: 1.3207 - val_accuracy: 0.6467
# Epoch 62/100
# 405/405 [==============================] - 113s 278ms/step - loss: 0.6743 - accuracy: 0.7455 - val_loss: 1.3771 - val_accuracy: 0.6330
# Epoch 63/100
# 405/405 [==============================] - 112s 277ms/step - loss: 0.6832 - accuracy: 0.7374 - val_loss: 1.2925 - val_accuracy: 0.6256
# Epoch 64/100
# 405/405 [==============================] - 111s 275ms/step - loss: 0.6864 - accuracy: 0.7416 - val_loss: 1.3155 - val_accuracy: 0.6386
# Epoch 65/100
# 405/405 [==============================] - 113s 278ms/step - loss: 0.6972 - accuracy: 0.7335 - val_loss: 1.3735 - val_accuracy: 0.6355
# Epoch 66/100
# 405/405 [==============================] - 114s 280ms/step - loss: 0.6858 - accuracy: 0.7433 - val_loss: 1.3139 - val_accuracy: 0.6275
# Epoch 67/100
# 405/405 [==============================] - 113s 278ms/step - loss: 0.6810 - accuracy: 0.7401 - val_loss: 1.3070 - val_accuracy: 0.6250
# Epoch 68/100
# 405/405 [==============================] - 114s 283ms/step - loss: 0.6903 - accuracy: 0.7337 - val_loss: 1.3189 - val_accuracy: 0.6318
# Epoch 69/100
# 405/405 [==============================] - 113s 279ms/step - loss: 0.7020 - accuracy: 0.7339 - val_loss: 1.4104 - val_accuracy: 0.6200
# Epoch 70/100
# 405/405 [==============================] - 112s 277ms/step - loss: 0.6784 - accuracy: 0.7397 - val_loss: 1.3184 - val_accuracy: 0.6411
# Epoch 71/100
# 405/405 [==============================] - 113s 278ms/step - loss: 0.6660 - accuracy: 0.7475 - val_loss: 1.5287 - val_accuracy: 0.5891
# Epoch 72/100
# 405/405 [==============================] - 113s 279ms/step - loss: 0.6813 - accuracy: 0.7420 - val_loss: 1.3571 - val_accuracy: 0.6374
# Epoch 73/100
# 405/405 [==============================] - 113s 278ms/step - loss: 0.6778 - accuracy: 0.7445 - val_loss: 1.3639 - val_accuracy: 0.6374
# Epoch 74/100
# 405/405 [==============================] - 113s 278ms/step - loss: 0.6966 - accuracy: 0.7376 - val_loss: 1.3353 - val_accuracy: 0.6361
# Epoch 75/100
# 405/405 [==============================] - 113s 279ms/step - loss: 0.6798 - accuracy: 0.7450 - val_loss: 1.4126 - val_accuracy: 0.6194
# Epoch 76/100
# 405/405 [==============================] - 113s 280ms/step - loss: 0.6837 - accuracy: 0.7437 - val_loss: 1.3782 - val_accuracy: 0.6343
# Epoch 77/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.6828 - accuracy: 0.7463 - val_loss: 1.3810 - val_accuracy: 0.6250
# Epoch 78/100
# 405/405 [==============================] - 113s 280ms/step - loss: 0.6700 - accuracy: 0.7484 - val_loss: 1.3671 - val_accuracy: 0.6368
# Epoch 79/100
# 405/405 [==============================] - 112s 277ms/step - loss: 0.6637 - accuracy: 0.7480 - val_loss: 1.4046 - val_accuracy: 0.6225
# Epoch 80/100
# 405/405 [==============================] - 112s 277ms/step - loss: 0.6748 - accuracy: 0.7457 - val_loss: 1.3104 - val_accuracy: 0.6473
# Epoch 81/100
# 405/405 [==============================] - 111s 275ms/step - loss: 0.6918 - accuracy: 0.7380 - val_loss: 1.3990 - val_accuracy: 0.6231
# Epoch 82/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.6906 - accuracy: 0.7370 - val_loss: 1.4612 - val_accuracy: 0.6170
# Epoch 83/100
# 405/405 [==============================] - 111s 275ms/step - loss: 0.6705 - accuracy: 0.7440 - val_loss: 1.3517 - val_accuracy: 0.6380
# Epoch 84/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.6769 - accuracy: 0.7471 - val_loss: 1.3558 - val_accuracy: 0.6411
# Epoch 85/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.6817 - accuracy: 0.7421 - val_loss: 1.3280 - val_accuracy: 0.6423
# Epoch 86/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.6579 - accuracy: 0.7509 - val_loss: 1.3555 - val_accuracy: 0.6423
# Epoch 87/100
# 405/405 [==============================] - 112s 277ms/step - loss: 0.6653 - accuracy: 0.7486 - val_loss: 1.3930 - val_accuracy: 0.6231
# Epoch 88/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.6809 - accuracy: 0.7437 - val_loss: 1.4074 - val_accuracy: 0.6337
# Epoch 89/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.6704 - accuracy: 0.7454 - val_loss: 1.3931 - val_accuracy: 0.6318
# Epoch 90/100
# 405/405 [==============================] - 117s 288ms/step - loss: 0.6651 - accuracy: 0.7466 - val_loss: 1.3532 - val_accuracy: 0.6361
# Epoch 91/100
# 405/405 [==============================] - 111s 275ms/step - loss: 0.6838 - accuracy: 0.7416 - val_loss: 1.4439 - val_accuracy: 0.6368
# Epoch 92/100
# 405/405 [==============================] - 111s 275ms/step - loss: 0.6690 - accuracy: 0.7470 - val_loss: 1.4619 - val_accuracy: 0.6281
# Epoch 93/100
# 405/405 [==============================] - 115s 284ms/step - loss: 0.6596 - accuracy: 0.7481 - val_loss: 1.3837 - val_accuracy: 0.6330
# Epoch 94/100
# 405/405 [==============================] - 111s 275ms/step - loss: 0.6606 - accuracy: 0.7508 - val_loss: 1.3539 - val_accuracy: 0.6355
# Epoch 95/100
# 405/405 [==============================] - 111s 274ms/step - loss: 0.6654 - accuracy: 0.7485 - val_loss: 1.4349 - val_accuracy: 0.6157
# Epoch 96/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.6726 - accuracy: 0.7454 - val_loss: 1.4269 - val_accuracy: 0.6318
# Epoch 97/100
# 405/405 [==============================] - 111s 273ms/step - loss: 0.6725 - accuracy: 0.7457 - val_loss: 1.3736 - val_accuracy: 0.6318
# Epoch 98/100
# 405/405 [==============================] - 112s 275ms/step - loss: 0.6606 - accuracy: 0.7493 - val_loss: 1.3745 - val_accuracy: 0.6386
# Epoch 99/100
# 405/405 [==============================] - 110s 272ms/step - loss: 0.6793 - accuracy: 0.7421 - val_loss: 1.4491 - val_accuracy: 0.6194
# Epoch 100/100
# 405/405 [==============================] - 111s 275ms/step - loss: 0.6573 - accuracy: 0.7462 - val_loss: 1.4740 - val_accuracy: 0.6213

# %% [markdown]
# # Evaluate Model's Training & Validation Results

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()

# %% [markdown]
# # Generate Predictions With Model

# %%
y_pred = model.predict(test_batches).argmax(axis=1)

# %%
model.evaluate(test_batches)
# Out:
# 51/51 [==============================] - 13s 251ms/step - loss: 1.3343 - accuracy: 0.6379
# [1.3342790603637695, 0.6378881931304932]

# %% [markdown]
# # Evaluate Model's Prediction Results

# %%
# generate classification report
class_labels = list(test_batches.class_indices.keys())
report = classification_report(test_batches.classes, y_pred, target_names=class_labels, output_dict=True)
df_classification_report = pd.DataFrame(report).transpose()
df_classification_report
# Out:
#               precision    recall  f1-score      support
# hatchback      0.423077  0.423077  0.423077   156.000000
# mpv            0.626168  0.620370  0.623256   108.000000
# sedan          0.750000  0.398551  0.520505   414.000000
# sport          0.662587  0.838496  0.740234   452.000000
# suv            0.621302  0.739437  0.675241   284.000000
# truck          0.779141  0.793750  0.786378   160.000000
# wagon          0.240741  0.361111  0.288889    36.000000
# accuracy       0.637888  0.637888  0.637888     0.637888
# macro avg      0.586145  0.596399  0.579654  1610.000000
# weighted avg   0.654282  0.637888  0.628184  1610.000000

# %%
# compute confusion matrix
matrix = confusion_matrix(test_batches.classes, y_pred)

# normalize confusion matrix
matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
matrix = np.around(matrix, decimals=2)

# generate confusion matrix heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(matrix, annot=True, xticklabels=class_labels, yticklabels=class_labels)
plt.ylabel('Test Values')
plt.xlabel('Predicted Values')
# Out:
# Text(0.5, 69.0, 'Predicted Values')

# %% [markdown]
# # Compute Execution Time

# %%
execution_time_s = round(time.time() - start_time, 2)
execution_time_m = round(execution_time_s/60, 2)
execution_time_h = round(execution_time_m/60, 2)

print('Execution Time (Hours):', execution_time_h)
print('Execution Time (Minutes):', execution_time_m)
print('Execution Time (Seconds):', execution_time_s)
# Out:
# Execution Time (Hours): 3.21
# Execution Time (Minutes): 192.7
# Execution Time (Seconds): 11561.97
