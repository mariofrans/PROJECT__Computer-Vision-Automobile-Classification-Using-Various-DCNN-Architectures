# %%
# !pip install pandas numpy seaborn matplotlib tensorflow keras sklearn &> /dev/null

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet50

import time
start_time = time.time()

# %%
PATH_DATA_TRAIN = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/train'
PATH_DATA_TEST = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/test'
PATH_DATA_VALIDATION = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/validation'
PATH_SAVED_MODEL = 'resnet50-imagenet.h5'

# %% [markdown]
# # Load Dataset As Generators

# %%
generator = ImageDataGenerator(rescale = 1./255.)

target_size = (100, 100)
batch_size = 32

train_batches = generator.flow_from_directory(
    PATH_DATA_TRAIN, class_mode='categorical', 
    batch_size=batch_size, target_size=target_size
)

validation_batches = generator.flow_from_directory(
    PATH_DATA_VALIDATION, class_mode='categorical',  
    batch_size=batch_size, target_size=target_size
)

test_batches = generator.flow_from_directory(
    PATH_DATA_TEST, class_mode='categorical', shuffle=False, 
    batch_size=batch_size, target_size=target_size
)
# Out:
# Found 12959 images belonging to 7 classes.
# Found 1616 images belonging to 7 classes.
# Found 1610 images belonging to 7 classes.

# %%
# preview data (batch size, width, height, colors)
print('x_train shape:', train_batches[0][0].shape)
print('x_validation shape:', validation_batches[0][0].shape)
print('x_test shape:', test_batches[0][0].shape)
print('y_train shape:', train_batches[0][1].shape)
print('y_validation shape:', validation_batches[0][1].shape)
print('y_test shape:', test_batches[0][1].shape)
# Out:
# x_train shape: (32, 100, 100, 3)
# x_validation shape: (32, 100, 100, 3)
# x_test shape: (32, 100, 100, 3)
# y_train shape: (32, 7)
# y_validation shape: (32, 7)
# y_test shape: (32, 7)

# %%
# input & output shape
input_shape = train_batches[0][0][0].shape
output_shape = len(train_batches[0][1][0])

# display input & output shape
print('Input Shape:', input_shape)
print('Output Shape:', output_shape)
# Out:
# Input Shape: (100, 100, 3)
# Output Shape: 7

# %% [markdown]
# # Build & Compile Model

# %%
model = ResNet50(
    input_shape=input_shape, 
    weights="imagenet", 
    include_top=False, 
    pooling='max'
)

for layer in model.layers:
    layer.trainable = False

i = Input(shape=input_shape)
x = model(i)
x = Flatten()(x)
x = Dense(output_shape, activation='softmax')(x)

model = Model(inputs=i, outputs=x)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# 2022-11-16 20:21:17.631576: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 20:21:17.632510: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 20:21:18.026683: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 20:21:18.027623: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 20:21:18.028477: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 20:21:18.029235: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 20:21:18.031044: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-16 20:21:18.288986: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 20:21:18.290144: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 20:21:18.291278: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 20:21:18.292463: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 20:21:18.293604: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 20:21:18.294696: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 20:21:22.942993: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 20:21:22.943920: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 20:21:22.944679: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 20:21:22.945377: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 20:21:22.946158: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 20:21:22.946871: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-11-16 20:21:22.952320: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 20:21:22.953046: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step
# 94781440/94765736 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 14343
# =================================================================
# Total params: 23,602,055
# Trainable params: 14,343
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %% [markdown]
# # Train Model

# %%
# train model
r = model.fit(train_batches, validation_data=validation_batches, epochs=100)

# save model
model.save(PATH_SAVED_MODEL)

# load model
# model = load_model(PATH_SAVED_MODEL)
# Out:
# 2022-11-16 20:21:25.981011: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-11-16 20:21:31.208609: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 405/405 [==============================] - 200s 459ms/step - loss: 1.8163 - accuracy: 0.3016 - val_loss: 1.6857 - val_accuracy: 0.3342
# Epoch 2/100
# 405/405 [==============================] - 107s 264ms/step - loss: 1.6872 - accuracy: 0.3480 - val_loss: 1.6645 - val_accuracy: 0.3546
# Epoch 3/100
# 405/405 [==============================] - 106s 261ms/step - loss: 1.6206 - accuracy: 0.3674 - val_loss: 1.6239 - val_accuracy: 0.3923
# Epoch 4/100
# 405/405 [==============================] - 107s 264ms/step - loss: 1.5999 - accuracy: 0.3856 - val_loss: 1.8357 - val_accuracy: 0.3713
# Epoch 5/100
# 405/405 [==============================] - 107s 265ms/step - loss: 1.5681 - accuracy: 0.4006 - val_loss: 1.6763 - val_accuracy: 0.4035
# Epoch 6/100
# 405/405 [==============================] - 109s 270ms/step - loss: 1.5415 - accuracy: 0.4091 - val_loss: 1.4416 - val_accuracy: 0.4387
# Epoch 7/100
# 405/405 [==============================] - 111s 274ms/step - loss: 1.4951 - accuracy: 0.4253 - val_loss: 1.6343 - val_accuracy: 0.3892
# Epoch 8/100
# 405/405 [==============================] - 105s 260ms/step - loss: 1.5146 - accuracy: 0.4153 - val_loss: 1.6970 - val_accuracy: 0.3298
# Epoch 9/100
# 405/405 [==============================] - 107s 263ms/step - loss: 1.4684 - accuracy: 0.4328 - val_loss: 1.4369 - val_accuracy: 0.4592
# Epoch 10/100
# 405/405 [==============================] - 107s 264ms/step - loss: 1.4777 - accuracy: 0.4344 - val_loss: 1.6544 - val_accuracy: 0.3601
# Epoch 11/100
# 405/405 [==============================] - 106s 261ms/step - loss: 1.4456 - accuracy: 0.4382 - val_loss: 1.5909 - val_accuracy: 0.3954
# Epoch 12/100
# 405/405 [==============================] - 106s 261ms/step - loss: 1.4536 - accuracy: 0.4421 - val_loss: 1.4928 - val_accuracy: 0.4344
# Epoch 13/100
# 405/405 [==============================] - 107s 264ms/step - loss: 1.4038 - accuracy: 0.4663 - val_loss: 1.5013 - val_accuracy: 0.4171
# Epoch 14/100
# 405/405 [==============================] - 105s 259ms/step - loss: 1.4146 - accuracy: 0.4566 - val_loss: 1.5131 - val_accuracy: 0.4233
# Epoch 15/100
# 405/405 [==============================] - 106s 262ms/step - loss: 1.4360 - accuracy: 0.4521 - val_loss: 1.5100 - val_accuracy: 0.4202
# Epoch 16/100
# 405/405 [==============================] - 104s 258ms/step - loss: 1.4234 - accuracy: 0.4538 - val_loss: 1.7460 - val_accuracy: 0.3942
# Epoch 17/100
# 405/405 [==============================] - 104s 257ms/step - loss: 1.3942 - accuracy: 0.4622 - val_loss: 1.4673 - val_accuracy: 0.4443
# Epoch 18/100
# 405/405 [==============================] - 105s 258ms/step - loss: 1.3967 - accuracy: 0.4672 - val_loss: 1.6817 - val_accuracy: 0.3830
# Epoch 19/100
# 405/405 [==============================] - 104s 258ms/step - loss: 1.3681 - accuracy: 0.4781 - val_loss: 1.4614 - val_accuracy: 0.4412
# Epoch 20/100
# 405/405 [==============================] - 105s 258ms/step - loss: 1.3903 - accuracy: 0.4697 - val_loss: 1.4347 - val_accuracy: 0.4480
# Epoch 21/100
# 405/405 [==============================] - 104s 256ms/step - loss: 1.4027 - accuracy: 0.4695 - val_loss: 1.4715 - val_accuracy: 0.4579
# Epoch 22/100
# 405/405 [==============================] - 102s 253ms/step - loss: 1.3809 - accuracy: 0.4726 - val_loss: 1.6073 - val_accuracy: 0.4053
# Epoch 23/100
# 405/405 [==============================] - 102s 251ms/step - loss: 1.3701 - accuracy: 0.4743 - val_loss: 1.5780 - val_accuracy: 0.4189
# Epoch 24/100
# 405/405 [==============================] - 102s 252ms/step - loss: 1.3480 - accuracy: 0.4848 - val_loss: 1.5060 - val_accuracy: 0.4418
# Epoch 25/100
# 405/405 [==============================] - 100s 248ms/step - loss: 1.3377 - accuracy: 0.4912 - val_loss: 1.4341 - val_accuracy: 0.4678
# Epoch 26/100
# 405/405 [==============================] - 101s 250ms/step - loss: 1.3445 - accuracy: 0.4905 - val_loss: 1.5745 - val_accuracy: 0.4505
# Epoch 27/100
# 405/405 [==============================] - 101s 249ms/step - loss: 1.3509 - accuracy: 0.4832 - val_loss: 1.5500 - val_accuracy: 0.4418
# Epoch 28/100
# 405/405 [==============================] - 102s 251ms/step - loss: 1.3361 - accuracy: 0.4913 - val_loss: 1.4786 - val_accuracy: 0.4437
# Epoch 29/100
# 405/405 [==============================] - 101s 250ms/step - loss: 1.3279 - accuracy: 0.4942 - val_loss: 1.5230 - val_accuracy: 0.4276
# Epoch 30/100
# 405/405 [==============================] - 103s 254ms/step - loss: 1.3170 - accuracy: 0.4985 - val_loss: 1.5112 - val_accuracy: 0.4363
# Epoch 31/100
# 405/405 [==============================] - 103s 255ms/step - loss: 1.3224 - accuracy: 0.4931 - val_loss: 1.4629 - val_accuracy: 0.4381
# Epoch 32/100
# 405/405 [==============================] - 102s 253ms/step - loss: 1.3269 - accuracy: 0.4960 - val_loss: 1.4488 - val_accuracy: 0.4381
# Epoch 33/100
# 405/405 [==============================] - 102s 252ms/step - loss: 1.3198 - accuracy: 0.4979 - val_loss: 1.4906 - val_accuracy: 0.4573
# Epoch 34/100
# 405/405 [==============================] - 101s 249ms/step - loss: 1.3230 - accuracy: 0.4936 - val_loss: 1.7146 - val_accuracy: 0.3849
# Epoch 35/100
# 405/405 [==============================] - 105s 259ms/step - loss: 1.3184 - accuracy: 0.4956 - val_loss: 1.7788 - val_accuracy: 0.4325
# Epoch 36/100
# 405/405 [==============================] - 108s 268ms/step - loss: 1.3319 - accuracy: 0.5024 - val_loss: 1.4666 - val_accuracy: 0.4536
# Epoch 37/100
# 405/405 [==============================] - 107s 264ms/step - loss: 1.2897 - accuracy: 0.5147 - val_loss: 1.4215 - val_accuracy: 0.4499
# Epoch 38/100
# 405/405 [==============================] - 101s 248ms/step - loss: 1.2991 - accuracy: 0.5071 - val_loss: 1.5538 - val_accuracy: 0.4239
# Epoch 39/100
# 405/405 [==============================] - 102s 253ms/step - loss: 1.2995 - accuracy: 0.5042 - val_loss: 1.4703 - val_accuracy: 0.4468
# Epoch 40/100
# 405/405 [==============================] - 105s 260ms/step - loss: 1.3069 - accuracy: 0.5056 - val_loss: 1.5643 - val_accuracy: 0.4418
# Epoch 41/100
# 405/405 [==============================] - 105s 259ms/step - loss: 1.3066 - accuracy: 0.5034 - val_loss: 1.4225 - val_accuracy: 0.4530
# Epoch 42/100
# 405/405 [==============================] - 105s 259ms/step - loss: 1.2818 - accuracy: 0.5112 - val_loss: 1.6590 - val_accuracy: 0.4468
# Epoch 43/100
# 405/405 [==============================] - 104s 257ms/step - loss: 1.2855 - accuracy: 0.5124 - val_loss: 1.5457 - val_accuracy: 0.4239
# Epoch 44/100
# 405/405 [==============================] - 107s 264ms/step - loss: 1.2877 - accuracy: 0.5095 - val_loss: 1.4907 - val_accuracy: 0.4356
# Epoch 45/100
# 405/405 [==============================] - 106s 261ms/step - loss: 1.2931 - accuracy: 0.5085 - val_loss: 1.6020 - val_accuracy: 0.4406
# Epoch 46/100
# 405/405 [==============================] - 106s 262ms/step - loss: 1.2773 - accuracy: 0.5125 - val_loss: 1.6107 - val_accuracy: 0.4214
# Epoch 47/100
# 405/405 [==============================] - 106s 262ms/step - loss: 1.2640 - accuracy: 0.5189 - val_loss: 1.7428 - val_accuracy: 0.4604
# Epoch 48/100
# 405/405 [==============================] - 105s 259ms/step - loss: 1.2639 - accuracy: 0.5202 - val_loss: 1.6390 - val_accuracy: 0.3861
# Epoch 49/100
# 405/405 [==============================] - 105s 259ms/step - loss: 1.2868 - accuracy: 0.5151 - val_loss: 1.5752 - val_accuracy: 0.4332
# Epoch 50/100
# 405/405 [==============================] - 105s 258ms/step - loss: 1.2588 - accuracy: 0.5193 - val_loss: 1.4657 - val_accuracy: 0.4344
# Epoch 51/100
# 405/405 [==============================] - 104s 257ms/step - loss: 1.2985 - accuracy: 0.5066 - val_loss: 1.5971 - val_accuracy: 0.4115
# Epoch 52/100
# 405/405 [==============================] - 104s 257ms/step - loss: 1.2508 - accuracy: 0.5211 - val_loss: 1.4602 - val_accuracy: 0.4759
# Epoch 53/100
# 405/405 [==============================] - 103s 255ms/step - loss: 1.2631 - accuracy: 0.5183 - val_loss: 1.6645 - val_accuracy: 0.4152
# Epoch 54/100
# 405/405 [==============================] - 104s 256ms/step - loss: 1.2713 - accuracy: 0.5179 - val_loss: 1.5363 - val_accuracy: 0.4511
# Epoch 55/100
# 405/405 [==============================] - 104s 257ms/step - loss: 1.2477 - accuracy: 0.5266 - val_loss: 1.7080 - val_accuracy: 0.3806
# Epoch 56/100
# 405/405 [==============================] - 103s 255ms/step - loss: 1.2655 - accuracy: 0.5144 - val_loss: 1.6233 - val_accuracy: 0.3762
# Epoch 57/100
# 405/405 [==============================] - 103s 254ms/step - loss: 1.2447 - accuracy: 0.5320 - val_loss: 1.4853 - val_accuracy: 0.4418
# Epoch 58/100
# 405/405 [==============================] - 103s 255ms/step - loss: 1.2501 - accuracy: 0.5259 - val_loss: 1.4500 - val_accuracy: 0.4746
# Epoch 59/100
# 405/405 [==============================] - 103s 255ms/step - loss: 1.2885 - accuracy: 0.5138 - val_loss: 1.4596 - val_accuracy: 0.4598
# Epoch 60/100
# 405/405 [==============================] - 104s 255ms/step - loss: 1.2481 - accuracy: 0.5236 - val_loss: 1.5326 - val_accuracy: 0.4356
# Epoch 61/100
# 405/405 [==============================] - 103s 255ms/step - loss: 1.2613 - accuracy: 0.5149 - val_loss: 1.6318 - val_accuracy: 0.4097
# Epoch 62/100
# 405/405 [==============================] - 104s 256ms/step - loss: 1.2432 - accuracy: 0.5240 - val_loss: 1.4574 - val_accuracy: 0.4715
# Epoch 63/100
# 405/405 [==============================] - 103s 254ms/step - loss: 1.2355 - accuracy: 0.5301 - val_loss: 1.4910 - val_accuracy: 0.4660
# Epoch 64/100
# 405/405 [==============================] - 103s 255ms/step - loss: 1.2346 - accuracy: 0.5377 - val_loss: 1.4805 - val_accuracy: 0.4567
# Epoch 65/100
# 405/405 [==============================] - 105s 259ms/step - loss: 1.2394 - accuracy: 0.5279 - val_loss: 1.4766 - val_accuracy: 0.4592
# Epoch 66/100
# 405/405 [==============================] - 103s 255ms/step - loss: 1.2452 - accuracy: 0.5252 - val_loss: 1.5775 - val_accuracy: 0.4078
# Epoch 67/100
# 405/405 [==============================] - 103s 253ms/step - loss: 1.2213 - accuracy: 0.5341 - val_loss: 1.5004 - val_accuracy: 0.4691
# Epoch 68/100
# 405/405 [==============================] - 102s 253ms/step - loss: 1.2454 - accuracy: 0.5277 - val_loss: 1.5575 - val_accuracy: 0.4542
# Epoch 69/100
# 405/405 [==============================] - 101s 250ms/step - loss: 1.2236 - accuracy: 0.5332 - val_loss: 1.4946 - val_accuracy: 0.4499
# Epoch 70/100
# 405/405 [==============================] - 99s 245ms/step - loss: 1.2110 - accuracy: 0.5394 - val_loss: 1.6287 - val_accuracy: 0.4109
# Epoch 71/100
# 405/405 [==============================] - 99s 245ms/step - loss: 1.2343 - accuracy: 0.5345 - val_loss: 1.6485 - val_accuracy: 0.4425
# Epoch 72/100
# 405/405 [==============================] - 100s 247ms/step - loss: 1.2446 - accuracy: 0.5270 - val_loss: 1.5587 - val_accuracy: 0.4387
# Epoch 73/100
# 405/405 [==============================] - 102s 252ms/step - loss: 1.2144 - accuracy: 0.5357 - val_loss: 1.6033 - val_accuracy: 0.3998
# Epoch 74/100
# 405/405 [==============================] - 103s 255ms/step - loss: 1.2206 - accuracy: 0.5356 - val_loss: 1.6325 - val_accuracy: 0.4004
# Epoch 75/100
# 405/405 [==============================] - 101s 250ms/step - loss: 1.1991 - accuracy: 0.5409 - val_loss: 1.5012 - val_accuracy: 0.4722
# Epoch 76/100
# 405/405 [==============================] - 100s 246ms/step - loss: 1.2159 - accuracy: 0.5321 - val_loss: 1.4842 - val_accuracy: 0.4666
# Epoch 77/100
# 405/405 [==============================] - 100s 247ms/step - loss: 1.2221 - accuracy: 0.5409 - val_loss: 1.5053 - val_accuracy: 0.4548
# Epoch 78/100
# 405/405 [==============================] - 99s 246ms/step - loss: 1.2115 - accuracy: 0.5415 - val_loss: 1.4791 - val_accuracy: 0.4653
# Epoch 79/100
# 405/405 [==============================] - 100s 247ms/step - loss: 1.2133 - accuracy: 0.5402 - val_loss: 1.5041 - val_accuracy: 0.4610
# Epoch 80/100
# 405/405 [==============================] - 100s 247ms/step - loss: 1.1951 - accuracy: 0.5457 - val_loss: 1.4395 - val_accuracy: 0.4641
# Epoch 81/100
# 405/405 [==============================] - 99s 245ms/step - loss: 1.2034 - accuracy: 0.5430 - val_loss: 1.5178 - val_accuracy: 0.4455
# Epoch 82/100
# 405/405 [==============================] - 99s 245ms/step - loss: 1.2128 - accuracy: 0.5355 - val_loss: 1.5183 - val_accuracy: 0.4425
# Epoch 83/100
# 405/405 [==============================] - 100s 247ms/step - loss: 1.2184 - accuracy: 0.5417 - val_loss: 1.5168 - val_accuracy: 0.4350
# Epoch 84/100
# 405/405 [==============================] - 100s 246ms/step - loss: 1.2012 - accuracy: 0.5397 - val_loss: 1.5818 - val_accuracy: 0.4214
# Epoch 85/100
# 405/405 [==============================] - 100s 248ms/step - loss: 1.2243 - accuracy: 0.5353 - val_loss: 1.5307 - val_accuracy: 0.4319
# Epoch 86/100
# 405/405 [==============================] - 100s 246ms/step - loss: 1.2157 - accuracy: 0.5381 - val_loss: 1.6275 - val_accuracy: 0.4146
# Epoch 87/100
# 405/405 [==============================] - 99s 245ms/step - loss: 1.2187 - accuracy: 0.5379 - val_loss: 1.5712 - val_accuracy: 0.4554
# Epoch 88/100
# 405/405 [==============================] - 102s 252ms/step - loss: 1.2211 - accuracy: 0.5340 - val_loss: 1.5278 - val_accuracy: 0.4629
# Epoch 89/100
# 405/405 [==============================] - 103s 253ms/step - loss: 1.2070 - accuracy: 0.5438 - val_loss: 1.6652 - val_accuracy: 0.4462
# Epoch 90/100
# 405/405 [==============================] - 102s 252ms/step - loss: 1.2121 - accuracy: 0.5333 - val_loss: 1.5059 - val_accuracy: 0.4579
# Epoch 91/100
# 405/405 [==============================] - 101s 250ms/step - loss: 1.1716 - accuracy: 0.5566 - val_loss: 1.5001 - val_accuracy: 0.4437
# Epoch 92/100
# 405/405 [==============================] - 100s 248ms/step - loss: 1.2047 - accuracy: 0.5416 - val_loss: 1.7236 - val_accuracy: 0.4028
# Epoch 93/100
# 405/405 [==============================] - 100s 246ms/step - loss: 1.2177 - accuracy: 0.5386 - val_loss: 1.5092 - val_accuracy: 0.4480
# Epoch 94/100
# 405/405 [==============================] - 101s 248ms/step - loss: 1.1732 - accuracy: 0.5532 - val_loss: 1.6564 - val_accuracy: 0.3911
# Epoch 95/100
# 405/405 [==============================] - 100s 247ms/step - loss: 1.2055 - accuracy: 0.5382 - val_loss: 1.6061 - val_accuracy: 0.4437
# Epoch 96/100
# 405/405 [==============================] - 100s 247ms/step - loss: 1.1884 - accuracy: 0.5510 - val_loss: 1.4909 - val_accuracy: 0.4641
# Epoch 97/100
# 405/405 [==============================] - 101s 249ms/step - loss: 1.2049 - accuracy: 0.5414 - val_loss: 1.5276 - val_accuracy: 0.4449
# Epoch 98/100
# 405/405 [==============================] - 100s 246ms/step - loss: 1.1870 - accuracy: 0.5479 - val_loss: 1.6613 - val_accuracy: 0.4183
# Epoch 99/100
# 405/405 [==============================] - 101s 249ms/step - loss: 1.1788 - accuracy: 0.5550 - val_loss: 1.5542 - val_accuracy: 0.4406
# Epoch 100/100
# 405/405 [==============================] - 100s 246ms/step - loss: 1.2057 - accuracy: 0.5417 - val_loss: 1.4743 - val_accuracy: 0.4573
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %% [markdown]
# # Evaluate Model's Training & Validation Results

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()

# %% [markdown]
# # Generate Predictions With Model

# %%
y_pred = model.predict(test_batches).argmax(axis=1)

# %%
model.evaluate(test_batches)
# Out:
# 51/51 [==============================] - 12s 238ms/step - loss: 1.3850 - accuracy: 0.4764
# [1.3849800825119019, 0.4763975143432617]

# %% [markdown]
# # Evaluate Model's Prediction Results

# %%
# generate classification report
class_labels = list(test_batches.class_indices.keys())
report = classification_report(test_batches.classes, y_pred, target_names=class_labels, output_dict=True)
df_classification_report = pd.DataFrame(report).transpose()
df_classification_report
# Out:
#               precision    recall  f1-score      support
# hatchback      0.328947  0.160256  0.215517   156.000000
# mpv            0.460526  0.324074  0.380435   108.000000
# sedan          0.400631  0.613527  0.484733   414.000000
# sport          0.576220  0.418142  0.484615   452.000000
# suv            0.473008  0.647887  0.546805   284.000000
# truck          0.761905  0.500000  0.603774   160.000000
# wagon          0.000000  0.000000  0.000000    36.000000
# accuracy       0.476398  0.476398  0.476398     0.476398
# macro avg      0.428748  0.380555  0.387983  1610.000000
# weighted avg   0.486711  0.476398  0.463559  1610.000000

# %%
# compute confusion matrix
matrix = confusion_matrix(test_batches.classes, y_pred)

# normalize confusion matrix
matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
matrix = np.around(matrix, decimals=2)

# generate confusion matrix heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(matrix, annot=True, xticklabels=class_labels, yticklabels=class_labels)
plt.ylabel('Test Values')
plt.xlabel('Predicted Values')
# Out:
# Text(0.5, 69.0, 'Predicted Values')

# %% [markdown]
# # Compute Execution Time

# %%
execution_time_s = round(time.time() - start_time, 2)
execution_time_m = round(execution_time_s/60, 2)
execution_time_h = round(execution_time_m/60, 2)

print('Execution Time (Hours):', execution_time_h)
print('Execution Time (Minutes):', execution_time_m)
print('Execution Time (Seconds):', execution_time_s)
# Out:
# Execution Time (Hours): 2.96
# Execution Time (Minutes): 177.87
# Execution Time (Seconds): 10672.24
