# %%
# !pip install pandas numpy seaborn matplotlib tensorflow keras sklearn &> /dev/null

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications import InceptionV3

import time
start_time = time.time()

# %%
PATH_DATA_TRAIN = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/train'
PATH_DATA_TEST = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/test'
PATH_DATA_VALIDATION = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/validation'
PATH_SAVED_MODEL = 'inception-v3-imagenet.h5'

# %% [markdown]
# # Load Dataset As Generators

# %%
generator = ImageDataGenerator(rescale = 1./255.)

target_size = (100, 100)
batch_size = 32

train_batches = generator.flow_from_directory(
    PATH_DATA_TRAIN, class_mode='categorical', 
    batch_size=batch_size, target_size=target_size
)

validation_batches = generator.flow_from_directory(
    PATH_DATA_VALIDATION, class_mode='categorical',  
    batch_size=batch_size, target_size=target_size
)

test_batches = generator.flow_from_directory(
    PATH_DATA_TEST, class_mode='categorical', shuffle=False, 
    batch_size=batch_size, target_size=target_size
)
# Out:
# Found 12959 images belonging to 7 classes.
# Found 1616 images belonging to 7 classes.
# Found 1610 images belonging to 7 classes.

# %%
# preview data (batch size, width, height, colors)
print('x_train shape:', train_batches[0][0].shape)
print('x_validation shape:', validation_batches[0][0].shape)
print('x_test shape:', test_batches[0][0].shape)
print('y_train shape:', train_batches[0][1].shape)
print('y_validation shape:', validation_batches[0][1].shape)
print('y_test shape:', test_batches[0][1].shape)
# Out:
# x_train shape: (32, 100, 100, 3)
# x_validation shape: (32, 100, 100, 3)
# x_test shape: (32, 100, 100, 3)
# y_train shape: (32, 7)
# y_validation shape: (32, 7)
# y_test shape: (32, 7)

# %%
# input & output shape
input_shape = train_batches[0][0][0].shape
output_shape = len(train_batches[0][1][0])

# display input & output shape
print('Input Shape:', input_shape)
print('Output Shape:', output_shape)
# Out:
# Input Shape: (100, 100, 3)
# Output Shape: 7

# %% [markdown]
# # Build & Compile Model

# %%
model = InceptionV3(
    input_shape=input_shape, 
    weights="imagenet", 
    include_top=False, 
    pooling='max'
)

for layer in model.layers:
    layer.trainable = False

i = Input(shape=input_shape)
x = model(i)
x = Flatten()(x)
x = Dense(output_shape, activation='softmax')(x)

model = Model(inputs=i, outputs=x)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# 2022-11-16 23:34:44.006119: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 23:34:44.007080: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 23:34:44.273497: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 23:34:44.274299: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 23:34:44.275039: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 23:34:44.275848: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 23:34:44.277268: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-16 23:34:44.530872: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 23:34:44.531737: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 23:34:44.532507: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 23:34:44.533237: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 23:34:44.533962: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 23:34:44.534695: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 23:34:49.082753: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 23:34:49.083659: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 23:34:49.084395: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 23:34:49.085100: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 23:34:49.085796: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 23:34:49.086453: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-11-16 23:34:49.091797: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 23:34:49.092535: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 0s 0us/step
# 87924736/87910968 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# inception_v3 (Functional)    (None, 2048)              21802784
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 14343
# =================================================================
# Total params: 21,817,127
# Trainable params: 14,343
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %% [markdown]
# # Train Model

# %%
# train model
r = model.fit(train_batches, validation_data=validation_batches, epochs=100)

# save model
model.save(PATH_SAVED_MODEL)

# load model
# model = load_model(PATH_SAVED_MODEL)
# Out:
# 2022-11-16 23:34:52.767661: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-11-16 23:34:58.685372: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 405/405 [==============================] - 192s 434ms/step - loss: 1.5360 - accuracy: 0.4107 - val_loss: 1.3876 - val_accuracy: 0.4542
# Epoch 2/100
# 405/405 [==============================] - 99s 245ms/step - loss: 1.3090 - accuracy: 0.4970 - val_loss: 1.3861 - val_accuracy: 0.4647
# Epoch 3/100
# 405/405 [==============================] - 99s 245ms/step - loss: 1.2496 - accuracy: 0.5171 - val_loss: 1.3564 - val_accuracy: 0.4796
# Epoch 4/100
# 405/405 [==============================] - 100s 247ms/step - loss: 1.2003 - accuracy: 0.5411 - val_loss: 1.3772 - val_accuracy: 0.4765
# Epoch 5/100
# 405/405 [==============================] - 100s 246ms/step - loss: 1.1648 - accuracy: 0.5517 - val_loss: 1.3884 - val_accuracy: 0.4672
# Epoch 6/100
# 405/405 [==============================] - 99s 244ms/step - loss: 1.1347 - accuracy: 0.5629 - val_loss: 1.3645 - val_accuracy: 0.4858
# Epoch 7/100
# 405/405 [==============================] - 98s 243ms/step - loss: 1.1158 - accuracy: 0.5699 - val_loss: 1.3404 - val_accuracy: 0.5031
# Epoch 8/100
# 405/405 [==============================] - 100s 247ms/step - loss: 1.0943 - accuracy: 0.5774 - val_loss: 1.3877 - val_accuracy: 0.4666
# Epoch 9/100
# 405/405 [==============================] - 101s 249ms/step - loss: 1.0700 - accuracy: 0.5886 - val_loss: 1.3637 - val_accuracy: 0.4870
# Epoch 10/100
# 405/405 [==============================] - 101s 249ms/step - loss: 1.0635 - accuracy: 0.5873 - val_loss: 1.5527 - val_accuracy: 0.4511
# Epoch 11/100
# 405/405 [==============================] - 100s 246ms/step - loss: 1.0514 - accuracy: 0.5929 - val_loss: 1.3998 - val_accuracy: 0.4895
# Epoch 12/100
# 405/405 [==============================] - 99s 245ms/step - loss: 1.0404 - accuracy: 0.5953 - val_loss: 1.3873 - val_accuracy: 0.4765
# Epoch 13/100
# 405/405 [==============================] - 100s 246ms/step - loss: 1.0224 - accuracy: 0.6058 - val_loss: 1.3874 - val_accuracy: 0.4814
# Epoch 14/100
# 405/405 [==============================] - 100s 247ms/step - loss: 1.0104 - accuracy: 0.6096 - val_loss: 1.4193 - val_accuracy: 0.4969
# Epoch 15/100
# 405/405 [==============================] - 102s 252ms/step - loss: 1.0072 - accuracy: 0.6071 - val_loss: 1.4530 - val_accuracy: 0.4808
# Epoch 16/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.9942 - accuracy: 0.6104 - val_loss: 1.4203 - val_accuracy: 0.4950
# Epoch 17/100
# 405/405 [==============================] - 102s 252ms/step - loss: 0.9834 - accuracy: 0.6193 - val_loss: 1.4505 - val_accuracy: 0.4814
# Epoch 18/100
# 405/405 [==============================] - 103s 253ms/step - loss: 0.9789 - accuracy: 0.6167 - val_loss: 1.4227 - val_accuracy: 0.4858
# Epoch 19/100
# 405/405 [==============================] - 102s 252ms/step - loss: 0.9741 - accuracy: 0.6212 - val_loss: 1.4740 - val_accuracy: 0.4759
# Epoch 20/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.9782 - accuracy: 0.6217 - val_loss: 1.4903 - val_accuracy: 0.4771
# Epoch 21/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.9615 - accuracy: 0.6247 - val_loss: 1.5157 - val_accuracy: 0.4715
# Epoch 22/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.9475 - accuracy: 0.6304 - val_loss: 1.4633 - val_accuracy: 0.4895
# Epoch 23/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.9408 - accuracy: 0.6329 - val_loss: 1.4928 - val_accuracy: 0.4833
# Epoch 24/100
# 405/405 [==============================] - 103s 256ms/step - loss: 0.9497 - accuracy: 0.6314 - val_loss: 1.5133 - val_accuracy: 0.4790
# Epoch 25/100
# 405/405 [==============================] - 104s 258ms/step - loss: 0.9363 - accuracy: 0.6366 - val_loss: 1.5345 - val_accuracy: 0.4746
# Epoch 26/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.9334 - accuracy: 0.6353 - val_loss: 1.4912 - val_accuracy: 0.4969
# Epoch 27/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.9205 - accuracy: 0.6419 - val_loss: 1.5438 - val_accuracy: 0.4647
# Epoch 28/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.9173 - accuracy: 0.6414 - val_loss: 1.5259 - val_accuracy: 0.4833
# Epoch 29/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.9111 - accuracy: 0.6492 - val_loss: 1.5575 - val_accuracy: 0.4765
# Epoch 30/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.9099 - accuracy: 0.6465 - val_loss: 1.5039 - val_accuracy: 0.4796
# Epoch 31/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.9049 - accuracy: 0.6429 - val_loss: 1.5565 - val_accuracy: 0.4697
# Epoch 32/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.9166 - accuracy: 0.6400 - val_loss: 1.5251 - val_accuracy: 0.4839
# Epoch 33/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.8965 - accuracy: 0.6507 - val_loss: 1.5175 - val_accuracy: 0.4715
# Epoch 34/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.8927 - accuracy: 0.6501 - val_loss: 1.5106 - val_accuracy: 0.4864
# Epoch 35/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.8892 - accuracy: 0.6550 - val_loss: 1.5576 - val_accuracy: 0.4697
# Epoch 36/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.8881 - accuracy: 0.6504 - val_loss: 1.5302 - val_accuracy: 0.4814
# Epoch 37/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.8851 - accuracy: 0.6519 - val_loss: 1.5839 - val_accuracy: 0.4616
# Epoch 38/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.8809 - accuracy: 0.6559 - val_loss: 1.5563 - val_accuracy: 0.4691
# Epoch 39/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.8761 - accuracy: 0.6575 - val_loss: 1.5863 - val_accuracy: 0.4752
# Epoch 40/100
# 405/405 [==============================] - 102s 253ms/step - loss: 0.8789 - accuracy: 0.6553 - val_loss: 1.5472 - val_accuracy: 0.4833
# Epoch 41/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.8730 - accuracy: 0.6594 - val_loss: 1.5758 - val_accuracy: 0.4666
# Epoch 42/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.8600 - accuracy: 0.6591 - val_loss: 1.5734 - val_accuracy: 0.4814
# Epoch 43/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.8606 - accuracy: 0.6629 - val_loss: 1.5899 - val_accuracy: 0.4851
# Epoch 44/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.8703 - accuracy: 0.6602 - val_loss: 1.6558 - val_accuracy: 0.4493
# Epoch 45/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.8602 - accuracy: 0.6632 - val_loss: 1.6504 - val_accuracy: 0.4629
# Epoch 46/100
# 405/405 [==============================] - 102s 253ms/step - loss: 0.8575 - accuracy: 0.6629 - val_loss: 1.5917 - val_accuracy: 0.4814
# Epoch 47/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.8611 - accuracy: 0.6614 - val_loss: 1.6164 - val_accuracy: 0.4703
# Epoch 48/100
# 405/405 [==============================] - 112s 276ms/step - loss: 0.8547 - accuracy: 0.6678 - val_loss: 1.6429 - val_accuracy: 0.4746
# Epoch 49/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.8574 - accuracy: 0.6598 - val_loss: 1.6597 - val_accuracy: 0.4672
# Epoch 50/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.8464 - accuracy: 0.6746 - val_loss: 1.6891 - val_accuracy: 0.4363
# Epoch 51/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.8431 - accuracy: 0.6709 - val_loss: 1.6168 - val_accuracy: 0.4851
# Epoch 52/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.8481 - accuracy: 0.6719 - val_loss: 1.6102 - val_accuracy: 0.4722
# Epoch 53/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.8405 - accuracy: 0.6656 - val_loss: 1.6491 - val_accuracy: 0.4752
# Epoch 54/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.8384 - accuracy: 0.6747 - val_loss: 1.6697 - val_accuracy: 0.4641
# Epoch 55/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.8376 - accuracy: 0.6720 - val_loss: 1.6648 - val_accuracy: 0.4722
# Epoch 56/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.8343 - accuracy: 0.6730 - val_loss: 1.6742 - val_accuracy: 0.4641
# Epoch 57/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.8410 - accuracy: 0.6708 - val_loss: 1.6659 - val_accuracy: 0.4703
# Epoch 58/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.8302 - accuracy: 0.6758 - val_loss: 1.7080 - val_accuracy: 0.4752
# Epoch 59/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.8307 - accuracy: 0.6754 - val_loss: 1.7249 - val_accuracy: 0.4579
# Epoch 60/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.8245 - accuracy: 0.6762 - val_loss: 1.6862 - val_accuracy: 0.4703
# Epoch 61/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.8281 - accuracy: 0.6737 - val_loss: 1.7172 - val_accuracy: 0.4548
# Epoch 62/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.8229 - accuracy: 0.6778 - val_loss: 1.7142 - val_accuracy: 0.4499
# Epoch 63/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.8218 - accuracy: 0.6765 - val_loss: 1.6856 - val_accuracy: 0.4610
# Epoch 64/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.8269 - accuracy: 0.6754 - val_loss: 1.7589 - val_accuracy: 0.4697
# Epoch 65/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.8134 - accuracy: 0.6811 - val_loss: 1.7077 - val_accuracy: 0.4647
# Epoch 66/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.8143 - accuracy: 0.6817 - val_loss: 1.7568 - val_accuracy: 0.4493
# Epoch 67/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.8275 - accuracy: 0.6751 - val_loss: 1.8272 - val_accuracy: 0.4350
# Epoch 68/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.8277 - accuracy: 0.6751 - val_loss: 1.7055 - val_accuracy: 0.4759
# Epoch 69/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.8047 - accuracy: 0.6889 - val_loss: 1.7303 - val_accuracy: 0.4629
# Epoch 70/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.8134 - accuracy: 0.6812 - val_loss: 1.7594 - val_accuracy: 0.4759
# Epoch 71/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.8060 - accuracy: 0.6841 - val_loss: 1.7312 - val_accuracy: 0.4722
# Epoch 72/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.8081 - accuracy: 0.6788 - val_loss: 1.7815 - val_accuracy: 0.4703
# Epoch 73/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.8132 - accuracy: 0.6810 - val_loss: 1.7411 - val_accuracy: 0.4530
# Epoch 74/100
# 405/405 [==============================] - 102s 252ms/step - loss: 0.8084 - accuracy: 0.6821 - val_loss: 1.7262 - val_accuracy: 0.4660
# Epoch 75/100
# 405/405 [==============================] - 103s 253ms/step - loss: 0.8098 - accuracy: 0.6827 - val_loss: 1.7845 - val_accuracy: 0.4554
# Epoch 76/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.8041 - accuracy: 0.6865 - val_loss: 1.8096 - val_accuracy: 0.4499
# Epoch 77/100
# 405/405 [==============================] - 103s 253ms/step - loss: 0.7992 - accuracy: 0.6852 - val_loss: 1.7702 - val_accuracy: 0.4715
# Epoch 78/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.7944 - accuracy: 0.6850 - val_loss: 1.7783 - val_accuracy: 0.4616
# Epoch 79/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.7955 - accuracy: 0.6862 - val_loss: 1.8031 - val_accuracy: 0.4585
# Epoch 80/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.7902 - accuracy: 0.6923 - val_loss: 1.7663 - val_accuracy: 0.4524
# Epoch 81/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.7890 - accuracy: 0.6889 - val_loss: 1.8125 - val_accuracy: 0.4356
# Epoch 82/100
# 405/405 [==============================] - 103s 253ms/step - loss: 0.8038 - accuracy: 0.6835 - val_loss: 1.7713 - val_accuracy: 0.4592
# Epoch 83/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.7906 - accuracy: 0.6889 - val_loss: 1.7921 - val_accuracy: 0.4455
# Epoch 84/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.7966 - accuracy: 0.6847 - val_loss: 1.9791 - val_accuracy: 0.4418
# Epoch 85/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.7959 - accuracy: 0.6876 - val_loss: 1.8832 - val_accuracy: 0.4542
# Epoch 86/100
# 405/405 [==============================] - 105s 258ms/step - loss: 0.7969 - accuracy: 0.6882 - val_loss: 1.7894 - val_accuracy: 0.4709
# Epoch 87/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.7846 - accuracy: 0.6936 - val_loss: 1.9386 - val_accuracy: 0.4493
# Epoch 88/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.7856 - accuracy: 0.6905 - val_loss: 1.8090 - val_accuracy: 0.4616
# Epoch 89/100
# 405/405 [==============================] - 105s 258ms/step - loss: 0.7812 - accuracy: 0.6924 - val_loss: 1.8204 - val_accuracy: 0.4524
# Epoch 90/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.7830 - accuracy: 0.6880 - val_loss: 1.8411 - val_accuracy: 0.4319
# Epoch 91/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.7834 - accuracy: 0.6940 - val_loss: 1.8871 - val_accuracy: 0.4604
# Epoch 92/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.7817 - accuracy: 0.6935 - val_loss: 1.8118 - val_accuracy: 0.4511
# Epoch 93/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.7835 - accuracy: 0.6916 - val_loss: 1.8257 - val_accuracy: 0.4554
# Epoch 94/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.7758 - accuracy: 0.6949 - val_loss: 1.8463 - val_accuracy: 0.4592
# Epoch 95/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.7824 - accuracy: 0.6921 - val_loss: 1.8598 - val_accuracy: 0.4573
# Epoch 96/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.7723 - accuracy: 0.6974 - val_loss: 1.9209 - val_accuracy: 0.4536
# Epoch 97/100
# 405/405 [==============================] - 104s 258ms/step - loss: 0.7794 - accuracy: 0.6926 - val_loss: 1.9257 - val_accuracy: 0.4505
# Epoch 98/100
# 405/405 [==============================] - 104s 258ms/step - loss: 0.7746 - accuracy: 0.6959 - val_loss: 1.8371 - val_accuracy: 0.4567
# Epoch 99/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.7778 - accuracy: 0.6890 - val_loss: 1.8859 - val_accuracy: 0.4567
# Epoch 100/100
# 405/405 [==============================] - 104s 256ms/step - loss: 0.7700 - accuracy: 0.6955 - val_loss: 1.8430 - val_accuracy: 0.4629

# %% [markdown]
# # Evaluate Model's Training & Validation Results

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()

# %% [markdown]
# # Generate Predictions With Model

# %%
y_pred = model.predict(test_batches).argmax(axis=1)

# %%
model.evaluate(test_batches)
# Out:
# 51/51 [==============================] - 12s 237ms/step - loss: 1.8419 - accuracy: 0.4398
# [1.8418996334075928, 0.4397515654563904]

# %% [markdown]
# # Evaluate Model's Prediction Results

# %%
# generate classification report
class_labels = list(test_batches.class_indices.keys())
report = classification_report(test_batches.classes, y_pred, target_names=class_labels, output_dict=True)
df_classification_report = pd.DataFrame(report).transpose()
df_classification_report
# Out:
#               precision    recall  f1-score      support
# hatchback      0.262500  0.134615  0.177966   156.000000
# mpv            0.349057  0.342593  0.345794   108.000000
# sedan          0.383197  0.451691  0.414634   414.000000
# sport          0.563927  0.546460  0.555056   452.000000
# suv            0.417445  0.471831  0.442975   284.000000
# truck          0.537415  0.493750  0.514658   160.000000
# wagon          0.100000  0.083333  0.090909    36.000000
# accuracy       0.439752  0.439752  0.439752     0.439752
# macro avg      0.373363  0.360610  0.363142  1610.000000
# weighted avg   0.434986  0.439752  0.434208  1610.000000

# %%
# compute confusion matrix
matrix = confusion_matrix(test_batches.classes, y_pred)

# normalize confusion matrix
matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
matrix = np.around(matrix, decimals=2)

# generate confusion matrix heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(matrix, annot=True, xticklabels=class_labels, yticklabels=class_labels)
plt.ylabel('Test Values')
plt.xlabel('Predicted Values')
# Out:
# Text(0.5, 69.0, 'Predicted Values')

# %% [markdown]
# # Compute Execution Time

# %%
execution_time_s = round(time.time() - start_time, 2)
execution_time_m = round(execution_time_s/60, 2)
execution_time_h = round(execution_time_m/60, 2)

print('Execution Time (Hours):', execution_time_h)
print('Execution Time (Minutes):', execution_time_m)
print('Execution Time (Seconds):', execution_time_s)
# Out:
# Execution Time (Hours): 2.91
# Execution Time (Minutes): 174.88
# Execution Time (Seconds): 10492.51
