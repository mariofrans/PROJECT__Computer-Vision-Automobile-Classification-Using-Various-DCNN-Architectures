# %%
# !pip install pandas numpy seaborn matplotlib tensorflow keras sklearn &> /dev/null

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications import Xception

import time
start_time = time.time()

# %%
PATH_DATA_TRAIN = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/train'
PATH_DATA_TEST = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/test'
PATH_DATA_VALIDATION = '../input/cars-data-ttv-80-10-10/data-preprocessed/data-preprocessed/validation'
PATH_SAVED_MODEL = 'xception-imagenet.h5'

# %% [markdown]
# # Load Dataset As Generators

# %%
generator = ImageDataGenerator(rescale = 1./255.)

target_size = (100, 100)
batch_size = 32

train_batches = generator.flow_from_directory(
    PATH_DATA_TRAIN, class_mode='categorical', 
    batch_size=batch_size, target_size=target_size
)

validation_batches = generator.flow_from_directory(
    PATH_DATA_VALIDATION, class_mode='categorical',  
    batch_size=batch_size, target_size=target_size
)

test_batches = generator.flow_from_directory(
    PATH_DATA_TEST, class_mode='categorical', shuffle=False, 
    batch_size=batch_size, target_size=target_size
)
# Out:
# Found 12959 images belonging to 7 classes.
# Found 1616 images belonging to 7 classes.
# Found 1610 images belonging to 7 classes.

# %%
# preview data (batch size, width, height, colors)
print('x_train shape:', train_batches[0][0].shape)
print('x_validation shape:', validation_batches[0][0].shape)
print('x_test shape:', test_batches[0][0].shape)
print('y_train shape:', train_batches[0][1].shape)
print('y_validation shape:', validation_batches[0][1].shape)
print('y_test shape:', test_batches[0][1].shape)
# Out:
# x_train shape: (32, 100, 100, 3)
# x_validation shape: (32, 100, 100, 3)
# x_test shape: (32, 100, 100, 3)
# y_train shape: (32, 7)
# y_validation shape: (32, 7)
# y_test shape: (32, 7)

# %%
# input & output shape
input_shape = train_batches[0][0][0].shape
output_shape = len(train_batches[0][1][0])

# display input & output shape
print('Input Shape:', input_shape)
print('Output Shape:', output_shape)
# Out:
# Input Shape: (100, 100, 3)
# Output Shape: 7

# %% [markdown]
# # Build & Compile Model

# %%
model = Xception(
    input_shape=input_shape, 
    weights="imagenet", 
    include_top=False, 
    pooling='max'
)

for layer in model.layers:
    layer.trainable = False

i = Input(shape=input_shape)
x = model(i)
x = Flatten()(x)
x = Dense(output_shape, activation='softmax')(x)

model = Model(inputs=i, outputs=x)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# 2022-11-17 09:11:57.985131: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 09:11:57.986013: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 09:11:57.994474: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 09:11:57.995226: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 09:11:57.995975: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 09:11:57.996689: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 09:11:57.997723: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-17 09:11:58.207227: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 09:11:58.208103: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 09:11:58.208828: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 09:11:58.209503: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 09:11:58.210184: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 09:11:58.210854: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 09:11:59.366841: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 09:11:59.367705: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 09:11:59.368470: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 09:11:59.369312: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 09:11:59.370025: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 09:11:59.370736: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-11-17 09:11:59.371165: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-17 09:11:59.371836: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# xception (Functional)        (None, 2048)              20861480
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 14343
# =================================================================
# Total params: 20,875,823
# Trainable params: 14,343
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %% [markdown]
# # Train Model

# %%
# train model
r = model.fit(train_batches, validation_data=validation_batches, epochs=100)

# save model
model.save(PATH_SAVED_MODEL)

# load model
# model = load_model(PATH_SAVED_MODEL)
# Out:
# 2022-11-17 09:12:01.291203: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-11-17 09:12:04.505620: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 405/405 [==============================] - 110s 258ms/step - loss: 1.3967 - accuracy: 0.4709 - val_loss: 1.2954 - val_accuracy: 0.5111
# Epoch 2/100
# 405/405 [==============================] - 102s 252ms/step - loss: 1.1931 - accuracy: 0.5489 - val_loss: 1.2416 - val_accuracy: 0.5297
# Epoch 3/100
# 405/405 [==============================] - 101s 250ms/step - loss: 1.1196 - accuracy: 0.5739 - val_loss: 1.1853 - val_accuracy: 0.5495
# Epoch 4/100
# 405/405 [==============================] - 101s 250ms/step - loss: 1.0504 - accuracy: 0.6003 - val_loss: 1.1858 - val_accuracy: 0.5619
# Epoch 5/100
# 405/405 [==============================] - 101s 249ms/step - loss: 1.0312 - accuracy: 0.6059 - val_loss: 1.1701 - val_accuracy: 0.5724
# Epoch 6/100
# 405/405 [==============================] - 101s 249ms/step - loss: 0.9874 - accuracy: 0.6252 - val_loss: 1.2048 - val_accuracy: 0.5569
# Epoch 7/100
# 405/405 [==============================] - 102s 251ms/step - loss: 0.9601 - accuracy: 0.6350 - val_loss: 1.1945 - val_accuracy: 0.5520
# Epoch 8/100
# 405/405 [==============================] - 101s 251ms/step - loss: 0.9219 - accuracy: 0.6517 - val_loss: 1.2689 - val_accuracy: 0.5309
# Epoch 9/100
# 405/405 [==============================] - 101s 249ms/step - loss: 0.9067 - accuracy: 0.6532 - val_loss: 1.1763 - val_accuracy: 0.5730
# Epoch 10/100
# 405/405 [==============================] - 101s 249ms/step - loss: 0.8826 - accuracy: 0.6674 - val_loss: 1.1388 - val_accuracy: 0.5866
# Epoch 11/100
# 405/405 [==============================] - 101s 250ms/step - loss: 0.8755 - accuracy: 0.6649 - val_loss: 1.2017 - val_accuracy: 0.5780
# Epoch 12/100
# 405/405 [==============================] - 100s 248ms/step - loss: 0.8553 - accuracy: 0.6750 - val_loss: 1.2004 - val_accuracy: 0.5767
# Epoch 13/100
# 405/405 [==============================] - 102s 251ms/step - loss: 0.8414 - accuracy: 0.6834 - val_loss: 1.2051 - val_accuracy: 0.5656
# Epoch 14/100
# 405/405 [==============================] - 100s 248ms/step - loss: 0.8206 - accuracy: 0.6849 - val_loss: 1.2003 - val_accuracy: 0.5625
# Epoch 15/100
# 405/405 [==============================] - 100s 246ms/step - loss: 0.8165 - accuracy: 0.6893 - val_loss: 1.2062 - val_accuracy: 0.5730
# Epoch 16/100
# 405/405 [==============================] - 99s 245ms/step - loss: 0.8050 - accuracy: 0.6887 - val_loss: 1.1844 - val_accuracy: 0.5712
# Epoch 17/100
# 405/405 [==============================] - 100s 247ms/step - loss: 0.8058 - accuracy: 0.6905 - val_loss: 1.2595 - val_accuracy: 0.5613
# Epoch 18/100
# 405/405 [==============================] - 98s 242ms/step - loss: 0.7875 - accuracy: 0.7013 - val_loss: 1.2975 - val_accuracy: 0.5495
# Epoch 19/100
# 405/405 [==============================] - 98s 242ms/step - loss: 0.7804 - accuracy: 0.7002 - val_loss: 1.2172 - val_accuracy: 0.5780
# Epoch 20/100
# 405/405 [==============================] - 99s 244ms/step - loss: 0.7676 - accuracy: 0.7078 - val_loss: 1.2586 - val_accuracy: 0.5687
# Epoch 21/100
# 405/405 [==============================] - 99s 245ms/step - loss: 0.7625 - accuracy: 0.7098 - val_loss: 1.2338 - val_accuracy: 0.5569
# Epoch 22/100
# 405/405 [==============================] - 101s 249ms/step - loss: 0.7590 - accuracy: 0.7099 - val_loss: 1.2605 - val_accuracy: 0.5582
# Epoch 23/100
# 405/405 [==============================] - 101s 250ms/step - loss: 0.7437 - accuracy: 0.7166 - val_loss: 1.2505 - val_accuracy: 0.5693
# Epoch 24/100
# 405/405 [==============================] - 100s 246ms/step - loss: 0.7426 - accuracy: 0.7146 - val_loss: 1.2327 - val_accuracy: 0.5780
# Epoch 25/100
# 405/405 [==============================] - 100s 246ms/step - loss: 0.7315 - accuracy: 0.7205 - val_loss: 1.2447 - val_accuracy: 0.5718
# Epoch 26/100
# 405/405 [==============================] - 100s 247ms/step - loss: 0.7200 - accuracy: 0.7254 - val_loss: 1.2659 - val_accuracy: 0.5749
# Epoch 27/100
# 405/405 [==============================] - 99s 245ms/step - loss: 0.7217 - accuracy: 0.7215 - val_loss: 1.2675 - val_accuracy: 0.5730
# Epoch 28/100
# 405/405 [==============================] - 100s 247ms/step - loss: 0.7149 - accuracy: 0.7257 - val_loss: 1.2521 - val_accuracy: 0.5606
# Epoch 29/100
# 405/405 [==============================] - 101s 249ms/step - loss: 0.7179 - accuracy: 0.7195 - val_loss: 1.2910 - val_accuracy: 0.5699
# Epoch 30/100
# 405/405 [==============================] - 99s 245ms/step - loss: 0.7028 - accuracy: 0.7337 - val_loss: 1.3451 - val_accuracy: 0.5606
# Epoch 31/100
# 405/405 [==============================] - 100s 246ms/step - loss: 0.6970 - accuracy: 0.7288 - val_loss: 1.3045 - val_accuracy: 0.5631
# Epoch 32/100
# 405/405 [==============================] - 101s 248ms/step - loss: 0.6916 - accuracy: 0.7339 - val_loss: 1.2907 - val_accuracy: 0.5774
# Epoch 33/100
# 405/405 [==============================] - 100s 248ms/step - loss: 0.6830 - accuracy: 0.7374 - val_loss: 1.3236 - val_accuracy: 0.5588
# Epoch 34/100
# 405/405 [==============================] - 101s 249ms/step - loss: 0.6834 - accuracy: 0.7420 - val_loss: 1.3143 - val_accuracy: 0.5724
# Epoch 35/100
# 405/405 [==============================] - 101s 250ms/step - loss: 0.6803 - accuracy: 0.7379 - val_loss: 1.3767 - val_accuracy: 0.5532
# Epoch 36/100
# 405/405 [==============================] - 101s 250ms/step - loss: 0.6816 - accuracy: 0.7399 - val_loss: 1.3334 - val_accuracy: 0.5749
# Epoch 37/100
# 405/405 [==============================] - 100s 247ms/step - loss: 0.6724 - accuracy: 0.7418 - val_loss: 1.3793 - val_accuracy: 0.5675
# Epoch 38/100
# 405/405 [==============================] - 100s 248ms/step - loss: 0.6690 - accuracy: 0.7472 - val_loss: 1.3485 - val_accuracy: 0.5681
# Epoch 39/100
# 405/405 [==============================] - 101s 248ms/step - loss: 0.6635 - accuracy: 0.7446 - val_loss: 1.3496 - val_accuracy: 0.5718
# Epoch 40/100
# 405/405 [==============================] - 100s 247ms/step - loss: 0.6608 - accuracy: 0.7483 - val_loss: 1.3765 - val_accuracy: 0.5650
# Epoch 41/100
# 405/405 [==============================] - 100s 246ms/step - loss: 0.6512 - accuracy: 0.7504 - val_loss: 1.3692 - val_accuracy: 0.5606
# Epoch 42/100
# 405/405 [==============================] - 101s 248ms/step - loss: 0.6533 - accuracy: 0.7480 - val_loss: 1.3630 - val_accuracy: 0.5705
# Epoch 43/100
# 405/405 [==============================] - 100s 248ms/step - loss: 0.6397 - accuracy: 0.7567 - val_loss: 1.3797 - val_accuracy: 0.5532
# Epoch 44/100
# 405/405 [==============================] - 100s 248ms/step - loss: 0.6545 - accuracy: 0.7450 - val_loss: 1.3919 - val_accuracy: 0.5588
# Epoch 45/100
# 405/405 [==============================] - 100s 247ms/step - loss: 0.6399 - accuracy: 0.7528 - val_loss: 1.4119 - val_accuracy: 0.5582
# Epoch 46/100
# 405/405 [==============================] - 100s 246ms/step - loss: 0.6440 - accuracy: 0.7511 - val_loss: 1.4740 - val_accuracy: 0.5340
# Epoch 47/100
# 405/405 [==============================] - 99s 245ms/step - loss: 0.6310 - accuracy: 0.7599 - val_loss: 1.4269 - val_accuracy: 0.5532
# Epoch 48/100
# 405/405 [==============================] - 100s 248ms/step - loss: 0.6335 - accuracy: 0.7550 - val_loss: 1.4413 - val_accuracy: 0.5625
# Epoch 49/100
# 405/405 [==============================] - 100s 246ms/step - loss: 0.6380 - accuracy: 0.7550 - val_loss: 1.3998 - val_accuracy: 0.5631
# Epoch 50/100
# 405/405 [==============================] - 100s 247ms/step - loss: 0.6305 - accuracy: 0.7604 - val_loss: 1.3994 - val_accuracy: 0.5718
# Epoch 51/100
# 405/405 [==============================] - 100s 246ms/step - loss: 0.6155 - accuracy: 0.7660 - val_loss: 1.4472 - val_accuracy: 0.5476
# Epoch 52/100
# 405/405 [==============================] - 100s 246ms/step - loss: 0.6215 - accuracy: 0.7611 - val_loss: 1.4409 - val_accuracy: 0.5668
# Epoch 53/100
# 405/405 [==============================] - 100s 246ms/step - loss: 0.6148 - accuracy: 0.7636 - val_loss: 1.4385 - val_accuracy: 0.5575
# Epoch 54/100
# 405/405 [==============================] - 100s 246ms/step - loss: 0.6185 - accuracy: 0.7623 - val_loss: 1.4522 - val_accuracy: 0.5631
# Epoch 55/100
# 405/405 [==============================] - 101s 250ms/step - loss: 0.6130 - accuracy: 0.7651 - val_loss: 1.4773 - val_accuracy: 0.5551
# Epoch 56/100
# 405/405 [==============================] - 100s 247ms/step - loss: 0.6194 - accuracy: 0.7602 - val_loss: 1.4609 - val_accuracy: 0.5551
# Epoch 57/100
# 405/405 [==============================] - 99s 245ms/step - loss: 0.6101 - accuracy: 0.7614 - val_loss: 1.4826 - val_accuracy: 0.5421
# Epoch 58/100
# 405/405 [==============================] - 99s 244ms/step - loss: 0.6021 - accuracy: 0.7683 - val_loss: 1.4965 - val_accuracy: 0.5507
# Epoch 59/100
# 405/405 [==============================] - 101s 249ms/step - loss: 0.6054 - accuracy: 0.7663 - val_loss: 1.5575 - val_accuracy: 0.5272
# Epoch 60/100
# 405/405 [==============================] - 100s 247ms/step - loss: 0.6045 - accuracy: 0.7661 - val_loss: 1.5254 - val_accuracy: 0.5514
# Epoch 61/100
# 405/405 [==============================] - 100s 247ms/step - loss: 0.6018 - accuracy: 0.7663 - val_loss: 1.5082 - val_accuracy: 0.5563
# Epoch 62/100
# 405/405 [==============================] - 100s 246ms/step - loss: 0.5994 - accuracy: 0.7673 - val_loss: 1.5186 - val_accuracy: 0.5464
# Epoch 63/100
# 405/405 [==============================] - 102s 251ms/step - loss: 0.6002 - accuracy: 0.7714 - val_loss: 1.5044 - val_accuracy: 0.5675
# Epoch 64/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.6024 - accuracy: 0.7658 - val_loss: 1.5218 - val_accuracy: 0.5637
# Epoch 65/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.5857 - accuracy: 0.7760 - val_loss: 1.5744 - val_accuracy: 0.5458
# Epoch 66/100
# 405/405 [==============================] - 102s 253ms/step - loss: 0.5872 - accuracy: 0.7724 - val_loss: 1.5359 - val_accuracy: 0.5520
# Epoch 67/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.5834 - accuracy: 0.7737 - val_loss: 1.5374 - val_accuracy: 0.5489
# Epoch 68/100
# 405/405 [==============================] - 102s 253ms/step - loss: 0.5762 - accuracy: 0.7773 - val_loss: 1.5416 - val_accuracy: 0.5452
# Epoch 69/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.5806 - accuracy: 0.7734 - val_loss: 1.6076 - val_accuracy: 0.5303
# Epoch 70/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.5864 - accuracy: 0.7686 - val_loss: 1.5876 - val_accuracy: 0.5439
# Epoch 71/100
# 405/405 [==============================] - 104s 257ms/step - loss: 0.5767 - accuracy: 0.7779 - val_loss: 1.5587 - val_accuracy: 0.5371
# Epoch 72/100
# 405/405 [==============================] - 102s 252ms/step - loss: 0.5756 - accuracy: 0.7775 - val_loss: 1.6110 - val_accuracy: 0.5371
# Epoch 73/100
# 405/405 [==============================] - 103s 253ms/step - loss: 0.5722 - accuracy: 0.7776 - val_loss: 1.5848 - val_accuracy: 0.5551
# Epoch 74/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.5738 - accuracy: 0.7775 - val_loss: 1.6232 - val_accuracy: 0.5291
# Epoch 75/100
# 405/405 [==============================] - 104s 258ms/step - loss: 0.5794 - accuracy: 0.7777 - val_loss: 1.5619 - val_accuracy: 0.5384
# Epoch 76/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.5630 - accuracy: 0.7822 - val_loss: 1.6616 - val_accuracy: 0.5272
# Epoch 77/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.5694 - accuracy: 0.7802 - val_loss: 1.6104 - val_accuracy: 0.5334
# Epoch 78/100
# 405/405 [==============================] - 107s 263ms/step - loss: 0.5633 - accuracy: 0.7856 - val_loss: 1.6408 - val_accuracy: 0.5390
# Epoch 79/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.5586 - accuracy: 0.7878 - val_loss: 1.6185 - val_accuracy: 0.5557
# Epoch 80/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.5642 - accuracy: 0.7819 - val_loss: 1.6410 - val_accuracy: 0.5439
# Epoch 81/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.5624 - accuracy: 0.7852 - val_loss: 1.6023 - val_accuracy: 0.5470
# Epoch 82/100
# 405/405 [==============================] - 105s 259ms/step - loss: 0.5576 - accuracy: 0.7858 - val_loss: 1.6511 - val_accuracy: 0.5464
# Epoch 83/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.5600 - accuracy: 0.7851 - val_loss: 1.7009 - val_accuracy: 0.5328
# Epoch 84/100
# 405/405 [==============================] - 106s 261ms/step - loss: 0.5523 - accuracy: 0.7877 - val_loss: 1.6476 - val_accuracy: 0.5402
# Epoch 85/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.5550 - accuracy: 0.7838 - val_loss: 1.6589 - val_accuracy: 0.5384
# Epoch 86/100
# 405/405 [==============================] - 106s 262ms/step - loss: 0.5613 - accuracy: 0.7856 - val_loss: 1.6614 - val_accuracy: 0.5433
# Epoch 87/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.5510 - accuracy: 0.7871 - val_loss: 1.6982 - val_accuracy: 0.5266
# Epoch 88/100
# 405/405 [==============================] - 102s 252ms/step - loss: 0.5468 - accuracy: 0.7886 - val_loss: 1.7049 - val_accuracy: 0.5316
# Epoch 89/100
# 405/405 [==============================] - 107s 265ms/step - loss: 0.5465 - accuracy: 0.7916 - val_loss: 1.7705 - val_accuracy: 0.5198
# Epoch 90/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.5454 - accuracy: 0.7898 - val_loss: 1.6958 - val_accuracy: 0.5297
# Epoch 91/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.5509 - accuracy: 0.7888 - val_loss: 1.7242 - val_accuracy: 0.5210
# Epoch 92/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.5467 - accuracy: 0.7910 - val_loss: 1.7738 - val_accuracy: 0.5229
# Epoch 93/100
# 405/405 [==============================] - 103s 255ms/step - loss: 0.5397 - accuracy: 0.7908 - val_loss: 1.6884 - val_accuracy: 0.5365
# Epoch 94/100
# 405/405 [==============================] - 102s 252ms/step - loss: 0.5431 - accuracy: 0.7936 - val_loss: 1.8304 - val_accuracy: 0.5080
# Epoch 95/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.5486 - accuracy: 0.7869 - val_loss: 1.7153 - val_accuracy: 0.5316
# Epoch 96/100
# 405/405 [==============================] - 101s 250ms/step - loss: 0.5499 - accuracy: 0.7886 - val_loss: 1.6955 - val_accuracy: 0.5532
# Epoch 97/100
# 405/405 [==============================] - 101s 249ms/step - loss: 0.5393 - accuracy: 0.7939 - val_loss: 1.7443 - val_accuracy: 0.5198
# Epoch 98/100
# 405/405 [==============================] - 103s 253ms/step - loss: 0.5349 - accuracy: 0.7978 - val_loss: 1.7934 - val_accuracy: 0.5167
# Epoch 99/100
# 405/405 [==============================] - 103s 253ms/step - loss: 0.5326 - accuracy: 0.7973 - val_loss: 1.7069 - val_accuracy: 0.5371
# Epoch 100/100
# 405/405 [==============================] - 103s 254ms/step - loss: 0.5366 - accuracy: 0.7941 - val_loss: 1.7339 - val_accuracy: 0.5303
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %% [markdown]
# # Evaluate Model's Training & Validation Results

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()

# %% [markdown]
# # Generate Predictions With Model

# %%
y_pred = model.predict(test_batches).argmax(axis=1)

# %%
model.evaluate(test_batches)
# Out:
# 51/51 [==============================] - 12s 236ms/step - loss: 1.7366 - accuracy: 0.5292
# [1.7365537881851196, 0.5291925668716431]

# %% [markdown]
# # Evaluate Model's Prediction Results

# %%
# generate classification report
class_labels = list(test_batches.class_indices.keys())
report = classification_report(test_batches.classes, y_pred, target_names=class_labels, output_dict=True)
df_classification_report = pd.DataFrame(report).transpose()
df_classification_report
# Out:
#               precision    recall  f1-score      support
# hatchback      0.322835  0.262821  0.289753   156.000000
# mpv            0.504587  0.509259  0.506912   108.000000
# sedan          0.463557  0.384058  0.420079   414.000000
# sport          0.612500  0.650442  0.630901   452.000000
# suv            0.516393  0.665493  0.581538   284.000000
# truck          0.675159  0.662500  0.668770   160.000000
# wagon          0.285714  0.222222  0.250000    36.000000
# accuracy       0.529193  0.529193  0.529193     0.529193
# macro avg      0.482964  0.479542  0.478279  1610.000000
# weighted avg   0.520862  0.529193  0.521856  1610.000000

# %%
# compute confusion matrix
matrix = confusion_matrix(test_batches.classes, y_pred)

# normalize confusion matrix
matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
matrix = np.around(matrix, decimals=2)

# generate confusion matrix heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(matrix, annot=True, xticklabels=class_labels, yticklabels=class_labels)
plt.ylabel('Test Values')
plt.xlabel('Predicted Values')
# Out:
# Text(0.5, 69.0, 'Predicted Values')

# %% [markdown]
# # Compute Execution Time

# %%
execution_time_s = round(time.time() - start_time, 2)
execution_time_m = round(execution_time_s/60, 2)
execution_time_h = round(execution_time_m/60, 2)

print('Execution Time (Hours):', execution_time_h)
print('Execution Time (Minutes):', execution_time_m)
print('Execution Time (Seconds):', execution_time_s)
# Out:
# Execution Time (Hours): 2.9
# Execution Time (Minutes): 174.15
# Execution Time (Seconds): 10448.93
