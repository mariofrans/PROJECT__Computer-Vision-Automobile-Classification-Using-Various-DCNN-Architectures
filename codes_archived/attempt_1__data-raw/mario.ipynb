# %%
# !pip install pandas numpy seaborn matplotlib tensorflow keras sklearn &> /dev/null

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout, GlobalMaxPooling2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.models import Model

import time
start_time = time.time()

# %%
PATH_DATA_TRAIN = '../input/cars-data-ttv-80-10-10/data-raw/data-raw/train'
PATH_DATA_TEST = '../input/cars-data-ttv-80-10-10/data-raw/data-raw/test'
PATH_DATA_VALIDATION = '../input/cars-data-ttv-80-10-10/data-raw/data-raw/validation'
PATH_SAVED_MODEL = 'mario.h5'

# %% [markdown]
# # Load Dataset As Generators

# %%
generator = ImageDataGenerator(rescale = 1./255.)

target_size = (100, 100)
batch_size = 32

train_batches = generator.flow_from_directory(
    PATH_DATA_TRAIN, class_mode='categorical', 
    batch_size=batch_size, target_size=target_size
)

validation_batches = generator.flow_from_directory(
    PATH_DATA_VALIDATION, class_mode='categorical',  
    batch_size=batch_size, target_size=target_size
)

test_batches = generator.flow_from_directory(
    PATH_DATA_TEST, class_mode='categorical', shuffle=False, 
    batch_size=batch_size, target_size=target_size
)
# Out:
# Found 12971 images belonging to 7 classes.
# Found 1612 images belonging to 7 classes.
# Found 1602 images belonging to 7 classes.

# %%
# preview data (batch size, width, height, colors)
print('x_train shape:', train_batches[0][0].shape)
print('x_validation shape:', validation_batches[0][0].shape)
print('x_test shape:', test_batches[0][0].shape)
print('y_train shape:', train_batches[0][1].shape)
print('y_validation shape:', validation_batches[0][1].shape)
print('y_test shape:', test_batches[0][1].shape)
# Out:
# x_train shape: (32, 100, 100, 3)
# x_validation shape: (32, 100, 100, 3)
# x_test shape: (32, 100, 100, 3)
# y_train shape: (32, 7)
# y_validation shape: (32, 7)
# y_test shape: (32, 7)

# %%
# input & output shape
input_shape = train_batches[0][0][0].shape
output_shape = len(train_batches[0][1][0])

# display input & output shape
print('Input Shape:', input_shape)
print('Output Shape:', output_shape)
# Out:
# Input Shape: (100, 100, 3)
# Output Shape: 7

# %% [markdown]
# # Build & Compile Model

# %%
i = Input(shape=input_shape)

x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = BatchNormalization()(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Flatten()(x)
x = Dropout(0.2)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(output_shape, activation='softmax')(x)

model = Model(i, x)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# 2022-12-06 15:45:23.018338: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-06 15:45:23.019342: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-06 15:45:23.256523: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-06 15:45:23.257419: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-06 15:45:23.258206: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-06 15:45:23.258964: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-06 15:45:23.260706: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-06 15:45:23.507353: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-06 15:45:23.508231: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-06 15:45:23.508963: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-06 15:45:23.509671: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-06 15:45:23.510387: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-06 15:45:23.511190: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-06 15:45:27.679912: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-06 15:45:27.681016: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-06 15:45:27.681968: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-06 15:45:27.682854: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-06 15:45:27.683681: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-06 15:45:27.684447: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 100, 100, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 100, 100, 32)      128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 100, 100, 32)      9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 100, 100, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 50, 50, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 50, 50, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 50, 50, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 50, 50, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 50, 50, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 25, 25, 128)       73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 25, 25, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 25, 25, 128)       147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 25, 25, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 18432)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              18875392
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 7175
# =================================================================
# Total params: 19,171,367
# Trainable params: 19,170,471
# Non-trainable params: 896
# _________________________________________________________________
# 0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-12-06 15:45:27.689238: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-06 15:45:27.690019: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %% [markdown]
# # Train Model

# %%
# train model
r = model.fit(train_batches, validation_data=validation_batches, epochs=100)

# save model
model.save(PATH_SAVED_MODEL)

# load model
# model = load_model(PATH_SAVED_MODEL)
# Out:
# 2022-12-06 15:45:28.602453: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-12-06 15:45:32.018348: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 406/406 [==============================] - 219s 503ms/step - loss: 3.2717 - accuracy: 0.2979 - val_loss: 4.3695 - val_accuracy: 0.2804
# Epoch 2/100
# 406/406 [==============================] - 143s 351ms/step - loss: 1.6248 - accuracy: 0.3525 - val_loss: 1.5933 - val_accuracy: 0.3505
# Epoch 3/100
# 406/406 [==============================] - 141s 347ms/step - loss: 1.5186 - accuracy: 0.3972 - val_loss: 1.6830 - val_accuracy: 0.3685
# Epoch 4/100
# 406/406 [==============================] - 142s 348ms/step - loss: 1.4266 - accuracy: 0.4322 - val_loss: 1.4216 - val_accuracy: 0.4404
# Epoch 5/100
# 406/406 [==============================] - 143s 352ms/step - loss: 1.3317 - accuracy: 0.4710 - val_loss: 1.3751 - val_accuracy: 0.4659
# Epoch 6/100
# 406/406 [==============================] - 146s 358ms/step - loss: 1.2487 - accuracy: 0.5054 - val_loss: 1.4009 - val_accuracy: 0.4646
# Epoch 7/100
# 406/406 [==============================] - 144s 354ms/step - loss: 1.1607 - accuracy: 0.5481 - val_loss: 1.4729 - val_accuracy: 0.4690
# Epoch 8/100
# 406/406 [==============================] - 141s 347ms/step - loss: 1.0616 - accuracy: 0.5849 - val_loss: 1.3196 - val_accuracy: 0.5118
# Epoch 9/100
# 406/406 [==============================] - 140s 344ms/step - loss: 0.9565 - accuracy: 0.6294 - val_loss: 1.4026 - val_accuracy: 0.5062
# Epoch 10/100
# 406/406 [==============================] - 139s 342ms/step - loss: 0.8491 - accuracy: 0.6798 - val_loss: 1.2549 - val_accuracy: 0.5509
# Epoch 11/100
# 406/406 [==============================] - 140s 345ms/step - loss: 0.7410 - accuracy: 0.7149 - val_loss: 1.5093 - val_accuracy: 0.4981
# Epoch 12/100
# 406/406 [==============================] - 139s 341ms/step - loss: 0.6538 - accuracy: 0.7554 - val_loss: 1.4759 - val_accuracy: 0.5180
# Epoch 13/100
# 406/406 [==============================] - 140s 345ms/step - loss: 0.5942 - accuracy: 0.7807 - val_loss: 1.5816 - val_accuracy: 0.4963
# Epoch 14/100
# 406/406 [==============================] - 139s 343ms/step - loss: 0.4839 - accuracy: 0.8201 - val_loss: 1.4079 - val_accuracy: 0.5589
# Epoch 15/100
# 406/406 [==============================] - 140s 346ms/step - loss: 0.4300 - accuracy: 0.8440 - val_loss: 1.5415 - val_accuracy: 0.5620
# Epoch 16/100
# 406/406 [==============================] - 142s 348ms/step - loss: 0.3856 - accuracy: 0.8608 - val_loss: 1.5453 - val_accuracy: 0.5465
# Epoch 17/100
# 406/406 [==============================] - 143s 352ms/step - loss: 0.3514 - accuracy: 0.8742 - val_loss: 1.6593 - val_accuracy: 0.5571
# Epoch 18/100
# 406/406 [==============================] - 140s 345ms/step - loss: 0.3239 - accuracy: 0.8838 - val_loss: 1.5980 - val_accuracy: 0.5788
# Epoch 19/100
# 406/406 [==============================] - 142s 349ms/step - loss: 0.2884 - accuracy: 0.8978 - val_loss: 1.9319 - val_accuracy: 0.5323
# Epoch 20/100
# 406/406 [==============================] - 141s 347ms/step - loss: 0.2614 - accuracy: 0.9049 - val_loss: 1.7774 - val_accuracy: 0.5819
# Epoch 21/100
# 406/406 [==============================] - 142s 349ms/step - loss: 0.2441 - accuracy: 0.9150 - val_loss: 1.7844 - val_accuracy: 0.5620
# Epoch 22/100
# 406/406 [==============================] - 141s 349ms/step - loss: 0.2220 - accuracy: 0.9240 - val_loss: 2.2396 - val_accuracy: 0.5459
# Epoch 23/100
# 406/406 [==============================] - 141s 348ms/step - loss: 0.2066 - accuracy: 0.9265 - val_loss: 1.9828 - val_accuracy: 0.5459
# Epoch 24/100
# 406/406 [==============================] - 144s 354ms/step - loss: 0.2103 - accuracy: 0.9271 - val_loss: 2.1067 - val_accuracy: 0.5440
# Epoch 25/100
# 406/406 [==============================] - 146s 359ms/step - loss: 0.2104 - accuracy: 0.9308 - val_loss: 1.9170 - val_accuracy: 0.5738
# Epoch 26/100
# 406/406 [==============================] - 145s 356ms/step - loss: 0.1917 - accuracy: 0.9330 - val_loss: 2.1457 - val_accuracy: 0.5453
# Epoch 27/100
# 406/406 [==============================] - 146s 359ms/step - loss: 0.1786 - accuracy: 0.9395 - val_loss: 2.1098 - val_accuracy: 0.5589
# Epoch 28/100
# 406/406 [==============================] - 142s 351ms/step - loss: 0.1666 - accuracy: 0.9416 - val_loss: 2.0925 - val_accuracy: 0.5651
# Epoch 29/100
# 406/406 [==============================] - 144s 353ms/step - loss: 0.1891 - accuracy: 0.9369 - val_loss: 1.9751 - val_accuracy: 0.5732
# Epoch 30/100
# 406/406 [==============================] - 144s 353ms/step - loss: 0.1744 - accuracy: 0.9424 - val_loss: 2.4699 - val_accuracy: 0.5416
# Epoch 31/100
# 406/406 [==============================] - 142s 351ms/step - loss: 0.1528 - accuracy: 0.9480 - val_loss: 2.2016 - val_accuracy: 0.5732
# Epoch 32/100
# 406/406 [==============================] - 139s 342ms/step - loss: 0.1554 - accuracy: 0.9480 - val_loss: 2.2484 - val_accuracy: 0.5509
# Epoch 33/100
# 406/406 [==============================] - 142s 349ms/step - loss: 0.1417 - accuracy: 0.9530 - val_loss: 2.0560 - val_accuracy: 0.5825
# Epoch 34/100
# 406/406 [==============================] - 139s 342ms/step - loss: 0.1312 - accuracy: 0.9547 - val_loss: 2.3885 - val_accuracy: 0.5744
# Epoch 35/100
# 406/406 [==============================] - 139s 343ms/step - loss: 0.1443 - accuracy: 0.9526 - val_loss: 2.4433 - val_accuracy: 0.5689
# Epoch 36/100
# 406/406 [==============================] - 140s 345ms/step - loss: 0.1345 - accuracy: 0.9557 - val_loss: 2.0420 - val_accuracy: 0.5837
# Epoch 37/100
# 406/406 [==============================] - 139s 342ms/step - loss: 0.1144 - accuracy: 0.9620 - val_loss: 2.3329 - val_accuracy: 0.5806
# Epoch 38/100
# 406/406 [==============================] - 140s 345ms/step - loss: 0.1332 - accuracy: 0.9571 - val_loss: 2.2757 - val_accuracy: 0.5521
# Epoch 39/100
# 406/406 [==============================] - 140s 344ms/step - loss: 0.1338 - accuracy: 0.9567 - val_loss: 2.2090 - val_accuracy: 0.5720
# Epoch 40/100
# 406/406 [==============================] - 139s 342ms/step - loss: 0.1190 - accuracy: 0.9613 - val_loss: 2.3237 - val_accuracy: 0.5788
# Epoch 41/100
# 406/406 [==============================] - 138s 339ms/step - loss: 0.1255 - accuracy: 0.9581 - val_loss: 2.4284 - val_accuracy: 0.5732
# Epoch 42/100
# 406/406 [==============================] - 137s 338ms/step - loss: 0.1093 - accuracy: 0.9628 - val_loss: 2.3087 - val_accuracy: 0.5850
# Epoch 43/100
# 406/406 [==============================] - 139s 342ms/step - loss: 0.1081 - accuracy: 0.9658 - val_loss: 2.1163 - val_accuracy: 0.5651
# Epoch 44/100
# 406/406 [==============================] - 140s 344ms/step - loss: 0.1089 - accuracy: 0.9650 - val_loss: 2.5862 - val_accuracy: 0.5769
# Epoch 45/100
# 406/406 [==============================] - 141s 348ms/step - loss: 0.1161 - accuracy: 0.9648 - val_loss: 2.3088 - val_accuracy: 0.5751
# Epoch 46/100
# 406/406 [==============================] - 139s 343ms/step - loss: 0.0984 - accuracy: 0.9675 - val_loss: 2.5027 - val_accuracy: 0.5627
# Epoch 47/100
# 406/406 [==============================] - 138s 340ms/step - loss: 0.1108 - accuracy: 0.9658 - val_loss: 2.1794 - val_accuracy: 0.5887
# Epoch 48/100
# 406/406 [==============================] - 138s 339ms/step - loss: 0.0932 - accuracy: 0.9721 - val_loss: 2.4280 - val_accuracy: 0.5819
# Epoch 49/100
# 406/406 [==============================] - 137s 338ms/step - loss: 0.0984 - accuracy: 0.9694 - val_loss: 2.1393 - val_accuracy: 0.5949
# Epoch 50/100
# 406/406 [==============================] - 138s 341ms/step - loss: 0.0978 - accuracy: 0.9699 - val_loss: 2.7285 - val_accuracy: 0.5738
# Epoch 51/100
# 406/406 [==============================] - 139s 343ms/step - loss: 0.0790 - accuracy: 0.9732 - val_loss: 2.3970 - val_accuracy: 0.5868
# Epoch 52/100
# 406/406 [==============================] - 139s 343ms/step - loss: 0.0955 - accuracy: 0.9695 - val_loss: 2.5598 - val_accuracy: 0.5837
# Epoch 53/100
# 406/406 [==============================] - 139s 344ms/step - loss: 0.0924 - accuracy: 0.9709 - val_loss: 2.1435 - val_accuracy: 0.5986
# Epoch 54/100
# 406/406 [==============================] - 141s 347ms/step - loss: 0.0687 - accuracy: 0.9776 - val_loss: 2.1841 - val_accuracy: 0.5893
# Epoch 55/100
# 406/406 [==============================] - 140s 344ms/step - loss: 0.0720 - accuracy: 0.9774 - val_loss: 2.7436 - val_accuracy: 0.5924
# Epoch 56/100
# 406/406 [==============================] - 140s 345ms/step - loss: 0.0856 - accuracy: 0.9726 - val_loss: 2.6205 - val_accuracy: 0.5689
# Epoch 57/100
# 406/406 [==============================] - 142s 349ms/step - loss: 0.0813 - accuracy: 0.9753 - val_loss: 2.5623 - val_accuracy: 0.5794
# Epoch 58/100
# 406/406 [==============================] - 141s 346ms/step - loss: 0.0785 - accuracy: 0.9769 - val_loss: 2.2982 - val_accuracy: 0.5744
# Epoch 59/100
# 406/406 [==============================] - 142s 349ms/step - loss: 0.0758 - accuracy: 0.9770 - val_loss: 2.4492 - val_accuracy: 0.5713
# Epoch 60/100
# 406/406 [==============================] - 140s 346ms/step - loss: 0.0718 - accuracy: 0.9780 - val_loss: 2.2266 - val_accuracy: 0.5825
# Epoch 61/100
# 406/406 [==============================] - 140s 345ms/step - loss: 0.0747 - accuracy: 0.9771 - val_loss: 2.5611 - val_accuracy: 0.5955
# Epoch 62/100
# 406/406 [==============================] - 139s 342ms/step - loss: 0.0711 - accuracy: 0.9780 - val_loss: 2.2473 - val_accuracy: 0.5720
# Epoch 63/100
# 406/406 [==============================] - 140s 345ms/step - loss: 0.0775 - accuracy: 0.9748 - val_loss: 2.8306 - val_accuracy: 0.5806
# Epoch 64/100
# 406/406 [==============================] - 140s 344ms/step - loss: 0.0702 - accuracy: 0.9787 - val_loss: 2.2959 - val_accuracy: 0.5924
# Epoch 65/100
# 406/406 [==============================] - 139s 343ms/step - loss: 0.0655 - accuracy: 0.9795 - val_loss: 2.3980 - val_accuracy: 0.5868
# Epoch 66/100
# 406/406 [==============================] - 139s 344ms/step - loss: 0.0759 - accuracy: 0.9769 - val_loss: 2.3830 - val_accuracy: 0.5831
# Epoch 67/100
# 406/406 [==============================] - 139s 343ms/step - loss: 0.0737 - accuracy: 0.9784 - val_loss: 2.3064 - val_accuracy: 0.5633
# Epoch 68/100
# 406/406 [==============================] - 140s 346ms/step - loss: 0.0741 - accuracy: 0.9783 - val_loss: 2.4578 - val_accuracy: 0.5962
# Epoch 69/100
# 406/406 [==============================] - 141s 347ms/step - loss: 0.0642 - accuracy: 0.9806 - val_loss: 3.0467 - val_accuracy: 0.5751
# Epoch 70/100
# 406/406 [==============================] - 140s 344ms/step - loss: 0.0662 - accuracy: 0.9800 - val_loss: 2.3510 - val_accuracy: 0.5788
# Epoch 71/100
# 406/406 [==============================] - 139s 343ms/step - loss: 0.0607 - accuracy: 0.9810 - val_loss: 3.0416 - val_accuracy: 0.5701
# Epoch 72/100
# 406/406 [==============================] - 139s 343ms/step - loss: 0.0606 - accuracy: 0.9811 - val_loss: 2.7029 - val_accuracy: 0.5670
# Epoch 73/100
# 406/406 [==============================] - 140s 344ms/step - loss: 0.0689 - accuracy: 0.9790 - val_loss: 2.6671 - val_accuracy: 0.5986
# Epoch 74/100
# 406/406 [==============================] - 138s 340ms/step - loss: 0.0585 - accuracy: 0.9828 - val_loss: 3.0737 - val_accuracy: 0.5837
# Epoch 75/100
# 406/406 [==============================] - 139s 343ms/step - loss: 0.0566 - accuracy: 0.9823 - val_loss: 2.8711 - val_accuracy: 0.5887
# Epoch 76/100
# 406/406 [==============================] - 139s 343ms/step - loss: 0.0497 - accuracy: 0.9843 - val_loss: 2.5470 - val_accuracy: 0.5893
# Epoch 77/100
# 406/406 [==============================] - 140s 345ms/step - loss: 0.0447 - accuracy: 0.9859 - val_loss: 2.9742 - val_accuracy: 0.5732
# Epoch 78/100
# 406/406 [==============================] - 139s 343ms/step - loss: 0.0449 - accuracy: 0.9871 - val_loss: 2.5406 - val_accuracy: 0.5689
# Epoch 79/100
# 406/406 [==============================] - 138s 339ms/step - loss: 0.0550 - accuracy: 0.9830 - val_loss: 3.2118 - val_accuracy: 0.5775
# Epoch 80/100
# 406/406 [==============================] - 137s 337ms/step - loss: 0.0672 - accuracy: 0.9806 - val_loss: 2.7463 - val_accuracy: 0.6048
# Epoch 81/100
# 406/406 [==============================] - 139s 343ms/step - loss: 0.0479 - accuracy: 0.9854 - val_loss: 2.5723 - val_accuracy: 0.5937
# Epoch 82/100
# 406/406 [==============================] - 137s 338ms/step - loss: 0.0564 - accuracy: 0.9835 - val_loss: 2.7928 - val_accuracy: 0.5949
# Epoch 83/100
# 406/406 [==============================] - 140s 344ms/step - loss: 0.0547 - accuracy: 0.9834 - val_loss: 2.2004 - val_accuracy: 0.5806
# Epoch 84/100
# 406/406 [==============================] - 139s 343ms/step - loss: 0.0428 - accuracy: 0.9875 - val_loss: 2.7138 - val_accuracy: 0.5986
# Epoch 85/100
# 406/406 [==============================] - 140s 345ms/step - loss: 0.0441 - accuracy: 0.9870 - val_loss: 3.4687 - val_accuracy: 0.5900
# Epoch 86/100
# 406/406 [==============================] - 140s 344ms/step - loss: 0.0513 - accuracy: 0.9851 - val_loss: 2.9794 - val_accuracy: 0.5918
# Epoch 87/100
# 406/406 [==============================] - 140s 344ms/step - loss: 0.0611 - accuracy: 0.9830 - val_loss: 2.3726 - val_accuracy: 0.5980
# Epoch 88/100
# 406/406 [==============================] - 139s 343ms/step - loss: 0.0500 - accuracy: 0.9863 - val_loss: 2.4878 - val_accuracy: 0.5707
# Epoch 89/100
# 406/406 [==============================] - 138s 341ms/step - loss: 0.0422 - accuracy: 0.9874 - val_loss: 2.8912 - val_accuracy: 0.5931
# Epoch 90/100
# 406/406 [==============================] - 138s 340ms/step - loss: 0.0452 - accuracy: 0.9868 - val_loss: 2.9164 - val_accuracy: 0.5955
# Epoch 91/100
# 406/406 [==============================] - 140s 346ms/step - loss: 0.0555 - accuracy: 0.9847 - val_loss: 2.3720 - val_accuracy: 0.5676
# Epoch 92/100
# 406/406 [==============================] - 139s 342ms/step - loss: 0.0504 - accuracy: 0.9854 - val_loss: 2.3330 - val_accuracy: 0.5937
# Epoch 93/100
# 406/406 [==============================] - 139s 344ms/step - loss: 0.0433 - accuracy: 0.9872 - val_loss: 2.1518 - val_accuracy: 0.5931
# Epoch 94/100
# 406/406 [==============================] - 139s 342ms/step - loss: 0.0394 - accuracy: 0.9884 - val_loss: 2.7327 - val_accuracy: 0.5924
# Epoch 95/100
# 406/406 [==============================] - 140s 344ms/step - loss: 0.0337 - accuracy: 0.9890 - val_loss: 2.0355 - val_accuracy: 0.5713
# Epoch 96/100
# 406/406 [==============================] - 140s 343ms/step - loss: 0.0391 - accuracy: 0.9884 - val_loss: 2.7728 - val_accuracy: 0.5837
# Epoch 97/100
# 406/406 [==============================] - 139s 342ms/step - loss: 0.0389 - accuracy: 0.9887 - val_loss: 2.8153 - val_accuracy: 0.6222
# Epoch 98/100
# 406/406 [==============================] - 139s 344ms/step - loss: 0.0336 - accuracy: 0.9879 - val_loss: 2.8021 - val_accuracy: 0.5769
# Epoch 99/100
# 406/406 [==============================] - 139s 343ms/step - loss: 0.0367 - accuracy: 0.9891 - val_loss: 2.7265 - val_accuracy: 0.5732
# Epoch 100/100
# 406/406 [==============================] - 139s 342ms/step - loss: 0.0424 - accuracy: 0.9877 - val_loss: 3.0022 - val_accuracy: 0.5552

# %% [markdown]
# # Evaluate Model's Training & Validation Results

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()

# %% [markdown]
# # Generate Predictions With Model

# %%
y_pred = model.predict(test_batches).argmax(axis=1)

# %%
model.evaluate(test_batches)
# Out:
# 51/51 [==============================] - 15s 299ms/step - loss: 3.1977 - accuracy: 0.5649
# [3.197692632675171, 0.5649188756942749]

# %% [markdown]
# # Evaluate Model's Prediction Results

# %%
# generate classification report
class_labels = list(test_batches.class_indices.keys())
report = classification_report(test_batches.classes, y_pred, target_names=class_labels, output_dict=True)
df_classification_report = pd.DataFrame(report).transpose()
df_classification_report
# Out:
#               precision    recall  f1-score      support
# hatchback      0.325581  0.179487  0.231405   156.000000
# mpv            0.689189  0.472222  0.560440   108.000000
# sedan          0.502128  0.570048  0.533937   414.000000
# sport          0.541401  0.776256  0.637899   438.000000
# suv            0.690583  0.542254  0.607495   284.000000
# truck          0.813559  0.600000  0.690647   160.000000
# wagon          0.000000  0.000000  0.000000    42.000000
# accuracy       0.564919  0.564919  0.564919     0.564919
# macro avg      0.508920  0.448610  0.465975  1602.000000
# weighted avg   0.559633  0.564919  0.549381  1602.000000

# %%
# compute confusion matrix
matrix = confusion_matrix(test_batches.classes, y_pred)

# normalize confusion matrix
matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
matrix = np.around(matrix, decimals=2)

# generate confusion matrix heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(matrix, annot=True, xticklabels=class_labels, yticklabels=class_labels)
plt.ylabel('Test Values')
plt.xlabel('Predicted Values')
# Out:
# Text(0.5, 69.0, 'Predicted Values')

# %% [markdown]
# # Compute Execution Time

# %%
execution_time_s = round(time.time() - start_time, 2)
execution_time_m = round(execution_time_s/60, 2)
execution_time_h = round(execution_time_m/60, 2)

print('Execution Time (Hours):', execution_time_h)
print('Execution Time (Minutes):', execution_time_m)
print('Execution Time (Seconds):', execution_time_s)
# Out:
# Execution Time (Hours): 3.94
# Execution Time (Minutes): 236.18
# Execution Time (Seconds): 14170.95
