# %%
# !pip install pandas numpy seaborn matplotlib tensorflow keras sklearn &> /dev/null

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications import Xception

import time
start_time = time.time()

# %%
PATH_DATA_TRAIN = '../input/cars-data-ttv-80-10-10/data-raw/data-raw/train'
PATH_DATA_TEST = '../input/cars-data-ttv-80-10-10/data-raw/data-raw/test'
PATH_DATA_VALIDATION = '../input/cars-data-ttv-80-10-10/data-raw/data-raw/validation'
PATH_SAVED_MODEL = 'xception-imagenet.h5'

# %% [markdown]
# # Load Dataset As Generators

# %%
generator = ImageDataGenerator(rescale = 1./255.)

target_size = (100, 100)
batch_size = 32

train_batches = generator.flow_from_directory(
    PATH_DATA_TRAIN, class_mode='categorical', 
    batch_size=batch_size, target_size=target_size
)

validation_batches = generator.flow_from_directory(
    PATH_DATA_VALIDATION, class_mode='categorical',  
    batch_size=batch_size, target_size=target_size
)

test_batches = generator.flow_from_directory(
    PATH_DATA_TEST, class_mode='categorical', shuffle=False, 
    batch_size=batch_size, target_size=target_size
)
# Out:
# Found 12971 images belonging to 7 classes.
# Found 1612 images belonging to 7 classes.
# Found 1602 images belonging to 7 classes.

# %%
# preview data (batch size, width, height, colors)
print('x_train shape:', train_batches[0][0].shape)
print('x_validation shape:', validation_batches[0][0].shape)
print('x_test shape:', test_batches[0][0].shape)
print('y_train shape:', train_batches[0][1].shape)
print('y_validation shape:', validation_batches[0][1].shape)
print('y_test shape:', test_batches[0][1].shape)
# Out:
# x_train shape: (32, 100, 100, 3)
# x_validation shape: (32, 100, 100, 3)
# x_test shape: (32, 100, 100, 3)
# y_train shape: (32, 7)
# y_validation shape: (32, 7)
# y_test shape: (32, 7)

# %%
# input & output shape
input_shape = train_batches[0][0][0].shape
output_shape = len(train_batches[0][1][0])

# display input & output shape
print('Input Shape:', input_shape)
print('Output Shape:', output_shape)
# Out:
# Input Shape: (100, 100, 3)
# Output Shape: 7

# %% [markdown]
# # Build & Compile Model

# %%
model = Xception(
    input_shape=input_shape, 
    weights="imagenet", 
    include_top=False, 
    pooling='max'
)

for layer in model.layers:
    layer.trainable = False

i = Input(shape=input_shape)
x = model(i)
x = Flatten()(x)
x = Dense(output_shape, activation='softmax')(x)

model = Model(inputs=i, outputs=x)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# 2022-12-10 22:04:53.974397: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 22:04:53.975339: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 22:04:54.263689: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 22:04:54.264689: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 22:04:54.265502: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 22:04:54.266336: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 22:04:54.267889: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-10 22:04:54.519521: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 22:04:54.520303: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 22:04:54.521118: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 22:04:54.521831: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 22:04:54.522544: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 22:04:54.523219: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 22:04:59.011475: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 22:04:59.012339: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 22:04:59.013118: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 22:04:59.013824: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 22:04:59.014584: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 22:04:59.015286: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-12-10 22:04:59.020343: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 22:04:59.021018: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 0s 0us/step
# 83697664/83683744 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# xception (Functional)        (None, 2048)              20861480
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 14343
# =================================================================
# Total params: 20,875,823
# Trainable params: 14,343
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %% [markdown]
# # Train Model

# %%
# train model
r = model.fit(train_batches, validation_data=validation_batches, epochs=100)

# save model
model.save(PATH_SAVED_MODEL)

# load model
# model = load_model(PATH_SAVED_MODEL)
# Out:
# 2022-12-10 22:05:01.610631: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-12-10 22:05:06.047457: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 406/406 [==============================] - 242s 561ms/step - loss: 1.5000 - accuracy: 0.4354 - val_loss: 1.4479 - val_accuracy: 0.4442
# Epoch 2/100
# 406/406 [==============================] - 137s 337ms/step - loss: 1.3110 - accuracy: 0.5002 - val_loss: 1.4333 - val_accuracy: 0.4733
# Epoch 3/100
# 406/406 [==============================] - 134s 331ms/step - loss: 1.2341 - accuracy: 0.5259 - val_loss: 1.4122 - val_accuracy: 0.4696
# Epoch 4/100
# 406/406 [==============================] - 135s 332ms/step - loss: 1.1878 - accuracy: 0.5478 - val_loss: 1.3810 - val_accuracy: 0.4876
# Epoch 5/100
# 406/406 [==============================] - 134s 329ms/step - loss: 1.1572 - accuracy: 0.5569 - val_loss: 1.4445 - val_accuracy: 0.4677
# Epoch 6/100
# 406/406 [==============================] - 135s 332ms/step - loss: 1.1239 - accuracy: 0.5693 - val_loss: 1.3892 - val_accuracy: 0.4950
# Epoch 7/100
# 406/406 [==============================] - 134s 330ms/step - loss: 1.0853 - accuracy: 0.5852 - val_loss: 1.3566 - val_accuracy: 0.5000
# Epoch 8/100
# 406/406 [==============================] - 134s 331ms/step - loss: 1.0845 - accuracy: 0.5872 - val_loss: 1.3358 - val_accuracy: 0.5050
# Epoch 9/100
# 406/406 [==============================] - 135s 333ms/step - loss: 1.0493 - accuracy: 0.5993 - val_loss: 1.3824 - val_accuracy: 0.4944
# Epoch 10/100
# 406/406 [==============================] - 135s 333ms/step - loss: 1.0370 - accuracy: 0.6008 - val_loss: 1.4213 - val_accuracy: 0.4981
# Epoch 11/100
# 406/406 [==============================] - 135s 332ms/step - loss: 1.0192 - accuracy: 0.6098 - val_loss: 1.4316 - val_accuracy: 0.4833
# Epoch 12/100
# 406/406 [==============================] - 134s 330ms/step - loss: 1.0094 - accuracy: 0.6157 - val_loss: 1.4210 - val_accuracy: 0.4876
# Epoch 13/100
# 406/406 [==============================] - 135s 333ms/step - loss: 0.9848 - accuracy: 0.6238 - val_loss: 1.3844 - val_accuracy: 0.4926
# Epoch 14/100
# 406/406 [==============================] - 134s 330ms/step - loss: 0.9833 - accuracy: 0.6210 - val_loss: 1.4303 - val_accuracy: 0.4907
# Epoch 15/100
# 406/406 [==============================] - 134s 330ms/step - loss: 0.9676 - accuracy: 0.6299 - val_loss: 1.4027 - val_accuracy: 0.4901
# Epoch 16/100
# 406/406 [==============================] - 135s 332ms/step - loss: 0.9560 - accuracy: 0.6337 - val_loss: 1.4179 - val_accuracy: 0.5093
# Epoch 17/100
# 406/406 [==============================] - 135s 333ms/step - loss: 0.9530 - accuracy: 0.6363 - val_loss: 1.4188 - val_accuracy: 0.4950
# Epoch 18/100
# 406/406 [==============================] - 135s 331ms/step - loss: 0.9380 - accuracy: 0.6398 - val_loss: 1.4877 - val_accuracy: 0.4739
# Epoch 19/100
# 406/406 [==============================] - 134s 330ms/step - loss: 0.9412 - accuracy: 0.6394 - val_loss: 1.4896 - val_accuracy: 0.4665
# Epoch 20/100
# 406/406 [==============================] - 135s 333ms/step - loss: 0.9277 - accuracy: 0.6441 - val_loss: 1.4936 - val_accuracy: 0.4944
# Epoch 21/100
# Epoch 58/100
# 406/406 [==============================] - 134s 328ms/step - loss: 0.7773 - accuracy: 0.7001 - val_loss: 1.8221 - val_accuracy: 0.4578
# Epoch 59/100
# 406/406 [==============================] - 133s 328ms/step - loss: 0.7630 - accuracy: 0.7035 - val_loss: 1.7475 - val_accuracy: 0.4758
# Epoch 60/100
# 406/406 [==============================] - 134s 331ms/step - loss: 0.7640 - accuracy: 0.7057 - val_loss: 1.7646 - val_accuracy: 0.4795
# Epoch 61/100
# 406/406 [==============================] - 135s 332ms/step - loss: 0.7653 - accuracy: 0.7016 - val_loss: 1.7261 - val_accuracy: 0.4820
# Epoch 62/100
# 406/406 [==============================] - 135s 333ms/step - loss: 0.7745 - accuracy: 0.7012 - val_loss: 1.7373 - val_accuracy: 0.4566
# Epoch 63/100
# 406/406 [==============================] - 134s 330ms/step - loss: 0.7606 - accuracy: 0.7053 - val_loss: 1.7462 - val_accuracy: 0.4758
# Epoch 64/100
# 406/406 [==============================] - 134s 329ms/step - loss: 0.7724 - accuracy: 0.6993 - val_loss: 1.7442 - val_accuracy: 0.4845
# Epoch 65/100
# 406/406 [==============================] - 134s 330ms/step - loss: 0.7567 - accuracy: 0.7107 - val_loss: 1.7467 - val_accuracy: 0.4733
# Epoch 66/100
# 406/406 [==============================] - 134s 329ms/step - loss: 0.7634 - accuracy: 0.7048 - val_loss: 1.8772 - val_accuracy: 0.4411
# Epoch 67/100
# 406/406 [==============================] - 134s 331ms/step - loss: 0.7640 - accuracy: 0.7067 - val_loss: 1.7589 - val_accuracy: 0.4833
# Epoch 68/100
# 406/406 [==============================] - 134s 330ms/step - loss: 0.7496 - accuracy: 0.7121 - val_loss: 1.7460 - val_accuracy: 0.4820
# Epoch 69/100
# 406/406 [==============================] - 134s 330ms/step - loss: 0.7661 - accuracy: 0.7071 - val_loss: 1.8007 - val_accuracy: 0.4659
# Epoch 70/100
# 406/406 [==============================] - 133s 327ms/step - loss: 0.7478 - accuracy: 0.7149 - val_loss: 1.7955 - val_accuracy: 0.4777
# Epoch 71/100
# 406/406 [==============================] - 134s 331ms/step - loss: 0.7505 - accuracy: 0.7111 - val_loss: 1.8342 - val_accuracy: 0.4684
# Epoch 72/100
# 406/406 [==============================] - 134s 330ms/step - loss: 0.7484 - accuracy: 0.7117 - val_loss: 1.8395 - val_accuracy: 0.4591
# Epoch 73/100
# 406/406 [==============================] - 134s 331ms/step - loss: 0.7487 - accuracy: 0.7124 - val_loss: 1.8150 - val_accuracy: 0.4739
# Epoch 74/100
# 406/406 [==============================] - 133s 329ms/step - loss: 0.7506 - accuracy: 0.7149 - val_loss: 1.8955 - val_accuracy: 0.4634
# Epoch 75/100
# 406/406 [==============================] - 133s 328ms/step - loss: 0.7558 - accuracy: 0.7043 - val_loss: 1.9154 - val_accuracy: 0.4684
# Epoch 76/100
# 406/406 [==============================] - 134s 331ms/step - loss: 0.7410 - accuracy: 0.7142 - val_loss: 1.8699 - val_accuracy: 0.4671
# Epoch 77/100
# 406/406 [==============================] - 133s 329ms/step - loss: 0.7363 - accuracy: 0.7156 - val_loss: 1.8380 - val_accuracy: 0.4721
# Epoch 78/100
# 406/406 [==============================] - 133s 328ms/step - loss: 0.7478 - accuracy: 0.7140 - val_loss: 1.8478 - val_accuracy: 0.4615
# Epoch 79/100
# 406/406 [==============================] - 133s 329ms/step - loss: 0.7399 - accuracy: 0.7137 - val_loss: 1.8472 - val_accuracy: 0.4715
# Epoch 80/100
# 406/406 [==============================] - 133s 328ms/step - loss: 0.7389 - accuracy: 0.7126 - val_loss: 1.8428 - val_accuracy: 0.4622
# Epoch 81/100
# 406/406 [==============================] - 133s 328ms/step - loss: 0.7323 - accuracy: 0.7188 - val_loss: 1.8859 - val_accuracy: 0.4603
# Epoch 82/100
# 406/406 [==============================] - 134s 329ms/step - loss: 0.7331 - accuracy: 0.7192 - val_loss: 1.8530 - val_accuracy: 0.4690
# Epoch 83/100
# 406/406 [==============================] - 134s 329ms/step - loss: 0.7415 - accuracy: 0.7114 - val_loss: 1.9004 - val_accuracy: 0.4504
# Epoch 84/100
# 406/406 [==============================] - 134s 330ms/step - loss: 0.7209 - accuracy: 0.7248 - val_loss: 1.9115 - val_accuracy: 0.4727
# Epoch 85/100
# 406/406 [==============================] - 133s 329ms/step - loss: 0.7241 - accuracy: 0.7194 - val_loss: 1.9427 - val_accuracy: 0.4671
# Epoch 86/100
# 406/406 [==============================] - 133s 328ms/step - loss: 0.7334 - accuracy: 0.7186 - val_loss: 1.8515 - val_accuracy: 0.4739
# Epoch 87/100
# 406/406 [==============================] - 134s 330ms/step - loss: 0.7259 - accuracy: 0.7212 - val_loss: 1.8853 - val_accuracy: 0.4733
# Epoch 88/100
# 406/406 [==============================] - 134s 329ms/step - loss: 0.7223 - accuracy: 0.7177 - val_loss: 1.8905 - val_accuracy: 0.4659
# Epoch 89/100
# 406/406 [==============================] - 136s 334ms/step - loss: 0.7253 - accuracy: 0.7234 - val_loss: 2.0370 - val_accuracy: 0.4274
# Epoch 90/100
# 406/406 [==============================] - 135s 333ms/step - loss: 0.7252 - accuracy: 0.7211 - val_loss: 1.9512 - val_accuracy: 0.4597
# Epoch 91/100
# 406/406 [==============================] - 133s 328ms/step - loss: 0.7172 - accuracy: 0.7214 - val_loss: 2.0147 - val_accuracy: 0.4498
# Epoch 92/100
# 406/406 [==============================] - 134s 331ms/step - loss: 0.7143 - accuracy: 0.7259 - val_loss: 1.9414 - val_accuracy: 0.4715
# Epoch 93/100
# 406/406 [==============================] - 134s 330ms/step - loss: 0.7215 - accuracy: 0.7203 - val_loss: 1.9290 - val_accuracy: 0.4721
# Epoch 94/100
# 406/406 [==============================] - 134s 330ms/step - loss: 0.7150 - accuracy: 0.7251 - val_loss: 1.9335 - val_accuracy: 0.4665
# Epoch 95/100
# 406/406 [==============================] - 134s 329ms/step - loss: 0.7205 - accuracy: 0.7215 - val_loss: 1.9722 - val_accuracy: 0.4572
# Epoch 96/100
# 406/406 [==============================] - 134s 330ms/step - loss: 0.7152 - accuracy: 0.7257 - val_loss: 1.9242 - val_accuracy: 0.4671
# Epoch 97/100
# 406/406 [==============================] - 132s 326ms/step - loss: 0.7128 - accuracy: 0.7254 - val_loss: 1.9435 - val_accuracy: 0.4690
# Epoch 98/100
# 406/406 [==============================] - 134s 331ms/step - loss: 0.7137 - accuracy: 0.7231 - val_loss: 2.0091 - val_accuracy: 0.4510
# Epoch 99/100
# 406/406 [==============================] - 134s 329ms/step - loss: 0.7098 - accuracy: 0.7257 - val_loss: 1.9416 - val_accuracy: 0.4690
# Epoch 100/100
# 406/406 [==============================] - 133s 328ms/step - loss: 0.7061 - accuracy: 0.7283 - val_loss: 1.9691 - val_accuracy: 0.4640
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %% [markdown]
# # Evaluate Model's Training & Validation Results

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()

# %% [markdown]
# # Generate Predictions With Model

# %%
y_pred = model.predict(test_batches).argmax(axis=1)

# %%
model.evaluate(test_batches)
# Out:
# 51/51 [==============================] - 15s 289ms/step - loss: 1.9737 - accuracy: 0.4519
# [1.9736974239349365, 0.4519350826740265]

# %% [markdown]
# # Evaluate Model's Prediction Results

# %%
# generate classification report
class_labels = list(test_batches.class_indices.keys())
report = classification_report(test_batches.classes, y_pred, target_names=class_labels, output_dict=True)
df_classification_report = pd.DataFrame(report).transpose()
df_classification_report
# Out:
#               precision    recall  f1-score      support
# hatchback      0.273810  0.294872  0.283951   156.000000
# mpv            0.401515  0.490741  0.441667   108.000000
# sedan          0.429257  0.432367  0.430806   414.000000
# sport          0.577608  0.518265  0.546330   438.000000
# suv            0.416216  0.542254  0.470948   284.000000
# truck          0.552381  0.362500  0.437736   160.000000
# wagon          0.411765  0.166667  0.237288    42.000000
# accuracy       0.451935  0.451935  0.451935     0.451935
# macro avg      0.437507  0.401095  0.406961  1602.000000
# weighted avg   0.462336  0.451935  0.451558  1602.000000

# %%
# compute confusion matrix
matrix = confusion_matrix(test_batches.classes, y_pred)

# normalize confusion matrix
matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
matrix = np.around(matrix, decimals=2)

# generate confusion matrix heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(matrix, annot=True, xticklabels=class_labels, yticklabels=class_labels)
plt.ylabel('Test Values')
plt.xlabel('Predicted Values')
# Out:
# Text(0.5, 69.0, 'Predicted Values')

# %% [markdown]
# # Compute Execution Time

# %%
execution_time_s = round(time.time() - start_time, 2)
execution_time_m = round(execution_time_s/60, 2)
execution_time_h = round(execution_time_m/60, 2)

print('Execution Time (Hours):', execution_time_h)
print('Execution Time (Minutes):', execution_time_m)
print('Execution Time (Seconds):', execution_time_s)
# Out:
# Execution Time (Hours): 3.78
# Execution Time (Minutes): 226.88
# Execution Time (Seconds): 13612.99
