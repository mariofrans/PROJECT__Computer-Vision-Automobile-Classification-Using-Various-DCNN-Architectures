# %%
# !pip install pandas numpy seaborn matplotlib tensorflow keras sklearn &> /dev/null

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet50

import time
start_time = time.time()

# %%
PATH_DATA_TRAIN = '../input/cars-data-ttv-80-10-10/data-raw/data-raw/train'
PATH_DATA_TEST = '../input/cars-data-ttv-80-10-10/data-raw/data-raw/test'
PATH_DATA_VALIDATION = '../input/cars-data-ttv-80-10-10/data-raw/data-raw/validation'
PATH_SAVED_MODEL = 'resnet50-imagenet.h5'

# %% [markdown]
# # Load Dataset As Generators

# %%
generator = ImageDataGenerator(rescale = 1./255.)

target_size = (100, 100)
batch_size = 32

train_batches = generator.flow_from_directory(
    PATH_DATA_TRAIN, class_mode='categorical', 
    batch_size=batch_size, target_size=target_size
)

validation_batches = generator.flow_from_directory(
    PATH_DATA_VALIDATION, class_mode='categorical',  
    batch_size=batch_size, target_size=target_size
)

test_batches = generator.flow_from_directory(
    PATH_DATA_TEST, class_mode='categorical', shuffle=False, 
    batch_size=batch_size, target_size=target_size
)
# Out:
# Found 12971 images belonging to 7 classes.
# Found 1612 images belonging to 7 classes.
# Found 1602 images belonging to 7 classes.

# %%
# preview data (batch size, width, height, colors)
print('x_train shape:', train_batches[0][0].shape)
print('x_validation shape:', validation_batches[0][0].shape)
print('x_test shape:', test_batches[0][0].shape)
print('y_train shape:', train_batches[0][1].shape)
print('y_validation shape:', validation_batches[0][1].shape)
print('y_test shape:', test_batches[0][1].shape)
# Out:
# x_train shape: (32, 100, 100, 3)
# x_validation shape: (32, 100, 100, 3)
# x_test shape: (32, 100, 100, 3)
# y_train shape: (32, 7)
# y_validation shape: (32, 7)
# y_test shape: (32, 7)

# %%
# input & output shape
input_shape = train_batches[0][0][0].shape
output_shape = len(train_batches[0][1][0])

# display input & output shape
print('Input Shape:', input_shape)
print('Output Shape:', output_shape)
# Out:
# Input Shape: (100, 100, 3)
# Output Shape: 7

# %% [markdown]
# # Build & Compile Model

# %%
model = ResNet50(
    input_shape=input_shape, 
    weights="imagenet", 
    include_top=False, 
    pooling='max'
)

for layer in model.layers:
    layer.trainable = False

i = Input(shape=input_shape)
x = model(i)
x = Flatten()(x)
x = Dense(output_shape, activation='softmax')(x)

model = Model(inputs=i, outputs=x)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# 2022-12-08 16:55:43.637165: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-08 16:55:43.638524: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-08 16:55:43.920981: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-08 16:55:43.921914: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-08 16:55:43.922723: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-08 16:55:43.923473: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-08 16:55:43.925516: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-08 16:55:44.186964: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-08 16:55:44.187822: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-08 16:55:44.188640: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-08 16:55:44.189389: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-08 16:55:44.190112: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-08 16:55:44.190802: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-08 16:55:48.542442: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-08 16:55:48.543348: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-08 16:55:48.544144: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-08 16:55:48.544964: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-08 16:55:48.545692: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-08 16:55:48.546366: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-12-08 16:55:48.551068: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-08 16:55:48.551772: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step
# 94781440/94765736 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 14343
# =================================================================
# Total params: 23,602,055
# Trainable params: 14,343
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %% [markdown]
# # Train Model

# %%
# train model
r = model.fit(train_batches, validation_data=validation_batches, epochs=100)

# save model
model.save(PATH_SAVED_MODEL)

# load model
# model = load_model(PATH_SAVED_MODEL)
# Out:
# 2022-12-08 16:55:51.404665: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-12-08 16:55:56.714208: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 406/406 [==============================] - 257s 598ms/step - loss: 1.8969 - accuracy: 0.2691 - val_loss: 1.7165 - val_accuracy: 0.2841
# Epoch 2/100
# 406/406 [==============================] - 140s 345ms/step - loss: 1.7775 - accuracy: 0.3026 - val_loss: 1.8382 - val_accuracy: 0.2649
# Epoch 3/100
# 406/406 [==============================] - 135s 332ms/step - loss: 1.7483 - accuracy: 0.3115 - val_loss: 1.7264 - val_accuracy: 0.2823
# Epoch 4/100
# 406/406 [==============================] - 135s 332ms/step - loss: 1.7437 - accuracy: 0.3142 - val_loss: 1.6984 - val_accuracy: 0.3009
# Epoch 5/100
# 406/406 [==============================] - 133s 328ms/step - loss: 1.7447 - accuracy: 0.3170 - val_loss: 1.6970 - val_accuracy: 0.3586
# Epoch 6/100
# 406/406 [==============================] - 134s 330ms/step - loss: 1.6969 - accuracy: 0.3375 - val_loss: 1.8204 - val_accuracy: 0.2761
# Epoch 7/100
# 406/406 [==============================] - 136s 335ms/step - loss: 1.6981 - accuracy: 0.3349 - val_loss: 1.6487 - val_accuracy: 0.3610
# Epoch 8/100
# 406/406 [==============================] - 134s 331ms/step - loss: 1.6864 - accuracy: 0.3457 - val_loss: 1.8513 - val_accuracy: 0.2860
# Epoch 9/100
# 406/406 [==============================] - 133s 327ms/step - loss: 1.6812 - accuracy: 0.3447 - val_loss: 1.6999 - val_accuracy: 0.3610
# Epoch 10/100
# 406/406 [==============================] - 133s 327ms/step - loss: 1.6471 - accuracy: 0.3556 - val_loss: 1.8562 - val_accuracy: 0.2959
# Epoch 11/100
# 406/406 [==============================] - 135s 332ms/step - loss: 1.6411 - accuracy: 0.3620 - val_loss: 1.6496 - val_accuracy: 0.3555
# Epoch 12/100
# 406/406 [==============================] - 132s 324ms/step - loss: 1.6493 - accuracy: 0.3561 - val_loss: 1.5918 - val_accuracy: 0.3797
# Epoch 13/100
# 406/406 [==============================] - 131s 324ms/step - loss: 1.6035 - accuracy: 0.3711 - val_loss: 1.5930 - val_accuracy: 0.3772
# Epoch 14/100
# 406/406 [==============================] - 132s 325ms/step - loss: 1.6255 - accuracy: 0.3680 - val_loss: 1.7420 - val_accuracy: 0.3108
# Epoch 15/100
# 406/406 [==============================] - 134s 331ms/step - loss: 1.6265 - accuracy: 0.3637 - val_loss: 1.5761 - val_accuracy: 0.3921
# Epoch 16/100
# 406/406 [==============================] - 134s 331ms/step - loss: 1.6068 - accuracy: 0.3777 - val_loss: 1.5750 - val_accuracy: 0.3747
# Epoch 17/100
# 406/406 [==============================] - 134s 329ms/step - loss: 1.6412 - accuracy: 0.3696 - val_loss: 1.6436 - val_accuracy: 0.3809
# Epoch 18/100
# 406/406 [==============================] - 133s 328ms/step - loss: 1.6073 - accuracy: 0.3765 - val_loss: 1.7401 - val_accuracy: 0.3244
# Epoch 19/100
# 406/406 [==============================] - 133s 327ms/step - loss: 1.5983 - accuracy: 0.3825 - val_loss: 1.6728 - val_accuracy: 0.3703
# Epoch 20/100
# 406/406 [==============================] - 133s 327ms/step - loss: 1.5969 - accuracy: 0.3852 - val_loss: 1.7894 - val_accuracy: 0.3648
# Epoch 21/100
# 406/406 [==============================] - 133s 327ms/step - loss: 1.5951 - accuracy: 0.3826 - val_loss: 1.7334 - val_accuracy: 0.3809
# Epoch 22/100
# 406/406 [==============================] - 132s 326ms/step - loss: 1.5934 - accuracy: 0.3879 - val_loss: 1.6157 - val_accuracy: 0.3493
# Epoch 23/100
# 406/406 [==============================] - 131s 323ms/step - loss: 1.5774 - accuracy: 0.3904 - val_loss: 1.8058 - val_accuracy: 0.3431
# Epoch 24/100
# 406/406 [==============================] - 133s 327ms/step - loss: 1.6036 - accuracy: 0.3758 - val_loss: 1.6664 - val_accuracy: 0.3654
# Epoch 25/100
# 406/406 [==============================] - 134s 331ms/step - loss: 1.5611 - accuracy: 0.3951 - val_loss: 1.9053 - val_accuracy: 0.3164
# Epoch 26/100
# 406/406 [==============================] - 134s 330ms/step - loss: 1.5814 - accuracy: 0.3921 - val_loss: 1.6218 - val_accuracy: 0.3517
# Epoch 27/100
# 406/406 [==============================] - 136s 334ms/step - loss: 1.5701 - accuracy: 0.3856 - val_loss: 1.6335 - val_accuracy: 0.3635
# Epoch 28/100
# 406/406 [==============================] - 134s 331ms/step - loss: 1.5715 - accuracy: 0.3946 - val_loss: 1.8602 - val_accuracy: 0.3555
# Epoch 29/100
# 406/406 [==============================] - 134s 331ms/step - loss: 1.5622 - accuracy: 0.4023 - val_loss: 1.5977 - val_accuracy: 0.3815
# Epoch 30/100
# 406/406 [==============================] - 134s 330ms/step - loss: 1.5682 - accuracy: 0.3891 - val_loss: 1.7487 - val_accuracy: 0.3586
# Epoch 31/100
# 406/406 [==============================] - 134s 331ms/step - loss: 1.5609 - accuracy: 0.3946 - val_loss: 1.7200 - val_accuracy: 0.3443
# Epoch 32/100
# 406/406 [==============================] - 135s 331ms/step - loss: 1.5568 - accuracy: 0.3996 - val_loss: 1.7508 - val_accuracy: 0.3406
# Epoch 33/100
# 406/406 [==============================] - 134s 331ms/step - loss: 1.5675 - accuracy: 0.3916 - val_loss: 1.8469 - val_accuracy: 0.3710
# Epoch 34/100
# 406/406 [==============================] - 134s 330ms/step - loss: 1.5633 - accuracy: 0.3959 - val_loss: 1.6259 - val_accuracy: 0.3555
# Epoch 35/100
# 406/406 [==============================] - 135s 332ms/step - loss: 1.5552 - accuracy: 0.4000 - val_loss: 1.7037 - val_accuracy: 0.3542
# Epoch 36/100
# 406/406 [==============================] - 134s 331ms/step - loss: 1.5438 - accuracy: 0.4057 - val_loss: 1.6524 - val_accuracy: 0.3759
# Epoch 37/100
# 406/406 [==============================] - 135s 332ms/step - loss: 1.5414 - accuracy: 0.4058 - val_loss: 1.6723 - val_accuracy: 0.3933
# Epoch 38/100
# 406/406 [==============================] - 134s 330ms/step - loss: 1.5489 - accuracy: 0.4063 - val_loss: 1.5775 - val_accuracy: 0.3840
# Epoch 39/100
# 406/406 [==============================] - 135s 333ms/step - loss: 1.5559 - accuracy: 0.3994 - val_loss: 1.7562 - val_accuracy: 0.3623
# Epoch 40/100
# 406/406 [==============================] - 134s 330ms/step - loss: 1.5283 - accuracy: 0.4107 - val_loss: 1.6296 - val_accuracy: 0.3722
# Epoch 41/100
# 406/406 [==============================] - 135s 333ms/step - loss: 1.5363 - accuracy: 0.4043 - val_loss: 2.1012 - val_accuracy: 0.3189
# Epoch 42/100
# 406/406 [==============================] - 135s 333ms/step - loss: 1.5382 - accuracy: 0.4058 - val_loss: 1.7209 - val_accuracy: 0.3567
# Epoch 43/100
# 406/406 [==============================] - 134s 331ms/step - loss: 1.5126 - accuracy: 0.4162 - val_loss: 1.6881 - val_accuracy: 0.3288
# Epoch 44/100
# 406/406 [==============================] - 134s 329ms/step - loss: 1.5335 - accuracy: 0.4102 - val_loss: 1.7282 - val_accuracy: 0.3331
# Epoch 45/100
# 406/406 [==============================] - 134s 331ms/step - loss: 1.5182 - accuracy: 0.4092 - val_loss: 1.7793 - val_accuracy: 0.3766
# Epoch 46/100
# 406/406 [==============================] - 134s 330ms/step - loss: 1.5092 - accuracy: 0.4143 - val_loss: 1.7380 - val_accuracy: 0.3244
# Epoch 47/100
# 406/406 [==============================] - 134s 330ms/step - loss: 1.5381 - accuracy: 0.4030 - val_loss: 1.5866 - val_accuracy: 0.4020
# Epoch 48/100
# 406/406 [==============================] - 133s 327ms/step - loss: 1.5104 - accuracy: 0.4155 - val_loss: 1.6530 - val_accuracy: 0.3654
# Epoch 49/100
# 406/406 [==============================] - 132s 325ms/step - loss: 1.5109 - accuracy: 0.4124 - val_loss: 1.6000 - val_accuracy: 0.3821
# Epoch 50/100
# 406/406 [==============================] - 131s 323ms/step - loss: 1.5342 - accuracy: 0.4108 - val_loss: 1.6911 - val_accuracy: 0.3753
# Epoch 51/100
# 406/406 [==============================] - 133s 328ms/step - loss: 1.5199 - accuracy: 0.4079 - val_loss: 1.8436 - val_accuracy: 0.3127
# Epoch 52/100
# 406/406 [==============================] - 132s 326ms/step - loss: 1.5422 - accuracy: 0.4074 - val_loss: 1.6120 - val_accuracy: 0.3890
# Epoch 53/100
# 406/406 [==============================] - 134s 329ms/step - loss: 1.4917 - accuracy: 0.4276 - val_loss: 1.6698 - val_accuracy: 0.3567
# Epoch 54/100
# 406/406 [==============================] - 133s 327ms/step - loss: 1.5221 - accuracy: 0.4170 - val_loss: 1.7842 - val_accuracy: 0.3220
# Epoch 55/100
# 406/406 [==============================] - 134s 331ms/step - loss: 1.5138 - accuracy: 0.4147 - val_loss: 1.6847 - val_accuracy: 0.3722
# Epoch 56/100
# 406/406 [==============================] - 134s 330ms/step - loss: 1.5015 - accuracy: 0.4217 - val_loss: 1.6489 - val_accuracy: 0.3815
# Epoch 57/100
# 406/406 [==============================] - 133s 328ms/step - loss: 1.5076 - accuracy: 0.4185 - val_loss: 1.6230 - val_accuracy: 0.3846
# Epoch 58/100
# 406/406 [==============================] - 133s 329ms/step - loss: 1.5221 - accuracy: 0.4138 - val_loss: 1.7294 - val_accuracy: 0.3697
# Epoch 59/100
# 406/406 [==============================] - 134s 331ms/step - loss: 1.4762 - accuracy: 0.4260 - val_loss: 1.6616 - val_accuracy: 0.3598
# Epoch 60/100
# 406/406 [==============================] - 133s 327ms/step - loss: 1.5129 - accuracy: 0.4155 - val_loss: 1.7120 - val_accuracy: 0.3722
# Epoch 61/100
# 406/406 [==============================] - 133s 327ms/step - loss: 1.4972 - accuracy: 0.4217 - val_loss: 1.5874 - val_accuracy: 0.3877
# Epoch 62/100
# 406/406 [==============================] - 134s 331ms/step - loss: 1.4812 - accuracy: 0.4263 - val_loss: 1.7622 - val_accuracy: 0.3164
# Epoch 63/100
# 406/406 [==============================] - 135s 333ms/step - loss: 1.5199 - accuracy: 0.4145 - val_loss: 1.7817 - val_accuracy: 0.3747
# Epoch 64/100
# 406/406 [==============================] - 133s 328ms/step - loss: 1.5032 - accuracy: 0.4254 - val_loss: 1.7156 - val_accuracy: 0.3753
# Epoch 65/100
# 406/406 [==============================] - 134s 330ms/step - loss: 1.4915 - accuracy: 0.4262 - val_loss: 1.6575 - val_accuracy: 0.3790
# Epoch 66/100
# 406/406 [==============================] - 134s 331ms/step - loss: 1.4816 - accuracy: 0.4313 - val_loss: 1.6538 - val_accuracy: 0.3852
# Epoch 67/100
# 406/406 [==============================] - 134s 331ms/step - loss: 1.5063 - accuracy: 0.4206 - val_loss: 1.6802 - val_accuracy: 0.3666
# Epoch 68/100
# 406/406 [==============================] - 134s 329ms/step - loss: 1.4580 - accuracy: 0.4309 - val_loss: 1.6932 - val_accuracy: 0.3766
# Epoch 69/100
# 406/406 [==============================] - 134s 331ms/step - loss: 1.4802 - accuracy: 0.4372 - val_loss: 1.6802 - val_accuracy: 0.3759
# Epoch 70/100
# 406/406 [==============================] - 133s 329ms/step - loss: 1.4840 - accuracy: 0.4287 - val_loss: 1.6550 - val_accuracy: 0.3679
# Epoch 71/100
# 406/406 [==============================] - 134s 330ms/step - loss: 1.4888 - accuracy: 0.4253 - val_loss: 1.7078 - val_accuracy: 0.3964
# Epoch 72/100
# 406/406 [==============================] - 134s 330ms/step - loss: 1.4992 - accuracy: 0.4236 - val_loss: 1.7260 - val_accuracy: 0.3983
# Epoch 73/100
# 406/406 [==============================] - 134s 329ms/step - loss: 1.5002 - accuracy: 0.4293 - val_loss: 1.7803 - val_accuracy: 0.3288
# Epoch 74/100
# 406/406 [==============================] - 134s 330ms/step - loss: 1.4850 - accuracy: 0.4254 - val_loss: 1.5715 - val_accuracy: 0.4057
# Epoch 75/100
# 406/406 [==============================] - 133s 327ms/step - loss: 1.4693 - accuracy: 0.4304 - val_loss: 1.6534 - val_accuracy: 0.3828
# Epoch 76/100
# 406/406 [==============================] - 135s 332ms/step - loss: 1.4863 - accuracy: 0.4309 - val_loss: 2.0211 - val_accuracy: 0.3058
# Epoch 77/100
# 406/406 [==============================] - 133s 329ms/step - loss: 1.4885 - accuracy: 0.4309 - val_loss: 1.8170 - val_accuracy: 0.3306
# Epoch 78/100
# 406/406 [==============================] - 133s 328ms/step - loss: 1.4749 - accuracy: 0.4301 - val_loss: 1.5750 - val_accuracy: 0.4107
# Epoch 79/100
# 406/406 [==============================] - 133s 327ms/step - loss: 1.4459 - accuracy: 0.4357 - val_loss: 1.6010 - val_accuracy: 0.3666
# Epoch 80/100
# 406/406 [==============================] - 134s 329ms/step - loss: 1.4663 - accuracy: 0.4357 - val_loss: 1.7839 - val_accuracy: 0.3542
# Epoch 81/100
# 406/406 [==============================] - 134s 329ms/step - loss: 1.4685 - accuracy: 0.4328 - val_loss: 1.7584 - val_accuracy: 0.3654
# Epoch 82/100
# 406/406 [==============================] - 134s 329ms/step - loss: 1.5034 - accuracy: 0.4240 - val_loss: 1.6710 - val_accuracy: 0.3846
# Epoch 83/100
# 406/406 [==============================] - 135s 333ms/step - loss: 1.4689 - accuracy: 0.4378 - val_loss: 1.7375 - val_accuracy: 0.3815
# Epoch 84/100
# 406/406 [==============================] - 133s 329ms/step - loss: 1.4872 - accuracy: 0.4273 - val_loss: 1.8611 - val_accuracy: 0.3660
# Epoch 85/100
# 406/406 [==============================] - 135s 332ms/step - loss: 1.4551 - accuracy: 0.4368 - val_loss: 1.6931 - val_accuracy: 0.3344
# Epoch 86/100
# 406/406 [==============================] - 134s 330ms/step - loss: 1.4555 - accuracy: 0.4395 - val_loss: 1.8668 - val_accuracy: 0.3083
# Epoch 87/100
# 406/406 [==============================] - 134s 331ms/step - loss: 1.4714 - accuracy: 0.4375 - val_loss: 1.7403 - val_accuracy: 0.3672
# Epoch 88/100
# 406/406 [==============================] - 133s 327ms/step - loss: 1.4607 - accuracy: 0.4376 - val_loss: 1.6600 - val_accuracy: 0.3995
# Epoch 89/100
# 406/406 [==============================] - 134s 329ms/step - loss: 1.4525 - accuracy: 0.4373 - val_loss: 1.6584 - val_accuracy: 0.3877
# Epoch 90/100
# 406/406 [==============================] - 134s 330ms/step - loss: 1.4551 - accuracy: 0.4369 - val_loss: 1.9932 - val_accuracy: 0.3505
# Epoch 91/100
# 406/406 [==============================] - 134s 329ms/step - loss: 1.4636 - accuracy: 0.4378 - val_loss: 1.7044 - val_accuracy: 0.3753
# Epoch 92/100
# 406/406 [==============================] - 133s 329ms/step - loss: 1.4911 - accuracy: 0.4331 - val_loss: 1.6969 - val_accuracy: 0.3722
# Epoch 93/100
# 406/406 [==============================] - 133s 329ms/step - loss: 1.4754 - accuracy: 0.4371 - val_loss: 1.6833 - val_accuracy: 0.3865
# Epoch 94/100
# 406/406 [==============================] - 134s 330ms/step - loss: 1.4639 - accuracy: 0.4357 - val_loss: 1.6802 - val_accuracy: 0.3927
# Epoch 95/100
# 406/406 [==============================] - 134s 329ms/step - loss: 1.4465 - accuracy: 0.4396 - val_loss: 1.7356 - val_accuracy: 0.3511
# Epoch 96/100
# 406/406 [==============================] - 134s 331ms/step - loss: 1.4335 - accuracy: 0.4424 - val_loss: 1.6252 - val_accuracy: 0.4113
# Epoch 97/100
# 406/406 [==============================] - 134s 330ms/step - loss: 1.4721 - accuracy: 0.4377 - val_loss: 1.7835 - val_accuracy: 0.3530
# Epoch 98/100
# 406/406 [==============================] - 134s 329ms/step - loss: 1.4531 - accuracy: 0.4424 - val_loss: 1.6753 - val_accuracy: 0.3759
# Epoch 99/100
# 406/406 [==============================] - 134s 329ms/step - loss: 1.4495 - accuracy: 0.4475 - val_loss: 1.7169 - val_accuracy: 0.3865
# Epoch 100/100
# 406/406 [==============================] - 135s 332ms/step - loss: 1.4293 - accuracy: 0.4458 - val_loss: 1.5960 - val_accuracy: 0.4045
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %% [markdown]
# # Evaluate Model's Training & Validation Results

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()

# %% [markdown]
# # Generate Predictions With Model

# %%
y_pred = model.predict(test_batches).argmax(axis=1)

# %%
model.evaluate(test_batches)
# Out:
# 51/51 [==============================] - 15s 298ms/step - loss: 1.6248 - accuracy: 0.3876
# [1.6248204708099365, 0.38764044642448425]

# %% [markdown]
# # Evaluate Model's Prediction Results

# %%
# generate classification report
class_labels = list(test_batches.class_indices.keys())
report = classification_report(test_batches.classes, y_pred, target_names=class_labels, output_dict=True)
df_classification_report = pd.DataFrame(report).transpose()
df_classification_report
# Out:
#               precision    recall  f1-score     support
# hatchback      0.322581  0.064103  0.106952   156.00000
# mpv            0.232704  0.342593  0.277154   108.00000
# sedan          0.398374  0.473430  0.432671   414.00000
# sport          0.407801  0.525114  0.459082   438.00000
# suv            0.407942  0.397887  0.402852   284.00000
# truck          0.479452  0.218750  0.300429   160.00000
# wagon          0.000000  0.000000  0.000000    42.00000
# accuracy       0.387640  0.387640  0.387640     0.38764
# macro avg      0.321265  0.288840  0.282734  1602.00000
# weighted avg   0.381752  0.387640  0.367852  1602.00000

# %%
# compute confusion matrix
matrix = confusion_matrix(test_batches.classes, y_pred)

# normalize confusion matrix
matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
matrix = np.around(matrix, decimals=2)

# generate confusion matrix heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(matrix, annot=True, xticklabels=class_labels, yticklabels=class_labels)
plt.ylabel('Test Values')
plt.xlabel('Predicted Values')
# Out:
# Text(0.5, 69.0, 'Predicted Values')

# %% [markdown]
# # Compute Execution Time

# %%
execution_time_s = round(time.time() - start_time, 2)
execution_time_m = round(execution_time_s/60, 2)
execution_time_h = round(execution_time_m/60, 2)

print('Execution Time (Hours):', execution_time_h)
print('Execution Time (Minutes):', execution_time_m)
print('Execution Time (Seconds):', execution_time_s)
# Out:
# Execution Time (Hours): 3.78
# Execution Time (Minutes): 226.94
# Execution Time (Seconds): 13616.37
