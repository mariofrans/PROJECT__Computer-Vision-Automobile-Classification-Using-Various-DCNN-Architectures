# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout, GlobalMaxPooling2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
PATH_DATA = '../input/cars-data/data_remove_bg/data_remove_bg'

# %%
generator = ImageDataGenerator(rescale = 1./255., validation_split=0.2, width_shift_range=[1, 2, 3, 4, 5, 6, 7])

target_size = (150, 150)
batch_size = 32

train_batches = generator.flow_from_directory(
    PATH_DATA, class_mode='categorical', subset='training',
    batch_size=batch_size, target_size=target_size
)

test_batches = generator.flow_from_directory(
    PATH_DATA, class_mode='categorical', subset='validation', 
    batch_size=batch_size, target_size=target_size
)

validation_batches = generator.flow_from_directory(
    PATH_DATA, class_mode='categorical', subset='validation', 
    batch_size=batch_size, target_size=target_size
)
# Out:
# Found 12951 images belonging to 7 classes.
# Found 3234 images belonging to 7 classes.
# Found 3234 images belonging to 7 classes.

# %%
# preview data (batch size, width, height, colors)
print('x_train shape: ', train_batches[0][0].shape)
print('x_test shape: ', test_batches[0][0].shape)
print('y_train shape: ', train_batches[0][1].shape)
print('y_test shape: ', test_batches[0][1].shape)
# Out:
# x_train shape:  (32, 150, 150, 3)
# x_test shape:  (32, 150, 150, 3)
# y_train shape:  (32, 7)
# y_test shape:  (32, 7)

# %%
# input shape
input_shape = train_batches[0][0][0].shape
input_shape
# Out:
# (150, 150, 3)

# %%
# output shape
output_shape = len(train_batches[0][1][0])
output_shape
# Out:
# 7

# %%
# build model
i = Input(shape=input_shape)

x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = BatchNormalization()(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Flatten()(x)
x = Dropout(0.2)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(output_shape, activation='softmax')(x)

model = Model(i, x)

# compile & fit model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# 2022-09-16 20:33:01.893794: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-16 20:33:01.985068: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-16 20:33:01.985882: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-16 20:33:01.986996: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-16 20:33:01.987243: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-16 20:33:01.987922: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-16 20:33:01.988550: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-16 20:33:04.187239: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-16 20:33:04.188053: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-16 20:33:04.188745: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-16 20:33:04.189353: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 150, 150, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 150, 150, 32)      128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 32)      9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 150, 150, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 75, 75, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 75, 75, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 75, 75, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 37, 37, 128)       73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 37, 37, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 37, 37, 128)       147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 37, 37, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 41472)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 41472)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              42468352
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 7175
# =================================================================
# Total params: 42,764,327
# Trainable params: 42,763,431
# Non-trainable params: 896
# _________________________________________________________________

# %%
r = model.fit(train_batches, validation_data=validation_batches, epochs=100)
# Out:
# 2022-09-16 20:33:05.189338: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-09-16 20:33:07.676250: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 405/405 [==============================] - 285s 683ms/step - loss: 2.8457 - accuracy: 0.2831 - val_loss: 3.2057 - val_accuracy: 0.2288
# Epoch 2/100
# 405/405 [==============================] - 172s 425ms/step - loss: 1.6866 - accuracy: 0.3251 - val_loss: 1.9245 - val_accuracy: 0.3602
# Epoch 3/100
# 405/405 [==============================] - 173s 429ms/step - loss: 1.6249 - accuracy: 0.3496 - val_loss: 1.7041 - val_accuracy: 0.3185
# Epoch 4/100
# 405/405 [==============================] - 173s 426ms/step - loss: 1.5343 - accuracy: 0.3851 - val_loss: 3.1115 - val_accuracy: 0.2944
# Epoch 5/100
# 405/405 [==============================] - 173s 428ms/step - loss: 1.4762 - accuracy: 0.3954 - val_loss: 1.5719 - val_accuracy: 0.4246
# Epoch 6/100
# 405/405 [==============================] - 175s 433ms/step - loss: 1.4353 - accuracy: 0.4160 - val_loss: 1.6385 - val_accuracy: 0.3658
# Epoch 7/100
# 405/405 [==============================] - 173s 428ms/step - loss: 1.3921 - accuracy: 0.4365 - val_loss: 1.3312 - val_accuracy: 0.4617
# Epoch 8/100
# 405/405 [==============================] - 172s 424ms/step - loss: 1.3594 - accuracy: 0.4513 - val_loss: 36.7672 - val_accuracy: 0.2811
# Epoch 9/100
# 405/405 [==============================] - 173s 427ms/step - loss: 1.3466 - accuracy: 0.4597 - val_loss: 1.8487 - val_accuracy: 0.3779
# Epoch 10/100
# 405/405 [==============================] - 172s 425ms/step - loss: 1.3306 - accuracy: 0.4725 - val_loss: 1.4717 - val_accuracy: 0.4400
# Epoch 11/100
# 405/405 [==============================] - 174s 430ms/step - loss: 1.2848 - accuracy: 0.4904 - val_loss: 1.5469 - val_accuracy: 0.4082
# Epoch 12/100
# 405/405 [==============================] - 172s 426ms/step - loss: 1.2543 - accuracy: 0.5060 - val_loss: 1.2504 - val_accuracy: 0.5074
# Epoch 13/100
# 405/405 [==============================] - 173s 426ms/step - loss: 1.2224 - accuracy: 0.5234 - val_loss: 1.3516 - val_accuracy: 0.4811
# Epoch 14/100
# 405/405 [==============================] - 175s 431ms/step - loss: 1.1917 - accuracy: 0.5274 - val_loss: 2.5467 - val_accuracy: 0.3664
# Epoch 15/100
# 405/405 [==============================] - 169s 418ms/step - loss: 1.1601 - accuracy: 0.5480 - val_loss: 3.3649 - val_accuracy: 0.3528
# Epoch 16/100
# 405/405 [==============================] - 171s 422ms/step - loss: 1.1203 - accuracy: 0.5647 - val_loss: 1.6744 - val_accuracy: 0.4861
# Epoch 17/100
# 405/405 [==============================] - 171s 423ms/step - loss: 1.0754 - accuracy: 0.5898 - val_loss: 1.4923 - val_accuracy: 0.5049
# Epoch 18/100
# 405/405 [==============================] - 174s 429ms/step - loss: 1.0204 - accuracy: 0.6089 - val_loss: 1.3036 - val_accuracy: 0.5538
# Epoch 19/100
# 405/405 [==============================] - 173s 427ms/step - loss: 0.9868 - accuracy: 0.6291 - val_loss: 1.1587 - val_accuracy: 0.5826
# Epoch 20/100
# 405/405 [==============================] - 172s 426ms/step - loss: 0.9215 - accuracy: 0.6506 - val_loss: 4.5381 - val_accuracy: 0.2888
# Epoch 21/100
# 405/405 [==============================] - 171s 424ms/step - loss: 0.8795 - accuracy: 0.6728 - val_loss: 1.3269 - val_accuracy: 0.5612
# Epoch 22/100
# 405/405 [==============================] - 173s 427ms/step - loss: 0.8773 - accuracy: 0.6675 - val_loss: 4.1736 - val_accuracy: 0.3652
# Epoch 23/100
# 405/405 [==============================] - 172s 425ms/step - loss: 0.8290 - accuracy: 0.6844 - val_loss: 1.3219 - val_accuracy: 0.5210
# Epoch 24/100
# 405/405 [==============================] - 173s 427ms/step - loss: 0.7867 - accuracy: 0.7052 - val_loss: 1.0255 - val_accuracy: 0.6537
# Epoch 25/100
# 405/405 [==============================] - 172s 426ms/step - loss: 0.7658 - accuracy: 0.7128 - val_loss: 0.9880 - val_accuracy: 0.6694
# Epoch 26/100
# 405/405 [==============================] - 173s 427ms/step - loss: 0.7083 - accuracy: 0.7418 - val_loss: 1.7623 - val_accuracy: 0.5461
# Epoch 27/100
# 405/405 [==============================] - 171s 423ms/step - loss: 0.6755 - accuracy: 0.7450 - val_loss: 1.0269 - val_accuracy: 0.6626
# Epoch 28/100
# 405/405 [==============================] - 174s 430ms/step - loss: 0.6612 - accuracy: 0.7546 - val_loss: 1.2701 - val_accuracy: 0.6231
# Epoch 29/100
# 405/405 [==============================] - 171s 423ms/step - loss: 0.6359 - accuracy: 0.7602 - val_loss: 0.9450 - val_accuracy: 0.6871
# Epoch 30/100
# 405/405 [==============================] - 172s 424ms/step - loss: 0.6101 - accuracy: 0.7738 - val_loss: 1.2810 - val_accuracy: 0.6481
# Epoch 31/100
# 405/405 [==============================] - 172s 425ms/step - loss: 0.5896 - accuracy: 0.7830 - val_loss: 0.9393 - val_accuracy: 0.6933
# Epoch 32/100
# 405/405 [==============================] - 174s 429ms/step - loss: 0.5675 - accuracy: 0.7939 - val_loss: 1.2143 - val_accuracy: 0.6336
# Epoch 33/100
# 405/405 [==============================] - 172s 424ms/step - loss: 0.5171 - accuracy: 0.8127 - val_loss: 1.1114 - val_accuracy: 0.6710
# Epoch 34/100
# 405/405 [==============================] - 172s 426ms/step - loss: 0.5024 - accuracy: 0.8188 - val_loss: 1.5808 - val_accuracy: 0.5563
# Epoch 35/100
# 405/405 [==============================] - 172s 425ms/step - loss: 0.4999 - accuracy: 0.8214 - val_loss: 1.0161 - val_accuracy: 0.6926
# Epoch 36/100
# 405/405 [==============================] - 172s 425ms/step - loss: 0.4637 - accuracy: 0.8361 - val_loss: 1.3314 - val_accuracy: 0.5986
# Epoch 37/100
# 405/405 [==============================] - 172s 426ms/step - loss: 0.4629 - accuracy: 0.8324 - val_loss: 1.4242 - val_accuracy: 0.6398
# Epoch 38/100
# 405/405 [==============================] - 174s 429ms/step - loss: 0.4448 - accuracy: 0.8428 - val_loss: 1.0860 - val_accuracy: 0.6933
# Epoch 39/100
# 405/405 [==============================] - 173s 426ms/step - loss: 0.4611 - accuracy: 0.8371 - val_loss: 1.1333 - val_accuracy: 0.6929
# Epoch 40/100
# 405/405 [==============================] - 173s 427ms/step - loss: 0.4447 - accuracy: 0.8458 - val_loss: 2.7353 - val_accuracy: 0.4864
# Epoch 41/100
# 405/405 [==============================] - 172s 426ms/step - loss: 0.4188 - accuracy: 0.8508 - val_loss: 0.9276 - val_accuracy: 0.7155
# Epoch 42/100
# 405/405 [==============================] - 172s 426ms/step - loss: 0.4048 - accuracy: 0.8558 - val_loss: 1.1151 - val_accuracy: 0.7171
# Epoch 43/100
# 405/405 [==============================] - 173s 426ms/step - loss: 0.3699 - accuracy: 0.8650 - val_loss: 1.5669 - val_accuracy: 0.6608
# Epoch 44/100
# 405/405 [==============================] - 173s 427ms/step - loss: 0.3597 - accuracy: 0.8734 - val_loss: 1.0013 - val_accuracy: 0.7062
# Epoch 45/100
# 405/405 [==============================] - 172s 426ms/step - loss: 0.3512 - accuracy: 0.8750 - val_loss: 1.1925 - val_accuracy: 0.7093
# Epoch 46/100
# 405/405 [==============================] - 174s 429ms/step - loss: 0.3497 - accuracy: 0.8756 - val_loss: 1.1815 - val_accuracy: 0.6562
# Epoch 47/100
# 405/405 [==============================] - 172s 425ms/step - loss: 0.3602 - accuracy: 0.8731 - val_loss: 1.0110 - val_accuracy: 0.6945
# Epoch 48/100
# 405/405 [==============================] - 173s 427ms/step - loss: 0.3381 - accuracy: 0.8780 - val_loss: 1.1731 - val_accuracy: 0.6840
# Epoch 49/100
# 405/405 [==============================] - 172s 424ms/step - loss: 0.3543 - accuracy: 0.8780 - val_loss: 1.0800 - val_accuracy: 0.6895
# Epoch 50/100
# 405/405 [==============================] - 173s 427ms/step - loss: 0.3209 - accuracy: 0.8880 - val_loss: 1.0353 - val_accuracy: 0.7047
# Epoch 51/100
# 405/405 [==============================] - 171s 423ms/step - loss: 0.3098 - accuracy: 0.8928 - val_loss: 1.2648 - val_accuracy: 0.7155
# Epoch 52/100
# 405/405 [==============================] - 172s 425ms/step - loss: 0.3053 - accuracy: 0.8917 - val_loss: 1.1246 - val_accuracy: 0.6899
# Epoch 53/100
# 405/405 [==============================] - 171s 424ms/step - loss: 0.3028 - accuracy: 0.8926 - val_loss: 1.1526 - val_accuracy: 0.7217
# Epoch 54/100
# 405/405 [==============================] - 173s 427ms/step - loss: 0.2985 - accuracy: 0.8955 - val_loss: 1.1370 - val_accuracy: 0.7288
# Epoch 55/100
# 405/405 [==============================] - 173s 429ms/step - loss: 0.2989 - accuracy: 0.8913 - val_loss: 1.1623 - val_accuracy: 0.6970
# Epoch 56/100
# 405/405 [==============================] - 172s 426ms/step - loss: 0.2833 - accuracy: 0.9003 - val_loss: 1.3833 - val_accuracy: 0.7109
# Epoch 57/100
# 405/405 [==============================] - 172s 425ms/step - loss: 0.2730 - accuracy: 0.9044 - val_loss: 1.4669 - val_accuracy: 0.7056
# Epoch 58/100
# 405/405 [==============================] - 172s 424ms/step - loss: 0.2718 - accuracy: 0.9035 - val_loss: 1.4121 - val_accuracy: 0.6679
# Epoch 59/100
# 405/405 [==============================] - 173s 426ms/step - loss: 0.2691 - accuracy: 0.9080 - val_loss: 1.1916 - val_accuracy: 0.6948
# Epoch 60/100
# 405/405 [==============================] - 174s 429ms/step - loss: 0.2752 - accuracy: 0.9005 - val_loss: 1.1789 - val_accuracy: 0.7056
# Epoch 61/100
# 405/405 [==============================] - 175s 433ms/step - loss: 0.2576 - accuracy: 0.9122 - val_loss: 1.3338 - val_accuracy: 0.7007
# Epoch 62/100
# 405/405 [==============================] - 176s 434ms/step - loss: 0.2473 - accuracy: 0.9158 - val_loss: 1.3869 - val_accuracy: 0.6939
# Epoch 63/100
# 405/405 [==============================] - 175s 432ms/step - loss: 0.2390 - accuracy: 0.9172 - val_loss: 1.0752 - val_accuracy: 0.7316
# Epoch 64/100
# 405/405 [==============================] - 177s 438ms/step - loss: 0.2446 - accuracy: 0.9184 - val_loss: 1.2060 - val_accuracy: 0.6917
# Epoch 65/100
# 405/405 [==============================] - 175s 433ms/step - loss: 0.2382 - accuracy: 0.9158 - val_loss: 1.2678 - val_accuracy: 0.7236
# Epoch 66/100
# 405/405 [==============================] - 175s 433ms/step - loss: 0.2312 - accuracy: 0.9202 - val_loss: 1.4171 - val_accuracy: 0.7313
# Epoch 67/100
# 405/405 [==============================] - 178s 439ms/step - loss: 0.2292 - accuracy: 0.9229 - val_loss: 2.0063 - val_accuracy: 0.6450
# Epoch 68/100
# 405/405 [==============================] - 176s 434ms/step - loss: 0.2377 - accuracy: 0.9181 - val_loss: 1.2689 - val_accuracy: 0.6954
# Epoch 69/100
# 405/405 [==============================] - 176s 435ms/step - loss: 0.2290 - accuracy: 0.9209 - val_loss: 1.3617 - val_accuracy: 0.7013
# Epoch 70/100
# 405/405 [==============================] - 175s 433ms/step - loss: 0.2174 - accuracy: 0.9239 - val_loss: 1.2260 - val_accuracy: 0.7223
# Epoch 71/100
# 405/405 [==============================] - 175s 433ms/step - loss: 0.2036 - accuracy: 0.9282 - val_loss: 1.6296 - val_accuracy: 0.6676
# Epoch 72/100
# 405/405 [==============================] - 175s 432ms/step - loss: 0.2224 - accuracy: 0.9242 - val_loss: 2.7905 - val_accuracy: 0.5510
# Epoch 73/100
# 405/405 [==============================] - 174s 431ms/step - loss: 0.2154 - accuracy: 0.9293 - val_loss: 1.3114 - val_accuracy: 0.7322
# Epoch 74/100
# 405/405 [==============================] - 176s 435ms/step - loss: 0.2103 - accuracy: 0.9293 - val_loss: 1.2578 - val_accuracy: 0.7195
# Epoch 75/100
# 405/405 [==============================] - 175s 431ms/step - loss: 0.2185 - accuracy: 0.9264 - val_loss: 1.1790 - val_accuracy: 0.6540
# Epoch 76/100
# 405/405 [==============================] - 175s 433ms/step - loss: 0.1976 - accuracy: 0.9340 - val_loss: 1.3770 - val_accuracy: 0.7233
# Epoch 77/100
# 405/405 [==============================] - 174s 430ms/step - loss: 0.1989 - accuracy: 0.9344 - val_loss: 1.2206 - val_accuracy: 0.7335
# Epoch 78/100
# 405/405 [==============================] - 176s 434ms/step - loss: 0.1912 - accuracy: 0.9366 - val_loss: 1.8630 - val_accuracy: 0.6954
# Epoch 79/100
# 405/405 [==============================] - 175s 432ms/step - loss: 0.1948 - accuracy: 0.9355 - val_loss: 1.2951 - val_accuracy: 0.7409
# Epoch 80/100
# 405/405 [==============================] - 175s 432ms/step - loss: 0.1879 - accuracy: 0.9374 - val_loss: 1.1576 - val_accuracy: 0.7344
# Epoch 81/100
# 405/405 [==============================] - 174s 429ms/step - loss: 0.1989 - accuracy: 0.9346 - val_loss: 1.0999 - val_accuracy: 0.7220
# Epoch 82/100
# 405/405 [==============================] - 171s 423ms/step - loss: 0.1902 - accuracy: 0.9338 - val_loss: 1.2372 - val_accuracy: 0.7495
# Epoch 83/100
# 405/405 [==============================] - 171s 422ms/step - loss: 0.1829 - accuracy: 0.9402 - val_loss: 1.6504 - val_accuracy: 0.7322
# Epoch 84/100
# 405/405 [==============================] - 170s 421ms/step - loss: 0.1816 - accuracy: 0.9395 - val_loss: 1.1064 - val_accuracy: 0.7403
# Epoch 85/100
# 405/405 [==============================] - 171s 422ms/step - loss: 0.1736 - accuracy: 0.9424 - val_loss: 1.4768 - val_accuracy: 0.7248
# Epoch 86/100
# 405/405 [==============================] - 172s 424ms/step - loss: 0.1766 - accuracy: 0.9434 - val_loss: 1.3574 - val_accuracy: 0.6849
# Epoch 87/100
# 405/405 [==============================] - 171s 421ms/step - loss: 0.1933 - accuracy: 0.9365 - val_loss: 1.4484 - val_accuracy: 0.7304
# Epoch 88/100
# 405/405 [==============================] - 171s 421ms/step - loss: 0.1743 - accuracy: 0.9422 - val_loss: 1.5564 - val_accuracy: 0.7328
# Epoch 89/100
# 405/405 [==============================] - 170s 421ms/step - loss: 0.1577 - accuracy: 0.9486 - val_loss: 1.5589 - val_accuracy: 0.6994
# Epoch 90/100
# 405/405 [==============================] - 171s 422ms/step - loss: 0.1607 - accuracy: 0.9484 - val_loss: 1.2246 - val_accuracy: 0.7517
# Epoch 91/100
# 405/405 [==============================] - 171s 422ms/step - loss: 0.1753 - accuracy: 0.9422 - val_loss: 1.5930 - val_accuracy: 0.7362
# Epoch 92/100
# 405/405 [==============================] - 170s 421ms/step - loss: 0.1498 - accuracy: 0.9504 - val_loss: 1.5759 - val_accuracy: 0.7350
# Epoch 93/100
# 405/405 [==============================] - 171s 422ms/step - loss: 0.1609 - accuracy: 0.9462 - val_loss: 1.2242 - val_accuracy: 0.7239
# Epoch 94/100
# 405/405 [==============================] - 172s 425ms/step - loss: 0.1441 - accuracy: 0.9522 - val_loss: 1.7953 - val_accuracy: 0.6868
# Epoch 95/100
# 405/405 [==============================] - 172s 424ms/step - loss: 0.1654 - accuracy: 0.9453 - val_loss: 1.3033 - val_accuracy: 0.6701
# Epoch 96/100
# 405/405 [==============================] - 172s 426ms/step - loss: 0.1546 - accuracy: 0.9507 - val_loss: 1.5725 - val_accuracy: 0.7415
# Epoch 97/100
# 405/405 [==============================] - 172s 426ms/step - loss: 0.1350 - accuracy: 0.9558 - val_loss: 1.5466 - val_accuracy: 0.7245
# Epoch 98/100
# 405/405 [==============================] - 171s 422ms/step - loss: 0.1633 - accuracy: 0.9473 - val_loss: 2.0926 - val_accuracy: 0.6914
# Epoch 99/100
# 405/405 [==============================] - 172s 425ms/step - loss: 0.1543 - accuracy: 0.9501 - val_loss: 1.3588 - val_accuracy: 0.7427
# Epoch 100/100
# 405/405 [==============================] - 170s 420ms/step - loss: 0.1484 - accuracy: 0.9525 - val_loss: 1.6250 - val_accuracy: 0.6871

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()
